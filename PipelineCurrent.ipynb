# %%
# ============================================================
# FULL CHECKPOINT / RESUME CODE
# + DAILY MACRO / INDEX FEATURES
# + YIELD CURVE FEATURE (TNX - FVX)
# ============================================================

import os
import copy
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from dataclasses import dataclass
from typing import List, Optional, Any, Dict
import xgboost as xgb

from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.calibration import CalibratedClassifierCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MaxAbsScaler
from sklearn.impute import SimpleImputer

# ---- your Chan imports ----
from sliding_window_chan import SlidingWindowChan
from ChanConfig import CChanConfig
from Common.CEnum import DATA_FIELD, KL_TYPE, AUTYPE
try:
    from Common.CEnum import DATA_SRC
except Exception:
    class DATA_SRC:
        CSV = "CSV"
from KLine.KLine_Unit import CKLine_Unit
from Common.CTime import CTime


# ============================================================
# BACKWARD-COMPAT CLASS DEFINITIONS
# ============================================================

@dataclass
class RetModelPack:
    feature_cols: List[str]
    model_ret: xgb.XGBRegressor

@dataclass
class DailyProbState:
    model: Optional[Any] = None
    new_labels: int = 0
    trained_n: int = 0


# ============================================================
# BASIC HELPERS
# ============================================================

def _safe_div(a, b, eps=1e-12):
    return a / (b + eps)

def _pick_col(df: pd.DataFrame, candidates: List[str]) -> Optional[str]:
    cols = list(df.columns)
    for c in candidates:
        if c in cols:
            return c
    lower_map = {c.lower(): c for c in cols}
    for c in candidates:
        if c.lower() in lower_map:
            return lower_map[c.lower()]
    return None

def save_joblib(path: str, obj):
    os.makedirs(os.path.dirname(path), exist_ok=True)
    joblib.dump(obj, path, compress=3)

def load_joblib(path: str):
    return joblib.load(path)

def _safe_copy_list_of_dict(lst):
    if lst is None:
        return []
    out = []
    for x in lst:
        try:
            out.append(dict(x))
        except Exception:
            pass
    return out

def _safe_set_to_list(s):
    if s is None:
        return []
    return list(s)

def _safe_list_to_set(lst):
    if lst is None:
        return set()
    out = set()
    for x in lst:
        if isinstance(x, list):
            out.add(tuple(x))
        else:
            out.add(x)
    return out


# ============================================================
# OHLCV CSV LOADER
# ============================================================

def load_ohlcv_csv(path: str, freq_name: str) -> pd.DataFrame:
    df = pd.read_csv(path)

    ts_col = _pick_col(df, ["timestamp", "date", "datetime", "time"])
    if ts_col is None:
        ts_col = df.columns[0]
    df[ts_col] = pd.to_datetime(df[ts_col], errors="coerce")
    df = df.dropna(subset=[ts_col]).sort_values(ts_col).reset_index(drop=True)
    df = df.rename(columns={ts_col: "timestamp"})

    open_col  = _pick_col(df, ["open", "Open", "o", "O"])
    high_col  = _pick_col(df, ["high", "High", "h", "H"])
    low_col   = _pick_col(df, ["low", "Low", "l", "L"])
    close_col = _pick_col(df, ["close", "Close", "adj_close", "Adj Close", "AdjClose", "c", "C"])
    vol_col   = _pick_col(df, ["volume", "Volume", "vol", "Vol", "v", "V"])

    if open_col is None or close_col is None:
        raise ValueError(f"{freq_name} CSV must contain open/close columns.")
    if high_col is None:
        high_col = close_col
    if low_col is None:
        low_col = close_col

    df["_open"]  = pd.to_numeric(df[open_col], errors="coerce").astype(float)
    df["_high"]  = pd.to_numeric(df[high_col], errors="coerce").astype(float)
    df["_low"]   = pd.to_numeric(df[low_col], errors="coerce").astype(float)
    df["_close"] = pd.to_numeric(df[close_col], errors="coerce").astype(float)
    df["_vol"]   = pd.to_numeric(df[vol_col], errors="coerce").astype(float) if vol_col is not None else 0.0

    df = df.dropna(subset=["_open", "_high", "_low", "_close"]).reset_index(drop=True)
    df["day"] = df["timestamp"].dt.normalize()
    return df


# ============================================================
# DAILY KLINE FEATURES
# ============================================================

KLINE_KEYS = [
    "ret1","ret_5","ret_10","ret_20","ret_40",
    "vol_5","vol_10","vol_20","vol_40",
    "atr_14","range_over_atr","close_pos","gap",
    "above_ma_20","above_ma_50","above_ma_100",
    "slope40",
]

def compute_daily_kline_features(df_day: pd.DataFrame) -> pd.DataFrame:
    d = df_day.copy().sort_values("timestamp").reset_index(drop=True)
    o = d["_open"].astype(float)
    h = d["_high"].astype(float)
    l = d["_low"].astype(float)
    c = d["_close"].astype(float)

    prev_c = c.shift(1)
    d["ret1"] = (_safe_div(c, prev_c) - 1.0).replace([np.inf, -np.inf], np.nan).fillna(0.0)

    tr = pd.concat([(h-l).abs(), (h-prev_c).abs(), (l-prev_c).abs()], axis=1).max(axis=1)
    d["tr"] = tr.fillna(0.0)
    d["atr_14"] = d["tr"].rolling(14).mean().bfill().fillna(0.0)

    d["range"] = (h - l).fillna(0.0)
    d["range_over_atr"] = _safe_div(d["range"], d["atr_14"]).replace([np.inf, -np.inf], np.nan).fillna(0.0)

    rng = (h - l).replace(0.0, np.nan)
    d["close_pos"] = ((c - l) / rng).replace([np.inf, -np.inf], np.nan).fillna(0.5)
    d["gap"] = (_safe_div(o, prev_c) - 1.0).replace([np.inf, -np.inf], np.nan).fillna(0.0)

    for w in [5, 10, 20, 40]:
        d[f"ret_{w}"] = (_safe_div(c, c.shift(w)) - 1.0).replace([np.inf, -np.inf], np.nan).fillna(0.0)
        d[f"vol_{w}"] = d["ret1"].rolling(w).std().replace([np.inf, -np.inf], np.nan).fillna(0.0)

    for w in [20, 50, 100]:
        ma = c.rolling(w).mean()
        d[f"above_ma_{w}"] = (_safe_div(c, ma) - 1.0).replace([np.inf, -np.inf], np.nan).fillna(0.0)

    def _slope_log(x):
        x = np.asarray(x, dtype=float)
        x = np.log(np.maximum(x, 1e-12))
        t = np.arange(len(x), dtype=float)
        t = t - t.mean()
        x = x - x.mean()
        den = (t*t).sum()
        return 0.0 if den <= 0 else float((t*x).sum() / den)

    d["slope40"] = d["_close"].rolling(40).apply(_slope_log, raw=False).fillna(0.0)
    return d

def make_kline_dict(row: pd.Series) -> Dict[str, float]:
    out = {}
    for k in KLINE_KEYS:
        val = row[k] if k in row.index else 0.0
        out[f"k_{k}"] = float(val) if np.isfinite(val) else 0.0
    return out


# ============================================================
# MACRO / INDEX FEATURES
# ============================================================

def load_macro_features_from_folder(folder: str, files: Dict[str, str], start: str) -> pd.DataFrame:
    out = None

    for pref, fn in files.items():
        path = os.path.join(folder, fn)
        if not os.path.exists(path):
            raise FileNotFoundError(f"Macro file not found: {path}")

        dfm = load_ohlcv_csv(path, pref.upper())
        dfm = dfm[dfm["timestamp"] >= pd.to_datetime(start)].copy().reset_index(drop=True)
        dfm["ts_norm"] = pd.to_datetime(dfm["timestamp"]).dt.normalize()

        dfm_feat = compute_daily_kline_features(dfm)

        # raw close level
        dfm_feat[f"{pref}level"] = dfm_feat["_close"].astype(float)

        keep_cols = ["ts_norm", f"{pref}level"] + KLINE_KEYS
        dfm_feat = dfm_feat[keep_cols].copy()

        rename = {k: f"{pref}{k}" for k in KLINE_KEYS}
        dfm_feat = dfm_feat.rename(columns=rename)

        out = dfm_feat.copy() if out is None else out.merge(dfm_feat, on="ts_norm", how="outer")

    if out is None:
        out = pd.DataFrame(columns=["ts_norm"])

    # 10Y - 5Y yield curve
    if ("us10y_level" in out.columns) and ("us5y_level" in out.columns):
        out["yc_10y5y_level"] = out["us10y_level"] - out["us5y_level"]

        prev = out["yc_10y5y_level"].shift(1)
        out["yc_10y5y_ret1"] = (_safe_div(out["yc_10y5y_level"], prev) - 1.0).replace([np.inf, -np.inf], np.nan).fillna(0.0)

        for w in [5, 10, 20, 40]:
            out[f"yc_10y5y_chg_{w}"] = (out["yc_10y5y_level"] - out["yc_10y5y_level"].shift(w)).replace([np.inf, -np.inf], np.nan).fillna(0.0)

    return out.sort_values("ts_norm").reset_index(drop=True)


# ============================================================
# CHAN BUILDERS
# ============================================================

def to_ctime(ts) -> CTime:
    if isinstance(ts, CTime):
        return ts
    dt = pd.to_datetime(ts).to_pydatetime()
    try:
        return CTime(dt.year, dt.month, dt.day, dt.hour, dt.minute, dt.second, auto=False)
    except Exception:
        pass
    try:
        return CTime(dt.year, dt.month, dt.day, dt.hour, dt.minute, dt.second)
    except Exception:
        pass
    s = dt.strftime("%Y-%m-%d %H:%M:%S")
    try:
        return CTime(s, auto=False)
    except Exception:
        return CTime(s)

def build_klu(ts, o, h, l, c, v=0.0) -> CKLine_Unit:
    ct = to_ctime(ts)
    kl_dict = {
        DATA_FIELD.FIELD_TIME: ct,
        DATA_FIELD.FIELD_OPEN: float(o),
        DATA_FIELD.FIELD_HIGH: float(h),
        DATA_FIELD.FIELD_LOW:  float(l),
        DATA_FIELD.FIELD_CLOSE: float(c),
        DATA_FIELD.FIELD_VOLUME: float(v),
        "time": ct, "timestamp": ct, "datetime": ct, "dt": ct,
        "open": float(o), "high": float(h), "low": float(l), "close": float(c),
        "volume": float(v),
    }
    klu = CKLine_Unit(kl_dict)
    try:
        klu.time = ct
    except Exception:
        pass
    return klu

def feed_chan_one(chan_obj, klu: CKLine_Unit):
    if hasattr(chan_obj, "process_new_kline"):
        return chan_obj.process_new_kline(klu)
    if hasattr(chan_obj, "step_load"):
        return chan_obj.step_load([klu])
    raise AttributeError("Chan object has neither process_new_kline nor step_load")


# ============================================================
# DAILY BSP HELPERS
# ============================================================

def normalize_bsp_row(r: Dict[str, Any]) -> Dict[str, Any]:
    rr = dict(r)
    if "timestamp" in rr:
        rr["timestamp"] = pd.to_datetime(rr["timestamp"], errors="coerce")
    if "direction" not in rr or rr["direction"] is None:
        if rr.get("is_buy", None) is not None:
            rr["direction"] = "buy" if bool(rr["is_buy"]) else "sell"
        else:
            rr["direction"] = "buy"
    rr["direction"] = str(rr["direction"]).lower()
    if "bsp_type" in rr and rr["bsp_type"] is not None:
        rr["bsp_type"] = str(rr["bsp_type"]).lower()
    else:
        rr["bsp_type"] = "?"
    return rr

def extract_bsp_rows_from_chan(chan_obj) -> List[Dict[str, Any]]:
    if hasattr(chan_obj, "export_new_historical_bsp_to_list"):
        out = chan_obj.export_new_historical_bsp_to_list()
        return out if out else []
    if hasattr(chan_obj, "export_new_bsp_to_list"):
        out = chan_obj.export_new_bsp_to_list()
        return out if out else []
    return []

def latest_bsp_dir_up_to(bsp_rows: List[Dict[str, Any]], ts: pd.Timestamp) -> Optional[str]:
    past = [r for r in bsp_rows if pd.to_datetime(r["timestamp"]) <= ts]
    if not past:
        return None
    past = sorted(past, key=lambda x: pd.to_datetime(x["timestamp"]))
    return str(past[-1].get("direction", "")).lower()

def make_daily_bsp_context(bsp_hist: List[Dict[str, Any]], cur_ts: pd.Timestamp, window_days: int = 60) -> Dict[str, float]:
    past = [r for r in bsp_hist if pd.to_datetime(r["timestamp"]) <= cur_ts]
    past = sorted(past, key=lambda x: pd.to_datetime(x["timestamp"]))
    if not past:
        return {
            "ctx_has_bsp": 0.0,
            "ctx_last_dir_buy": 0.0,
            "ctx_last_dir_sell": 0.0,
            "ctx_days_since_last_bsp": 999.0,
            "ctx_days_since_last_buy": 999.0,
            "ctx_days_since_last_sell": 999.0,
            "ctx_density_total": 0.0,
            "ctx_density_buy": 0.0,
            "ctx_density_sell": 0.0,
            "ctx_density_imb": 0.0,
        }

    last = past[-1]
    last_dir = str(last.get("direction", "")).lower()
    days_since_last = float((cur_ts.normalize() - pd.to_datetime(last["timestamp"]).normalize()).days)

    def _days_since(target: str) -> float:
        for r in reversed(past):
            if str(r.get("direction", "")).lower() == target:
                return float((cur_ts.normalize() - pd.to_datetime(r["timestamp"]).normalize()).days)
        return 999.0

    start = cur_ts.normalize() - pd.Timedelta(days=int(window_days))
    recent = [r for r in past if pd.to_datetime(r["timestamp"]).normalize() >= start]
    buy = sum(1 for r in recent if str(r.get("direction", "")).lower() == "buy")
    sell = sum(1 for r in recent if str(r.get("direction", "")).lower() == "sell")
    tot = max(1.0, float(buy + sell))

    return {
        "ctx_has_bsp": 1.0,
        "ctx_last_dir_buy": 1.0 if last_dir == "buy" else 0.0,
        "ctx_last_dir_sell": 1.0 if last_dir == "sell" else 0.0,
        "ctx_days_since_last_bsp": days_since_last,
        "ctx_days_since_last_buy": _days_since("buy"),
        "ctx_days_since_last_sell": _days_since("sell"),
        "ctx_density_total": float(len(recent)),
        "ctx_density_buy": float(buy),
        "ctx_density_sell": float(sell),
        "ctx_density_imb": float((sell - buy) / tot),
    }

def compute_chain_endpoints(bsp_rows: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
    if not bsp_rows:
        return []
    bsps = sorted(bsp_rows, key=lambda r: pd.to_datetime(r["timestamp"]))
    ends = []
    cur_dir = str(bsps[0].get("direction", "")).lower()
    cur_end = bsps[0]
    cur_end_i = 0
    for i in range(1, len(bsps)):
        d = str(bsps[i].get("direction", "")).lower()
        if d == cur_dir:
            cur_end = bsps[i]
            cur_end_i = i
        else:
            ends.append({"end_ts": pd.to_datetime(cur_end["timestamp"]).normalize(), "end_dir": cur_dir, "end_i": cur_end_i})
            cur_dir = d
            cur_end = bsps[i]
            cur_end_i = i
    ends.append({"end_ts": pd.to_datetime(cur_end["timestamp"]).normalize(), "end_dir": cur_dir, "end_i": cur_end_i})
    return ends

def regime_for_day_from_ends(day_norm: pd.Timestamp, ends: List[Dict[str, Any]]) -> str:
    if len(ends) < 2:
        return "unknown"
    for k in range(len(ends) - 1):
        a = ends[k]
        b = ends[k + 1]
        a_ts, a_dir = a["end_ts"], a["end_dir"]
        b_ts, b_dir = b["end_ts"], b["end_dir"]
        if (day_norm >= a_ts) and (day_norm <= b_ts):
            if a_dir == "buy" and b_dir == "sell":
                return "up"
            if a_dir == "sell" and b_dir == "buy":
                return "down"
    return "unknown"


# ============================================================
# DAILY LABEL + MODEL
# ============================================================

def label_confirm_extreme(df_day_feat: pd.DataFrame, idx: int, N: int, base_dir: str) -> Optional[int]:
    if N <= 0:
        return None
    if idx + N >= len(df_day_feat):
        return None
    h0 = float(df_day_feat.loc[idx, "_high"])
    l0 = float(df_day_feat.loc[idx, "_low"])
    fut = df_day_feat.loc[idx+1:idx+N]
    if fut.empty:
        return None
    if base_dir == "sell":
        mx = float(fut["_high"].max())
        return 1 if mx < h0 else 0
    if base_dir == "buy":
        mn = float(fut["_low"].min())
        return 1 if mn > l0 else 0
    return None

def make_daily_features_one_model(
    kline_row: pd.Series,
    bsp_hist_up_to_day: List[Dict[str, Any]],
    p_val: float,
    dp_minK: float,
    dp_maxK: float,
    regime: str,
    base_dir: Optional[str],
    macro_cols: Optional[List[str]] = None,
) -> Dict[str, float]:
    feats: Dict[str, float] = {}
    feats.update(make_kline_dict(kline_row))

    if macro_cols is not None:
        for c in macro_cols:
            if c in kline_row.index:
                val = kline_row[c]
                feats[c] = float(val) if np.isfinite(val) else 0.0

    ts = pd.to_datetime(kline_row["timestamp"])
    feats.update(make_daily_bsp_context(bsp_hist_up_to_day, ts, window_days=60))

    feats["p"] = float(p_val) if np.isfinite(p_val) else 0.0
    feats["dp_minK"] = float(dp_minK) if np.isfinite(dp_minK) else 0.0
    feats["dp_maxK"] = float(dp_maxK) if np.isfinite(dp_maxK) else 0.0

    rg = str(regime).lower()
    feats["rg_up"] = 1.0 if rg == "up" else 0.0
    feats["rg_down"] = 1.0 if rg == "down" else 0.0
    feats["rg_unknown"] = 1.0 if rg not in ("up", "down") else 0.0

    bd = str(base_dir).lower() if base_dir is not None else "none"
    feats["bd_buy"] = 1.0 if bd == "buy" else 0.0
    feats["bd_sell"] = 1.0 if bd == "sell" else 0.0
    feats["bd_none"] = 1.0 if bd not in ("buy", "sell") else 0.0

    return feats

def fit_prob_model_dicts(X_dicts: List[Dict[str, float]], y: np.ndarray):
    base = Pipeline([
        ("vec", DictVectorizer(sparse=True)),
        ("scaler", MaxAbsScaler()),
        ("lr", LogisticRegression(
            max_iter=8000,
            class_weight="balanced",
            solver="saga",
            C=0.5,
            n_jobs=-1
        ))
    ])
    uniq, counts = np.unique(y, return_counts=True)
    if len(uniq) < 2:
        raise ValueError("Only one class in y so far.")
    min_count = int(counts.min())

    if min_count >= 5:
        cal = CalibratedClassifierCV(base, method="sigmoid", cv=3)
        cal.fit(X_dicts, y)
        return cal
    elif min_count >= 3:
        cal = CalibratedClassifierCV(base, method="sigmoid", cv=2)
        cal.fit(X_dicts, y)
        return cal
    else:
        base.fit(X_dicts, y)
        return base

def predict_prob(model, X_dicts: List[Dict[str, float]]) -> np.ndarray:
    return model.predict_proba(X_dicts)[:, 1]

def _get_underlying_pipeline(model):
    if hasattr(model, "calibrated_classifiers_") and len(getattr(model, "calibrated_classifiers_", [])) > 0:
        cc0 = model.calibrated_classifiers_[0]
        if hasattr(cc0, "estimator") and cc0.estimator is not None:
            return cc0.estimator
    return model

def feature_importance_from_lr(model, top_n: int = 80) -> pd.DataFrame:
    pipe = _get_underlying_pipeline(model)
    if not (hasattr(pipe, "named_steps") and "vec" in pipe.named_steps and "lr" in pipe.named_steps):
        return pd.DataFrame(columns=["feature", "coef", "abs_coef"])
    vec = pipe.named_steps["vec"]
    lr = pipe.named_steps["lr"]

    try:
        names = np.array(vec.get_feature_names_out(), dtype=object)
    except Exception:
        names = np.array(getattr(vec, "feature_names_", []), dtype=object)

    coef = lr.coef_.ravel()
    if len(names) != len(coef):
        return pd.DataFrame(columns=["feature", "coef", "abs_coef"])

    df_imp = pd.DataFrame({"feature": names, "coef": coef})
    df_imp["abs_coef"] = df_imp["coef"].abs()
    return df_imp.sort_values("abs_coef", ascending=False).head(int(top_n)).reset_index(drop=True)


# ============================================================
# 5M MODEL + THRESHOLDS
# ============================================================

LABEL_COLS = {"best_return_pct"}
BSP_TYPE_MAP = {"1":1,"2":2,"3a":3,"1p":4,"2s":5,"3b":6}

def prepare_ml_dataset(df: pd.DataFrame) -> pd.DataFrame:
    if df.empty:
        return df
    df = df.copy()

    if "direction" in df.columns:
        d = df["direction"].fillna("unknown").astype(str).str.lower()
        df["direction_encoded"] = np.where(d == "buy", 1, np.where(d == "sell", 0, -1)).astype(np.int32)

    if "bsp_type" in df.columns:
        t = df["bsp_type"].fillna("unknown").astype(str).str.lower()
        df["bsp_type_encoded"] = t.map(BSP_TYPE_MAP).fillna(0).astype(np.int32)

    df = df.replace([np.inf, -np.inf], np.nan)

    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    numeric_cols = [c for c in numeric_cols if c not in LABEL_COLS]

    if numeric_cols:
        imputer = SimpleImputer(strategy="mean")
        imputed = imputer.fit_transform(df[numeric_cols])
        df[numeric_cols] = pd.DataFrame(imputed, columns=numeric_cols, index=df.index).fillna(0.0)

    return df

def get_feature_columns(df: pd.DataFrame) -> List[str]:
    exclude = set(LABEL_COLS) | {
        "timestamp","code","direction","bsp_type","klu_idx",
        "has_best_exit","best_exit_type","best_exit_klu_idx","best_exit_price",
        "regime_bucket",
    }
    num_cols = df.select_dtypes(include=[np.number, "bool"]).columns.tolist()
    cols = [c for c in num_cols if c not in exclude]
    return sorted(cols)

def to_float_matrix(df: pd.DataFrame, cols: List[str]) -> np.ndarray:
    if not cols:
        return np.zeros((len(df), 0), dtype=np.float32)
    X = df[cols].copy()
    for c in cols:
        X[c] = pd.to_numeric(X[c], errors="coerce")
    X = X.replace([np.inf, -np.inf], np.nan).fillna(0.0)
    return X.to_numpy(dtype=np.float32, copy=False)

def _fit_ret_pack(df_dir: pd.DataFrame, feature_cols: List[str], seed: int) -> RetModelPack:
    ret_df = df_dir.dropna(subset=["best_return_pct"]).copy()
    X = to_float_matrix(ret_df, feature_cols)
    y = ret_df["best_return_pct"].to_numpy(dtype=np.float32)

    model = xgb.XGBRegressor(
        n_estimators=500,
        max_depth=5,
        learning_rate=0.05,
        subsample=0.85,
        colsample_bytree=0.85,
        reg_lambda=1.0,
        random_state=seed,
        n_jobs=4,
    )
    model.fit(X, y)
    return RetModelPack(feature_cols=feature_cols, model_ret=model)

def train_models_two_sided_ret_only(
    bsp_df: pd.DataFrame,
    feature_cols: List[str],
    min_samples_total: int = 300,
):
    if bsp_df.empty or "direction" not in bsp_df.columns:
        return None, None

    df = bsp_df.copy()
    for c in feature_cols:
        if c not in df.columns:
            df[c] = 0.0

    buy_df = df[df["direction"].astype(str).str.lower() == "buy"].copy()
    sell_df = df[df["direction"].astype(str).str.lower() == "sell"].copy()

    buy_pack = None
    if len(buy_df.dropna(subset=["best_return_pct"])) >= min_samples_total:
        buy_pack = _fit_ret_pack(buy_df, feature_cols, seed=42)

    sell_pack = None
    if len(sell_df.dropna(subset=["best_return_pct"])) >= min_samples_total:
        sell_pack = _fit_ret_pack(sell_df, feature_cols, seed=52)

    return buy_pack, sell_pack

def predict_ret(pack: RetModelPack, row_df: pd.DataFrame) -> float:
    X = to_float_matrix(row_df, pack.feature_cols)
    return float(pack.model_ret.predict(X)[0])

def make_ret_grid(start: float = -0.5, end: float = 2.5, step: float = 0.05) -> List[float]:
    vals = np.arange(start, end + 1e-12, step, dtype=float)
    return [float(x) for x in vals]

def _bars_from_days(days: float, bar_interval_minutes: int) -> int:
    minutes = float(days) * 24.0 * 60.0
    return max(1, int(round(minutes / float(bar_interval_minutes))))

def label_bestlookahead_for_ready_points(
    bsp_rows: List[Dict[str, Any]],
    highs: np.ndarray,
    lows: np.ndarray,
    closes: np.ndarray,
    lookahead_days: float,
    bar_interval_minutes: int,
    current_bar_idx: int,
):
    if not bsp_rows:
        return
    lookahead_bars = _bars_from_days(lookahead_days, bar_interval_minutes)
    n = len(closes)

    for r in bsp_rows:
        if not np.isnan(r.get("best_return_pct", np.nan)):
            continue
        i = r.get("klu_idx", None)
        if i is None:
            continue
        i = int(i)
        end_i = i + lookahead_bars
        if end_i >= n:
            continue
        if end_i > current_bar_idx:
            continue

        d = str(r.get("direction", "buy")).lower()
        c0 = float(closes[i])

        if d == "buy":
            mx = float(np.nanmax(highs[i + 1 : end_i + 1]))
            r["best_return_pct"] = (mx - c0) / c0 * 100.0
        else:
            mn = float(np.nanmin(lows[i + 1 : end_i + 1]))
            r["best_return_pct"] = (c0 - mn) / c0 * 100.0

def _simulate_realized_ret_only_long(
    events: List[Dict[str, Any]],
    pred_buy: Dict[Any, float],
    pred_sell: Dict[Any, float],
    buy_th: float,
    sell_th: float,
    next_open_by_idx: np.ndarray,
    closes: np.ndarray,
    end_bar_idx: int,
    fee_pct: float = 0.0,
):
    cash = 1.0
    pos = 0
    qty = 0.0
    trades = 0

    def exec_next_open(idx: int):
        if not (0 <= idx < len(next_open_by_idx)):
            return None
        px = next_open_by_idx[idx]
        if px is None or (isinstance(px, float) and np.isnan(px)):
            return None
        return float(px)

    for r in events:
        d = str(r.get("direction", "")).lower()
        ki = int(r.get("klu_idx", -1))
        px = exec_next_open(ki)
        if px is None:
            continue

        if pos == 0 and d == "buy":
            key = (int(r.get("klu_idx",-1)), "buy", str(r.get("bsp_type","?")))
            pr = pred_buy.get(key)
            if pr is not None and pr >= float(buy_th):
                notional = cash
                spend = notional * (1 + fee_pct)
                if spend > cash:
                    spend = cash
                    notional = spend / (1 + fee_pct)
                qty = notional / px
                cash -= spend
                pos = 1
                trades += 1

        elif pos == 1 and d == "sell":
            key = (int(r.get("klu_idx",-1)), "sell", str(r.get("bsp_type","?")))
            pr = pred_sell.get(key)
            if pr is not None and pr >= float(sell_th):
                cash += (qty * px) * (1 - fee_pct)
                qty = 0.0
                pos = 0
                trades += 1

    end_px = float(closes[end_bar_idx])
    eq = cash if pos == 0 else (cash + qty * end_px)
    return float(eq), int(trades)

def choose_thresholds_global_realized(
    df_5m: pd.DataFrame,
    bsp_rows: List[Dict[str, Any]],
    buy_pack: Optional[RetModelPack],
    sell_pack: Optional[RetModelPack],
    asof_bar_idx: int,
    window_days: float,
    ret_grid: List[float],
    next_open_by_idx: np.ndarray,
    closes: np.ndarray,
    fee_pct: float = 0.0,
    min_open_signals: int = 10,
):
    if df_5m.empty or not bsp_rows or buy_pack is None or sell_pack is None:
        return None

    end_ts = pd.to_datetime(df_5m.loc[asof_bar_idx, "timestamp"])
    start_ts = end_ts - pd.Timedelta(days=float(window_days))

    events = []
    buy_cand = []
    sell_cand = []
    for r in bsp_rows:
        t = pd.to_datetime(r.get("timestamp", None), errors="coerce")
        if pd.isna(t) or not (start_ts <= t <= end_ts):
            continue
        ki = r.get("klu_idx", None)
        if ki is None:
            continue
        rr = dict(r)
        rr["klu_idx"] = int(ki)
        events.append(rr)
        d = str(rr.get("direction","")).lower()
        if d == "buy":
            buy_cand.append(rr)
        elif d == "sell":
            sell_cand.append(rr)

    if len(buy_cand) < int(min_open_signals) or len(sell_cand) < 1:
        return None

    events.sort(key=lambda x: int(x["klu_idx"]))

    buy_df = prepare_ml_dataset(pd.DataFrame(buy_cand))
    for c in buy_pack.feature_cols:
        if c not in buy_df.columns:
            buy_df[c] = 0.0
    buy_pred = buy_pack.model_ret.predict(to_float_matrix(buy_df, buy_pack.feature_cols)).astype(float)
    pred_buy = {(int(buy_cand[i]["klu_idx"]), "buy", str(buy_cand[i].get("bsp_type","?"))): float(buy_pred[i]) for i in range(len(buy_cand))}

    sell_df = prepare_ml_dataset(pd.DataFrame(sell_cand))
    for c in sell_pack.feature_cols:
        if c not in sell_df.columns:
            sell_df[c] = 0.0
    sell_pred = sell_pack.model_ret.predict(to_float_matrix(sell_df, sell_pack.feature_cols)).astype(float)
    pred_sell = {(int(sell_cand[i]["klu_idx"]), "sell", str(sell_cand[i].get("bsp_type","?"))): float(sell_pred[i]) for i in range(len(sell_cand))}

    end_bar_idx = asof_bar_idx
    best_eq = None
    best_pair = None

    for bt in ret_grid:
        for st in ret_grid:
            eq, trades = _simulate_realized_ret_only_long(
                events=events,
                pred_buy=pred_buy,
                pred_sell=pred_sell,
                buy_th=float(bt),
                sell_th=float(st),
                next_open_by_idx=next_open_by_idx,
                closes=closes,
                end_bar_idx=end_bar_idx,
                fee_pct=fee_pct,
            )
            if best_eq is None or eq > best_eq:
                best_eq = float(eq)
                best_pair = (float(bt), float(st))

    return best_pair


# ============================================================
# EXECUTION ENGINE
# ============================================================

class ExecutionEngine:
    def __init__(self, initial_capital: float, fee_pct: float):
        self.cash = float(initial_capital)
        self.fee_pct = float(fee_pct)
        self.pos = 0
        self.qty = 0.0
        self.entry_px = None
        self.entry_idx = None
        self.pending_order = None
        self.trades = []

    def _exec_px(self, seen_idx: int, next_open_by_idx: np.ndarray):
        if not (0 <= seen_idx < len(next_open_by_idx)):
            return None
        px = next_open_by_idx[seen_idx]
        if px is None or (isinstance(px, float) and np.isnan(px)):
            return None
        return float(px)

    def place_order_for_next_bar(self, side: str, seen_idx: int, reason: str, meta: dict = None, overwrite=True):
        if self.pending_order is not None and not overwrite:
            return
        self.pending_order = {"side": side, "seen_idx": int(seen_idx), "reason": reason, "meta": dict(meta) if meta else {}}

    def maybe_execute_pending(self, next_open_by_idx: np.ndarray):
        if self.pending_order is None:
            return
        side = self.pending_order["side"]
        idx  = self.pending_order["seen_idx"]
        reason = self.pending_order["reason"]
        meta = self.pending_order.get("meta", {}) or {}

        px = self._exec_px(idx, next_open_by_idx)
        if px is None:
            return

        fee = self.fee_pct

        if side == "buy" and self.pos == 0:
            notional = self.cash / (1.0 + fee)
            fee_amt = notional * fee
            qty = notional / px
            self.cash -= (notional + fee_amt)
            self.pos = 1
            self.qty = qty
            self.entry_px = px
            self.entry_idx = idx
            self.trades.append({"side":"buy","seen_idx":idx,"exec_px":px,"qty":qty,"fee":fee_amt,"reason":reason, **meta})

        elif side == "sell" and self.pos == 1:
            notional = self.qty * px
            fee_amt = notional * fee
            recv = notional - fee_amt
            self.cash += recv
            pnl = (px - self.entry_px) * self.qty - fee_amt
            self.trades.append({
                "side":"sell","seen_idx":idx,"exec_px":px,"qty":self.qty,"fee":fee_amt,"reason":reason,
                "pnl": pnl, "entry_px": self.entry_px, "entry_idx": self.entry_idx, **meta
            })
            self.pos = 0
            self.qty = 0.0
            self.entry_px = None
            self.entry_idx = None

        self.pending_order = None

    def mark_to_market(self, last_close: float) -> float:
        px = float(last_close)
        if self.pos == 0:
            return float(self.cash)
        return float(self.cash + self.qty * px)

    def state_dict(self) -> dict:
        return {
            "cash": self.cash,
            "fee_pct": self.fee_pct,
            "pos": self.pos,
            "qty": self.qty,
            "entry_px": self.entry_px,
            "entry_idx": self.entry_idx,
            "pending_order": copy.deepcopy(self.pending_order),
            "trades": copy.deepcopy(self.trades),
        }

    def load_state_dict(self, d: dict):
        self.cash = float(d.get("cash", self.cash))
        self.fee_pct = float(d.get("fee_pct", self.fee_pct))
        self.pos = int(d.get("pos", 0))
        self.qty = float(d.get("qty", 0.0))
        self.entry_px = d.get("entry_px", None)
        self.entry_idx = d.get("entry_idx", None)
        self.pending_order = copy.deepcopy(d.get("pending_order", None))
        self.trades = copy.deepcopy(d.get("trades", []))


# ============================================================
# 5M INDEX LOAD
# ============================================================

def load_5m_index(df_5m: pd.DataFrame, start_time: str, end_time: str):
    df = df_5m.copy()
    st = pd.to_datetime(start_time)
    et = pd.to_datetime(end_time)
    df = df[(df["timestamp"] >= st) & (df["timestamp"] <= et)].copy().reset_index(drop=True)

    df = df.rename(columns={"_open":"Open","_high":"High","_low":"Low","_close":"Close","_vol":"Volume"})
    df.columns = [str(c).strip() for c in df.columns]

    if not df.columns.is_unique:
        df = df.loc[:, ~df.columns.duplicated(keep="first")]

    df["date"] = df["timestamp"].dt.date
    df["next_open"] = df["Open"].shift(-1)
    df["next_close"] = df["Close"].shift(-1)

    next_open_by_idx = df["next_open"].to_numpy()
    next_close_by_idx = df["next_close"].to_numpy()
    closes = df["Close"].to_numpy(dtype=float)
    highs  = df["High"].to_numpy(dtype=float)
    lows   = df["Low"].to_numpy(dtype=float)

    day_close_map = df.groupby("date")["Close"].last().to_dict()
    all_days = sorted(df["date"].unique())
    return df, next_open_by_idx, next_close_by_idx, closes, highs, lows, day_close_map, all_days

def compute_buy_hold_equity(day_close_map: dict, daily_dates: list, initial_capital: float) -> pd.Series:
    closes, dates = [], []
    for d in daily_dates:
        px = day_close_map.get(d)
        if px is None or pd.isna(px):
            continue
        dates.append(d)
        closes.append(float(px))
    if not closes:
        return pd.Series(dtype=float)
    first = closes[0]
    equity = [initial_capital * (c / first) for c in closes]
    return pd.Series(equity, index=pd.to_datetime(dates))


# ============================================================
# GATE LOGIC
# ============================================================

def gate_from_p(p_day: float, p_sell_level: float, p_buy_level: float) -> str:
    if not np.isfinite(p_day):
        return "NO_P"
    if p_day >= p_sell_level:
        return "FORCE_SELL"
    if p_day <= p_buy_level:
        return "FORCE_BUY"
    return "FREE"


# ============================================================
# CLASS-FREE SERIALIZATION HELPERS
# ============================================================

def pack_ret_modelpack_for_save(pack):
    if pack is None:
        return None
    return {
        "__type__": "RetModelPack",
        "feature_cols": list(pack.feature_cols),
        "model_ret": pack.model_ret,
    }

def unpack_ret_modelpack_from_load(obj):
    if obj is None:
        return None
    if isinstance(obj, dict) and obj.get("__type__") == "RetModelPack":
        return RetModelPack(
            feature_cols=list(obj["feature_cols"]),
            model_ret=obj["model_ret"],
        )
    return obj


# ============================================================
# CHECKPOINT BUNDLE BUILD / LOAD
# ============================================================

def build_checkpoint_bundle(
    *,
    code: str,
    checkpoint_time: str,

    original_daily_chan_start: str,
    original_accumulation_start: str,
    original_sim_start: str,
    original_end_time: str,

    macro_files: dict,

    daily_prob_model,
    daily_prob_trained_n: int,
    X_days,
    y_days,
    pending_idx,
    p_by_day,
    p_series,
    dp_vs_minK_series,
    dp_vs_maxK_series,
    bsp_rows_daily,
    seen_bsp_daily,

    buy_pack,
    sell_pack,
    buy_ret_th_live: float,
    sell_ret_th_live: float,

    bsp_rows_5m,
    seen_keys_5m,

    engine_state: dict,
    daily_log,

    daily_i_last: int,
    five_i_last: int,
    current_day,

    warmup_daily_bars: pd.DataFrame,
    warmup_5m_bars: pd.DataFrame,

    daily_chan_max_klines: int,
    five_chan_max_klines: int,
):
    p_by_day_str = {}
    if p_by_day is not None:
        for k, v in p_by_day.items():
            try:
                p_by_day_str[str(pd.to_datetime(k))] = float(v)
            except Exception:
                pass

    bundle = {
        "schema": "chan_xgb_dailyprob_checkpoint_v4_macro",
        "code": code,
        "checkpoint_time": checkpoint_time,

        "original_daily_chan_start": str(original_daily_chan_start),
        "original_accumulation_start": str(original_accumulation_start),
        "original_sim_start": str(original_sim_start),
        "original_end_time": str(original_end_time),

        "macro_files": copy.deepcopy(macro_files),

        "daily_prob_model": daily_prob_model,
        "daily_prob_trained_n": int(daily_prob_trained_n),

        "X_days": copy.deepcopy(X_days),
        "y_days": copy.deepcopy(y_days),
        "pending_idx": copy.deepcopy(pending_idx),

        "p_by_day_str": p_by_day_str,
        "p_series": np.asarray(p_series, dtype=float),
        "dp_vs_minK_series": np.asarray(dp_vs_minK_series, dtype=float),
        "dp_vs_maxK_series": np.asarray(dp_vs_maxK_series, dtype=float),

        "bsp_rows_daily": _safe_copy_list_of_dict(bsp_rows_daily),
        "seen_bsp_daily_list": _safe_set_to_list(seen_bsp_daily),

        "buy_pack": pack_ret_modelpack_for_save(buy_pack),
        "sell_pack": pack_ret_modelpack_for_save(sell_pack),

        "buy_ret_th_live": float(buy_ret_th_live),
        "sell_ret_th_live": float(sell_ret_th_live),

        "bsp_rows_5m": _safe_copy_list_of_dict(bsp_rows_5m),
        "seen_keys_5m_list": _safe_set_to_list(seen_keys_5m),

        "engine_state": copy.deepcopy(engine_state),
        "daily_log": copy.deepcopy(daily_log),

        "daily_i_last": int(daily_i_last),
        "five_i_last": int(five_i_last),
        "current_day": None if current_day is None else str(current_day),

        "warmup_daily_bars": warmup_daily_bars.reset_index(drop=True),
        "warmup_5m_bars": warmup_5m_bars.reset_index(drop=True),

        "daily_chan_max_klines": int(daily_chan_max_klines),
        "five_chan_max_klines": int(five_chan_max_klines),
    }
    return bundle

def load_checkpoint_bundle(path: str) -> dict:
    b = load_joblib(path)
    if not isinstance(b, dict):
        raise ValueError("Checkpoint is not a dict.")
    schema = b.get("schema", "")
    if schema not in (
        "chan_xgb_dailyprob_checkpoint_v1",
        "chan_xgb_dailyprob_checkpoint_v2",
        "chan_xgb_dailyprob_checkpoint_v3",
        "chan_xgb_dailyprob_checkpoint_v4_macro",
    ):
        raise ValueError(f"Unknown checkpoint schema: {schema}")
    return b


# ============================================================
# CHECKPOINT START-TIME INFERENCE
# ============================================================

def _load_any_csv_time_index(csv_path: str) -> pd.DataFrame:
    df = pd.read_csv(csv_path)

    ts_candidates = ["timestamp", "date", "datetime", "time"]
    ts_col = None
    for c in ts_candidates:
        if c in df.columns:
            ts_col = c
            break

    if ts_col is None:
        lower_map = {c.lower(): c for c in df.columns}
        for c in ts_candidates:
            if c.lower() in lower_map:
                ts_col = lower_map[c.lower()]
                break

    if ts_col is None:
        ts_col = df.columns[0]

    df[ts_col] = pd.to_datetime(df[ts_col], errors="coerce")
    df = df.dropna(subset=[ts_col]).sort_values(ts_col).reset_index(drop=True)
    df = df.rename(columns={ts_col: "timestamp"})
    return df

def infer_checkpoint_plot_start_time(
    ckpt: dict,
    daily_csv_path: str | None = None,
    k5m_csv_path: str | None = None,
    verbose: bool = True,
):
    ts_keys = [
        "last_checkpoint_time",
        "last_processed_time",
        "last_processed_ts",
        "resume_time",
        "resume_ts",
        "cur_time",
        "current_time",
        "last_day_time",
        "last_day_ts",
        "last_daily_ts",
        "last_5m_ts",
        "five_ts_last",
        "day_ts_last",
        "checkpoint_time",
    ]
    for k in ts_keys:
        if k in ckpt and ckpt[k] is not None:
            try:
                ts = pd.to_datetime(ckpt[k])
                if pd.notna(ts):
                    if verbose:
                        print(f"[PLOT START] inferred from checkpoint key '{k}' = {ts}")
                    return ts
            except Exception:
                pass

    daily_idx_keys = [
        "daily_i_last",
        "day_i_last",
        "last_daily_i",
        "last_day_idx",
        "daily_idx_last",
        "current_daily_i",
        "resume_daily_i",
    ]
    if daily_csv_path is not None and os.path.exists(daily_csv_path):
        try:
            df_day = _load_any_csv_time_index(daily_csv_path)
            for k in daily_idx_keys:
                if k in ckpt and ckpt[k] is not None:
                    i = int(ckpt[k])
                    if 0 <= i < len(df_day):
                        ts = pd.to_datetime(df_day.loc[i, "timestamp"])
                        if verbose:
                            print(f"[PLOT START] inferred from daily index key '{k}' = {ts}")
                        return ts
        except Exception as e:
            if verbose:
                print(f"[PLOT START] daily index inference failed: {e}")

    five_idx_keys = [
        "five_i_last",
        "last_5m_i",
        "five_idx_last",
        "current_five_i",
        "resume_five_i",
        "seen_idx_last",
    ]
    if k5m_csv_path is not None and os.path.exists(k5m_csv_path):
        try:
            df_5m = _load_any_csv_time_index(k5m_csv_path)
            for k in five_idx_keys:
                if k in ckpt and ckpt[k] is not None:
                    i = int(ckpt[k])
                    if 0 <= i < len(df_5m):
                        ts = pd.to_datetime(df_5m.loc[i, "timestamp"])
                        if verbose:
                            print(f"[PLOT START] inferred from 5m index key '{k}' = {ts}")
                        return ts
        except Exception as e:
            if verbose:
                print(f"[PLOT START] 5m index inference failed: {e}")

    if verbose:
        print("[PLOT START] could not infer checkpoint plot start time.")
    return None


# ============================================================
# RESUMED-SEGMENT PLOTTING
# ============================================================

def plot_resumed_segment_from_checkpoint(
    res: dict,
    checkpoint_start_time,
    title_prefix: str = "Resumed Run",
    output_dir: str | None = None,
):
    if "daily_log_df" not in res:
        print("res['daily_log_df'] not found, cannot plot.")
        return

    d = res["daily_log_df"].copy()

    if "timestamp" in d.columns:
        d["plot_time"] = pd.to_datetime(d["timestamp"], errors="coerce")
    elif "date" in d.columns:
        d["plot_time"] = pd.to_datetime(d["date"], errors="coerce")
    else:
        ts_candidates = [c for c in d.columns if "time" in c.lower() or "date" in c.lower()]
        if len(ts_candidates) == 0:
            print("No timestamp/date column found in daily_log_df.")
            return
        d["plot_time"] = pd.to_datetime(d[ts_candidates[0]], errors="coerce")

    d = d.dropna(subset=["plot_time"]).sort_values("plot_time").reset_index(drop=True)

    if checkpoint_start_time is not None:
        d = d[d["plot_time"] >= pd.to_datetime(checkpoint_start_time)].copy().reset_index(drop=True)

    if len(d) == 0:
        print("No rows available after checkpoint start time.")
        return

    if output_dir:
        os.makedirs(output_dir, exist_ok=True)

    equity_col = None
    for c in ["equity", "portfolio_value", "nav", "strategy_equity"]:
        if c in d.columns:
            equity_col = c
            break

    if equity_col is not None:
        plt.figure(figsize=(16, 6))
        base_eq = float(d[equity_col].iloc[0]) if np.isfinite(d[equity_col].iloc[0]) else 1.0
        plt.plot(d["plot_time"], d[equity_col] / (base_eq + 1e-12), label="Strategy (normalized)")
        plt.title(f"{title_prefix} | Equity after checkpoint")
        plt.legend()
        plt.grid(True, alpha=0.25)
        plt.tight_layout()
        if output_dir:
            plt.savefig(os.path.join(output_dir, "resumed_equity_from_checkpoint.png"), dpi=200)
        plt.show()

    p_col = None
    for c in d.columns:
        cl = c.lower()
        if c == "p_day" or "prob" in cl or "p_" in cl:
            p_col = c
            break

    if p_col is not None:
        plt.figure(figsize=(16, 5))
        plt.plot(d["plot_time"], d[p_col], label=p_col)
        plt.title(f"{title_prefix} | Daily probability after checkpoint")
        plt.grid(True, alpha=0.25)
        plt.legend()
        plt.tight_layout()
        if output_dir:
            plt.savefig(os.path.join(output_dir, "resumed_pday_from_checkpoint.png"), dpi=200)
        plt.show()

    if "trades_df" in res and isinstance(res["trades_df"], pd.DataFrame) and not res["trades_df"].empty:
        tr = res["trades_df"].copy()
        if "ts" in tr.columns:
            tr["plot_time"] = pd.to_datetime(tr["ts"], errors="coerce")
            tr = tr.dropna(subset=["plot_time"]).sort_values("plot_time").reset_index(drop=True)

            if checkpoint_start_time is not None:
                tr = tr[tr["plot_time"] >= pd.to_datetime(checkpoint_start_time)].copy().reset_index(drop=True)

            if len(tr) > 0 and "exec_px" in tr.columns:
                plt.figure(figsize=(16, 6))
                buys = tr[tr["side"].astype(str).str.lower() == "buy"]
                sells = tr[tr["side"].astype(str).str.lower() == "sell"]

                if len(buys):
                    plt.scatter(buys["plot_time"], buys["exec_px"], marker="^", label="Buy")
                if len(sells):
                    plt.scatter(sells["plot_time"], sells["exec_px"], marker="v", label="Sell")

                plt.title(f"{title_prefix} | Trades after checkpoint")
                plt.grid(True, alpha=0.25)
                plt.legend()
                plt.tight_layout()
                if output_dir:
                    plt.savefig(os.path.join(output_dir, "resumed_trades_from_checkpoint.png"), dpi=200)
                plt.show()


# ============================================================
# MAIN STRATEGY RUNNER
# ============================================================

def run_daily_prob_then_5m_xgb_gated(
    daily_csv_path: str,
    k5m_csv_path: str,
    code: str = "QQQ",

    daily_chan_start: str = "2016-06-01",
    accumulation_start: str = "2018-10-01",
    sim_start: str = "2019-01-01",
    end_time: str = "2019-12-30",

    N_confirm: int = 5,
    min_labeled_days_to_train: int = 200,
    retrain_every_new_labels: int = 25,
    dp_lookback: int = 5,

    p_sell_level: float = 0.30,
    p_buy_level: float = 0.20,

    bar_interval_minutes: int = 5,
    lookahead_days_5m: float = 2.0,
    retrain_every_days_5m: int = 5,
    min_samples_total_5m: int = 300,

    threshold_window_days: float = 2.0,
    threshold_ret_grid=None,
    threshold_min_open_signals: int = 10,

    initial_capital: float = 100000.0,
    fee_pct: float = 0.0,

    daily_chan_max_klines: int = 500,
    five_chan_max_klines: int = 20000,

    macro_files: dict | None = None,

    output_dir: str = "output_dailyprob_gated_5m_xgb",
    verbose: bool = True,

    save_checkpoint_path: str | None = None,
    checkpoint_every_n_days: int = 1,
    resume_from_checkpoint_path: str | None = None,
):
    os.makedirs(output_dir, exist_ok=True)

    if macro_files is None:
        macro_files = {
            "vix_":   "VIX.csv",
            "dxy_":   "DXY.csv",
            "us5y_":  "FVX.csv",
            "us10y_": "TNX.csv",
            "us30y_": "TYX.csv",
            "xau_":   "XAU.csv",
            "nyxbt_": "NYXBT.csv",
        }

    # ----------------------------
    # Load raw data
    # ----------------------------
    df_day_raw = load_ohlcv_csv(daily_csv_path, "DAILY")
    df_5m_raw  = load_ohlcv_csv(k5m_csv_path, "5M")

    daily_s = pd.to_datetime(daily_chan_start)
    acc_s   = pd.to_datetime(accumulation_start)
    sim_s   = pd.to_datetime(sim_start)
    end_t   = pd.to_datetime(end_time)

    df_day = df_day_raw[(df_day_raw["timestamp"] >= daily_s) & (df_day_raw["timestamp"] <= end_t)].copy().reset_index(drop=True)
    if df_day.empty:
        raise ValueError("No daily bars in requested range.")
    df_day_feat = compute_daily_kline_features(df_day)
    df_day_feat["ts_norm"] = pd.to_datetime(df_day_feat["timestamp"]).dt.normalize()

    macro_folder = os.path.dirname(os.path.abspath(daily_csv_path))
    macro_feat = load_macro_features_from_folder(
        folder=macro_folder,
        files=macro_files,
        start=daily_chan_start,
    )
    df_day_feat = df_day_feat.merge(macro_feat, on="ts_norm", how="left").sort_values("timestamp").reset_index(drop=True)

    macro_cols = [
        c for c in df_day_feat.columns
        if (
            c.startswith("vix_")
            or c.startswith("dxy_")
            or c.startswith("us5y_")
            or c.startswith("us10y_")
            or c.startswith("us30y_")
            or c.startswith("xau_")
            or c.startswith("nyxbt_")
            or c.startswith("yc_")
        )
    ]

    df_5m = df_5m_raw[(df_5m_raw["timestamp"] >= acc_s) & (df_5m_raw["timestamp"] <= end_t + pd.Timedelta(days=1))].copy()
    df_5m = df_5m.sort_values("timestamp").reset_index(drop=True)

    df_5m_idx, next_open_by_idx, next_close_by_idx, closes, highs, lows, day_close_map, all_days = load_5m_index(
        df_5m, accumulation_start, end_time
    )
    buy_hold = compute_buy_hold_equity(day_close_map, all_days, initial_capital)

    # ----------------------------
    # Chan config / objects
    # ----------------------------
    config = CChanConfig({
        "cal_demark": True,
        "cal_kdj": True,
        "cal_dmi": True,
        "cal_rsi": True,
        "cal_rsl": True,
        "cal_demand_index": True,
        "cal_adline": True,
        "cal_bb_vals": True,
        "cal_kc_vals": True,
        "cal_starc_vals": True,
        "bi_strict": True,
        "trigger_step": True,
        "skip_step": 0,
        "divergence_rate": float("inf"),
        "bsp2_follow_1": True,
        "bsp3_follow_1": False,
        "min_zs_cnt": 0,
        "bs1_peak": False,
        "macd_algo": "peak",
        "bs_type": "1,2,3a,1p,2s,3b",
        "print_warning": False,
        "zs_algo": "normal",
    })

    daily_chan = SlidingWindowChan(
        code=code,
        begin_time=None,
        end_time=None,
        data_src=getattr(DATA_SRC, "CSV", "CSV"),
        lv_list=[KL_TYPE.K_DAY],
        config=config,
        autype=AUTYPE.QFQ,
        max_klines=int(daily_chan_max_klines),
    )

    chan_5m = SlidingWindowChan(
        code=code,
        begin_time=None,
        end_time=None,
        data_src=getattr(DATA_SRC, "CSV", "CSV"),
        lv_list=[KL_TYPE.K_5M],
        config=config,
        autype=AUTYPE.QFQ,
        max_klines=int(five_chan_max_klines),
    )

    # ----------------------------
    # Fresh state defaults
    # ----------------------------
    bsp_rows_daily = []
    seen_bsp_daily = set()

    X_days = []
    y_days = []
    st = DailyProbState()
    pending_idx = []

    p_series = np.full(len(df_day_feat), np.nan, dtype=float)
    dp_vs_minK_series = np.full(len(df_day_feat), np.nan, dtype=float)
    dp_vs_maxK_series = np.full(len(df_day_feat), np.nan, dtype=float)
    p_by_day = {}

    engine = ExecutionEngine(initial_capital=initial_capital, fee_pct=fee_pct)
    bsp_rows_5m = []
    seen_keys_5m = set()
    buy_pack = None
    sell_pack = None
    last_train_day = None

    if threshold_ret_grid is None:
        threshold_ret_grid = make_ret_grid(-0.5, 2.5, 0.05)
    buy_ret_th_live = 0.30
    sell_ret_th_live = 0.30

    daily_i_start = 0
    five_i_start = 0
    current_day = None
    daily_log = []

    # ----------------------------
    # Resume restore
    # ----------------------------
    if resume_from_checkpoint_path is not None and os.path.exists(resume_from_checkpoint_path):
        B = load_checkpoint_bundle(resume_from_checkpoint_path)
        if verbose:
            print(f"[RESUME] loading checkpoint: {resume_from_checkpoint_path} @ {B.get('checkpoint_time')}")

        st.model = B.get("daily_prob_model", None)
        st.trained_n = int(B.get("daily_prob_trained_n", 0))
        st.new_labels = 0

        X_days = B.get("X_days", []) or []
        y_days = B.get("y_days", []) or []
        pending_idx = B.get("pending_idx", []) or []

        p_series_loaded = B.get("p_series", None)
        if p_series_loaded is not None and len(p_series_loaded) == len(p_series):
            p_series = np.asarray(p_series_loaded, dtype=float)

        dp_min_loaded = B.get("dp_vs_minK_series", None)
        dp_max_loaded = B.get("dp_vs_maxK_series", None)
        if dp_min_loaded is not None and len(dp_min_loaded) == len(dp_vs_minK_series):
            dp_vs_minK_series = np.asarray(dp_min_loaded, dtype=float)
        if dp_max_loaded is not None and len(dp_max_loaded) == len(dp_vs_maxK_series):
            dp_vs_maxK_series = np.asarray(dp_max_loaded, dtype=float)

        p_by_day_str = B.get("p_by_day_str", {}) or {}
        p_by_day = {pd.to_datetime(k).normalize(): float(v) for k, v in p_by_day_str.items()}

        bsp_rows_daily = B.get("bsp_rows_daily", []) or []
        seen_bsp_daily = _safe_list_to_set(B.get("seen_bsp_daily_list", []))

        buy_pack = unpack_ret_modelpack_from_load(B.get("buy_pack", None))
        sell_pack = unpack_ret_modelpack_from_load(B.get("sell_pack", None))
        buy_ret_th_live = float(B.get("buy_ret_th_live", buy_ret_th_live))
        sell_ret_th_live = float(B.get("sell_ret_th_live", sell_ret_th_live))

        bsp_rows_5m = B.get("bsp_rows_5m", []) or []
        seen_keys_5m = _safe_list_to_set(B.get("seen_keys_5m_list", []))

        engine.load_state_dict(B.get("engine_state", {}) or {})
        daily_log = B.get("daily_log", []) or []

        daily_i_start = int(B.get("daily_i_last", -1)) + 1
        five_i_start = int(B.get("five_i_last", -1)) + 1

        cur_day_s = B.get("current_day", None)
        current_day = None if cur_day_s is None else datetime.date.fromisoformat(cur_day_s)

        warm_day = B.get("warmup_daily_bars", None)
        if warm_day is not None and len(warm_day):
            for _, rr in warm_day.iterrows():
                ts = pd.to_datetime(rr["timestamp"])
                daily_chan.process_new_kline(build_klu(ts, rr["_open"], rr["_high"], rr["_low"], rr["_close"], rr.get("_vol", 0.0)))

        warm_5m = B.get("warmup_5m_bars", None)
        if warm_5m is not None and len(warm_5m):
            for _, rr in warm_5m.iterrows():
                ts = pd.to_datetime(rr["timestamp"])
                feed_chan_one(chan_5m, build_klu(ts, rr["_open"], rr["_high"], rr["_low"], rr["_close"], rr.get("_vol", 0.0)))

        if verbose:
            print(f"[RESUME] daily_i_start={daily_i_start} / {len(df_day_feat)}")
            print(f"[RESUME] five_i_start={five_i_start} / {len(df_5m_idx)}")
            print(f"[RESUME] daily_model={'YES' if st.model is not None else 'NO'} "
                  f"5m_buy={'YES' if buy_pack else 'NO'} 5m_sell={'YES' if sell_pack else 'NO'}")

    # ----------------------------
    # Daily trainer helper
    # ----------------------------
    def maybe_train_daily():
        if len(y_days) < int(min_labeled_days_to_train):
            return
        if st.model is None or st.new_labels >= int(retrain_every_new_labels):
            y = np.asarray(y_days, dtype=int)
            if len(np.unique(y)) < 2:
                return
            try:
                st.model = fit_prob_model_dicts(X_days, y)
                st.trained_n = len(y)
                st.new_labels = 0
                if verbose:
                    print(f"[TRAIN][DAILY-PROB] n={len(y)} pos={int(y.sum())} ({y.mean():.2%})")
            except Exception as e:
                if verbose:
                    print(f"[TRAIN][DAILY-PROB] skipped: {e}")

    # ----------------------------
    # Save checkpoint helper
    # ----------------------------
    def save_checkpoint(now_ts: pd.Timestamp, daily_i_last: int, five_i_last: int, current_day):
        nonlocal daily_log
        if save_checkpoint_path is None:
            return

        warm_daily = df_day_raw[df_day_raw["timestamp"] <= now_ts].tail(int(daily_chan_max_klines)).copy()
        warm_5m = df_5m_raw[df_5m_raw["timestamp"] <= now_ts].tail(int(five_chan_max_klines)).copy()

        bundle = build_checkpoint_bundle(
            code=code,
            checkpoint_time=str(now_ts),

            original_daily_chan_start=str(daily_chan_start),
            original_accumulation_start=str(accumulation_start),
            original_sim_start=str(sim_start),
            original_end_time=str(end_time),

            macro_files=macro_files,

            daily_prob_model=st.model,
            daily_prob_trained_n=st.trained_n,
            X_days=X_days,
            y_days=y_days,
            pending_idx=pending_idx,
            p_by_day=p_by_day,
            p_series=p_series,
            dp_vs_minK_series=dp_vs_minK_series,
            dp_vs_maxK_series=dp_vs_maxK_series,
            bsp_rows_daily=bsp_rows_daily,
            seen_bsp_daily=seen_bsp_daily,

            buy_pack=buy_pack,
            sell_pack=sell_pack,
            buy_ret_th_live=buy_ret_th_live,
            sell_ret_th_live=sell_ret_th_live,

            bsp_rows_5m=bsp_rows_5m,
            seen_keys_5m=seen_keys_5m,

            engine_state=engine.state_dict(),
            daily_log=daily_log,

            daily_i_last=daily_i_last,
            five_i_last=five_i_last,
            current_day=current_day,

            warmup_daily_bars=warm_daily[["timestamp","_open","_high","_low","_close","_vol"]].reset_index(drop=True),
            warmup_5m_bars=warm_5m[["timestamp","_open","_high","_low","_close","_vol"]].reset_index(drop=True),

            daily_chan_max_klines=daily_chan_max_klines,
            five_chan_max_klines=five_chan_max_klines,
        )

        save_joblib(save_checkpoint_path, bundle)
        if verbose:
            print(f"[CHECKPOINT] saved -> {save_checkpoint_path} @ {now_ts}")

    # ----------------------------
    # DAILY PHASE
    # ----------------------------
    for i in range(daily_i_start, len(df_day_feat)):
        r = df_day_feat.loc[i]
        ts = pd.to_datetime(r["timestamp"])
        day = ts.normalize()

        daily_chan.process_new_kline(build_klu(ts, r["_open"], r["_high"], r["_low"], r["_close"], r["_vol"]))

        new_bsp = extract_bsp_rows_from_chan(daily_chan)
        if new_bsp:
            for rr0 in new_bsp:
                rr = normalize_bsp_row(dict(rr0))
                rr.setdefault("timestamp", ts)
                key = (pd.to_datetime(rr["timestamp"]).strftime("%Y-%m-%d"), rr["direction"], rr.get("bsp_type", "?"))
                if key in seen_bsp_daily:
                    continue
                seen_bsp_daily.add(key)
                bsp_rows_daily.append(rr)

        ends = compute_chain_endpoints(bsp_rows_daily)
        regime = regime_for_day_from_ends(day, ends)
        base_dir_today = latest_bsp_dir_up_to(bsp_rows_daily, ts)

        p_val = np.nan
        if st.model is not None:
            bsp_hist = [b for b in bsp_rows_daily if pd.to_datetime(b["timestamp"]) <= ts]
            feat_i = make_daily_features_one_model(
                kline_row=r,
                bsp_hist_up_to_day=bsp_hist,
                p_val=0.0,
                dp_minK=0.0,
                dp_maxK=0.0,
                regime=regime,
                base_dir=base_dir_today,
                macro_cols=macro_cols,
            )
            p_val = float(predict_prob(st.model, [feat_i])[0])
            p_series[i] = p_val
            p_by_day[day] = p_val

        lb = int(dp_lookback)
        p_minK = np.nan
        p_maxK = np.nan
        if lb > 0 and i >= 1 and np.isfinite(p_val):
            start = max(0, i - lb)
            prev = pd.Series(p_series[start:i]).dropna()
            if len(prev) > 0:
                p_minK = float(prev.min())
                p_maxK = float(prev.max())

        dp_vs_minK = (p_val - p_minK) if (np.isfinite(p_val) and np.isfinite(p_minK)) else np.nan
        dp_vs_maxK = (p_val - p_maxK) if (np.isfinite(p_val) and np.isfinite(p_maxK)) else np.nan
        dp_vs_minK_series[i] = dp_vs_minK
        dp_vs_maxK_series[i] = dp_vs_maxK

        pending_idx.append(i)
        while pending_idx and i >= pending_idx[0] + int(N_confirm):
            j = pending_idx.pop(0)
            t0 = pd.to_datetime(df_day_feat.loc[j, "timestamp"])
            base_dir_j = latest_bsp_dir_up_to(bsp_rows_daily, t0)
            if base_dir_j not in ("buy", "sell"):
                continue

            y = label_confirm_extreme(df_day_feat, j, int(N_confirm), base_dir_j)
            if y is None:
                continue

            ends_j = compute_chain_endpoints([b for b in bsp_rows_daily if pd.to_datetime(b["timestamp"]) <= t0])
            regime_j = regime_for_day_from_ends(t0.normalize(), ends_j)

            bsp_hist_j = [b for b in bsp_rows_daily if pd.to_datetime(b["timestamp"]) <= t0]
            feat_j = make_daily_features_one_model(
                kline_row=df_day_feat.loc[j],
                bsp_hist_up_to_day=bsp_hist_j,
                p_val=float(p_series[j]) if np.isfinite(p_series[j]) else 0.0,
                dp_minK=float(dp_vs_minK_series[j]) if np.isfinite(dp_vs_minK_series[j]) else 0.0,
                dp_maxK=float(dp_vs_maxK_series[j]) if np.isfinite(dp_vs_maxK_series[j]) else 0.0,
                regime=regime_j,
                base_dir=base_dir_j,
                macro_cols=macro_cols,
            )

            X_days.append(feat_j)
            y_days.append(int(y))
            st.new_labels += 1

        maybe_train_daily()

    feat_imp_path = os.path.join(output_dir, "daily_lr_feature_importance.csv")
    if st.model is not None:
        try:
            imp_df = feature_importance_from_lr(st.model, top_n=120)
            imp_df.to_csv(feat_imp_path, index=False)
            if verbose:
                print(f"[SAVED] {feat_imp_path}")
        except Exception as e:
            if verbose:
                print(f"[IMP][DAILY-PROB] skipped: {e}")

    # ----------------------------
    # 5M PHASE
    # ----------------------------
    if verbose:
        print(f"[PHASE2/3] 5m feed begins at accumulation_start={acc_s.date()}, trading starts at sim_s={sim_s.date()}")

    def maybe_retrain_5m(day_ts: pd.Timestamp):
        nonlocal buy_pack, sell_pack, last_train_day
        if last_train_day is not None and (day_ts - last_train_day).days < int(retrain_every_days_5m):
            return
        dfb = pd.DataFrame(bsp_rows_5m)
        if dfb.empty:
            return
        dfb2 = prepare_ml_dataset(dfb)
        feat_cols = get_feature_columns(dfb2)
        bp, sp = train_models_two_sided_ret_only(dfb2, feat_cols, min_samples_total=min_samples_total_5m)
        if bp is not None:
            buy_pack = bp
        if sp is not None:
            sell_pack = sp
        if (bp is not None) or (sp is not None):
            last_train_day = day_ts
            if verbose:
                print(f"[TRAIN][5M] asof={day_ts.date()} feats={len(feat_cols)} buy={'YES' if bp else 'NO'} sell={'YES' if sp else 'NO'} rows={len(dfb2)}")

    def maybe_opt_thresholds(asof_bar_idx: int):
        nonlocal buy_ret_th_live, sell_ret_th_live
        if buy_pack is None or sell_pack is None:
            return
        out = choose_thresholds_global_realized(
            df_5m=df_5m_idx,
            bsp_rows=bsp_rows_5m,
            buy_pack=buy_pack,
            sell_pack=sell_pack,
            asof_bar_idx=asof_bar_idx,
            window_days=threshold_window_days,
            ret_grid=threshold_ret_grid,
            next_open_by_idx=next_open_by_idx,
            closes=closes,
            fee_pct=fee_pct,
            min_open_signals=threshold_min_open_signals,
        )
        if out is not None:
            buy_ret_th_live, sell_ret_th_live = out
            if verbose:
                print(f"[TH-OPT][GLOBAL] asof_bar={asof_bar_idx} buy_th={buy_ret_th_live:.2f} sell_th={sell_ret_th_live:.2f}")

    sim_start_ts = pd.to_datetime(sim_start)
    last_day_end_idx = None
    day_gate = "NO_P"
    must_trade_dir = None
    allow_buy = True
    allow_sell = True
    days_since_checkpoint = 0

    for i in range(five_i_start, len(df_5m_idx)):
        bar_ts = pd.to_datetime(df_5m_idx.loc[i, "timestamp"])
        bar_day = bar_ts.date()
        in_sim = (bar_ts >= sim_start_ts)

        if current_day is None:
            current_day = bar_day
            p_day = p_by_day.get(pd.to_datetime(bar_day), np.nan)
            day_gate = gate_from_p(p_day, p_sell_level, p_buy_level)

            allow_buy = True
            allow_sell = True
            must_trade_dir = None

            if day_gate == "FORCE_BUY":
                allow_sell = False
                if engine.pos == 0:
                    must_trade_dir = "buy"
            elif day_gate == "FORCE_SELL":
                allow_buy = False
                if engine.pos == 1:
                    must_trade_dir = "sell"

        if bar_day != current_day:
            prev_day = current_day
            prev_day_ts = pd.to_datetime(prev_day)

            label_bestlookahead_for_ready_points(
                bsp_rows=bsp_rows_5m,
                highs=highs, lows=lows, closes=closes,
                lookahead_days=lookahead_days_5m,
                bar_interval_minutes=bar_interval_minutes,
                current_bar_idx=i,
            )

            maybe_retrain_5m(prev_day_ts)
            if last_day_end_idx is not None:
                maybe_opt_thresholds(last_day_end_idx)

            day_close = day_close_map.get(prev_day)
            equity = engine.mark_to_market(day_close) if day_close is not None else engine.cash
            daily_log.append({
                "date": prev_day,
                "equity": equity,
                "cash": engine.cash,
                "pos": engine.pos,
                "buy_th": buy_ret_th_live,
                "sell_th": sell_ret_th_live,
                "p_day": float(p_by_day.get(pd.to_datetime(prev_day), np.nan)),
            })

            days_since_checkpoint += 1
            if save_checkpoint_path is not None and days_since_checkpoint >= int(checkpoint_every_n_days):
                save_checkpoint(
                    now_ts=pd.to_datetime(df_5m_idx.loc[last_day_end_idx, "timestamp"]),
                    daily_i_last=(len(df_day_feat) - 1),
                    five_i_last=int(last_day_end_idx),
                    current_day=prev_day,
                )
                days_since_checkpoint = 0

            current_day = bar_day
            p_day = p_by_day.get(pd.to_datetime(bar_day), np.nan)
            day_gate = gate_from_p(p_day, p_sell_level, p_buy_level)

            allow_buy = True
            allow_sell = True
            must_trade_dir = None

            if day_gate == "FORCE_BUY":
                allow_sell = False
                if engine.pos == 0:
                    must_trade_dir = "buy"
            elif day_gate == "FORCE_SELL":
                allow_buy = False
                if engine.pos == 1:
                    must_trade_dir = "sell"

        last_day_end_idx = i

        if in_sim:
            engine.maybe_execute_pending(next_open_by_idx)

        klu = build_klu(
            df_5m_idx.loc[i, "timestamp"],
            df_5m_idx.loc[i, "Open"], df_5m_idx.loc[i, "High"], df_5m_idx.loc[i, "Low"], df_5m_idx.loc[i, "Close"],
            df_5m_idx.loc[i, "Volume"],
        )
        feed_chan_one(chan_5m, klu)

        new_rows = extract_bsp_rows_from_chan(chan_5m)
        if not new_rows:
            continue

        for r0 in new_rows:
            r = dict(r0)
            r.setdefault("timestamp", str(bar_ts))
            r.setdefault("klu_idx", i)

            if "direction" not in r or r["direction"] is None:
                if r.get("is_buy", None) is not None:
                    r["direction"] = "buy" if bool(r["is_buy"]) else "sell"
                else:
                    r["direction"] = "buy"
            r["direction"] = str(r["direction"]).lower()
            if "bsp_type" in r and r["bsp_type"] is not None:
                r["bsp_type"] = str(r["bsp_type"]).lower()
            r.setdefault("best_return_pct", np.nan)

            k = (int(r.get("klu_idx", -1)), str(r.get("direction")), str(r.get("bsp_type")))
            if k in seen_keys_5m:
                continue
            seen_keys_5m.add(k)
            bsp_rows_5m.append(r)

            if not in_sim:
                continue

            d = str(r.get("direction", "buy")).lower()
            ki = int(r.get("klu_idx", i))

            if d == "buy" and not allow_buy:
                continue
            if d == "sell" and not allow_sell:
                continue
            if must_trade_dir is not None and d != must_trade_dir:
                continue

            if d == "buy" and engine.pos == 0 and buy_pack is not None:
                row_df = prepare_ml_dataset(pd.DataFrame([r]))
                for cc in buy_pack.feature_cols:
                    if cc not in row_df.columns:
                        row_df[cc] = 0.0
                pr = predict_ret(buy_pack, row_df)
                if pr >= float(buy_ret_th_live):
                    engine.place_order_for_next_bar(
                        side="buy",
                        seen_idx=ki,
                        reason=("FORCE_BUY->first acceptable 5m signal" if day_gate == "FORCE_BUY" else "5m BUY signal"),
                        meta={
                            "ts": str(bar_ts),
                            "p_day": float(p_by_day.get(pd.to_datetime(bar_day), np.nan)),
                            "pred": float(pr),
                            "th": float(buy_ret_th_live),
                            "gate": day_gate,
                        },
                    )
                    if must_trade_dir == "buy":
                        must_trade_dir = None

            elif d == "sell" and engine.pos == 1 and sell_pack is not None:
                row_df = prepare_ml_dataset(pd.DataFrame([r]))
                for cc in sell_pack.feature_cols:
                    if cc not in row_df.columns:
                        row_df[cc] = 0.0
                pr = predict_ret(sell_pack, row_df)
                if pr >= float(sell_ret_th_live):
                    engine.place_order_for_next_bar(
                        side="sell",
                        seen_idx=ki,
                        reason=("FORCE_SELL->first acceptable 5m signal" if day_gate == "FORCE_SELL" else "5m SELL signal"),
                        meta={
                            "ts": str(bar_ts),
                            "p_day": float(p_by_day.get(pd.to_datetime(bar_day), np.nan)),
                            "pred": float(pr),
                            "th": float(sell_ret_th_live),
                            "gate": day_gate,
                        },
                    )
                    if must_trade_dir == "sell":
                        must_trade_dir = None

    if current_day is not None:
        day_close = day_close_map.get(current_day)
        equity = engine.mark_to_market(day_close) if day_close is not None else engine.cash
        daily_log.append({
            "date": current_day,
            "equity": equity,
            "cash": engine.cash,
            "pos": engine.pos,
            "buy_th": buy_ret_th_live,
            "sell_th": sell_ret_th_live,
            "p_day": float(p_by_day.get(pd.to_datetime(current_day), np.nan)),
        })

    if save_checkpoint_path is not None and len(df_5m_idx) > 0:
        final_ts = pd.to_datetime(df_5m_idx.loc[len(df_5m_idx)-1, "timestamp"])
        save_checkpoint(
            now_ts=final_ts,
            daily_i_last=(len(df_day_feat) - 1),
            five_i_last=(len(df_5m_idx) - 1),
            current_day=current_day,
        )

    # ----------------------------
    # Save outputs
    # ----------------------------
    trades_df = pd.DataFrame(engine.trades)
    daily_df = pd.DataFrame(daily_log)
    if not daily_df.empty:
        if "date" in daily_df.columns:
            daily_df["date"] = pd.to_datetime(daily_df["date"])
            daily_df = daily_df.sort_values("date").reset_index(drop=True)

    trades_csv = os.path.join(output_dir, "trades.csv")
    daily_csv = os.path.join(output_dir, "daily_log.csv")
    trades_df.to_csv(trades_csv, index=False)
    daily_df.to_csv(daily_csv, index=False)

    out_eq = os.path.join(output_dir, "equity_vs_buyhold.png")
    out_px = os.path.join(output_dir, "price_with_trades.png")
    out_p  = os.path.join(output_dir, "p_day.png")

    plt.figure()
    if not daily_df.empty and "date" in daily_df.columns and "equity" in daily_df.columns:
        plt.plot(daily_df["date"], daily_df["equity"], label="Strategy Equity")
    if len(buy_hold) > 0:
        plt.plot(buy_hold.index, buy_hold.values, label="Buy&Hold")
    plt.legend()
    plt.title("Equity vs Buy&Hold")
    plt.xlabel("Date")
    plt.ylabel("Equity")
    plt.savefig(out_eq, dpi=150, bbox_inches="tight")
    plt.show()

    plt.figure()
    plt.plot(df_5m_idx["timestamp"], df_5m_idx["Close"], label="5m Close")
    if not trades_df.empty and "seen_idx" in trades_df.columns and "exec_px" in trades_df.columns:
        for _, tr in trades_df.iterrows():
            idx = int(tr["seen_idx"])
            if idx in df_5m_idx.index:
                t = pd.to_datetime(df_5m_idx.loc[idx, "timestamp"])
                px = float(tr["exec_px"])
                if tr.get("side", "") == "buy":
                    plt.scatter([t], [px], marker="^")
                else:
                    plt.scatter([t], [px], marker="v")
    plt.title("Price with Trade Markers")
    plt.xlabel("Time")
    plt.ylabel("Price")
    plt.savefig(out_px, dpi=150, bbox_inches="tight")
    plt.show()

    days_sorted = sorted(p_by_day.keys())
    if days_sorted:
        plt.figure()
        xs = pd.to_datetime(days_sorted)
        ys = [p_by_day[d] for d in days_sorted]
        plt.plot(xs, ys, label="p_day")
        plt.axhline(p_sell_level, linestyle="--", label="p_sell_level")
        plt.axhline(p_buy_level, linestyle="--", label="p_buy_level")
        plt.legend()
        plt.title("Daily Probability p_day")
        plt.xlabel("Date")
        plt.ylabel("Probability")
        plt.savefig(out_p, dpi=150, bbox_inches="tight")
        plt.show()

    if verbose:
        print(f"[SAVED] {trades_csv}")
        print(f"[SAVED] {daily_csv}")
        print(f"[SAVED] {out_eq}")
        print(f"[SAVED] {out_px}")
        if days_sorted:
            print(f"[SAVED] {out_p}")
        if st.model is not None:
            print(f"[SAVED] {feat_imp_path}")
        print(f"[TRADES] total={len(trades_df)}")
        if not trades_df.empty and "seen_idx" in trades_df.columns:
            min_seen_idx = int(trades_df["seen_idx"].min())
            if min_seen_idx in df_5m_idx.index:
                ts0 = pd.to_datetime(df_5m_idx.loc[min_seen_idx, "timestamp"])
                print(f"[TRADES] first_trade_ts={ts0} (sim_start={sim_start_ts})")
            else:
                print(f"[TRADES] first_trade_seen_idx={min_seen_idx} not found in current df_5m_idx index")

    return {
        "trades_df": trades_df,
        "daily_log_df": daily_df,
        "p_by_day": p_by_day,
        "buy_hold": buy_hold,
        "output_dir": output_dir,
        "checkpoint_path": save_checkpoint_path,
    }


# ============================================================
# RESUME WRAPPER
# ============================================================

def resume_from_checkpoint(
    checkpoint_path: str,
    daily_csv_path: str,
    k5m_csv_path: str,
    end_time: str | None = None,
    output_dir: str = "output_resumed_run",
    verbose: bool = True,
    plot_from_checkpoint: bool = True,
):
    if not os.path.exists(checkpoint_path):
        raise FileNotFoundError(f"Checkpoint not found: {checkpoint_path}")

    ckpt = load_checkpoint_bundle(checkpoint_path)

    code = ckpt.get("code", "QQQ")
    original_daily_chan_start = ckpt.get("original_daily_chan_start")
    original_accumulation_start = ckpt.get("original_accumulation_start")
    original_sim_start = ckpt.get("original_sim_start")
    original_end_time = ckpt.get("original_end_time")
    macro_files = ckpt.get("macro_files", None)

    if original_daily_chan_start is None or original_accumulation_start is None or original_sim_start is None:
        raise ValueError(
            "This checkpoint does not contain the original run window. "
            "It was likely created by the older checkpoint format."
        )

    final_end_time = end_time if end_time is not None else original_end_time

    checkpoint_plot_start = infer_checkpoint_plot_start_time(
        ckpt=ckpt,
        daily_csv_path=daily_csv_path,
        k5m_csv_path=k5m_csv_path,
        verbose=verbose,
    )

    if verbose:
        print(f"[RESUME WRAPPER] checkpoint={checkpoint_path}")
        print(f"[RESUME WRAPPER] code={code}")
        print(f"[RESUME WRAPPER] original_daily_chan_start={original_daily_chan_start}")
        print(f"[RESUME WRAPPER] original_accumulation_start={original_accumulation_start}")
        print(f"[RESUME WRAPPER] original_sim_start={original_sim_start}")
        print(f"[RESUME WRAPPER] original_end_time={original_end_time}")
        print(f"[RESUME WRAPPER] continue_until={final_end_time}")
        print(f"[RESUME WRAPPER] plot_from={checkpoint_plot_start}")
        print(f"[RESUME WRAPPER] output_dir={output_dir}")

    res = run_daily_prob_then_5m_xgb_gated(
        daily_csv_path=daily_csv_path,
        k5m_csv_path=k5m_csv_path,
        code=code,

        daily_chan_start=original_daily_chan_start,
        accumulation_start=original_accumulation_start,
        sim_start=original_sim_start,
        end_time=final_end_time,

        N_confirm=5,
        min_labeled_days_to_train=200,
        retrain_every_new_labels=25,
        dp_lookback=5,

        p_sell_level=0.30,
        p_buy_level=0.20,

        lookahead_days_5m=2.0,
        retrain_every_days_5m=5,
        min_samples_total_5m=300,

        threshold_window_days=2.0,
        threshold_ret_grid=None,
        threshold_min_open_signals=10,

        initial_capital=100000.0,
        fee_pct=0.0,

        daily_chan_max_klines=int(ckpt.get("daily_chan_max_klines", 500)),
        five_chan_max_klines=int(ckpt.get("five_chan_max_klines", 20000)),

        macro_files=macro_files,

        output_dir=output_dir,
        verbose=verbose,

        resume_from_checkpoint_path=checkpoint_path,
        save_checkpoint_path=checkpoint_path,
        checkpoint_every_n_days=5,
    )

    res["checkpoint_plot_start"] = checkpoint_plot_start

    if plot_from_checkpoint:
        plot_resumed_segment_from_checkpoint(
            res=res,
            checkpoint_start_time=checkpoint_plot_start,
            title_prefix=f"{code} resumed from checkpoint",
            output_dir=output_dir,
        )

    return res


# ============================================================
# EXAMPLE: FRESH RUN
# ============================================================
# res = run_daily_prob_then_5m_xgb_gated(
#     daily_csv_path="DataAPI/data/QQQ_DAY.csv",
#     k5m_csv_path="DataAPI/data/QQQ_5M.csv",
#     code="QQQ",

#     daily_chan_start="2014-06-01",
#     accumulation_start="2016-10-01",
#     sim_start="2019-01-01",
#     end_time="2026-12-31",

#     N_confirm=5,
#     min_labeled_days_to_train=200,
#     retrain_every_new_labels=25,
#     dp_lookback=5,

#     p_sell_level=0.30,
#     p_buy_level=0.20,

#     lookahead_days_5m=2.0,
#     retrain_every_days_5m=5,
#     min_samples_total_5m=300,

#     threshold_window_days=2.0,
#     threshold_ret_grid=None,
#     threshold_min_open_signals=10,

#     initial_capital=100000.0,
#     fee_pct=0.0,

#     daily_chan_max_klines=500,
#     five_chan_max_klines=500,

#     macro_files={
#         "vix_":   "VIX.csv",
#         "dxy_":   "DXY.csv",
#         "us5y_":  "US5Y.csv",
#         "us10y_": "US10Y.csv",
#         "us30y_": "US30Y.csv",
#         "xau_":   "XAU.csv",
#         "nyxbt_": "NYXBT.csv",
#         "10y2ys_": "10Y2YS.csv",
#         "us2y_": "US2Y.csv",
#         #spgsci_": "SPGSCI.csv",
#     },

#     output_dir="output_dailyprob_gated_5m_xgb_QQQ_macro_us2",
#     verbose=True,

#     save_checkpoint_path="checkpoints/QQQ_macro_US2_checkpoint.joblib",
#     checkpoint_every_n_days=5,
# )

# ============================================================
# EXAMPLE: RESUME
# ============================================================
# res = resume_from_checkpoint(
#     checkpoint_path="checkpoints/QQQ_macro_checkpoint.joblib",
#     daily_csv_path="DataAPI/data/QQQ_DAY.csv",
#     k5m_csv_path="DataAPI/data/QQQ_5M.csv",
#     end_time="2026-12-31",
#     output_dir="output_resumed_QQQ_macro",
#     verbose=True,
#     plot_from_checkpoint=True,
# )
#
# display(res["trades_df"].tail(50))
# display(res["daily_log_df"].tail(20))
# print("checkpoint_plot_start =", res.get("checkpoint_plot_start"))

# %%
res = run_daily_prob_then_5m_xgb_gated(
    daily_csv_path="DataAPI/data/SPY_DAY.csv",
    k5m_csv_path="DataAPI/data/SPY_5M.csv",
    code="SPY",

    daily_chan_start="2020-06-01",
    accumulation_start="2022-10-01",
    sim_start="2024-01-01",
    end_time="2026-12-31",

    N_confirm=5,
    min_labeled_days_to_train=200,
    retrain_every_new_labels=25,
    dp_lookback=5,

    p_sell_level=0.30,
    p_buy_level=0.20,

    lookahead_days_5m=2.0,
    retrain_every_days_5m=5,
    min_samples_total_5m=300,

    threshold_window_days=2.0,
    threshold_ret_grid=None,
    threshold_min_open_signals=10,

    initial_capital=100000.0,
    fee_pct=0.0,

    daily_chan_max_klines=500,
    five_chan_max_klines=500,

    macro_files={
        "vix_":   "VIX.csv",
        "dxy_":   "DXY.csv",
        "us5y_":  "US5Y.csv",
        "us10y_": "US10Y.csv",
        "us30y_": "US30Y.csv",
        "xau_":   "XAU.csv",
        "nyxbt_": "NYXBT.csv",
        "10y2ys_": "10Y2YS.csv",
        "us2y_": "US2Y.csv",
        #spgsci_": "SPGSCI.csv",
    },

    output_dir="output_dailyprob_gated_5m_xgb_SPY_macro_us2",
    verbose=True,

    save_checkpoint_path="checkpoints/SPY_macro_US2_checkpoint.joblib",
    checkpoint_every_n_days=5,
)
# Out:
# [TRAIN][DAILY-PROB] n=200 pos=25 (12.50%)
# [TRAIN][DAILY-PROB] n=225 pos=39 (17.33%)
# [TRAIN][DAILY-PROB] n=250 pos=39 (15.60%)
# [TRAIN][DAILY-PROB] n=275 pos=44 (16.00%)
# [TRAIN][DAILY-PROB] n=300 pos=51 (17.00%)
# [TRAIN][DAILY-PROB] n=325 pos=61 (18.77%)
# [TRAIN][DAILY-PROB] n=350 pos=67 (19.14%)
# [TRAIN][DAILY-PROB] n=375 pos=69 (18.40%)
# [TRAIN][DAILY-PROB] n=400 pos=79 (19.75%)
# [TRAIN][DAILY-PROB] n=425 pos=87 (20.47%)
# [TRAIN][DAILY-PROB] n=450 pos=91 (20.22%)
# [TRAIN][DAILY-PROB] n=475 pos=100 (21.05%)
# [TRAIN][DAILY-PROB] n=500 pos=109 (21.80%)
# [TRAIN][DAILY-PROB] n=525 pos=113 (21.52%)
# [TRAIN][DAILY-PROB] n=550 pos=120 (21.82%)
# [TRAIN][DAILY-PROB] n=575 pos=127 (22.09%)
# [TRAIN][DAILY-PROB] n=600 pos=132 (22.00%)
# [TRAIN][DAILY-PROB] n=625 pos=137 (21.92%)
# [TRAIN][DAILY-PROB] n=650 pos=142 (21.85%)
# [TRAIN][DAILY-PROB] n=675 pos=151 (22.37%)
# [TRAIN][DAILY-PROB] n=700 pos=160 (22.86%)
# [TRAIN][DAILY-PROB] n=725 pos=166 (22.90%)
# [TRAIN][DAILY-PROB] n=750 pos=178 (23.73%)
# [TRAIN][DAILY-PROB] n=775 pos=178 (22.97%)
# [TRAIN][DAILY-PROB] n=800 pos=182 (22.75%)
# [TRAIN][DAILY-PROB] n=825 pos=183 (22.18%)
# [TRAIN][DAILY-PROB] n=850 pos=185 (21.76%)
# [TRAIN][DAILY-PROB] n=875 pos=193 (22.06%)
# [TRAIN][DAILY-PROB] n=900 pos=199 (22.11%)
# [TRAIN][DAILY-PROB] n=925 pos=202 (21.84%)
# [TRAIN][DAILY-PROB] n=950 pos=207 (21.79%)
# [TRAIN][DAILY-PROB] n=975 pos=209 (21.44%)
# [TRAIN][DAILY-PROB] n=1000 pos=217 (21.70%)
# [TRAIN][DAILY-PROB] n=1025 pos=221 (21.56%)
# [TRAIN][DAILY-PROB] n=1050 pos=228 (21.71%)
# [TRAIN][DAILY-PROB] n=1075 pos=232 (21.58%)
# [TRAIN][DAILY-PROB] n=1100 pos=243 (22.09%)
# [TRAIN][DAILY-PROB] n=1125 pos=251 (22.31%)
# [TRAIN][DAILY-PROB] n=1150 pos=253 (22.00%)
# [TRAIN][DAILY-PROB] n=1175 pos=255 (21.70%)
# [TRAIN][DAILY-PROB] n=1200 pos=258 (21.50%)
# [TRAIN][DAILY-PROB] n=1225 pos=268 (21.88%)
# [TRAIN][DAILY-PROB] n=1250 pos=279 (22.32%)
# [TRAIN][DAILY-PROB] n=1275 pos=287 (22.51%)
# [TRAIN][DAILY-PROB] n=1300 pos=293 (22.54%)
# [TRAIN][DAILY-PROB] n=1325 pos=302 (22.79%)
# [SAVED] output_dailyprob_gated_5m_xgb_SPY_macro_us2\daily_lr_feature_importance.csv
# [PHASE2/3] 5m feed begins at accumulation_start=2022-10-01, trading starts at sim_s=2024-01-01
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2022-10-07 19:55:00
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2022-10-14 19:55:00
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2022-10-21 19:55:00
# [TRAIN][5M] asof=2022-10-26 feats=69 buy=YES sell=YES rows=784
# [TH-OPT][GLOBAL] asof_bar=3452 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=3644 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=3834 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2022-10-28 19:55:00
# [TRAIN][5M] asof=2022-10-31 feats=69 buy=YES sell=YES rows=883
# [TH-OPT][GLOBAL] asof_bar=4026 buy_th=1.60 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=4218 buy_th=1.65 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=4406 buy_th=2.05 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=4598 buy_th=1.70 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=4785 buy_th=-0.50 sell_th=2.25
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2022-11-04 19:55:00
# [TRAIN][5M] asof=2022-11-07 feats=69 buy=YES sell=YES rows=1095
# [TH-OPT][GLOBAL] asof_bar=4977 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=5168 buy_th=2.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=5360 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=5552 buy_th=2.15 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2022-11-11 19:55:00
# [TRAIN][5M] asof=2022-11-14 feats=69 buy=YES sell=YES rows=1300
# [TH-OPT][GLOBAL] asof_bar=5934 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=6126 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=6318 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=6510 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=6702 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2022-11-18 19:55:00
# [TRAIN][5M] asof=2022-11-21 feats=69 buy=YES sell=YES rows=1502
# [TH-OPT][GLOBAL] asof_bar=6894 buy_th=0.65 sell_th=1.70
# [TH-OPT][GLOBAL] asof_bar=7086 buy_th=0.40 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=7278 buy_th=0.50 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=7429 buy_th=0.85 sell_th=-0.50
# [TRAIN][5M] asof=2022-11-28 feats=69 buy=YES sell=YES rows=1683
# [TH-OPT][GLOBAL] asof_bar=7621 buy_th=2.10 sell_th=1.05
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2022-11-28 19:55:00
# [TH-OPT][GLOBAL] asof_bar=7813 buy_th=2.10 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=8005 buy_th=2.15 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=8196 buy_th=1.95 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=8387 buy_th=1.75 sell_th=1.50
# [TRAIN][5M] asof=2022-12-05 feats=69 buy=YES sell=YES rows=1823
# [TH-OPT][GLOBAL] asof_bar=8579 buy_th=2.40 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2022-12-05 19:55:00
# [TH-OPT][GLOBAL] asof_bar=8771 buy_th=2.40 sell_th=0.40
# [TH-OPT][GLOBAL] asof_bar=8963 buy_th=2.45 sell_th=0.40
# [TH-OPT][GLOBAL] asof_bar=9155 buy_th=-0.50 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=9342 buy_th=-0.50 sell_th=0.70
# [TRAIN][5M] asof=2022-12-12 feats=69 buy=YES sell=YES rows=1981
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2022-12-12 19:55:00
# [TH-OPT][GLOBAL] asof_bar=10107 buy_th=2.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=10297 buy_th=2.00 sell_th=-0.50
# [TRAIN][5M] asof=2022-12-19 feats=69 buy=YES sell=YES rows=2154
# [TH-OPT][GLOBAL] asof_bar=10489 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2022-12-19 19:55:00
# [TH-OPT][GLOBAL] asof_bar=10680 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=10871 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=11062 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=11248 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2022-12-27 feats=69 buy=YES sell=YES rows=2372
# [TH-OPT][GLOBAL] asof_bar=11439 buy_th=1.95 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2022-12-27 19:55:00
# [TH-OPT][GLOBAL] asof_bar=11630 buy_th=2.30 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=11822 buy_th=2.50 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=12009 buy_th=2.40 sell_th=1.90
# [TRAIN][5M] asof=2023-01-03 feats=69 buy=YES sell=YES rows=2499
# [TH-OPT][GLOBAL] asof_bar=12200 buy_th=1.95 sell_th=1.40
# [TH-OPT][GLOBAL] asof_bar=12391 buy_th=1.90 sell_th=2.25
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-01-04 19:55:00
# [TH-OPT][GLOBAL] asof_bar=12583 buy_th=1.30 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=12774 buy_th=2.00 sell_th=0.85
# [TRAIN][5M] asof=2023-01-09 feats=69 buy=YES sell=YES rows=2651
# [TH-OPT][GLOBAL] asof_bar=12965 buy_th=2.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=13156 buy_th=1.60 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=13348 buy_th=1.30 sell_th=2.30
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-01-11 19:55:00
# [TH-OPT][GLOBAL] asof_bar=13729 buy_th=-0.50 sell_th=2.15
# [TRAIN][5M] asof=2023-01-17 feats=69 buy=YES sell=YES rows=2899
# [TH-OPT][GLOBAL] asof_bar=13920 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=14111 buy_th=2.40 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=14303 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-01-19 19:55:00
# [TH-OPT][GLOBAL] asof_bar=14495 buy_th=-0.50 sell_th=0.95
# [TRAIN][5M] asof=2023-01-23 feats=69 buy=YES sell=YES rows=3078
# [TH-OPT][GLOBAL] asof_bar=14879 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=15070 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=15262 buy_th=-0.50 sell_th=2.35
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-01-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=15448 buy_th=0.75 sell_th=-0.50
# [TRAIN][5M] asof=2023-01-30 feats=69 buy=YES sell=YES rows=3278
# [TH-OPT][GLOBAL] asof_bar=15640 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=15832 buy_th=2.50 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=16024 buy_th=-0.50 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=16216 buy_th=-0.50 sell_th=1.95
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-02-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=16407 buy_th=-0.50 sell_th=1.20
# [TRAIN][5M] asof=2023-02-06 feats=69 buy=YES sell=YES rows=3449
# [TH-OPT][GLOBAL] asof_bar=16599 buy_th=-0.50 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=16790 buy_th=-0.50 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=16980 buy_th=2.25 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=17171 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-02-09 19:55:00
# [TH-OPT][GLOBAL] asof_bar=17358 buy_th=-0.50 sell_th=1.45
# [TRAIN][5M] asof=2023-02-13 feats=69 buy=YES sell=YES rows=3646
# [TH-OPT][GLOBAL] asof_bar=17926 buy_th=-0.50 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=18116 buy_th=1.45 sell_th=2.15
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-02-16 19:55:00
# [TH-OPT][GLOBAL] asof_bar=18305 buy_th=2.35 sell_th=1.25
# [TRAIN][5M] asof=2023-02-21 feats=69 buy=YES sell=YES rows=3820
# [TH-OPT][GLOBAL] asof_bar=18688 buy_th=-0.50 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=18879 buy_th=-0.50 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=19066 buy_th=-0.50 sell_th=2.10
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-02-24 19:55:00
# [TRAIN][5M] asof=2023-02-27 feats=69 buy=YES sell=YES rows=4008
# [TH-OPT][GLOBAL] asof_bar=19255 buy_th=0.90 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=19446 buy_th=0.85 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=19638 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=19829 buy_th=2.45 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=20018 buy_th=-0.50 sell_th=1.60
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-03-03 19:55:00
# [TRAIN][5M] asof=2023-03-06 feats=69 buy=YES sell=YES rows=4218
# [TH-OPT][GLOBAL] asof_bar=20210 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=20402 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=20593 buy_th=-0.50 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=20784 buy_th=-0.50 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=20976 buy_th=-0.50 sell_th=1.20
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-03-10 19:55:00
# [TRAIN][5M] asof=2023-03-13 feats=69 buy=YES sell=YES rows=4373
# [TH-OPT][GLOBAL] asof_bar=21360 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=21552 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=21744 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=21935 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-03-17 19:55:00
# [TRAIN][5M] asof=2023-03-20 feats=69 buy=YES sell=YES rows=4561
# [TH-OPT][GLOBAL] asof_bar=22127 buy_th=0.95 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=22319 buy_th=-0.50 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=22511 buy_th=1.90 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=22703 buy_th=1.45 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=22894 buy_th=1.70 sell_th=2.35
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-03-24 19:55:00
# [TRAIN][5M] asof=2023-03-27 feats=69 buy=YES sell=YES rows=4721
# [TH-OPT][GLOBAL] asof_bar=23278 buy_th=1.05 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=23470 buy_th=0.95 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=23661 buy_th=0.75 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-03-31 19:55:00
# [TRAIN][5M] asof=2023-04-03 feats=69 buy=YES sell=YES rows=4933
# [TH-OPT][GLOBAL] asof_bar=24416 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=24607 buy_th=2.45 sell_th=0.90
# [TRAIN][5M] asof=2023-04-10 feats=69 buy=YES sell=YES rows=5097
# [TH-OPT][GLOBAL] asof_bar=24795 buy_th=2.40 sell_th=1.35
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-04-10 19:55:00
# [TH-OPT][GLOBAL] asof_bar=24985 buy_th=2.40 sell_th=1.40
# [TH-OPT][GLOBAL] asof_bar=25174 buy_th=2.50 sell_th=1.25
# [TH-OPT][GLOBAL] asof_bar=25366 buy_th=1.95 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=25554 buy_th=2.15 sell_th=1.85
# [TRAIN][5M] asof=2023-04-17 feats=69 buy=YES sell=YES rows=5292
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-04-17 19:55:00
# [TH-OPT][GLOBAL] asof_bar=26125 buy_th=1.70 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=26315 buy_th=1.55 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=26494 buy_th=1.45 sell_th=1.80
# [TRAIN][5M] asof=2023-04-24 feats=69 buy=YES sell=YES rows=5473
# [TH-OPT][GLOBAL] asof_bar=26682 buy_th=1.45 sell_th=1.10
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-04-24 19:55:00
# [TH-OPT][GLOBAL] asof_bar=26874 buy_th=1.35 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=27065 buy_th=1.40 sell_th=0.30
# [TH-OPT][GLOBAL] asof_bar=27257 buy_th=2.10 sell_th=1.20
# [TRAIN][5M] asof=2023-05-01 feats=69 buy=YES sell=YES rows=5645
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-05-01 19:55:00
# [TH-OPT][GLOBAL] asof_bar=27830 buy_th=2.35 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=28016 buy_th=2.40 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=28208 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=28397 buy_th=1.25 sell_th=2.00
# [TRAIN][5M] asof=2023-05-08 feats=69 buy=YES sell=YES rows=5880
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-05-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=28772 buy_th=0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=28962 buy_th=1.35 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=29150 buy_th=1.55 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=29338 buy_th=1.65 sell_th=2.35
# [TRAIN][5M] asof=2023-05-15 feats=69 buy=YES sell=YES rows=6055
# [TH-OPT][GLOBAL] asof_bar=29528 buy_th=0.80 sell_th=1.30
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-05-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=29717 buy_th=0.95 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=29906 buy_th=0.95 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=30097 buy_th=0.55 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=30285 buy_th=-0.50 sell_th=2.10
# [TRAIN][5M] asof=2023-05-22 feats=69 buy=YES sell=YES rows=6213
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-05-22 19:55:00
# [TH-OPT][GLOBAL] asof_bar=30663 buy_th=1.75 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=30855 buy_th=2.30 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=31047 buy_th=2.30 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=31231 buy_th=-0.50 sell_th=0.90
# [TRAIN][5M] asof=2023-05-30 feats=69 buy=YES sell=YES rows=6403
# [TH-OPT][GLOBAL] asof_bar=31420 buy_th=1.85 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-05-30 19:55:00
# [TH-OPT][GLOBAL] asof_bar=31612 buy_th=1.95 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=31801 buy_th=2.05 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=31990 buy_th=2.05 sell_th=1.95
# [TRAIN][5M] asof=2023-06-05 feats=69 buy=YES sell=YES rows=6551
# [TH-OPT][GLOBAL] asof_bar=32367 buy_th=-0.50 sell_th=1.05
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-06-06 19:55:00
# [TH-OPT][GLOBAL] asof_bar=32554 buy_th=1.55 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=32739 buy_th=1.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=32925 buy_th=1.70 sell_th=1.40
# [TRAIN][5M] asof=2023-06-12 feats=69 buy=YES sell=YES rows=6740
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-06-13 19:55:00
# [TH-OPT][GLOBAL] asof_bar=33498 buy_th=-0.50 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=33690 buy_th=-0.50 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=33877 buy_th=1.20 sell_th=1.00
# [TRAIN][5M] asof=2023-06-20 feats=69 buy=YES sell=YES rows=6907
# [TH-OPT][GLOBAL] asof_bar=34252 buy_th=2.10 sell_th=0.80
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-06-21 19:55:00
# [TH-OPT][GLOBAL] asof_bar=34442 buy_th=2.15 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=34630 buy_th=-0.50 sell_th=0.50
# [TRAIN][5M] asof=2023-06-26 feats=69 buy=YES sell=YES rows=7094
# [TH-OPT][GLOBAL] asof_bar=34821 buy_th=-0.50 sell_th=0.60
# [TH-OPT][GLOBAL] asof_bar=35011 buy_th=-0.50 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=35202 buy_th=0.55 sell_th=1.10
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-06-28 19:55:00
# [TH-OPT][GLOBAL] asof_bar=35393 buy_th=-0.50 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=35580 buy_th=0.50 sell_th=1.85
# [TRAIN][5M] asof=2023-07-03 feats=69 buy=YES sell=YES rows=7322
# [TH-OPT][GLOBAL] asof_bar=35920 buy_th=1.65 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=36109 buy_th=1.55 sell_th=1.30
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-07-06 19:55:00
# [TH-OPT][GLOBAL] asof_bar=36297 buy_th=1.60 sell_th=1.35
# [TRAIN][5M] asof=2023-07-10 feats=69 buy=YES sell=YES rows=7491
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-07-13 19:55:00
# [TH-OPT][GLOBAL] asof_bar=37242 buy_th=-0.50 sell_th=1.45
# [TRAIN][5M] asof=2023-07-17 feats=69 buy=YES sell=YES rows=7722
# [TH-OPT][GLOBAL] asof_bar=37429 buy_th=0.90 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=37618 buy_th=1.10 sell_th=0.50
# [TH-OPT][GLOBAL] asof_bar=37810 buy_th=1.15 sell_th=0.75
# [TH-OPT][GLOBAL] asof_bar=38000 buy_th=1.35 sell_th=0.20
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-07-20 19:55:00
# [TH-OPT][GLOBAL] asof_bar=38177 buy_th=1.35 sell_th=0.30
# [TRAIN][5M] asof=2023-07-24 feats=69 buy=YES sell=YES rows=7922
# [TH-OPT][GLOBAL] asof_bar=38552 buy_th=1.35 sell_th=0.55
# [TH-OPT][GLOBAL] asof_bar=38741 buy_th=1.10 sell_th=0.40
# [TH-OPT][GLOBAL] asof_bar=38932 buy_th=1.60 sell_th=0.95
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-07-27 19:55:00
# [TH-OPT][GLOBAL] asof_bar=39119 buy_th=1.50 sell_th=0.80
# [TRAIN][5M] asof=2023-07-31 feats=69 buy=YES sell=YES rows=8152
# [TH-OPT][GLOBAL] asof_bar=39310 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=39501 buy_th=1.35 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=39693 buy_th=1.60 sell_th=0.45
# [TH-OPT][GLOBAL] asof_bar=39885 buy_th=1.45 sell_th=0.25
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-08-03 19:55:00
# [TH-OPT][GLOBAL] asof_bar=40072 buy_th=1.65 sell_th=0.90
# [TRAIN][5M] asof=2023-08-07 feats=69 buy=YES sell=YES rows=8354
# [TH-OPT][GLOBAL] asof_bar=40453 buy_th=1.15 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=40643 buy_th=1.30 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=40835 buy_th=1.35 sell_th=1.35
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-08-10 19:55:00
# [TH-OPT][GLOBAL] asof_bar=41020 buy_th=0.95 sell_th=1.35
# [TRAIN][5M] asof=2023-08-14 feats=69 buy=YES sell=YES rows=8581
# [TH-OPT][GLOBAL] asof_bar=41401 buy_th=1.10 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=41592 buy_th=1.60 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=41784 buy_th=2.45 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-08-17 19:55:00
# [TH-OPT][GLOBAL] asof_bar=41973 buy_th=2.25 sell_th=0.60
# [TRAIN][5M] asof=2023-08-21 feats=69 buy=YES sell=YES rows=8779
# [TH-OPT][GLOBAL] asof_bar=42352 buy_th=-0.50 sell_th=2.20
# [TH-OPT][GLOBAL] asof_bar=42542 buy_th=1.25 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=42734 buy_th=1.05 sell_th=2.35
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-08-24 19:55:00
# [TH-OPT][GLOBAL] asof_bar=42920 buy_th=1.00 sell_th=2.35
# [TRAIN][5M] asof=2023-08-28 feats=69 buy=YES sell=YES rows=8953
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-08-31 19:55:00
# [TH-OPT][GLOBAL] asof_bar=43856 buy_th=1.15 sell_th=2.20
# [TRAIN][5M] asof=2023-09-05 feats=69 buy=YES sell=YES rows=9161
# [TH-OPT][GLOBAL] asof_bar=44044 buy_th=1.40 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=44226 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=44415 buy_th=1.95 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=44601 buy_th=1.50 sell_th=0.75
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-09-08 19:55:00
# [TRAIN][5M] asof=2023-09-11 feats=69 buy=YES sell=YES rows=9300
# [TH-OPT][GLOBAL] asof_bar=44972 buy_th=0.95 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=45159 buy_th=0.85 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=45346 buy_th=0.50 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=45536 buy_th=1.25 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-09-15 19:55:00
# [TRAIN][5M] asof=2023-09-18 feats=69 buy=YES sell=YES rows=9462
# [TH-OPT][GLOBAL] asof_bar=45906 buy_th=1.40 sell_th=0.75
# [TH-OPT][GLOBAL] asof_bar=46097 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=46289 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=46477 buy_th=-0.50 sell_th=0.55
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-09-22 19:55:00
# [TRAIN][5M] asof=2023-09-25 feats=69 buy=YES sell=YES rows=9717
# [TH-OPT][GLOBAL] asof_bar=46667 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=46858 buy_th=1.60 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=47050 buy_th=2.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=47242 buy_th=1.95 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=47427 buy_th=2.00 sell_th=1.80
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-09-29 19:55:00
# [TRAIN][5M] asof=2023-10-02 feats=69 buy=YES sell=YES rows=9894
# [TH-OPT][GLOBAL] asof_bar=47811 buy_th=1.65 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=48001 buy_th=1.85 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=48190 buy_th=1.70 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=48376 buy_th=-0.50 sell_th=2.25
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-10-06 19:55:00
# [TRAIN][5M] asof=2023-10-09 feats=69 buy=YES sell=YES rows=10082
# [TH-OPT][GLOBAL] asof_bar=48951 buy_th=0.85 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=49141 buy_th=0.90 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=49332 buy_th=0.85 sell_th=2.35
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-10-13 19:55:00
# [TRAIN][5M] asof=2023-10-16 feats=69 buy=YES sell=YES rows=10314
# [TH-OPT][GLOBAL] asof_bar=49708 buy_th=1.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=49900 buy_th=1.45 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-10-20 19:55:00
# [TRAIN][5M] asof=2023-10-23 feats=69 buy=YES sell=YES rows=10496
# [TH-OPT][GLOBAL] asof_bar=50475 buy_th=2.50 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=50667 buy_th=2.30 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=50858 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=51048 buy_th=-0.50 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=51239 buy_th=2.45 sell_th=1.80
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-10-27 19:55:00
# [TRAIN][5M] asof=2023-10-30 feats=69 buy=YES sell=YES rows=10682
# [TH-OPT][GLOBAL] asof_bar=51427 buy_th=0.95 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=51619 buy_th=0.95 sell_th=2.35
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-11-03 19:55:00
# [TRAIN][5M] asof=2023-11-06 feats=69 buy=YES sell=YES rows=10849
# [TH-OPT][GLOBAL] asof_bar=52374 buy_th=1.35 sell_th=1.40
# [TH-OPT][GLOBAL] asof_bar=52561 buy_th=1.60 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=52745 buy_th=-0.50 sell_th=1.70
# [TH-OPT][GLOBAL] asof_bar=52935 buy_th=2.20 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=53122 buy_th=-0.50 sell_th=2.05
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-11-10 19:55:00
# [TRAIN][5M] asof=2023-11-13 feats=69 buy=YES sell=YES rows=11016
# [TH-OPT][GLOBAL] asof_bar=53494 buy_th=-0.50 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=53681 buy_th=0.50 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=53869 buy_th=0.40 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=54054 buy_th=0.40 sell_th=1.55
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-11-17 19:55:00
# [TRAIN][5M] asof=2023-11-20 feats=69 buy=YES sell=YES rows=11239
# [TH-OPT][GLOBAL] asof_bar=54240 buy_th=1.10 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=54427 buy_th=1.10 sell_th=0.65
# [TRAIN][5M] asof=2023-11-27 feats=69 buy=YES sell=YES rows=11323
# [TH-OPT][GLOBAL] asof_bar=54943 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-11-27 19:55:00
# [TH-OPT][GLOBAL] asof_bar=55124 buy_th=1.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=55309 buy_th=1.25 sell_th=1.40
# [TH-OPT][GLOBAL] asof_bar=55499 buy_th=1.00 sell_th=0.60
# [TH-OPT][GLOBAL] asof_bar=55685 buy_th=0.95 sell_th=1.40
# [TRAIN][5M] asof=2023-12-04 feats=69 buy=YES sell=YES rows=11486
# [TH-OPT][GLOBAL] asof_bar=55873 buy_th=1.65 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-12-04 19:55:00
# [TH-OPT][GLOBAL] asof_bar=56060 buy_th=1.40 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=56246 buy_th=1.20 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=56431 buy_th=1.10 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=56618 buy_th=-0.50 sell_th=0.95
# [TRAIN][5M] asof=2023-12-11 feats=69 buy=YES sell=YES rows=11701
# [TH-OPT][GLOBAL] asof_bar=56804 buy_th=-0.50 sell_th=1.25
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-12-11 19:55:00
# [TH-OPT][GLOBAL] asof_bar=56992 buy_th=-0.50 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=57366 buy_th=-0.50 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=57555 buy_th=1.15 sell_th=-0.50
# [TRAIN][5M] asof=2023-12-18 feats=69 buy=YES sell=YES rows=11854
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-12-18 19:55:00
# [TH-OPT][GLOBAL] asof_bar=58112 buy_th=2.40 sell_th=0.30
# [TH-OPT][GLOBAL] asof_bar=58302 buy_th=2.45 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=58479 buy_th=2.30 sell_th=-0.50
# [TRAIN][5M] asof=2023-12-26 feats=69 buy=YES sell=YES rows=12027
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2023-12-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=58834 buy_th=0.85 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=59016 buy_th=-0.50 sell_th=1.40
# [TH-OPT][GLOBAL] asof_bar=59194 buy_th=0.95 sell_th=-0.50
# [TRAIN][5M] asof=2024-01-02 feats=69 buy=YES sell=YES rows=12156
# [TH-OPT][GLOBAL] asof_bar=59575 buy_th=2.10 sell_th=0.35
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-01-03 19:55:00
# [TH-OPT][GLOBAL] asof_bar=59765 buy_th=1.95 sell_th=0.35
# [TH-OPT][GLOBAL] asof_bar=59951 buy_th=2.25 sell_th=-0.50
# [TRAIN][5M] asof=2024-01-08 feats=69 buy=YES sell=YES rows=12306
# [TH-OPT][GLOBAL] asof_bar=60140 buy_th=-0.50 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=60329 buy_th=-0.50 sell_th=1.35
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-01-10 19:55:00
# [TH-OPT][GLOBAL] asof_bar=60703 buy_th=0.60 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=60893 buy_th=1.00 sell_th=1.80
# [TRAIN][5M] asof=2024-01-16 feats=69 buy=YES sell=YES rows=12477
# [TH-OPT][GLOBAL] asof_bar=61080 buy_th=1.20 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=61267 buy_th=1.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=61458 buy_th=1.00 sell_th=0.65
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-01-18 19:55:00
# [TRAIN][5M] asof=2024-01-22 feats=69 buy=YES sell=YES rows=12577
# [TH-OPT][GLOBAL] asof_bar=62019 buy_th=1.25 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=62205 buy_th=1.70 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=62387 buy_th=1.65 sell_th=1.30
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-01-25 19:55:00
# [TH-OPT][GLOBAL] asof_bar=62571 buy_th=1.50 sell_th=1.35
# [TRAIN][5M] asof=2024-01-29 feats=69 buy=YES sell=YES rows=12866
# [TH-OPT][GLOBAL] asof_bar=62949 buy_th=-0.50 sell_th=0.70
# [TH-OPT][GLOBAL] asof_bar=63141 buy_th=1.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=63333 buy_th=1.20 sell_th=0.85
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-02-01 19:55:00
# [TH-OPT][GLOBAL] asof_bar=63522 buy_th=1.15 sell_th=1.05
# [TRAIN][5M] asof=2024-02-05 feats=69 buy=YES sell=YES rows=13019
# [TH-OPT][GLOBAL] asof_bar=63896 buy_th=1.15 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=64272 buy_th=-0.50 sell_th=1.35
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-02-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=64461 buy_th=-0.50 sell_th=1.55
# [TRAIN][5M] asof=2024-02-12 feats=69 buy=YES sell=YES rows=13165
# [TH-OPT][GLOBAL] asof_bar=64642 buy_th=1.30 sell_th=0.35
# [TH-OPT][GLOBAL] asof_bar=64834 buy_th=1.45 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=65026 buy_th=1.45 sell_th=1.00
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-02-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=65402 buy_th=1.30 sell_th=0.75
# [TRAIN][5M] asof=2024-02-20 feats=69 buy=YES sell=YES rows=13372
# [TH-OPT][GLOBAL] asof_bar=65592 buy_th=2.25 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=65781 buy_th=1.80 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=65973 buy_th=1.80 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=66158 buy_th=0.75 sell_th=2.15
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-02-23 19:55:00
# [TRAIN][5M] asof=2024-02-26 feats=69 buy=YES sell=YES rows=13494
# [TH-OPT][GLOBAL] asof_bar=66533 buy_th=2.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=66721 buy_th=1.60 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=66912 buy_th=2.00 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=67098 buy_th=2.00 sell_th=1.85
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-03-01 19:55:00
# [TRAIN][5M] asof=2024-03-04 feats=69 buy=YES sell=YES rows=13698
# [TH-OPT][GLOBAL] asof_bar=67284 buy_th=0.60 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=67475 buy_th=1.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=67661 buy_th=1.50 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=67848 buy_th=0.65 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=68036 buy_th=0.70 sell_th=1.20
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-03-08 19:55:00
# [TRAIN][5M] asof=2024-03-11 feats=69 buy=YES sell=YES rows=13911
# [TH-OPT][GLOBAL] asof_bar=68224 buy_th=1.90 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=68413 buy_th=1.60 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=68602 buy_th=1.20 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=68789 buy_th=1.30 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=68978 buy_th=1.60 sell_th=0.80
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-03-15 19:55:00
# [TRAIN][5M] asof=2024-03-18 feats=69 buy=YES sell=YES rows=14091
# [TH-OPT][GLOBAL] asof_bar=69349 buy_th=1.65 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=69536 buy_th=1.60 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=69724 buy_th=0.75 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=69908 buy_th=1.10 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-03-22 19:55:00
# [TRAIN][5M] asof=2024-03-25 feats=69 buy=YES sell=YES rows=14239
# [TH-OPT][GLOBAL] asof_bar=70090 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=70279 buy_th=1.90 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=70470 buy_th=1.75 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=70656 buy_th=1.65 sell_th=0.95
# [TRAIN][5M] asof=2024-04-01 feats=69 buy=YES sell=YES rows=14325
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-04-01 19:55:00
# [TH-OPT][GLOBAL] asof_bar=71027 buy_th=1.55 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=71215 buy_th=1.50 sell_th=0.60
# [TH-OPT][GLOBAL] asof_bar=71405 buy_th=1.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=71589 buy_th=1.60 sell_th=-0.50
# [TRAIN][5M] asof=2024-04-08 feats=69 buy=YES sell=YES rows=14472
# [TH-OPT][GLOBAL] asof_bar=71772 buy_th=0.75 sell_th=1.00
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-04-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=71959 buy_th=1.20 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=72145 buy_th=-0.50 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=72335 buy_th=1.25 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=72526 buy_th=1.40 sell_th=-0.50
# [TRAIN][5M] asof=2024-04-15 feats=69 buy=YES sell=YES rows=14640
# [TH-OPT][GLOBAL] asof_bar=72718 buy_th=2.35 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-04-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=72909 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=73100 buy_th=2.05 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=73291 buy_th=2.15 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=73482 buy_th=2.25 sell_th=-0.50
# [TRAIN][5M] asof=2024-04-22 feats=69 buy=YES sell=YES rows=14768
# [TH-OPT][GLOBAL] asof_bar=73673 buy_th=1.85 sell_th=2.40
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-04-22 19:55:00
# [TH-OPT][GLOBAL] asof_bar=73864 buy_th=0.80 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=74055 buy_th=0.95 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=74247 buy_th=1.50 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=74430 buy_th=0.75 sell_th=2.15
# [TRAIN][5M] asof=2024-04-29 feats=69 buy=YES sell=YES rows=14952
# [TH-OPT][GLOBAL] asof_bar=74617 buy_th=1.05 sell_th=1.70
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-04-29 19:55:00
# [TH-OPT][GLOBAL] asof_bar=74804 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=74991 buy_th=1.70 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=75181 buy_th=1.60 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=75371 buy_th=1.40 sell_th=2.20
# [TRAIN][5M] asof=2024-05-06 feats=69 buy=YES sell=YES rows=15135
# [TH-OPT][GLOBAL] asof_bar=75562 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-05-06 19:55:00
# [TH-OPT][GLOBAL] asof_bar=75748 buy_th=1.30 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=75934 buy_th=-0.50 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=76113 buy_th=1.35 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=76303 buy_th=1.30 sell_th=2.50
# [TRAIN][5M] asof=2024-05-13 feats=69 buy=YES sell=YES rows=15344
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-05-13 19:55:00
# [TH-OPT][GLOBAL] asof_bar=76663 buy_th=1.50 sell_th=0.75
# [TH-OPT][GLOBAL] asof_bar=77039 buy_th=-0.50 sell_th=0.70
# [TH-OPT][GLOBAL] asof_bar=77216 buy_th=1.30 sell_th=-0.50
# [TRAIN][5M] asof=2024-05-20 feats=69 buy=YES sell=YES rows=15495
# [TH-OPT][GLOBAL] asof_bar=77395 buy_th=1.05 sell_th=1.15
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-05-20 19:55:00
# [TH-OPT][GLOBAL] asof_bar=77575 buy_th=0.85 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=77756 buy_th=1.70 sell_th=0.20
# [TH-OPT][GLOBAL] asof_bar=77942 buy_th=1.80 sell_th=0.55
# [TH-OPT][GLOBAL] asof_bar=78121 buy_th=1.50 sell_th=0.30
# [TRAIN][5M] asof=2024-05-28 feats=69 buy=YES sell=YES rows=15694
# [TH-OPT][GLOBAL] asof_bar=78302 buy_th=1.05 sell_th=0.75
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-05-28 19:55:00
# [TH-OPT][GLOBAL] asof_bar=78494 buy_th=1.45 sell_th=0.75
# [TH-OPT][GLOBAL] asof_bar=78682 buy_th=1.20 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=78871 buy_th=1.95 sell_th=1.30
# [TRAIN][5M] asof=2024-06-03 feats=69 buy=YES sell=YES rows=15838
# [TH-OPT][GLOBAL] asof_bar=79237 buy_th=0.80 sell_th=1.95
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-06-04 19:55:00
# [TH-OPT][GLOBAL] asof_bar=79427 buy_th=0.60 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=79605 buy_th=0.80 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=79789 buy_th=0.40 sell_th=1.35
# [TRAIN][5M] asof=2024-06-10 feats=69 buy=YES sell=YES rows=16074
# [TH-OPT][GLOBAL] asof_bar=79976 buy_th=1.35 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=80163 buy_th=2.05 sell_th=1.00
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-06-11 19:55:00
# [TH-OPT][GLOBAL] asof_bar=80340 buy_th=1.95 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=80527 buy_th=1.25 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=80716 buy_th=1.25 sell_th=0.65
# [TRAIN][5M] asof=2024-06-17 feats=69 buy=YES sell=YES rows=16284
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-06-18 19:55:00
# [TH-OPT][GLOBAL] asof_bar=81266 buy_th=1.85 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=81450 buy_th=2.05 sell_th=-0.50
# [TRAIN][5M] asof=2024-06-24 feats=69 buy=YES sell=YES rows=16405
# [TH-OPT][GLOBAL] asof_bar=81637 buy_th=1.60 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=81825 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=82010 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-06-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=82197 buy_th=2.10 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=82384 buy_th=1.95 sell_th=0.50
# [TRAIN][5M] asof=2024-07-01 feats=69 buy=YES sell=YES rows=16607
# [TH-OPT][GLOBAL] asof_bar=82571 buy_th=0.90 sell_th=0.25
# [TH-OPT][GLOBAL] asof_bar=82760 buy_th=0.90 sell_th=0.20
# [TH-OPT][GLOBAL] asof_bar=82911 buy_th=1.05 sell_th=1.10
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-07-03 16:55:00
# [TH-OPT][GLOBAL] asof_bar=83082 buy_th=-0.50 sell_th=1.00
# [TRAIN][5M] asof=2024-07-08 feats=69 buy=YES sell=YES rows=16736
# [TH-OPT][GLOBAL] asof_bar=83447 buy_th=1.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=83633 buy_th=1.65 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=83819 buy_th=1.25 sell_th=0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-07-11 19:55:00
# [TH-OPT][GLOBAL] asof_bar=84002 buy_th=1.00 sell_th=0.60
# [TRAIN][5M] asof=2024-07-15 feats=69 buy=YES sell=YES rows=16914
# [TH-OPT][GLOBAL] asof_bar=84191 buy_th=1.25 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=84374 buy_th=1.40 sell_th=0.55
# [TH-OPT][GLOBAL] asof_bar=84565 buy_th=-0.50 sell_th=0.40
# [TH-OPT][GLOBAL] asof_bar=84755 buy_th=1.35 sell_th=0.10
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-07-18 19:55:00
# [TH-OPT][GLOBAL] asof_bar=84944 buy_th=1.40 sell_th=0.25
# [TRAIN][5M] asof=2024-07-22 feats=69 buy=YES sell=YES rows=17139
# [TH-OPT][GLOBAL] asof_bar=85324 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=85516 buy_th=1.85 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=85708 buy_th=1.65 sell_th=1.10
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-07-25 19:55:00
# [TH-OPT][GLOBAL] asof_bar=85898 buy_th=1.45 sell_th=1.45
# [TRAIN][5M] asof=2024-07-29 feats=69 buy=YES sell=YES rows=17359
# [TH-OPT][GLOBAL] asof_bar=86078 buy_th=1.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=86266 buy_th=1.00 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=86649 buy_th=1.10 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-08-01 19:55:00
# [TH-OPT][GLOBAL] asof_bar=86839 buy_th=1.30 sell_th=-0.50
# [TRAIN][5M] asof=2024-08-05 feats=69 buy=YES sell=YES rows=17575
# [TH-OPT][GLOBAL] asof_bar=87032 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=87224 buy_th=2.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=87416 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=87607 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-08-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=87794 buy_th=2.00 sell_th=-0.50
# [TRAIN][5M] asof=2024-08-12 feats=69 buy=YES sell=YES rows=17787
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-08-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=88721 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2024-08-19 feats=69 buy=YES sell=YES rows=17992
# [TH-OPT][GLOBAL] asof_bar=89470 buy_th=2.20 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-08-22 19:55:00
# [TH-OPT][GLOBAL] asof_bar=89658 buy_th=2.30 sell_th=-0.50
# [TRAIN][5M] asof=2024-08-26 feats=69 buy=YES sell=YES rows=18176
# [TH-OPT][GLOBAL] asof_bar=89844 buy_th=2.05 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=90028 buy_th=1.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=90219 buy_th=1.80 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=90410 buy_th=1.60 sell_th=1.35
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-08-29 19:55:00
# [TH-OPT][GLOBAL] asof_bar=90592 buy_th=1.45 sell_th=1.15
# [TRAIN][5M] asof=2024-09-03 feats=69 buy=YES sell=YES rows=18366
# [TH-OPT][GLOBAL] asof_bar=91160 buy_th=1.75 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=91350 buy_th=1.50 sell_th=1.05
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-09-06 19:55:00
# [TRAIN][5M] asof=2024-09-09 feats=69 buy=YES sell=YES rows=18499
# [TH-OPT][GLOBAL] asof_bar=91541 buy_th=1.10 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=91727 buy_th=1.25 sell_th=1.25
# [TH-OPT][GLOBAL] asof_bar=91917 buy_th=1.40 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=92105 buy_th=2.00 sell_th=1.90
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-09-13 19:55:00
# [TRAIN][5M] asof=2024-09-16 feats=69 buy=YES sell=YES rows=18656
# [TH-OPT][GLOBAL] asof_bar=92477 buy_th=0.90 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=92666 buy_th=1.45 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=92852 buy_th=1.15 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=93044 buy_th=0.85 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=93235 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-09-20 19:55:00
# [TRAIN][5M] asof=2024-09-23 feats=69 buy=YES sell=YES rows=18849
# [TH-OPT][GLOBAL] asof_bar=93420 buy_th=-0.50 sell_th=0.20
# [TH-OPT][GLOBAL] asof_bar=93607 buy_th=-0.50 sell_th=0.20
# [TH-OPT][GLOBAL] asof_bar=93789 buy_th=1.55 sell_th=0.75
# [TH-OPT][GLOBAL] asof_bar=93980 buy_th=-0.50 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=94164 buy_th=1.70 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-09-27 19:55:00
# [TRAIN][5M] asof=2024-09-30 feats=69 buy=YES sell=YES rows=19027
# [TH-OPT][GLOBAL] asof_bar=94354 buy_th=1.25 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=94544 buy_th=1.10 sell_th=0.70
# [TH-OPT][GLOBAL] asof_bar=94735 buy_th=1.05 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=94926 buy_th=0.95 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=95111 buy_th=-0.50 sell_th=0.65
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-10-04 19:55:00
# [TRAIN][5M] asof=2024-10-07 feats=69 buy=YES sell=YES rows=19195
# [TH-OPT][GLOBAL] asof_bar=95303 buy_th=1.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=95493 buy_th=1.25 sell_th=0.55
# [TH-OPT][GLOBAL] asof_bar=95681 buy_th=-0.50 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=95870 buy_th=0.85 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=96054 buy_th=0.95 sell_th=0.80
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-10-11 19:55:00
# [TRAIN][5M] asof=2024-10-14 feats=69 buy=YES sell=YES rows=19383
# [TH-OPT][GLOBAL] asof_bar=96436 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=96625 buy_th=1.40 sell_th=0.15
# [TH-OPT][GLOBAL] asof_bar=96812 buy_th=1.25 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=96994 buy_th=-0.50 sell_th=0.20
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-10-18 19:55:00
# [TRAIN][5M] asof=2024-10-21 feats=69 buy=YES sell=YES rows=19577
# [TH-OPT][GLOBAL] asof_bar=97176 buy_th=1.70 sell_th=0.55
# [TH-OPT][GLOBAL] asof_bar=97363 buy_th=0.90 sell_th=0.60
# [TH-OPT][GLOBAL] asof_bar=97554 buy_th=1.35 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=97742 buy_th=1.45 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=97926 buy_th=1.80 sell_th=2.00
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-10-25 19:55:00
# [TRAIN][5M] asof=2024-10-28 feats=69 buy=YES sell=YES rows=19804
# [TH-OPT][GLOBAL] asof_bar=98298 buy_th=0.95 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=98489 buy_th=0.95 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=98680 buy_th=1.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=98869 buy_th=1.55 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-11-01 19:55:00
# [TRAIN][5M] asof=2024-11-04 feats=69 buy=YES sell=YES rows=19956
# [TH-OPT][GLOBAL] asof_bar=99241 buy_th=1.05 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=99433 buy_th=0.70 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=99623 buy_th=0.20 sell_th=1.70
# [TH-OPT][GLOBAL] asof_bar=99812 buy_th=0.25 sell_th=2.05
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-11-08 19:55:00
# [TRAIN][5M] asof=2024-11-11 feats=69 buy=YES sell=YES rows=20146
# [TH-OPT][GLOBAL] asof_bar=100002 buy_th=-0.50 sell_th=0.70
# [TH-OPT][GLOBAL] asof_bar=100194 buy_th=-0.50 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=100382 buy_th=-0.50 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=100574 buy_th=1.85 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=100764 buy_th=2.10 sell_th=1.10
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-11-15 19:55:00
# [TRAIN][5M] asof=2024-11-18 feats=69 buy=YES sell=YES rows=20333
# [TH-OPT][GLOBAL] asof_bar=100953 buy_th=1.05 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=101145 buy_th=-0.50 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=101334 buy_th=-0.50 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=101525 buy_th=1.50 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=101717 buy_th=0.70 sell_th=1.45
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-11-22 19:55:00
# [TRAIN][5M] asof=2024-11-25 feats=69 buy=YES sell=YES rows=20541
# [TH-OPT][GLOBAL] asof_bar=101908 buy_th=1.40 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=102098 buy_th=1.30 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=102280 buy_th=-0.50 sell_th=2.35
# [TRAIN][5M] asof=2024-12-02 feats=69 buy=YES sell=YES rows=20651
# [TH-OPT][GLOBAL] asof_bar=102617 buy_th=-0.50 sell_th=1.05
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-12-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=102804 buy_th=0.70 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=102991 buy_th=-0.50 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=103172 buy_th=-0.50 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=103354 buy_th=0.75 sell_th=-0.50
# [TRAIN][5M] asof=2024-12-09 feats=69 buy=YES sell=YES rows=20826
# [TH-OPT][GLOBAL] asof_bar=103541 buy_th=0.80 sell_th=0.40
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-12-09 19:55:00
# [TH-OPT][GLOBAL] asof_bar=103719 buy_th=0.95 sell_th=0.35
# [TH-OPT][GLOBAL] asof_bar=103903 buy_th=1.05 sell_th=1.10
# [TRAIN][5M] asof=2024-12-16 feats=69 buy=YES sell=YES rows=20964
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-12-16 19:55:00
# [TH-OPT][GLOBAL] asof_bar=104648 buy_th=1.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=104836 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=105028 buy_th=2.10 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=105220 buy_th=1.70 sell_th=-0.50
# [TRAIN][5M] asof=2024-12-23 feats=69 buy=YES sell=YES rows=21182
# [TH-OPT][GLOBAL] asof_bar=105408 buy_th=1.10 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-12-23 19:55:00
# [TH-OPT][GLOBAL] asof_bar=105551 buy_th=1.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=105922 buy_th=0.90 sell_th=-0.50
# [TRAIN][5M] asof=2024-12-30 feats=69 buy=YES sell=YES rows=21292
# [TH-OPT][GLOBAL] asof_bar=106294 buy_th=2.40 sell_th=1.35
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2024-12-31 19:55:00
# [TRAIN][5M] asof=2025-01-06 feats=69 buy=YES sell=YES rows=21401
# [TH-OPT][GLOBAL] asof_bar=107048 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=107238 buy_th=1.65 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-01-08 19:55:00
# [TRAIN][5M] asof=2025-01-13 feats=69 buy=YES sell=YES rows=21563
# [TH-OPT][GLOBAL] asof_bar=107619 buy_th=-0.50 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=107805 buy_th=-0.50 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=108187 buy_th=1.15 sell_th=2.40
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-01-16 19:55:00
# [TH-OPT][GLOBAL] asof_bar=108377 buy_th=-0.50 sell_th=1.85
# [TRAIN][5M] asof=2025-01-21 feats=69 buy=YES sell=YES rows=21789
# [TH-OPT][GLOBAL] asof_bar=108756 buy_th=1.10 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=108945 buy_th=0.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=109123 buy_th=0.55 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-01-24 19:55:00
# [TRAIN][5M] asof=2025-01-27 feats=69 buy=YES sell=YES rows=21940
# [TH-OPT][GLOBAL] asof_bar=109315 buy_th=1.85 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=109507 buy_th=2.35 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=109697 buy_th=0.85 sell_th=0.35
# [TH-OPT][GLOBAL] asof_bar=109885 buy_th=1.05 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=110071 buy_th=1.05 sell_th=2.20
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-01-31 19:55:00
# [TRAIN][5M] asof=2025-02-03 feats=69 buy=YES sell=YES rows=22147
# [TH-OPT][GLOBAL] asof_bar=110263 buy_th=1.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=110454 buy_th=1.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=110642 buy_th=1.75 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=110831 buy_th=0.95 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=111011 buy_th=1.00 sell_th=2.40
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-02-07 19:55:00
# [TRAIN][5M] asof=2025-02-10 feats=69 buy=YES sell=YES rows=22341
# [TH-OPT][GLOBAL] asof_bar=111196 buy_th=0.90 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=111382 buy_th=0.95 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=111564 buy_th=-0.50 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=111933 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-02-14 19:55:00
# ...
# [TRAIN][5M] asof=2025-06-02 feats=69 buy=YES sell=YES rows=25172
# [TH-OPT][GLOBAL] asof_bar=125860 buy_th=1.00 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=126051 buy_th=1.10 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=126243 buy_th=1.30 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-06-04 19:55:00
# [TH-OPT][GLOBAL] asof_bar=126434 buy_th=0.45 sell_th=2.35
# [TRAIN][5M] asof=2025-06-09 feats=69 buy=YES sell=YES rows=25358
# [TH-OPT][GLOBAL] asof_bar=126814 buy_th=1.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=127006 buy_th=1.10 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=127198 buy_th=1.00 sell_th=1.55
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-06-11 19:55:00
# [TH-OPT][GLOBAL] asof_bar=127390 buy_th=0.95 sell_th=0.60
# [TH-OPT][GLOBAL] asof_bar=127582 buy_th=1.25 sell_th=1.60
# [TRAIN][5M] asof=2025-06-16 feats=69 buy=YES sell=YES rows=25520
# [TH-OPT][GLOBAL] asof_bar=127774 buy_th=1.30 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=127967 buy_th=1.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=128159 buy_th=1.00 sell_th=1.75
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-06-18 19:55:00
# [TH-OPT][GLOBAL] asof_bar=128350 buy_th=1.15 sell_th=2.05
# [TRAIN][5M] asof=2025-06-23 feats=69 buy=YES sell=YES rows=25629
# [TH-OPT][GLOBAL] asof_bar=128542 buy_th=1.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=128731 buy_th=-0.50 sell_th=2.45
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-06-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=129305 buy_th=-0.50 sell_th=2.35
# [TRAIN][5M] asof=2025-06-30 feats=69 buy=YES sell=YES rows=25767
# [TH-OPT][GLOBAL] asof_bar=129688 buy_th=0.55 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=129880 buy_th=-0.50 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=130033 buy_th=1.00 sell_th=1.40
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-07-03 16:55:00
# [TRAIN][5M] asof=2025-07-07 feats=69 buy=YES sell=YES rows=25884
# [TH-OPT][GLOBAL] asof_bar=130602 buy_th=1.35 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=130794 buy_th=1.40 sell_th=0.75
# [TH-OPT][GLOBAL] asof_bar=130982 buy_th=0.80 sell_th=0.70
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-07-11 19:55:00
# [TRAIN][5M] asof=2025-07-14 feats=69 buy=YES sell=YES rows=26080
# [TH-OPT][GLOBAL] asof_bar=131173 buy_th=1.00 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=131365 buy_th=1.15 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=131555 buy_th=1.30 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=131744 buy_th=1.10 sell_th=1.25
# [TH-OPT][GLOBAL] asof_bar=131932 buy_th=0.85 sell_th=1.05
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-07-18 19:55:00
# [TRAIN][5M] asof=2025-07-21 feats=69 buy=YES sell=YES rows=26302
# [TH-OPT][GLOBAL] asof_bar=132312 buy_th=1.15 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=132504 buy_th=1.20 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=132875 buy_th=0.95 sell_th=1.35
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-07-25 19:55:00
# [TRAIN][5M] asof=2025-07-28 feats=69 buy=YES sell=YES rows=26453
# [TH-OPT][GLOBAL] asof_bar=133257 buy_th=0.95 sell_th=0.60
# [TH-OPT][GLOBAL] asof_bar=133447 buy_th=1.60 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=133639 buy_th=1.90 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=133831 buy_th=2.10 sell_th=0.30
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-08-01 19:55:00
# [TRAIN][5M] asof=2025-08-04 feats=69 buy=YES sell=YES rows=26640
# [TH-OPT][GLOBAL] asof_bar=134215 buy_th=1.45 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=134407 buy_th=1.35 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=134599 buy_th=1.30 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=134790 buy_th=0.75 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-08-08 19:55:00
# [TRAIN][5M] asof=2025-08-11 feats=69 buy=YES sell=YES rows=26823
# [TH-OPT][GLOBAL] asof_bar=134981 buy_th=0.95 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=135173 buy_th=1.00 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=135364 buy_th=0.95 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=135552 buy_th=1.15 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=135742 buy_th=1.20 sell_th=1.75
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-08-15 19:55:00
# [TRAIN][5M] asof=2025-08-18 feats=69 buy=YES sell=YES rows=26995
# [TH-OPT][GLOBAL] asof_bar=135930 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=136120 buy_th=0.90 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=136311 buy_th=0.90 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=136499 buy_th=0.95 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=136686 buy_th=1.50 sell_th=2.25
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-08-22 19:55:00
# [TRAIN][5M] asof=2025-08-25 feats=69 buy=YES sell=YES rows=27233
# [TH-OPT][GLOBAL] asof_bar=136877 buy_th=0.40 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=137065 buy_th=0.85 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=137633 buy_th=0.80 sell_th=1.95
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-08-29 19:55:00
# [TRAIN][5M] asof=2025-09-02 feats=69 buy=YES sell=YES rows=27384
# [TH-OPT][GLOBAL] asof_bar=137823 buy_th=1.80 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=138015 buy_th=1.95 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=138204 buy_th=-0.50 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=138394 buy_th=0.65 sell_th=1.70
# [TRAIN][5M] asof=2025-09-08 feats=69 buy=YES sell=YES rows=27551
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-09-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=138961 buy_th=1.70 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=139150 buy_th=1.70 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=139339 buy_th=1.10 sell_th=2.00
# [TRAIN][5M] asof=2025-09-15 feats=69 buy=YES sell=YES rows=27737
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-09-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=139718 buy_th=1.35 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=139908 buy_th=1.85 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=140100 buy_th=1.45 sell_th=0.35
# [TH-OPT][GLOBAL] asof_bar=140288 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2025-09-22 feats=69 buy=YES sell=YES rows=27915
# [TH-OPT][GLOBAL] asof_bar=140476 buy_th=-0.50 sell_th=2.15
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-09-22 19:55:00
# [TH-OPT][GLOBAL] asof_bar=140663 buy_th=-0.50 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=140851 buy_th=1.40 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=141039 buy_th=1.70 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=141224 buy_th=1.75 sell_th=1.95
# [TRAIN][5M] asof=2025-09-29 feats=69 buy=YES sell=YES rows=28086
# [TH-OPT][GLOBAL] asof_bar=141417 buy_th=0.95 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-09-29 20:00:00
# [TH-OPT][GLOBAL] asof_bar=141606 buy_th=-0.50 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=141798 buy_th=0.75 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=141988 buy_th=-0.50 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=142171 buy_th=0.60 sell_th=1.65
# [TRAIN][5M] asof=2025-10-06 feats=69 buy=YES sell=YES rows=28278
# [TH-OPT][GLOBAL] asof_bar=142360 buy_th=-0.50 sell_th=1.05
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-10-06 19:55:00
# [TH-OPT][GLOBAL] asof_bar=142552 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=142928 buy_th=-0.50 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=143120 buy_th=1.65 sell_th=-0.50
# [TRAIN][5M] asof=2025-10-13 feats=69 buy=YES sell=YES rows=28455
# [TH-OPT][GLOBAL] asof_bar=143312 buy_th=1.20 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-10-13 19:55:00
# [TH-OPT][GLOBAL] asof_bar=143503 buy_th=1.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=143695 buy_th=1.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=143887 buy_th=0.65 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=144077 buy_th=1.50 sell_th=-0.50
# [TRAIN][5M] asof=2025-10-20 feats=69 buy=YES sell=YES rows=28625
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-10-20 19:55:00
# [TH-OPT][GLOBAL] asof_bar=144647 buy_th=1.15 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=144838 buy_th=1.20 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=145025 buy_th=0.50 sell_th=-0.50
# [TRAIN][5M] asof=2025-10-27 feats=69 buy=YES sell=YES rows=28807
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-10-27 19:55:00
# [TH-OPT][GLOBAL] asof_bar=145601 buy_th=1.10 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=145793 buy_th=1.05 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=145980 buy_th=2.15 sell_th=2.40
# [TRAIN][5M] asof=2025-11-03 feats=69 buy=YES sell=YES rows=28952
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-11-03 19:55:00
# [TH-OPT][GLOBAL] asof_bar=146365 buy_th=1.35 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=146557 buy_th=1.00 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=146749 buy_th=0.65 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=146942 buy_th=2.30 sell_th=2.00
# [TRAIN][5M] asof=2025-11-10 feats=69 buy=YES sell=YES rows=29184
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-11-10 19:55:00
# [TH-OPT][GLOBAL] asof_bar=147326 buy_th=-0.50 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=147518 buy_th=0.65 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=147710 buy_th=1.55 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=147902 buy_th=1.95 sell_th=-0.50
# [TRAIN][5M] asof=2025-11-17 feats=69 buy=YES sell=YES rows=29394
# [TH-OPT][GLOBAL] asof_bar=148094 buy_th=2.50 sell_th=2.15
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-11-17 19:55:00
# [TH-OPT][GLOBAL] asof_bar=148286 buy_th=2.50 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=148478 buy_th=-0.50 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=148670 buy_th=-0.50 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=148862 buy_th=-0.50 sell_th=1.70
# [TRAIN][5M] asof=2025-11-24 feats=69 buy=YES sell=YES rows=29610
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-11-24 19:55:00
# [TH-OPT][GLOBAL] asof_bar=149245 buy_th=1.40 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=149437 buy_th=1.45 sell_th=-0.50
# [TRAIN][5M] asof=2025-12-01 feats=69 buy=YES sell=YES rows=29724
# [TH-OPT][GLOBAL] asof_bar=149785 buy_th=1.45 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=149977 buy_th=1.35 sell_th=1.55
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-12-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=150361 buy_th=-0.50 sell_th=1.70
# [TRAIN][5M] asof=2025-12-08 feats=69 buy=YES sell=YES rows=29877
# [TH-OPT][GLOBAL] asof_bar=150745 buy_th=0.90 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=150937 buy_th=1.15 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-12-09 19:55:00
# [TH-OPT][GLOBAL] asof_bar=151129 buy_th=1.10 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=151321 buy_th=0.90 sell_th=1.70
# [TH-OPT][GLOBAL] asof_bar=151513 buy_th=1.00 sell_th=1.10
# [TRAIN][5M] asof=2025-12-15 feats=69 buy=YES sell=YES rows=30076
# [TH-OPT][GLOBAL] asof_bar=151897 buy_th=1.25 sell_th=0.80
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-12-16 19:55:00
# [TH-OPT][GLOBAL] asof_bar=152089 buy_th=1.25 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=152281 buy_th=1.80 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=152473 buy_th=-0.50 sell_th=2.30
# [TRAIN][5M] asof=2025-12-22 feats=69 buy=YES sell=YES rows=30261
# [TH-OPT][GLOBAL] asof_bar=152665 buy_th=0.65 sell_th=1.70
# [TH-OPT][GLOBAL] asof_bar=152855 buy_th=0.55 sell_th=1.70
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-12-23 19:55:00
# [TH-OPT][GLOBAL] asof_bar=153011 buy_th=0.85 sell_th=2.20
# [TRAIN][5M] asof=2025-12-29 feats=69 buy=YES sell=YES rows=30412
# [TH-OPT][GLOBAL] asof_bar=153392 buy_th=1.15 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=153584 buy_th=1.15 sell_th=0.70
# [TH-OPT][GLOBAL] asof_bar=153775 buy_th=1.10 sell_th=0.75
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2025-12-31 19:55:00
# [TRAIN][5M] asof=2026-01-05 feats=69 buy=YES sell=YES rows=30576
# [TH-OPT][GLOBAL] asof_bar=154351 buy_th=0.60 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=154543 buy_th=-0.50 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=154735 buy_th=0.65 sell_th=0.85
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2026-01-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=154927 buy_th=1.00 sell_th=1.00
# [TRAIN][5M] asof=2026-01-12 feats=69 buy=YES sell=YES rows=30814
# [TH-OPT][GLOBAL] asof_bar=155119 buy_th=0.85 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=155311 buy_th=-0.50 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=155503 buy_th=1.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=155695 buy_th=1.30 sell_th=2.40
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2026-01-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=155887 buy_th=1.05 sell_th=-0.50
# [TRAIN][5M] asof=2026-01-20 feats=69 buy=YES sell=YES rows=30973
# [TH-OPT][GLOBAL] asof_bar=156079 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=156271 buy_th=1.05 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=156463 buy_th=0.75 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=156654 buy_th=0.80 sell_th=1.30
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2026-01-23 19:55:00
# [TRAIN][5M] asof=2026-01-26 feats=69 buy=YES sell=YES rows=31144
# [TH-OPT][GLOBAL] asof_bar=157229 buy_th=1.05 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=157421 buy_th=1.20 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=157612 buy_th=1.70 sell_th=2.25
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2026-01-30 19:55:00
# [TRAIN][5M] asof=2026-02-02 feats=69 buy=YES sell=YES rows=31400
# [TH-OPT][GLOBAL] asof_bar=157804 buy_th=0.45 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=157996 buy_th=1.70 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=158188 buy_th=1.65 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=158380 buy_th=2.10 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=158572 buy_th=1.80 sell_th=2.00
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2026-02-06 19:55:00
# [TRAIN][5M] asof=2026-02-09 feats=69 buy=YES sell=YES rows=31642
# [TH-OPT][GLOBAL] asof_bar=158764 buy_th=1.00 sell_th=2.20
# [TH-OPT][GLOBAL] asof_bar=158956 buy_th=0.50 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=159148 buy_th=0.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=159340 buy_th=1.55 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=159532 buy_th=1.40 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2026-02-13 19:55:00
# [TRAIN][5M] asof=2026-02-17 feats=69 buy=YES sell=YES rows=31829
# [TH-OPT][GLOBAL] asof_bar=159724 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=159916 buy_th=1.90 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=160108 buy_th=2.05 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=160300 buy_th=1.90 sell_th=2.15
# [TRAIN][5M] asof=2026-02-23 feats=69 buy=YES sell=YES rows=31951
# [TH-OPT][GLOBAL] asof_bar=160492 buy_th=1.10 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2026-02-23 19:55:00
# [TH-OPT][GLOBAL] asof_bar=160684 buy_th=1.35 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=161067 buy_th=1.15 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=161259 buy_th=1.05 sell_th=0.80
# [TRAIN][5M] asof=2026-03-02 feats=69 buy=YES sell=YES rows=32158
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2026-03-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=161643 buy_th=-0.50 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=161835 buy_th=2.05 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=162027 buy_th=1.55 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=162219 buy_th=1.85 sell_th=1.20
# [TRAIN][5M] asof=2026-03-09 feats=69 buy=YES sell=YES rows=32372
# [TH-OPT][GLOBAL] asof_bar=162411 buy_th=2.30 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2026-03-09 19:55:00
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2026-03-10 19:55:00
# [SAVED] output_dailyprob_gated_5m_xgb_SPY_macro_us2\trades.csv
# [SAVED] output_dailyprob_gated_5m_xgb_SPY_macro_us2\daily_log.csv
# [SAVED] output_dailyprob_gated_5m_xgb_SPY_macro_us2\equity_vs_buyhold.png
# [SAVED] output_dailyprob_gated_5m_xgb_SPY_macro_us2\price_with_trades.png
# [SAVED] output_dailyprob_gated_5m_xgb_SPY_macro_us2\p_day.png
# [SAVED] output_dailyprob_gated_5m_xgb_SPY_macro_us2\daily_lr_feature_importance.csv
# [TRADES] total=786
# [TRADES] first_trade_ts=2024-02-07 12:40:00 (sim_start=2024-01-01 00:00:00)

# %%
res = resume_from_checkpoint(
    checkpoint_path="checkpoints/SPY_macro_US2_checkpoint.joblib",
    daily_csv_path="DataAPI/data/SPY_DAY.csv",
    k5m_csv_path="DataAPI/data/SPY_5M.csv",
    end_time="2026-12-31",
    output_dir="output_resumed_SPY_macro",
    verbose=True,
    plot_from_checkpoint=True,
)
# Out:
# [PLOT START] inferred from checkpoint key 'checkpoint_time' = 2026-03-10 19:55:00
# [RESUME WRAPPER] checkpoint=checkpoints/SPY_macro_US2_checkpoint.joblib
# [RESUME WRAPPER] code=SPY
# [RESUME WRAPPER] original_daily_chan_start=2020-06-01
# [RESUME WRAPPER] original_accumulation_start=2022-10-01
# [RESUME WRAPPER] original_sim_start=2024-01-01
# [RESUME WRAPPER] original_end_time=2026-12-31
# [RESUME WRAPPER] continue_until=2026-12-31
# [RESUME WRAPPER] plot_from=2026-03-10 19:55:00
# [RESUME WRAPPER] output_dir=output_resumed_SPY_macro
# [RESUME] loading checkpoint: checkpoints/SPY_macro_US2_checkpoint.joblib @ 2026-03-10 19:55:00
# [RESUME] daily_i_start=1454 / 1464
# [RESUME] five_i_start=162604 / 165100
# [RESUME] daily_model=YES 5m_buy=YES 5m_sell=YES
# [SAVED] output_resumed_SPY_macro\daily_lr_feature_importance.csv
# [PHASE2/3] 5m feed begins at accumulation_start=2022-10-01, trading starts at sim_s=2024-01-01
# [TRAIN][5M] asof=2026-03-10 feats=69 buy=YES sell=YES rows=32391
# [TH-OPT][GLOBAL] asof_bar=162795 buy_th=2.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=162987 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=163179 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2026-03-16 feats=69 buy=YES sell=YES rows=32648
# [TH-OPT][GLOBAL] asof_bar=163371 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2026-03-16 19:55:00
# [TH-OPT][GLOBAL] asof_bar=163563 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=163755 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=163947 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=164139 buy_th=1.00 sell_th=2.35
# [TRAIN][5M] asof=2026-03-23 feats=69 buy=YES sell=YES rows=32847
# [TH-OPT][GLOBAL] asof_bar=164331 buy_th=-0.50 sell_th=2.45
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2026-03-23 19:55:00
# [TH-OPT][GLOBAL] asof_bar=164523 buy_th=2.15 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=164715 buy_th=1.65 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=164907 buy_th=1.80 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/SPY_macro_US2_checkpoint.joblib @ 2026-03-27 19:55:00
# [SAVED] output_resumed_SPY_macro\trades.csv
# [SAVED] output_resumed_SPY_macro\daily_log.csv
# [SAVED] output_resumed_SPY_macro\equity_vs_buyhold.png
# [SAVED] output_resumed_SPY_macro\price_with_trades.png
# [SAVED] output_resumed_SPY_macro\p_day.png
# [SAVED] output_resumed_SPY_macro\daily_lr_feature_importance.csv
# [TRADES] total=833
# [TRADES] first_trade_ts=2022-10-10 04:35:00 (sim_start=2024-01-01 00:00:00)

# %%
# ============================================================
# FULL CHECKPOINT / RESUME CODE
# + DAILY MACRO / INDEX FEATURES
# + YIELD CURVE FEATURE (TNX - FVX)
# ============================================================

import os
import copy
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from dataclasses import dataclass
from typing import List, Optional, Any, Dict
import xgboost as xgb

from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.calibration import CalibratedClassifierCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MaxAbsScaler
from sklearn.impute import SimpleImputer

# ---- your Chan imports ----
from sliding_window_chan import SlidingWindowChan
from ChanConfig import CChanConfig
from Common.CEnum import DATA_FIELD, KL_TYPE, AUTYPE
try:
    from Common.CEnum import DATA_SRC
except Exception:
    class DATA_SRC:
        CSV = "CSV"
from KLine.KLine_Unit import CKLine_Unit
from Common.CTime import CTime


# ============================================================
# BACKWARD-COMPAT CLASS DEFINITIONS
# ============================================================

@dataclass
class RetModelPack:
    feature_cols: List[str]
    model_ret: xgb.XGBRegressor

@dataclass
class DailyProbState:
    model: Optional[Any] = None
    new_labels: int = 0
    trained_n: int = 0


# ============================================================
# BASIC HELPERS
# ============================================================

def _safe_div(a, b, eps=1e-12):
    return a / (b + eps)

def _pick_col(df: pd.DataFrame, candidates: List[str]) -> Optional[str]:
    cols = list(df.columns)
    for c in candidates:
        if c in cols:
            return c
    lower_map = {c.lower(): c for c in cols}
    for c in candidates:
        if c.lower() in lower_map:
            return lower_map[c.lower()]
    return None

def save_joblib(path: str, obj):
    os.makedirs(os.path.dirname(path), exist_ok=True)
    joblib.dump(obj, path, compress=3)

def load_joblib(path: str):
    return joblib.load(path)

def _safe_copy_list_of_dict(lst):
    if lst is None:
        return []
    out = []
    for x in lst:
        try:
            out.append(dict(x))
        except Exception:
            pass
    return out

def _safe_set_to_list(s):
    if s is None:
        return []
    return list(s)

def _safe_list_to_set(lst):
    if lst is None:
        return set()
    out = set()
    for x in lst:
        if isinstance(x, list):
            out.add(tuple(x))
        else:
            out.add(x)
    return out


# ============================================================
# OHLCV CSV LOADER
# ============================================================

def load_ohlcv_csv(path: str, freq_name: str) -> pd.DataFrame:
    df = pd.read_csv(path)

    ts_col = _pick_col(df, ["timestamp", "date", "datetime", "time"])
    if ts_col is None:
        ts_col = df.columns[0]
    df[ts_col] = pd.to_datetime(df[ts_col], errors="coerce")
    df = df.dropna(subset=[ts_col]).sort_values(ts_col).reset_index(drop=True)
    df = df.rename(columns={ts_col: "timestamp"})

    open_col  = _pick_col(df, ["open", "Open", "o", "O"])
    high_col  = _pick_col(df, ["high", "High", "h", "H"])
    low_col   = _pick_col(df, ["low", "Low", "l", "L"])
    close_col = _pick_col(df, ["close", "Close", "adj_close", "Adj Close", "AdjClose", "c", "C"])
    vol_col   = _pick_col(df, ["volume", "Volume", "vol", "Vol", "v", "V"])

    if open_col is None or close_col is None:
        raise ValueError(f"{freq_name} CSV must contain open/close columns.")
    if high_col is None:
        high_col = close_col
    if low_col is None:
        low_col = close_col

    df["_open"]  = pd.to_numeric(df[open_col], errors="coerce").astype(float)
    df["_high"]  = pd.to_numeric(df[high_col], errors="coerce").astype(float)
    df["_low"]   = pd.to_numeric(df[low_col], errors="coerce").astype(float)
    df["_close"] = pd.to_numeric(df[close_col], errors="coerce").astype(float)
    df["_vol"]   = pd.to_numeric(df[vol_col], errors="coerce").astype(float) if vol_col is not None else 0.0

    df = df.dropna(subset=["_open", "_high", "_low", "_close"]).reset_index(drop=True)
    df["day"] = df["timestamp"].dt.normalize()
    return df


# ============================================================
# DAILY KLINE FEATURES
# ============================================================

KLINE_KEYS = [
    "ret1","ret_5","ret_10","ret_20","ret_40",
    "vol_5","vol_10","vol_20","vol_40",
    "atr_14","range_over_atr","close_pos","gap",
    "above_ma_20","above_ma_50","above_ma_100",
    "slope40",
]

def compute_daily_kline_features(df_day: pd.DataFrame) -> pd.DataFrame:
    d = df_day.copy().sort_values("timestamp").reset_index(drop=True)
    o = d["_open"].astype(float)
    h = d["_high"].astype(float)
    l = d["_low"].astype(float)
    c = d["_close"].astype(float)

    prev_c = c.shift(1)
    d["ret1"] = (_safe_div(c, prev_c) - 1.0).replace([np.inf, -np.inf], np.nan).fillna(0.0)

    tr = pd.concat([(h-l).abs(), (h-prev_c).abs(), (l-prev_c).abs()], axis=1).max(axis=1)
    d["tr"] = tr.fillna(0.0)
    d["atr_14"] = d["tr"].rolling(14).mean().bfill().fillna(0.0)

    d["range"] = (h - l).fillna(0.0)
    d["range_over_atr"] = _safe_div(d["range"], d["atr_14"]).replace([np.inf, -np.inf], np.nan).fillna(0.0)

    rng = (h - l).replace(0.0, np.nan)
    d["close_pos"] = ((c - l) / rng).replace([np.inf, -np.inf], np.nan).fillna(0.5)
    d["gap"] = (_safe_div(o, prev_c) - 1.0).replace([np.inf, -np.inf], np.nan).fillna(0.0)

    for w in [5, 10, 20, 40]:
        d[f"ret_{w}"] = (_safe_div(c, c.shift(w)) - 1.0).replace([np.inf, -np.inf], np.nan).fillna(0.0)
        d[f"vol_{w}"] = d["ret1"].rolling(w).std().replace([np.inf, -np.inf], np.nan).fillna(0.0)

    for w in [20, 50, 100]:
        ma = c.rolling(w).mean()
        d[f"above_ma_{w}"] = (_safe_div(c, ma) - 1.0).replace([np.inf, -np.inf], np.nan).fillna(0.0)

    def _slope_log(x):
        x = np.asarray(x, dtype=float)
        x = np.log(np.maximum(x, 1e-12))
        t = np.arange(len(x), dtype=float)
        t = t - t.mean()
        x = x - x.mean()
        den = (t*t).sum()
        return 0.0 if den <= 0 else float((t*x).sum() / den)

    d["slope40"] = d["_close"].rolling(40).apply(_slope_log, raw=False).fillna(0.0)
    return d

def make_kline_dict(row: pd.Series) -> Dict[str, float]:
    out = {}
    for k in KLINE_KEYS:
        val = row[k] if k in row.index else 0.0
        out[f"k_{k}"] = float(val) if np.isfinite(val) else 0.0
    return out


# ============================================================
# MACRO / INDEX FEATURES
# ============================================================

def load_macro_features_from_folder(folder: str, files: Dict[str, str], start: str) -> pd.DataFrame:
    out = None

    for pref, fn in files.items():
        path = os.path.join(folder, fn)
        if not os.path.exists(path):
            raise FileNotFoundError(f"Macro file not found: {path}")

        dfm = load_ohlcv_csv(path, pref.upper())
        dfm = dfm[dfm["timestamp"] >= pd.to_datetime(start)].copy().reset_index(drop=True)
        dfm["ts_norm"] = pd.to_datetime(dfm["timestamp"]).dt.normalize()

        dfm_feat = compute_daily_kline_features(dfm)

        # raw close level
        dfm_feat[f"{pref}level"] = dfm_feat["_close"].astype(float)

        keep_cols = ["ts_norm", f"{pref}level"] + KLINE_KEYS
        dfm_feat = dfm_feat[keep_cols].copy()

        rename = {k: f"{pref}{k}" for k in KLINE_KEYS}
        dfm_feat = dfm_feat.rename(columns=rename)

        out = dfm_feat.copy() if out is None else out.merge(dfm_feat, on="ts_norm", how="outer")

    if out is None:
        out = pd.DataFrame(columns=["ts_norm"])

    # 10Y - 5Y yield curve
    if ("us10y_level" in out.columns) and ("us5y_level" in out.columns):
        out["yc_10y5y_level"] = out["us10y_level"] - out["us5y_level"]

        prev = out["yc_10y5y_level"].shift(1)
        out["yc_10y5y_ret1"] = (_safe_div(out["yc_10y5y_level"], prev) - 1.0).replace([np.inf, -np.inf], np.nan).fillna(0.0)

        for w in [5, 10, 20, 40]:
            out[f"yc_10y5y_chg_{w}"] = (out["yc_10y5y_level"] - out["yc_10y5y_level"].shift(w)).replace([np.inf, -np.inf], np.nan).fillna(0.0)

    return out.sort_values("ts_norm").reset_index(drop=True)


# ============================================================
# CHAN BUILDERS
# ============================================================

def to_ctime(ts) -> CTime:
    if isinstance(ts, CTime):
        return ts
    dt = pd.to_datetime(ts).to_pydatetime()
    try:
        return CTime(dt.year, dt.month, dt.day, dt.hour, dt.minute, dt.second, auto=False)
    except Exception:
        pass
    try:
        return CTime(dt.year, dt.month, dt.day, dt.hour, dt.minute, dt.second)
    except Exception:
        pass
    s = dt.strftime("%Y-%m-%d %H:%M:%S")
    try:
        return CTime(s, auto=False)
    except Exception:
        return CTime(s)

def build_klu(ts, o, h, l, c, v=0.0) -> CKLine_Unit:
    ct = to_ctime(ts)
    kl_dict = {
        DATA_FIELD.FIELD_TIME: ct,
        DATA_FIELD.FIELD_OPEN: float(o),
        DATA_FIELD.FIELD_HIGH: float(h),
        DATA_FIELD.FIELD_LOW:  float(l),
        DATA_FIELD.FIELD_CLOSE: float(c),
        DATA_FIELD.FIELD_VOLUME: float(v),
        "time": ct, "timestamp": ct, "datetime": ct, "dt": ct,
        "open": float(o), "high": float(h), "low": float(l), "close": float(c),
        "volume": float(v),
    }
    klu = CKLine_Unit(kl_dict)
    try:
        klu.time = ct
    except Exception:
        pass
    return klu

def _safe_pd_ts(x):
    try:
        return pd.to_datetime(str(x))
    except Exception:
        return pd.NaT


def feed_chan_one(chan_obj, klu: CKLine_Unit, verbose=False):
    """
    Safely feed one KLine into chan object.
    Skip exact duplicate timestamps to avoid KL_NOT_MONOTONOUS on resume.
    """
    # hard guard for SlidingWindowChan / any chan object with all_klines
    if hasattr(chan_obj, "all_klines") and len(chan_obj.all_klines) > 0:
        last_time = getattr(chan_obj.all_klines[-1], "time", None)
        cur_time = getattr(klu, "time", None)

        last_ts = _safe_pd_ts(last_time)
        cur_ts = _safe_pd_ts(cur_time)

        if pd.notna(last_ts) and pd.notna(cur_ts):
            if cur_ts == last_ts:
                if verbose:
                    print(f"[CHAN-SKIP] duplicate kline skipped: {cur_ts}")
                return None
            if cur_ts < last_ts:
                if verbose:
                    print(f"[CHAN-SKIP] non-monotonic older kline skipped: cur={cur_ts}, last={last_ts}")
                return None

    if hasattr(chan_obj, "process_new_kline"):
        return chan_obj.process_new_kline(klu)
    if hasattr(chan_obj, "step_load"):
        return chan_obj.step_load([klu])

    raise AttributeError("chan_obj has neither process_new_kline nor step_load")


# ============================================================
# DAILY BSP HELPERS
# ============================================================

def normalize_bsp_row(r: Dict[str, Any]) -> Dict[str, Any]:
    rr = dict(r)
    if "timestamp" in rr:
        rr["timestamp"] = pd.to_datetime(rr["timestamp"], errors="coerce")
    if "direction" not in rr or rr["direction"] is None:
        if rr.get("is_buy", None) is not None:
            rr["direction"] = "buy" if bool(rr["is_buy"]) else "sell"
        else:
            rr["direction"] = "buy"
    rr["direction"] = str(rr["direction"]).lower()
    if "bsp_type" in rr and rr["bsp_type"] is not None:
        rr["bsp_type"] = str(rr["bsp_type"]).lower()
    else:
        rr["bsp_type"] = "?"
    return rr

def extract_bsp_rows_from_chan(chan_obj) -> List[Dict[str, Any]]:
    if hasattr(chan_obj, "export_new_historical_bsp_to_list"):
        out = chan_obj.export_new_historical_bsp_to_list()
        return out if out else []
    if hasattr(chan_obj, "export_new_bsp_to_list"):
        out = chan_obj.export_new_bsp_to_list()
        return out if out else []
    return []

def latest_bsp_dir_up_to(bsp_rows: List[Dict[str, Any]], ts: pd.Timestamp) -> Optional[str]:
    past = [r for r in bsp_rows if pd.to_datetime(r["timestamp"]) <= ts]
    if not past:
        return None
    past = sorted(past, key=lambda x: pd.to_datetime(x["timestamp"]))
    return str(past[-1].get("direction", "")).lower()

def make_daily_bsp_context(bsp_hist: List[Dict[str, Any]], cur_ts: pd.Timestamp, window_days: int = 60) -> Dict[str, float]:
    past = [r for r in bsp_hist if pd.to_datetime(r["timestamp"]) <= cur_ts]
    past = sorted(past, key=lambda x: pd.to_datetime(x["timestamp"]))
    if not past:
        return {
            "ctx_has_bsp": 0.0,
            "ctx_last_dir_buy": 0.0,
            "ctx_last_dir_sell": 0.0,
            "ctx_days_since_last_bsp": 999.0,
            "ctx_days_since_last_buy": 999.0,
            "ctx_days_since_last_sell": 999.0,
            "ctx_density_total": 0.0,
            "ctx_density_buy": 0.0,
            "ctx_density_sell": 0.0,
            "ctx_density_imb": 0.0,
        }

    last = past[-1]
    last_dir = str(last.get("direction", "")).lower()
    days_since_last = float((cur_ts.normalize() - pd.to_datetime(last["timestamp"]).normalize()).days)

    def _days_since(target: str) -> float:
        for r in reversed(past):
            if str(r.get("direction", "")).lower() == target:
                return float((cur_ts.normalize() - pd.to_datetime(r["timestamp"]).normalize()).days)
        return 999.0

    start = cur_ts.normalize() - pd.Timedelta(days=int(window_days))
    recent = [r for r in past if pd.to_datetime(r["timestamp"]).normalize() >= start]
    buy = sum(1 for r in recent if str(r.get("direction", "")).lower() == "buy")
    sell = sum(1 for r in recent if str(r.get("direction", "")).lower() == "sell")
    tot = max(1.0, float(buy + sell))

    return {
        "ctx_has_bsp": 1.0,
        "ctx_last_dir_buy": 1.0 if last_dir == "buy" else 0.0,
        "ctx_last_dir_sell": 1.0 if last_dir == "sell" else 0.0,
        "ctx_days_since_last_bsp": days_since_last,
        "ctx_days_since_last_buy": _days_since("buy"),
        "ctx_days_since_last_sell": _days_since("sell"),
        "ctx_density_total": float(len(recent)),
        "ctx_density_buy": float(buy),
        "ctx_density_sell": float(sell),
        "ctx_density_imb": float((sell - buy) / tot),
    }

def compute_chain_endpoints(bsp_rows: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
    if not bsp_rows:
        return []
    bsps = sorted(bsp_rows, key=lambda r: pd.to_datetime(r["timestamp"]))
    ends = []
    cur_dir = str(bsps[0].get("direction", "")).lower()
    cur_end = bsps[0]
    cur_end_i = 0
    for i in range(1, len(bsps)):
        d = str(bsps[i].get("direction", "")).lower()
        if d == cur_dir:
            cur_end = bsps[i]
            cur_end_i = i
        else:
            ends.append({"end_ts": pd.to_datetime(cur_end["timestamp"]).normalize(), "end_dir": cur_dir, "end_i": cur_end_i})
            cur_dir = d
            cur_end = bsps[i]
            cur_end_i = i
    ends.append({"end_ts": pd.to_datetime(cur_end["timestamp"]).normalize(), "end_dir": cur_dir, "end_i": cur_end_i})
    return ends

def regime_for_day_from_ends(day_norm: pd.Timestamp, ends: List[Dict[str, Any]]) -> str:
    if len(ends) < 2:
        return "unknown"
    for k in range(len(ends) - 1):
        a = ends[k]
        b = ends[k + 1]
        a_ts, a_dir = a["end_ts"], a["end_dir"]
        b_ts, b_dir = b["end_ts"], b["end_dir"]
        if (day_norm >= a_ts) and (day_norm <= b_ts):
            if a_dir == "buy" and b_dir == "sell":
                return "up"
            if a_dir == "sell" and b_dir == "buy":
                return "down"
    return "unknown"


# ============================================================
# DAILY LABEL + MODEL
# ============================================================

def label_confirm_extreme(df_day_feat: pd.DataFrame, idx: int, N: int, base_dir: str) -> Optional[int]:
    if N <= 0:
        return None
    if idx + N >= len(df_day_feat):
        return None
    h0 = float(df_day_feat.loc[idx, "_high"])
    l0 = float(df_day_feat.loc[idx, "_low"])
    fut = df_day_feat.loc[idx+1:idx+N]
    if fut.empty:
        return None
    if base_dir == "sell":
        mx = float(fut["_high"].max())
        return 1 if mx < h0 else 0
    if base_dir == "buy":
        mn = float(fut["_low"].min())
        return 1 if mn > l0 else 0
    return None

def make_daily_features_one_model(
    kline_row: pd.Series,
    bsp_hist_up_to_day: List[Dict[str, Any]],
    p_val: float,
    dp_minK: float,
    dp_maxK: float,
    regime: str,
    base_dir: Optional[str],
    macro_cols: Optional[List[str]] = None,
) -> Dict[str, float]:
    feats: Dict[str, float] = {}
    feats.update(make_kline_dict(kline_row))

    if macro_cols is not None:
        for c in macro_cols:
            if c in kline_row.index:
                val = kline_row[c]
                feats[c] = float(val) if np.isfinite(val) else 0.0

    ts = pd.to_datetime(kline_row["timestamp"])
    feats.update(make_daily_bsp_context(bsp_hist_up_to_day, ts, window_days=60))

    feats["p"] = float(p_val) if np.isfinite(p_val) else 0.0
    feats["dp_minK"] = float(dp_minK) if np.isfinite(dp_minK) else 0.0
    feats["dp_maxK"] = float(dp_maxK) if np.isfinite(dp_maxK) else 0.0

    rg = str(regime).lower()
    feats["rg_up"] = 1.0 if rg == "up" else 0.0
    feats["rg_down"] = 1.0 if rg == "down" else 0.0
    feats["rg_unknown"] = 1.0 if rg not in ("up", "down") else 0.0

    bd = str(base_dir).lower() if base_dir is not None else "none"
    feats["bd_buy"] = 1.0 if bd == "buy" else 0.0
    feats["bd_sell"] = 1.0 if bd == "sell" else 0.0
    feats["bd_none"] = 1.0 if bd not in ("buy", "sell") else 0.0

    return feats

def fit_prob_model_dicts(X_dicts: List[Dict[str, float]], y: np.ndarray):
    base = Pipeline([
        ("vec", DictVectorizer(sparse=True)),
        ("scaler", MaxAbsScaler()),
        ("lr", LogisticRegression(
            max_iter=8000,
            class_weight="balanced",
            solver="saga",
            C=0.5,
            n_jobs=-1
        ))
    ])
    uniq, counts = np.unique(y, return_counts=True)
    if len(uniq) < 2:
        raise ValueError("Only one class in y so far.")
    min_count = int(counts.min())

    if min_count >= 5:
        cal = CalibratedClassifierCV(base, method="sigmoid", cv=3)
        cal.fit(X_dicts, y)
        return cal
    elif min_count >= 3:
        cal = CalibratedClassifierCV(base, method="sigmoid", cv=2)
        cal.fit(X_dicts, y)
        return cal
    else:
        base.fit(X_dicts, y)
        return base

def predict_prob(model, X_dicts: List[Dict[str, float]]) -> np.ndarray:
    return model.predict_proba(X_dicts)[:, 1]

def _get_underlying_pipeline(model):
    if hasattr(model, "calibrated_classifiers_") and len(getattr(model, "calibrated_classifiers_", [])) > 0:
        cc0 = model.calibrated_classifiers_[0]
        if hasattr(cc0, "estimator") and cc0.estimator is not None:
            return cc0.estimator
    return model

def feature_importance_from_lr(model, top_n: int = 80) -> pd.DataFrame:
    pipe = _get_underlying_pipeline(model)
    if not (hasattr(pipe, "named_steps") and "vec" in pipe.named_steps and "lr" in pipe.named_steps):
        return pd.DataFrame(columns=["feature", "coef", "abs_coef"])
    vec = pipe.named_steps["vec"]
    lr = pipe.named_steps["lr"]

    try:
        names = np.array(vec.get_feature_names_out(), dtype=object)
    except Exception:
        names = np.array(getattr(vec, "feature_names_", []), dtype=object)

    coef = lr.coef_.ravel()
    if len(names) != len(coef):
        return pd.DataFrame(columns=["feature", "coef", "abs_coef"])

    df_imp = pd.DataFrame({"feature": names, "coef": coef})
    df_imp["abs_coef"] = df_imp["coef"].abs()
    return df_imp.sort_values("abs_coef", ascending=False).head(int(top_n)).reset_index(drop=True)


# ============================================================
# 5M MODEL + THRESHOLDS
# ============================================================

LABEL_COLS = {"best_return_pct"}
BSP_TYPE_MAP = {"1":1,"2":2,"3a":3,"1p":4,"2s":5,"3b":6}

def prepare_ml_dataset(df: pd.DataFrame) -> pd.DataFrame:
    if df.empty:
        return df
    df = df.copy()

    if "direction" in df.columns:
        d = df["direction"].fillna("unknown").astype(str).str.lower()
        df["direction_encoded"] = np.where(d == "buy", 1, np.where(d == "sell", 0, -1)).astype(np.int32)

    if "bsp_type" in df.columns:
        t = df["bsp_type"].fillna("unknown").astype(str).str.lower()
        df["bsp_type_encoded"] = t.map(BSP_TYPE_MAP).fillna(0).astype(np.int32)

    df = df.replace([np.inf, -np.inf], np.nan)

    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    numeric_cols = [c for c in numeric_cols if c not in LABEL_COLS]

    if numeric_cols:
        imputer = SimpleImputer(strategy="mean")
        imputed = imputer.fit_transform(df[numeric_cols])
        df[numeric_cols] = pd.DataFrame(imputed, columns=numeric_cols, index=df.index).fillna(0.0)

    return df

def get_feature_columns(df: pd.DataFrame) -> List[str]:
    exclude = set(LABEL_COLS) | {
        "timestamp","code","direction","bsp_type","klu_idx",
        "has_best_exit","best_exit_type","best_exit_klu_idx","best_exit_price",
        "regime_bucket",
    }
    num_cols = df.select_dtypes(include=[np.number, "bool"]).columns.tolist()
    cols = [c for c in num_cols if c not in exclude]
    return sorted(cols)

def to_float_matrix(df: pd.DataFrame, cols: List[str]) -> np.ndarray:
    if not cols:
        return np.zeros((len(df), 0), dtype=np.float32)
    X = df[cols].copy()
    for c in cols:
        X[c] = pd.to_numeric(X[c], errors="coerce")
    X = X.replace([np.inf, -np.inf], np.nan).fillna(0.0)
    return X.to_numpy(dtype=np.float32, copy=False)

def _fit_ret_pack(df_dir: pd.DataFrame, feature_cols: List[str], seed: int) -> RetModelPack:
    ret_df = df_dir.dropna(subset=["best_return_pct"]).copy()
    X = to_float_matrix(ret_df, feature_cols)
    y = ret_df["best_return_pct"].to_numpy(dtype=np.float32)

    model = xgb.XGBRegressor(
        n_estimators=500,
        max_depth=5,
        learning_rate=0.05,
        subsample=0.85,
        colsample_bytree=0.85,
        reg_lambda=1.0,
        random_state=seed,
        n_jobs=4,
    )
    model.fit(X, y)
    return RetModelPack(feature_cols=feature_cols, model_ret=model)

def train_models_two_sided_ret_only(
    bsp_df: pd.DataFrame,
    feature_cols: List[str],
    min_samples_total: int = 300,
):
    if bsp_df.empty or "direction" not in bsp_df.columns:
        return None, None

    df = bsp_df.copy()
    for c in feature_cols:
        if c not in df.columns:
            df[c] = 0.0

    buy_df = df[df["direction"].astype(str).str.lower() == "buy"].copy()
    sell_df = df[df["direction"].astype(str).str.lower() == "sell"].copy()

    buy_pack = None
    if len(buy_df.dropna(subset=["best_return_pct"])) >= min_samples_total:
        buy_pack = _fit_ret_pack(buy_df, feature_cols, seed=42)

    sell_pack = None
    if len(sell_df.dropna(subset=["best_return_pct"])) >= min_samples_total:
        sell_pack = _fit_ret_pack(sell_df, feature_cols, seed=52)

    return buy_pack, sell_pack

def predict_ret(pack: RetModelPack, row_df: pd.DataFrame) -> float:
    X = to_float_matrix(row_df, pack.feature_cols)
    return float(pack.model_ret.predict(X)[0])

def make_ret_grid(start: float = -0.5, end: float = 2.5, step: float = 0.05) -> List[float]:
    vals = np.arange(start, end + 1e-12, step, dtype=float)
    return [float(x) for x in vals]

def _bars_from_days(days: float, bar_interval_minutes: int) -> int:
    minutes = float(days) * 24.0 * 60.0
    return max(1, int(round(minutes / float(bar_interval_minutes))))

def label_bestlookahead_for_ready_points(
    bsp_rows: List[Dict[str, Any]],
    highs: np.ndarray,
    lows: np.ndarray,
    closes: np.ndarray,
    lookahead_days: float,
    bar_interval_minutes: int,
    current_bar_idx: int,
):
    if not bsp_rows:
        return
    lookahead_bars = _bars_from_days(lookahead_days, bar_interval_minutes)
    n = len(closes)

    for r in bsp_rows:
        if not np.isnan(r.get("best_return_pct", np.nan)):
            continue
        i = r.get("klu_idx", None)
        if i is None:
            continue
        i = int(i)
        end_i = i + lookahead_bars
        if end_i >= n:
            continue
        if end_i > current_bar_idx:
            continue

        d = str(r.get("direction", "buy")).lower()
        c0 = float(closes[i])

        if d == "buy":
            mx = float(np.nanmax(highs[i + 1 : end_i + 1]))
            r["best_return_pct"] = (mx - c0) / c0 * 100.0
        else:
            mn = float(np.nanmin(lows[i + 1 : end_i + 1]))
            r["best_return_pct"] = (c0 - mn) / c0 * 100.0

def _simulate_realized_ret_only_long(
    events: List[Dict[str, Any]],
    pred_buy: Dict[Any, float],
    pred_sell: Dict[Any, float],
    buy_th: float,
    sell_th: float,
    next_open_by_idx: np.ndarray,
    closes: np.ndarray,
    end_bar_idx: int,
    fee_pct: float = 0.0,
):
    cash = 1.0
    pos = 0
    qty = 0.0
    trades = 0

    def exec_next_open(idx: int):
        if not (0 <= idx < len(next_open_by_idx)):
            return None
        px = next_open_by_idx[idx]
        if px is None or (isinstance(px, float) and np.isnan(px)):
            return None
        return float(px)

    for r in events:
        d = str(r.get("direction", "")).lower()
        ki = int(r.get("klu_idx", -1))
        px = exec_next_open(ki)
        if px is None:
            continue

        if pos == 0 and d == "buy":
            key = (int(r.get("klu_idx",-1)), "buy", str(r.get("bsp_type","?")))
            pr = pred_buy.get(key)
            if pr is not None and pr >= float(buy_th):
                notional = cash
                spend = notional * (1 + fee_pct)
                if spend > cash:
                    spend = cash
                    notional = spend / (1 + fee_pct)
                qty = notional / px
                cash -= spend
                pos = 1
                trades += 1

        elif pos == 1 and d == "sell":
            key = (int(r.get("klu_idx",-1)), "sell", str(r.get("bsp_type","?")))
            pr = pred_sell.get(key)
            if pr is not None and pr >= float(sell_th):
                cash += (qty * px) * (1 - fee_pct)
                qty = 0.0
                pos = 0
                trades += 1

    end_px = float(closes[end_bar_idx])
    eq = cash if pos == 0 else (cash + qty * end_px)
    return float(eq), int(trades)

def choose_thresholds_global_realized(
    df_5m: pd.DataFrame,
    bsp_rows: List[Dict[str, Any]],
    buy_pack: Optional[RetModelPack],
    sell_pack: Optional[RetModelPack],
    asof_bar_idx: int,
    window_days: float,
    ret_grid: List[float],
    next_open_by_idx: np.ndarray,
    closes: np.ndarray,
    fee_pct: float = 0.0,
    min_open_signals: int = 10,
):
    if df_5m.empty or not bsp_rows or buy_pack is None or sell_pack is None:
        return None

    end_ts = pd.to_datetime(df_5m.loc[asof_bar_idx, "timestamp"])
    start_ts = end_ts - pd.Timedelta(days=float(window_days))

    events = []
    buy_cand = []
    sell_cand = []
    for r in bsp_rows:
        t = pd.to_datetime(r.get("timestamp", None), errors="coerce")
        if pd.isna(t) or not (start_ts <= t <= end_ts):
            continue
        ki = r.get("klu_idx", None)
        if ki is None:
            continue
        rr = dict(r)
        rr["klu_idx"] = int(ki)
        events.append(rr)
        d = str(rr.get("direction","")).lower()
        if d == "buy":
            buy_cand.append(rr)
        elif d == "sell":
            sell_cand.append(rr)

    if len(buy_cand) < int(min_open_signals) or len(sell_cand) < 1:
        return None

    events.sort(key=lambda x: int(x["klu_idx"]))

    buy_df = prepare_ml_dataset(pd.DataFrame(buy_cand))
    for c in buy_pack.feature_cols:
        if c not in buy_df.columns:
            buy_df[c] = 0.0
    buy_pred = buy_pack.model_ret.predict(to_float_matrix(buy_df, buy_pack.feature_cols)).astype(float)
    pred_buy = {(int(buy_cand[i]["klu_idx"]), "buy", str(buy_cand[i].get("bsp_type","?"))): float(buy_pred[i]) for i in range(len(buy_cand))}

    sell_df = prepare_ml_dataset(pd.DataFrame(sell_cand))
    for c in sell_pack.feature_cols:
        if c not in sell_df.columns:
            sell_df[c] = 0.0
    sell_pred = sell_pack.model_ret.predict(to_float_matrix(sell_df, sell_pack.feature_cols)).astype(float)
    pred_sell = {(int(sell_cand[i]["klu_idx"]), "sell", str(sell_cand[i].get("bsp_type","?"))): float(sell_pred[i]) for i in range(len(sell_cand))}

    end_bar_idx = asof_bar_idx
    best_eq = None
    best_pair = None

    for bt in ret_grid:
        for st in ret_grid:
            eq, trades = _simulate_realized_ret_only_long(
                events=events,
                pred_buy=pred_buy,
                pred_sell=pred_sell,
                buy_th=float(bt),
                sell_th=float(st),
                next_open_by_idx=next_open_by_idx,
                closes=closes,
                end_bar_idx=end_bar_idx,
                fee_pct=fee_pct,
            )
            if best_eq is None or eq > best_eq:
                best_eq = float(eq)
                best_pair = (float(bt), float(st))

    return best_pair


# ============================================================
# EXECUTION ENGINE
# ============================================================

class ExecutionEngine:
    def __init__(self, initial_capital: float, fee_pct: float):
        self.cash = float(initial_capital)
        self.fee_pct = float(fee_pct)
        self.pos = 0
        self.qty = 0.0
        self.entry_px = None
        self.entry_idx = None              # actual execution index
        self.entry_signal_idx = None       # signal bar index
        self.pending_order = None
        self.trades = []

    def _exec_px(self, signal_idx: int, next_open_by_idx: np.ndarray):
        if not (0 <= signal_idx < len(next_open_by_idx)):
            return None
        px = next_open_by_idx[signal_idx]
        if px is None or (isinstance(px, float) and np.isnan(px)):
            return None
        return float(px)

    def place_order_for_next_bar(self, side: str, seen_idx: int, reason: str, meta: dict = None, overwrite=True):
        if self.pending_order is not None and not overwrite:
            return
        self.pending_order = {
            "side": side,
            "signal_idx": int(seen_idx),
            "reason": reason,
            "meta": dict(meta) if meta else {},
        }

    def maybe_execute_pending(self, next_open_by_idx: np.ndarray):
        if self.pending_order is None:
            return

        side = self.pending_order["side"]
        signal_idx = int(self.pending_order["signal_idx"])
        reason = self.pending_order["reason"]
        meta = self.pending_order.get("meta", {}) or {}

        px = self._exec_px(signal_idx, next_open_by_idx)
        if px is None:
            return

        exec_idx = signal_idx + 1
        fee = self.fee_pct

        if side == "buy" and self.pos == 0:
            notional = self.cash / (1.0 + fee)
            fee_amt = notional * fee
            qty = notional / px

            self.cash -= (notional + fee_amt)
            self.pos = 1
            self.qty = qty
            self.entry_px = px
            self.entry_idx = exec_idx
            self.entry_signal_idx = signal_idx

            self.trades.append({
                "side": "buy",
                "signal_idx": signal_idx,
                "exec_idx": exec_idx,
                "seen_idx": exec_idx,   # keep old downstream code compatible
                "exec_px": px,
                "qty": qty,
                "fee": fee_amt,
                "reason": reason,
                **meta
            })

        elif side == "sell" and self.pos == 1:
            notional = self.qty * px
            fee_amt = notional * fee
            recv = notional - fee_amt
            self.cash += recv
            pnl = (px - self.entry_px) * self.qty - fee_amt

            self.trades.append({
                "side": "sell",
                "signal_idx": signal_idx,
                "exec_idx": exec_idx,
                "seen_idx": exec_idx,
                "exec_px": px,
                "qty": self.qty,
                "fee": fee_amt,
                "reason": reason,
                "pnl": pnl,
                "entry_px": self.entry_px,
                "entry_idx": self.entry_idx,
                "entry_signal_idx": self.entry_signal_idx,
                **meta
            })

            self.pos = 0
            self.qty = 0.0
            self.entry_px = None
            self.entry_idx = None
            self.entry_signal_idx = None

        self.pending_order = None

    def mark_to_market(self, last_close: float) -> float:
        px = float(last_close)
        if self.pos == 0:
            return float(self.cash)
        return float(self.cash + self.qty * px)

    def state_dict(self) -> dict:
        return {
            "cash": self.cash,
            "fee_pct": self.fee_pct,
            "pos": self.pos,
            "qty": self.qty,
            "entry_px": self.entry_px,
            "entry_idx": self.entry_idx,
            "entry_signal_idx": self.entry_signal_idx,
            "pending_order": copy.deepcopy(self.pending_order),
            "trades": copy.deepcopy(self.trades),
        }

    def load_state_dict(self, d: dict):
        self.cash = float(d.get("cash", self.cash))
        self.fee_pct = float(d.get("fee_pct", self.fee_pct))
        self.pos = int(d.get("pos", 0))
        self.qty = float(d.get("qty", 0.0))
        self.entry_px = d.get("entry_px", None)
        self.entry_idx = d.get("entry_idx", None)
        self.entry_signal_idx = d.get("entry_signal_idx", None)
        self.pending_order = copy.deepcopy(d.get("pending_order", None))
        self.trades = copy.deepcopy(d.get("trades", []))


# ============================================================
# 5M INDEX LOAD
# ============================================================

def load_5m_index(df_5m: pd.DataFrame, start_time: str, end_time: str):
    df = df_5m.copy()
    st = pd.to_datetime(start_time)
    et = pd.to_datetime(end_time)
    df = df[(df["timestamp"] >= st) & (df["timestamp"] <= et)].copy().reset_index(drop=True)

    df = df.rename(columns={"_open":"Open","_high":"High","_low":"Low","_close":"Close","_vol":"Volume"})
    df.columns = [str(c).strip() for c in df.columns]

    if not df.columns.is_unique:
        df = df.loc[:, ~df.columns.duplicated(keep="first")]

    df["date"] = df["timestamp"].dt.date
    df["next_open"] = df["Open"].shift(-1)
    df["next_close"] = df["Close"].shift(-1)

    next_open_by_idx = df["next_open"].to_numpy()
    next_close_by_idx = df["next_close"].to_numpy()
    closes = df["Close"].to_numpy(dtype=float)
    highs  = df["High"].to_numpy(dtype=float)
    lows   = df["Low"].to_numpy(dtype=float)

    day_close_map = df.groupby("date")["Close"].last().to_dict()
    all_days = sorted(df["date"].unique())
    return df, next_open_by_idx, next_close_by_idx, closes, highs, lows, day_close_map, all_days

def compute_buy_hold_equity(day_close_map: dict, daily_dates: list, initial_capital: float) -> pd.Series:
    closes, dates = [], []
    for d in daily_dates:
        px = day_close_map.get(d)
        if px is None or pd.isna(px):
            continue
        dates.append(d)
        closes.append(float(px))
    if not closes:
        return pd.Series(dtype=float)
    first = closes[0]
    equity = [initial_capital * (c / first) for c in closes]
    return pd.Series(equity, index=pd.to_datetime(dates))


# ============================================================
# GATE LOGIC
# ============================================================

def gate_from_p(p_day: float, p_sell_level: float, p_buy_level: float) -> str:
    if not np.isfinite(p_day):
        return "NO_P"
    if p_day >= p_sell_level:
        return "FORCE_SELL"
    if p_day <= p_buy_level:
        return "FORCE_BUY"
    return "FREE"


# ============================================================
# CLASS-FREE SERIALIZATION HELPERS
# ============================================================

def pack_ret_modelpack_for_save(pack):
    if pack is None:
        return None
    return {
        "__type__": "RetModelPack",
        "feature_cols": list(pack.feature_cols),
        "model_ret": pack.model_ret,
    }

def unpack_ret_modelpack_from_load(obj):
    if obj is None:
        return None
    if isinstance(obj, dict) and obj.get("__type__") == "RetModelPack":
        return RetModelPack(
            feature_cols=list(obj["feature_cols"]),
            model_ret=obj["model_ret"],
        )
    return obj


# ============================================================
# CHECKPOINT BUNDLE BUILD / LOAD
# ============================================================

def build_checkpoint_bundle(
    *,
    code: str,
    checkpoint_time: str,

    original_daily_chan_start: str,
    original_accumulation_start: str,
    original_sim_start: str,
    original_end_time: str,

    macro_files: dict,

    daily_prob_model,
    daily_prob_trained_n: int,
    X_days,
    y_days,
    pending_idx,
    p_by_day,
    p_series,
    dp_vs_minK_series,
    dp_vs_maxK_series,
    bsp_rows_daily,
    seen_bsp_daily,

    buy_pack,
    sell_pack,
    buy_ret_th_live: float,
    sell_ret_th_live: float,

    bsp_rows_5m,
    seen_keys_5m,

    engine_state: dict,
    daily_log,

    daily_i_last: int,
    five_i_last: int,
    current_day,

    warmup_daily_bars: pd.DataFrame,
    warmup_5m_bars: pd.DataFrame,

    daily_chan_max_klines: int,
    five_chan_max_klines: int,
):
    p_by_day_str = {}
    if p_by_day is not None:
        for k, v in p_by_day.items():
            try:
                p_by_day_str[str(pd.to_datetime(k))] = float(v)
            except Exception:
                pass

    bundle = {
        "schema": "chan_xgb_dailyprob_checkpoint_v4_macro",
        "code": code,
        "checkpoint_time": checkpoint_time,

        "original_daily_chan_start": str(original_daily_chan_start),
        "original_accumulation_start": str(original_accumulation_start),
        "original_sim_start": str(original_sim_start),
        "original_end_time": str(original_end_time),

        "macro_files": copy.deepcopy(macro_files),

        "daily_prob_model": daily_prob_model,
        "daily_prob_trained_n": int(daily_prob_trained_n),

        "X_days": copy.deepcopy(X_days),
        "y_days": copy.deepcopy(y_days),
        "pending_idx": copy.deepcopy(pending_idx),

        "p_by_day_str": p_by_day_str,
        "p_series": np.asarray(p_series, dtype=float),
        "dp_vs_minK_series": np.asarray(dp_vs_minK_series, dtype=float),
        "dp_vs_maxK_series": np.asarray(dp_vs_maxK_series, dtype=float),

        "bsp_rows_daily": _safe_copy_list_of_dict(bsp_rows_daily),
        "seen_bsp_daily_list": _safe_set_to_list(seen_bsp_daily),

        "buy_pack": pack_ret_modelpack_for_save(buy_pack),
        "sell_pack": pack_ret_modelpack_for_save(sell_pack),

        "buy_ret_th_live": float(buy_ret_th_live),
        "sell_ret_th_live": float(sell_ret_th_live),

        "bsp_rows_5m": _safe_copy_list_of_dict(bsp_rows_5m),
        "seen_keys_5m_list": _safe_set_to_list(seen_keys_5m),

        "engine_state": copy.deepcopy(engine_state),
        "daily_log": copy.deepcopy(daily_log),

        "daily_i_last": int(daily_i_last),
        "five_i_last": int(five_i_last),
        "current_day": None if current_day is None else str(current_day),

        "warmup_daily_bars": warmup_daily_bars.reset_index(drop=True),
        "warmup_5m_bars": warmup_5m_bars.reset_index(drop=True),

        "daily_chan_max_klines": int(daily_chan_max_klines),
        "five_chan_max_klines": int(five_chan_max_klines),
    }
    return bundle

def load_checkpoint_bundle(path: str) -> dict:
    b = load_joblib(path)
    if not isinstance(b, dict):
        raise ValueError("Checkpoint is not a dict.")
    schema = b.get("schema", "")
    if schema not in (
        "chan_xgb_dailyprob_checkpoint_v1",
        "chan_xgb_dailyprob_checkpoint_v2",
        "chan_xgb_dailyprob_checkpoint_v3",
        "chan_xgb_dailyprob_checkpoint_v4_macro",
    ):
        raise ValueError(f"Unknown checkpoint schema: {schema}")
    return b


# ============================================================
# CHECKPOINT START-TIME INFERENCE
# ============================================================

def _load_any_csv_time_index(csv_path: str) -> pd.DataFrame:
    df = pd.read_csv(csv_path)

    ts_candidates = ["timestamp", "date", "datetime", "time"]
    ts_col = None
    for c in ts_candidates:
        if c in df.columns:
            ts_col = c
            break

    if ts_col is None:
        lower_map = {c.lower(): c for c in df.columns}
        for c in ts_candidates:
            if c.lower() in lower_map:
                ts_col = lower_map[c.lower()]
                break

    if ts_col is None:
        ts_col = df.columns[0]

    df[ts_col] = pd.to_datetime(df[ts_col], errors="coerce")
    df = df.dropna(subset=[ts_col]).sort_values(ts_col).reset_index(drop=True)
    df = df.rename(columns={ts_col: "timestamp"})
    return df

def infer_checkpoint_plot_start_time(
    ckpt: dict,
    daily_csv_path: str | None = None,
    k5m_csv_path: str | None = None,
    verbose: bool = True,
):
    ts_keys = [
        "last_checkpoint_time",
        "last_processed_time",
        "last_processed_ts",
        "resume_time",
        "resume_ts",
        "cur_time",
        "current_time",
        "last_day_time",
        "last_day_ts",
        "last_daily_ts",
        "last_5m_ts",
        "five_ts_last",
        "day_ts_last",
        "checkpoint_time",
    ]
    for k in ts_keys:
        if k in ckpt and ckpt[k] is not None:
            try:
                ts = pd.to_datetime(ckpt[k])
                if pd.notna(ts):
                    if verbose:
                        print(f"[PLOT START] inferred from checkpoint key '{k}' = {ts}")
                    return ts
            except Exception:
                pass

    daily_idx_keys = [
        "daily_i_last",
        "day_i_last",
        "last_daily_i",
        "last_day_idx",
        "daily_idx_last",
        "current_daily_i",
        "resume_daily_i",
    ]
    if daily_csv_path is not None and os.path.exists(daily_csv_path):
        try:
            df_day = _load_any_csv_time_index(daily_csv_path)
            for k in daily_idx_keys:
                if k in ckpt and ckpt[k] is not None:
                    i = int(ckpt[k])
                    if 0 <= i < len(df_day):
                        ts = pd.to_datetime(df_day.loc[i, "timestamp"])
                        if verbose:
                            print(f"[PLOT START] inferred from daily index key '{k}' = {ts}")
                        return ts
        except Exception as e:
            if verbose:
                print(f"[PLOT START] daily index inference failed: {e}")

    five_idx_keys = [
        "five_i_last",
        "last_5m_i",
        "five_idx_last",
        "current_five_i",
        "resume_five_i",
        "seen_idx_last",
    ]
    if k5m_csv_path is not None and os.path.exists(k5m_csv_path):
        try:
            df_5m = _load_any_csv_time_index(k5m_csv_path)
            for k in five_idx_keys:
                if k in ckpt and ckpt[k] is not None:
                    i = int(ckpt[k])
                    if 0 <= i < len(df_5m):
                        ts = pd.to_datetime(df_5m.loc[i, "timestamp"])
                        if verbose:
                            print(f"[PLOT START] inferred from 5m index key '{k}' = {ts}")
                        return ts
        except Exception as e:
            if verbose:
                print(f"[PLOT START] 5m index inference failed: {e}")

    if verbose:
        print("[PLOT START] could not infer checkpoint plot start time.")
    return None


# ============================================================
# RESUMED-SEGMENT PLOTTING
# ============================================================

def plot_resumed_segment_from_checkpoint(
    res: dict,
    checkpoint_start_time,
    title_prefix: str = "Resumed Run",
    output_dir: str | None = None,
):
    if "daily_log_df" not in res:
        print("res['daily_log_df'] not found, cannot plot.")
        return

    d = res["daily_log_df"].copy()

    if "timestamp" in d.columns:
        d["plot_time"] = pd.to_datetime(d["timestamp"], errors="coerce")
    elif "date" in d.columns:
        d["plot_time"] = pd.to_datetime(d["date"], errors="coerce")
    else:
        ts_candidates = [c for c in d.columns if "time" in c.lower() or "date" in c.lower()]
        if len(ts_candidates) == 0:
            print("No timestamp/date column found in daily_log_df.")
            return
        d["plot_time"] = pd.to_datetime(d[ts_candidates[0]], errors="coerce")

    d = d.dropna(subset=["plot_time"]).sort_values("plot_time").reset_index(drop=True)

    if checkpoint_start_time is not None:
        d = d[d["plot_time"] >= pd.to_datetime(checkpoint_start_time)].copy().reset_index(drop=True)

    if len(d) == 0:
        print("No rows available after checkpoint start time.")
        return

    if output_dir:
        os.makedirs(output_dir, exist_ok=True)

    equity_col = None
    for c in ["equity", "portfolio_value", "nav", "strategy_equity"]:
        if c in d.columns:
            equity_col = c
            break

    if equity_col is not None:
        plt.figure(figsize=(16, 6))
        base_eq = float(d[equity_col].iloc[0]) if np.isfinite(d[equity_col].iloc[0]) else 1.0
        plt.plot(d["plot_time"], d[equity_col] / (base_eq + 1e-12), label="Strategy (normalized)")
        plt.title(f"{title_prefix} | Equity after checkpoint")
        plt.legend()
        plt.grid(True, alpha=0.25)
        plt.tight_layout()
        if output_dir:
            plt.savefig(os.path.join(output_dir, "resumed_equity_from_checkpoint.png"), dpi=200)
        plt.show()

    p_col = None
    for c in d.columns:
        cl = c.lower()
        if c == "p_day" or "prob" in cl or "p_" in cl:
            p_col = c
            break

    if p_col is not None:
        plt.figure(figsize=(16, 5))
        plt.plot(d["plot_time"], d[p_col], label=p_col)
        plt.title(f"{title_prefix} | Daily probability after checkpoint")
        plt.grid(True, alpha=0.25)
        plt.legend()
        plt.tight_layout()
        if output_dir:
            plt.savefig(os.path.join(output_dir, "resumed_pday_from_checkpoint.png"), dpi=200)
        plt.show()

    if "trades_df" in res and isinstance(res["trades_df"], pd.DataFrame) and not res["trades_df"].empty:
        tr = res["trades_df"].copy()
        if "ts" in tr.columns:
            tr["plot_time"] = pd.to_datetime(tr["ts"], errors="coerce")
            tr = tr.dropna(subset=["plot_time"]).sort_values("plot_time").reset_index(drop=True)

            if checkpoint_start_time is not None:
                tr = tr[tr["plot_time"] >= pd.to_datetime(checkpoint_start_time)].copy().reset_index(drop=True)

            if len(tr) > 0 and "exec_px" in tr.columns:
                plt.figure(figsize=(16, 6))
                buys = tr[tr["side"].astype(str).str.lower() == "buy"]
                sells = tr[tr["side"].astype(str).str.lower() == "sell"]

                if len(buys):
                    plt.scatter(buys["plot_time"], buys["exec_px"], marker="^", label="Buy")
                if len(sells):
                    plt.scatter(sells["plot_time"], sells["exec_px"], marker="v", label="Sell")

                plt.title(f"{title_prefix} | Trades after checkpoint")
                plt.grid(True, alpha=0.25)
                plt.legend()
                plt.tight_layout()
                if output_dir:
                    plt.savefig(os.path.join(output_dir, "resumed_trades_from_checkpoint.png"), dpi=200)
                plt.show()


# ============================================================
# MAIN STRATEGY RUNNER
# ============================================================

def run_daily_prob_then_5m_xgb_gated(
    daily_csv_path: str,
    k5m_csv_path: str,
    code: str = "QQQ",

    daily_chan_start: str = "2016-06-01",
    accumulation_start: str = "2018-10-01",
    sim_start: str = "2019-01-01",
    end_time: str = "2019-12-30",

    N_confirm: int = 5,
    min_labeled_days_to_train: int = 200,
    retrain_every_new_labels: int = 25,
    dp_lookback: int = 5,

    p_sell_level: float = 0.30,
    p_buy_level: float = 0.20,

    bar_interval_minutes: int = 5,
    lookahead_days_5m: float = 2.0,
    retrain_every_days_5m: int = 5,
    min_samples_total_5m: int = 300,

    threshold_window_days: float = 2.0,
    threshold_ret_grid=None,
    threshold_min_open_signals: int = 10,

    initial_capital: float = 100000.0,
    fee_pct: float = 0.0,

    daily_chan_max_klines: int = 500,
    five_chan_max_klines: int = 20000,

    macro_files: dict | None = None,

    output_dir: str = "output_dailyprob_gated_5m_xgb",
    verbose: bool = True,

    save_checkpoint_path: str | None = None,
    checkpoint_every_n_days: int = 1,
    resume_from_checkpoint_path: str | None = None,
):
    os.makedirs(output_dir, exist_ok=True)

    if macro_files is None:
        macro_files = {
            "vix_":   "VIX.csv",
            "dxy_":   "DXY.csv",
            "us5y_":  "FVX.csv",
            "us10y_": "TNX.csv",
            "us30y_": "TYX.csv",
            "xau_":   "XAU.csv",
            "nyxbt_": "NYXBT.csv",
        }

    # ----------------------------
    # Load raw data
    # ----------------------------
    df_day_raw = load_ohlcv_csv(daily_csv_path, "DAILY")
    df_5m_raw  = load_ohlcv_csv(k5m_csv_path, "5M")

    daily_s = pd.to_datetime(daily_chan_start)
    acc_s   = pd.to_datetime(accumulation_start)
    sim_s   = pd.to_datetime(sim_start)
    end_t   = pd.to_datetime(end_time)

    df_day = df_day_raw[(df_day_raw["timestamp"] >= daily_s) & (df_day_raw["timestamp"] <= end_t)].copy().reset_index(drop=True)
    if df_day.empty:
        raise ValueError("No daily bars in requested range.")
    df_day_feat = compute_daily_kline_features(df_day)
    df_day_feat["ts_norm"] = pd.to_datetime(df_day_feat["timestamp"]).dt.normalize()

    macro_folder = os.path.dirname(os.path.abspath(daily_csv_path))
    macro_feat = load_macro_features_from_folder(
        folder=macro_folder,
        files=macro_files,
        start=daily_chan_start,
    )
    df_day_feat = df_day_feat.merge(macro_feat, on="ts_norm", how="left").sort_values("timestamp").reset_index(drop=True)

    macro_cols = [
        c for c in df_day_feat.columns
        if (
            c.startswith("vix_")
            or c.startswith("dxy_")
            or c.startswith("us5y_")
            or c.startswith("us10y_")
            or c.startswith("us30y_")
            or c.startswith("xau_")
            or c.startswith("nyxbt_")
            or c.startswith("yc_")
        )
    ]

    df_5m = df_5m_raw[(df_5m_raw["timestamp"] >= acc_s) & (df_5m_raw["timestamp"] <= end_t + pd.Timedelta(days=1))].copy()
    df_5m = df_5m.sort_values("timestamp").reset_index(drop=True)

    df_5m_idx, next_open_by_idx, next_close_by_idx, closes, highs, lows, day_close_map, all_days = load_5m_index(
        df_5m, accumulation_start, end_time
    )
    buy_hold = compute_buy_hold_equity(day_close_map, all_days, initial_capital)

    # ----------------------------
    # Chan config / objects
    # ----------------------------
    config = CChanConfig({
        "cal_demark": True,
        "cal_kdj": True,
        "cal_dmi": True,
        "cal_rsi": True,
        "cal_rsl": True,
        "cal_demand_index": True,
        "cal_adline": True,
        "cal_bb_vals": True,
        "cal_kc_vals": True,
        "cal_starc_vals": True,
        "bi_strict": True,
        "trigger_step": True,
        "skip_step": 0,
        "divergence_rate": float("inf"),
        "bsp2_follow_1": True,
        "bsp3_follow_1": False,
        "min_zs_cnt": 0,
        "bs1_peak": False,
        "macd_algo": "peak",
        "bs_type": "1,2,3a,1p,2s,3b",
        "print_warning": False,
        "zs_algo": "normal",
    })

    daily_chan = SlidingWindowChan(
        code=code,
        begin_time=None,
        end_time=None,
        data_src=getattr(DATA_SRC, "CSV", "CSV"),
        lv_list=[KL_TYPE.K_DAY],
        config=config,
        autype=AUTYPE.QFQ,
        max_klines=int(daily_chan_max_klines),
    )

    chan_5m = SlidingWindowChan(
        code=code,
        begin_time=None,
        end_time=None,
        data_src=getattr(DATA_SRC, "CSV", "CSV"),
        lv_list=[KL_TYPE.K_5M],
        config=config,
        autype=AUTYPE.QFQ,
        max_klines=int(five_chan_max_klines),
    )

    # ----------------------------
    # Fresh state defaults
    # ----------------------------
    bsp_rows_daily = []
    seen_bsp_daily = set()

    X_days = []
    y_days = []
    st = DailyProbState()
    pending_idx = []

    p_series = np.full(len(df_day_feat), np.nan, dtype=float)
    dp_vs_minK_series = np.full(len(df_day_feat), np.nan, dtype=float)
    dp_vs_maxK_series = np.full(len(df_day_feat), np.nan, dtype=float)
    p_by_day = {}

    engine = ExecutionEngine(initial_capital=initial_capital, fee_pct=fee_pct)
    bsp_rows_5m = []
    seen_keys_5m = set()
    buy_pack = None
    sell_pack = None
    last_train_day = None

    if threshold_ret_grid is None:
        threshold_ret_grid = make_ret_grid(-0.5, 2.5, 0.05)
    buy_ret_th_live = 0.30
    sell_ret_th_live = 0.30

    daily_i_start = 0
    five_i_start = 0
    current_day = None
    daily_log = []

    # ----------------------------
    # Resume restore
    # ----------------------------
    if resume_from_checkpoint_path is not None and os.path.exists(resume_from_checkpoint_path):
        B = load_checkpoint_bundle(resume_from_checkpoint_path)
        if verbose:
            print(f"[RESUME] loading checkpoint: {resume_from_checkpoint_path} @ {B.get('checkpoint_time')}")

        st.model = B.get("daily_prob_model", None)
        st.trained_n = int(B.get("daily_prob_trained_n", 0))
        st.new_labels = 0

        X_days = B.get("X_days", []) or []
        y_days = B.get("y_days", []) or []
        pending_idx = B.get("pending_idx", []) or []

        p_series_loaded = B.get("p_series", None)
        if p_series_loaded is not None and len(p_series_loaded) == len(p_series):
            p_series = np.asarray(p_series_loaded, dtype=float)

        dp_min_loaded = B.get("dp_vs_minK_series", None)
        dp_max_loaded = B.get("dp_vs_maxK_series", None)
        if dp_min_loaded is not None and len(dp_min_loaded) == len(dp_vs_minK_series):
            dp_vs_minK_series = np.asarray(dp_min_loaded, dtype=float)
        if dp_max_loaded is not None and len(dp_max_loaded) == len(dp_vs_maxK_series):
            dp_vs_maxK_series = np.asarray(dp_max_loaded, dtype=float)

        p_by_day_str = B.get("p_by_day_str", {}) or {}
        p_by_day = {pd.to_datetime(k).normalize(): float(v) for k, v in p_by_day_str.items()}

        bsp_rows_daily = B.get("bsp_rows_daily", []) or []
        seen_bsp_daily = _safe_list_to_set(B.get("seen_bsp_daily_list", []))

        buy_pack = unpack_ret_modelpack_from_load(B.get("buy_pack", None))
        sell_pack = unpack_ret_modelpack_from_load(B.get("sell_pack", None))
        buy_ret_th_live = float(B.get("buy_ret_th_live", buy_ret_th_live))
        sell_ret_th_live = float(B.get("sell_ret_th_live", sell_ret_th_live))

        bsp_rows_5m = B.get("bsp_rows_5m", []) or []
        seen_keys_5m = _safe_list_to_set(B.get("seen_keys_5m_list", []))

        engine.load_state_dict(B.get("engine_state", {}) or {})
        if engine.pending_order is not None:
            if "signal_idx" not in engine.pending_order and "seen_idx" in engine.pending_order:
                engine.pending_order["signal_idx"] = int(engine.pending_order["seen_idx"])
        daily_log = B.get("daily_log", []) or []

        daily_i_start = int(B.get("daily_i_last", -1)) + 1
        five_i_start = int(B.get("five_i_last", -1)) + 1

        cur_day_s = B.get("current_day", None)
        current_day = None if cur_day_s is None else datetime.date.fromisoformat(cur_day_s)

        # ----------------------------
        # Warm daily chan safely
        # ----------------------------
        warm_day = B.get("warmup_daily_bars", None)
        last_warm_day_ts = None
        if warm_day is not None and len(warm_day):
            warm_day = warm_day.copy()
            warm_day["timestamp"] = pd.to_datetime(warm_day["timestamp"], errors="coerce")
            warm_day = (
                warm_day.dropna(subset=["timestamp"])
                        .sort_values("timestamp")
                        .drop_duplicates(subset=["timestamp"], keep="last")
                        .reset_index(drop=True)
            )

            for _, rr in warm_day.iterrows():
                ts = pd.to_datetime(rr["timestamp"])
                daily_chan.process_new_kline(
                    build_klu(
                        ts,
                        rr["_open"], rr["_high"], rr["_low"], rr["_close"],
                        rr.get("_vol", 0.0)
                    )
                )
            if len(warm_day):
                last_warm_day_ts = pd.to_datetime(warm_day["timestamp"].iloc[-1])

        # ----------------------------
        # Warm 5m chan safely
        # ----------------------------
        warm_5m = B.get("warmup_5m_bars", None)
        last_warm_5m_ts = None
        if warm_5m is not None and len(warm_5m):
            warm_5m = warm_5m.copy()
            warm_5m["timestamp"] = pd.to_datetime(warm_5m["timestamp"], errors="coerce")
            warm_5m = (
                warm_5m.dropna(subset=["timestamp"])
                       .sort_values("timestamp")
                       .drop_duplicates(subset=["timestamp"], keep="last")
                       .reset_index(drop=True)
            )

            for _, rr in warm_5m.iterrows():
                ts = pd.to_datetime(rr["timestamp"])
                feed_chan_one(
                    chan_5m,
                    build_klu(
                        ts,
                        rr["_open"], rr["_high"], rr["_low"], rr["_close"],
                        rr.get("_vol", 0.0)
                    )
                )
            if len(warm_5m):
                last_warm_5m_ts = pd.to_datetime(warm_5m["timestamp"].iloc[-1])

        # ----------------------------
        # REALIGN start indices by warmup tail timestamp
        # This is the key fix
        # ----------------------------
        if last_warm_day_ts is not None:
            day_pos = df_day_feat.index[df_day_feat["timestamp"] > last_warm_day_ts]
            daily_i_start = int(day_pos[0]) if len(day_pos) else len(df_day_feat)

        if last_warm_5m_ts is not None:
            five_pos = df_5m_idx.index[df_5m_idx["timestamp"] > last_warm_5m_ts]
            five_i_start = int(five_pos[0]) if len(five_pos) else len(df_5m_idx)

        if verbose:
            print(f"[RESUME] last_warm_day_ts={last_warm_day_ts}")
            print(f"[RESUME] last_warm_5m_ts={last_warm_5m_ts}")
            print(f"[RESUME] realigned daily_i_start={daily_i_start} / {len(df_day_feat)}")
            print(f"[RESUME] realigned five_i_start={five_i_start} / {len(df_5m_idx)}")
            print(f"[RESUME] daily_model={'YES' if st.model is not None else 'NO'} "
                  f"5m_buy={'YES' if buy_pack else 'NO'} 5m_sell={'YES' if sell_pack else 'NO'}")

    # ----------------------------
    # Daily trainer helper
    # ----------------------------
    def maybe_train_daily():
        if len(y_days) < int(min_labeled_days_to_train):
            return
        if st.model is None or st.new_labels >= int(retrain_every_new_labels):
            y = np.asarray(y_days, dtype=int)
            if len(np.unique(y)) < 2:
                return
            try:
                st.model = fit_prob_model_dicts(X_days, y)
                st.trained_n = len(y)
                st.new_labels = 0
                if verbose:
                    print(f"[TRAIN][DAILY-PROB] n={len(y)} pos={int(y.sum())} ({y.mean():.2%})")
            except Exception as e:
                if verbose:
                    print(f"[TRAIN][DAILY-PROB] skipped: {e}")

    # ----------------------------
    # Save checkpoint helper
    # ----------------------------
    def save_checkpoint(now_ts: pd.Timestamp, daily_i_last: int, five_i_last: int, current_day):
        nonlocal daily_log
        if save_checkpoint_path is None:
            return

        warm_daily = df_day_raw[df_day_raw["timestamp"] <= now_ts].tail(int(daily_chan_max_klines)).copy()
        warm_5m = df_5m_raw[df_5m_raw["timestamp"] <= now_ts].tail(int(five_chan_max_klines)).copy()

        bundle = build_checkpoint_bundle(
            code=code,
            checkpoint_time=str(now_ts),

            original_daily_chan_start=str(daily_chan_start),
            original_accumulation_start=str(accumulation_start),
            original_sim_start=str(sim_start),
            original_end_time=str(end_time),

            macro_files=macro_files,

            daily_prob_model=st.model,
            daily_prob_trained_n=st.trained_n,
            X_days=X_days,
            y_days=y_days,
            pending_idx=pending_idx,
            p_by_day=p_by_day,
            p_series=p_series,
            dp_vs_minK_series=dp_vs_minK_series,
            dp_vs_maxK_series=dp_vs_maxK_series,
            bsp_rows_daily=bsp_rows_daily,
            seen_bsp_daily=seen_bsp_daily,

            buy_pack=buy_pack,
            sell_pack=sell_pack,
            buy_ret_th_live=buy_ret_th_live,
            sell_ret_th_live=sell_ret_th_live,

            bsp_rows_5m=bsp_rows_5m,
            seen_keys_5m=seen_keys_5m,

            engine_state=engine.state_dict(),
            daily_log=daily_log,

            daily_i_last=daily_i_last,
            five_i_last=five_i_last,
            current_day=current_day,

            warmup_daily_bars=warm_daily[["timestamp","_open","_high","_low","_close","_vol"]].reset_index(drop=True),
            warmup_5m_bars=warm_5m[["timestamp","_open","_high","_low","_close","_vol"]].reset_index(drop=True),

            daily_chan_max_klines=daily_chan_max_klines,
            five_chan_max_klines=five_chan_max_klines,
        )

        save_joblib(save_checkpoint_path, bundle)
        if verbose:
            print(f"[CHECKPOINT] saved -> {save_checkpoint_path} @ {now_ts}")

    # ----------------------------
    # DAILY PHASE
    # ----------------------------
    for i in range(daily_i_start, len(df_day_feat)):
        r = df_day_feat.loc[i]
        ts = pd.to_datetime(r["timestamp"])
        day = ts.normalize()

        daily_chan.process_new_kline(build_klu(ts, r["_open"], r["_high"], r["_low"], r["_close"], r["_vol"]))

        new_bsp = extract_bsp_rows_from_chan(daily_chan)
        if new_bsp:
            for rr0 in new_bsp:
                rr = normalize_bsp_row(dict(rr0))
                rr.setdefault("timestamp", ts)
                key = (pd.to_datetime(rr["timestamp"]).strftime("%Y-%m-%d"), rr["direction"], rr.get("bsp_type", "?"))
                if key in seen_bsp_daily:
                    continue
                seen_bsp_daily.add(key)
                bsp_rows_daily.append(rr)

        ends = compute_chain_endpoints(bsp_rows_daily)
        regime = regime_for_day_from_ends(day, ends)
        base_dir_today = latest_bsp_dir_up_to(bsp_rows_daily, ts)

        p_val = np.nan
        if st.model is not None:
            bsp_hist = [b for b in bsp_rows_daily if pd.to_datetime(b["timestamp"]) <= ts]
            feat_i = make_daily_features_one_model(
                kline_row=r,
                bsp_hist_up_to_day=bsp_hist,
                p_val=0.0,
                dp_minK=0.0,
                dp_maxK=0.0,
                regime=regime,
                base_dir=base_dir_today,
                macro_cols=macro_cols,
            )
            p_val = float(predict_prob(st.model, [feat_i])[0])
            p_series[i] = p_val
            p_by_day[day] = p_val

        lb = int(dp_lookback)
        p_minK = np.nan
        p_maxK = np.nan
        if lb > 0 and i >= 1 and np.isfinite(p_val):
            start = max(0, i - lb)
            prev = pd.Series(p_series[start:i]).dropna()
            if len(prev) > 0:
                p_minK = float(prev.min())
                p_maxK = float(prev.max())

        dp_vs_minK = (p_val - p_minK) if (np.isfinite(p_val) and np.isfinite(p_minK)) else np.nan
        dp_vs_maxK = (p_val - p_maxK) if (np.isfinite(p_val) and np.isfinite(p_maxK)) else np.nan
        dp_vs_minK_series[i] = dp_vs_minK
        dp_vs_maxK_series[i] = dp_vs_maxK

        pending_idx.append(i)
        while pending_idx and i >= pending_idx[0] + int(N_confirm):
            j = pending_idx.pop(0)
            t0 = pd.to_datetime(df_day_feat.loc[j, "timestamp"])
            base_dir_j = latest_bsp_dir_up_to(bsp_rows_daily, t0)
            if base_dir_j not in ("buy", "sell"):
                continue

            y = label_confirm_extreme(df_day_feat, j, int(N_confirm), base_dir_j)
            if y is None:
                continue

            ends_j = compute_chain_endpoints([b for b in bsp_rows_daily if pd.to_datetime(b["timestamp"]) <= t0])
            regime_j = regime_for_day_from_ends(t0.normalize(), ends_j)

            bsp_hist_j = [b for b in bsp_rows_daily if pd.to_datetime(b["timestamp"]) <= t0]
            feat_j = make_daily_features_one_model(
                kline_row=df_day_feat.loc[j],
                bsp_hist_up_to_day=bsp_hist_j,
                p_val=float(p_series[j]) if np.isfinite(p_series[j]) else 0.0,
                dp_minK=float(dp_vs_minK_series[j]) if np.isfinite(dp_vs_minK_series[j]) else 0.0,
                dp_maxK=float(dp_vs_maxK_series[j]) if np.isfinite(dp_vs_maxK_series[j]) else 0.0,
                regime=regime_j,
                base_dir=base_dir_j,
                macro_cols=macro_cols,
            )

            X_days.append(feat_j)
            y_days.append(int(y))
            st.new_labels += 1

        maybe_train_daily()

    feat_imp_path = os.path.join(output_dir, "daily_lr_feature_importance.csv")
    if st.model is not None:
        try:
            imp_df = feature_importance_from_lr(st.model, top_n=120)
            imp_df.to_csv(feat_imp_path, index=False)
            if verbose:
                print(f"[SAVED] {feat_imp_path}")
        except Exception as e:
            if verbose:
                print(f"[IMP][DAILY-PROB] skipped: {e}")

    # ----------------------------
    # 5M PHASE
    # ----------------------------
    if verbose:
        print(f"[PHASE2/3] 5m feed begins at accumulation_start={acc_s.date()}, trading starts at sim_s={sim_s.date()}")

    def maybe_retrain_5m(day_ts: pd.Timestamp):
        nonlocal buy_pack, sell_pack, last_train_day
        if last_train_day is not None and (day_ts - last_train_day).days < int(retrain_every_days_5m):
            return
        dfb = pd.DataFrame(bsp_rows_5m)
        if dfb.empty:
            return
        dfb2 = prepare_ml_dataset(dfb)
        feat_cols = get_feature_columns(dfb2)
        bp, sp = train_models_two_sided_ret_only(dfb2, feat_cols, min_samples_total=min_samples_total_5m)
        if bp is not None:
            buy_pack = bp
        if sp is not None:
            sell_pack = sp
        if (bp is not None) or (sp is not None):
            last_train_day = day_ts
            if verbose:
                print(f"[TRAIN][5M] asof={day_ts.date()} feats={len(feat_cols)} buy={'YES' if bp else 'NO'} sell={'YES' if sp else 'NO'} rows={len(dfb2)}")

    def maybe_opt_thresholds(asof_bar_idx: int):
        nonlocal buy_ret_th_live, sell_ret_th_live
        if buy_pack is None or sell_pack is None:
            return
        out = choose_thresholds_global_realized(
            df_5m=df_5m_idx,
            bsp_rows=bsp_rows_5m,
            buy_pack=buy_pack,
            sell_pack=sell_pack,
            asof_bar_idx=asof_bar_idx,
            window_days=threshold_window_days,
            ret_grid=threshold_ret_grid,
            next_open_by_idx=next_open_by_idx,
            closes=closes,
            fee_pct=fee_pct,
            min_open_signals=threshold_min_open_signals,
        )
        if out is not None:
            buy_ret_th_live, sell_ret_th_live = out
            if verbose:
                print(f"[TH-OPT][GLOBAL] asof_bar={asof_bar_idx} buy_th={buy_ret_th_live:.2f} sell_th={sell_ret_th_live:.2f}")

    sim_start_ts = pd.to_datetime(sim_start)
    last_day_end_idx = None
    day_gate = "NO_P"
    must_trade_dir = None
    allow_buy = True
    allow_sell = True
    days_since_checkpoint = 0

    for i in range(five_i_start, len(df_5m_idx)):
        bar_ts = pd.to_datetime(df_5m_idx.loc[i, "timestamp"])
        bar_day = bar_ts.date()
        in_sim = (bar_ts >= sim_start_ts)

        if current_day is None:
            current_day = bar_day
            p_day = p_by_day.get(pd.to_datetime(bar_day), np.nan)
            day_gate = gate_from_p(p_day, p_sell_level, p_buy_level)

            allow_buy = True
            allow_sell = True
            must_trade_dir = None

            if day_gate == "FORCE_BUY":
                allow_sell = False
                if engine.pos == 0:
                    must_trade_dir = "buy"
            elif day_gate == "FORCE_SELL":
                allow_buy = False
                if engine.pos == 1:
                    must_trade_dir = "sell"

        if bar_day != current_day:
            prev_day = current_day
            prev_day_ts = pd.to_datetime(prev_day)

            label_bestlookahead_for_ready_points(
                bsp_rows=bsp_rows_5m,
                highs=highs, lows=lows, closes=closes,
                lookahead_days=lookahead_days_5m,
                bar_interval_minutes=bar_interval_minutes,
                current_bar_idx=i,
            )

            maybe_retrain_5m(prev_day_ts)
            if last_day_end_idx is not None:
                maybe_opt_thresholds(last_day_end_idx)

            day_close = day_close_map.get(prev_day)
            equity = engine.mark_to_market(day_close) if day_close is not None else engine.cash
            daily_log.append({
                "date": prev_day,
                "equity": equity,
                "cash": engine.cash,
                "pos": engine.pos,
                "buy_th": buy_ret_th_live,
                "sell_th": sell_ret_th_live,
                "p_day": float(p_by_day.get(pd.to_datetime(prev_day), np.nan)),
            })

            days_since_checkpoint += 1
            if save_checkpoint_path is not None and days_since_checkpoint >= int(checkpoint_every_n_days):
                save_checkpoint(
                    now_ts=pd.to_datetime(df_5m_idx.loc[last_day_end_idx, "timestamp"]),
                    daily_i_last=(len(df_day_feat) - 1),
                    five_i_last=int(last_day_end_idx),
                    current_day=prev_day,
                )
                days_since_checkpoint = 0

            current_day = bar_day
            p_day = p_by_day.get(pd.to_datetime(bar_day), np.nan)
            day_gate = gate_from_p(p_day, p_sell_level, p_buy_level)

            allow_buy = True
            allow_sell = True
            must_trade_dir = None

            if day_gate == "FORCE_BUY":
                allow_sell = False
                if engine.pos == 0:
                    must_trade_dir = "buy"
            elif day_gate == "FORCE_SELL":
                allow_buy = False
                if engine.pos == 1:
                    must_trade_dir = "sell"

        last_day_end_idx = i

        if in_sim:
            engine.maybe_execute_pending(next_open_by_idx)

        klu = build_klu(
            df_5m_idx.loc[i, "timestamp"],
            df_5m_idx.loc[i, "Open"], df_5m_idx.loc[i, "High"], df_5m_idx.loc[i, "Low"], df_5m_idx.loc[i, "Close"],
            df_5m_idx.loc[i, "Volume"],
        )
        feed_chan_one(chan_5m, klu)

        new_rows = extract_bsp_rows_from_chan(chan_5m)
        if not new_rows:
            continue

        for r0 in new_rows:
            r = dict(r0)
            r.setdefault("timestamp", str(bar_ts))
            r.setdefault("klu_idx", i)

            if "direction" not in r or r["direction"] is None:
                if r.get("is_buy", None) is not None:
                    r["direction"] = "buy" if bool(r["is_buy"]) else "sell"
                else:
                    r["direction"] = "buy"
            r["direction"] = str(r["direction"]).lower()
            if "bsp_type" in r and r["bsp_type"] is not None:
                r["bsp_type"] = str(r["bsp_type"]).lower()
            r.setdefault("best_return_pct", np.nan)

            k = (int(r.get("klu_idx", -1)), str(r.get("direction")), str(r.get("bsp_type")))
            if k in seen_keys_5m:
                continue
            seen_keys_5m.add(k)
            bsp_rows_5m.append(r)

            if not in_sim:
                continue

            d = str(r.get("direction", "buy")).lower()
            ki = int(r.get("klu_idx", i))

            if d == "buy" and not allow_buy:
                continue
            if d == "sell" and not allow_sell:
                continue
            if must_trade_dir is not None and d != must_trade_dir:
                continue

            if d == "buy" and engine.pos == 0 and buy_pack is not None:
                row_df = prepare_ml_dataset(pd.DataFrame([r]))
                for cc in buy_pack.feature_cols:
                    if cc not in row_df.columns:
                        row_df[cc] = 0.0
                pr = predict_ret(buy_pack, row_df)
                if pr >= float(buy_ret_th_live):
                    engine.place_order_for_next_bar(
                        side="buy",
                        seen_idx=ki,
                        reason=("FORCE_BUY->first acceptable 5m signal" if day_gate == "FORCE_BUY" else "5m BUY signal"),
                        meta={
                            "ts": str(bar_ts),
                            "p_day": float(p_by_day.get(pd.to_datetime(bar_day), np.nan)),
                            "pred": float(pr),
                            "th": float(buy_ret_th_live),
                            "gate": day_gate,
                        },
                    )
                    if must_trade_dir == "buy":
                        must_trade_dir = None

            elif d == "sell" and engine.pos == 1 and sell_pack is not None:
                row_df = prepare_ml_dataset(pd.DataFrame([r]))
                for cc in sell_pack.feature_cols:
                    if cc not in row_df.columns:
                        row_df[cc] = 0.0
                pr = predict_ret(sell_pack, row_df)
                if pr >= float(sell_ret_th_live):
                    engine.place_order_for_next_bar(
                        side="sell",
                        seen_idx=ki,
                        reason=("FORCE_SELL->first acceptable 5m signal" if day_gate == "FORCE_SELL" else "5m SELL signal"),
                        meta={
                            "ts": str(bar_ts),
                            "p_day": float(p_by_day.get(pd.to_datetime(bar_day), np.nan)),
                            "pred": float(pr),
                            "th": float(sell_ret_th_live),
                            "gate": day_gate,
                        },
                    )
                    if must_trade_dir == "sell":
                        must_trade_dir = None

    if current_day is not None:
        day_close = day_close_map.get(current_day)
        equity = engine.mark_to_market(day_close) if day_close is not None else engine.cash
        daily_log.append({
            "date": current_day,
            "equity": equity,
            "cash": engine.cash,
            "pos": engine.pos,
            "buy_th": buy_ret_th_live,
            "sell_th": sell_ret_th_live,
            "p_day": float(p_by_day.get(pd.to_datetime(current_day), np.nan)),
        })

    if save_checkpoint_path is not None and len(df_5m_idx) > 0:
        final_ts = pd.to_datetime(df_5m_idx.loc[len(df_5m_idx)-1, "timestamp"])
        save_checkpoint(
            now_ts=final_ts,
            daily_i_last=(len(df_day_feat) - 1),
            five_i_last=(len(df_5m_idx) - 1),
            current_day=current_day,
        )

    # ----------------------------
    # Save outputs
    # ----------------------------
    trades_df = pd.DataFrame(engine.trades)
    daily_df = pd.DataFrame(daily_log)
    if not daily_df.empty:
        if "date" in daily_df.columns:
            daily_df["date"] = pd.to_datetime(daily_df["date"])
            daily_df = daily_df.sort_values("date").reset_index(drop=True)

    trades_csv = os.path.join(output_dir, "trades.csv")
    daily_csv = os.path.join(output_dir, "daily_log.csv")
    trades_df.to_csv(trades_csv, index=False)
    daily_df.to_csv(daily_csv, index=False)

    out_eq = os.path.join(output_dir, "equity_vs_buyhold.png")
    out_px = os.path.join(output_dir, "price_with_trades.png")
    out_p  = os.path.join(output_dir, "p_day.png")

    plt.figure()
    if not daily_df.empty and "date" in daily_df.columns and "equity" in daily_df.columns:
        plt.plot(daily_df["date"], daily_df["equity"], label="Strategy Equity")
    if len(buy_hold) > 0:
        plt.plot(buy_hold.index, buy_hold.values, label="Buy&Hold")
    plt.legend()
    plt.title("Equity vs Buy&Hold")
    plt.xlabel("Date")
    plt.ylabel("Equity")
    plt.savefig(out_eq, dpi=150, bbox_inches="tight")
    plt.show()

    plt.figure()
    plt.plot(df_5m_idx["timestamp"], df_5m_idx["Close"], label="5m Close")
    if not trades_df.empty and "seen_idx" in trades_df.columns and "exec_px" in trades_df.columns:
        for _, tr in trades_df.iterrows():
            idx = int(tr["seen_idx"])
            if idx in df_5m_idx.index:
                t = pd.to_datetime(df_5m_idx.loc[idx, "timestamp"])
                px = float(tr["exec_px"])
                if tr.get("side", "") == "buy":
                    plt.scatter([t], [px], marker="^")
                else:
                    plt.scatter([t], [px], marker="v")
    plt.title("Price with Trade Markers")
    plt.xlabel("Time")
    plt.ylabel("Price")
    plt.savefig(out_px, dpi=150, bbox_inches="tight")
    plt.show()

    days_sorted = sorted(p_by_day.keys())
    if days_sorted:
        plt.figure()
        xs = pd.to_datetime(days_sorted)
        ys = [p_by_day[d] for d in days_sorted]
        plt.plot(xs, ys, label="p_day")
        plt.axhline(p_sell_level, linestyle="--", label="p_sell_level")
        plt.axhline(p_buy_level, linestyle="--", label="p_buy_level")
        plt.legend()
        plt.title("Daily Probability p_day")
        plt.xlabel("Date")
        plt.ylabel("Probability")
        plt.savefig(out_p, dpi=150, bbox_inches="tight")
        plt.show()

    if verbose:
        print(f"[SAVED] {trades_csv}")
        print(f"[SAVED] {daily_csv}")
        print(f"[SAVED] {out_eq}")
        print(f"[SAVED] {out_px}")
        if days_sorted:
            print(f"[SAVED] {out_p}")
        if st.model is not None:
            print(f"[SAVED] {feat_imp_path}")
        print(f"[TRADES] total={len(trades_df)}")
        if not trades_df.empty and "seen_idx" in trades_df.columns:
            min_seen_idx = int(trades_df["seen_idx"].min())
            if min_seen_idx in df_5m_idx.index:
                ts0 = pd.to_datetime(df_5m_idx.loc[min_seen_idx, "timestamp"])
                print(f"[TRADES] first_trade_ts={ts0} (sim_start={sim_start_ts})")
            else:
                print(f"[TRADES] first_trade_seen_idx={min_seen_idx} not found in current df_5m_idx index")

    return {
        "trades_df": trades_df,
        "daily_log_df": daily_df,
        "p_by_day": p_by_day,
        "buy_hold": buy_hold,
        "output_dir": output_dir,
        "checkpoint_path": save_checkpoint_path,
    }

def make_resumed_checkpoint_path(checkpoint_path: str) -> str:
    base_dir = os.path.dirname(checkpoint_path) or "."
    ckpt_name = os.path.basename(checkpoint_path)

    root, ext = os.path.splitext(ckpt_name)
    if ext == "":
        ext = ".joblib"

    resumed_dir = os.path.join(base_dir, "resumed")
    os.makedirs(resumed_dir, exist_ok=True)

    return os.path.join(resumed_dir, f"{root}__resumed{ext}")
# ============================================================
# RESUME WRAPPER
# ============================================================

def resume_from_checkpoint(
    checkpoint_path: str,
    daily_csv_path: str,
    k5m_csv_path: str,
    end_time: str | None = None,
    output_dir: str = "output_resumed_run",
    verbose: bool = True,
    plot_from_checkpoint: bool = True,
):
    if not os.path.exists(checkpoint_path):
        raise FileNotFoundError(f"Checkpoint not found: {checkpoint_path}")

    ckpt = load_checkpoint_bundle(checkpoint_path)

    code = ckpt.get("code", "QQQ")
    original_daily_chan_start = ckpt.get("original_daily_chan_start")
    original_accumulation_start = ckpt.get("original_accumulation_start")
    original_sim_start = ckpt.get("original_sim_start")
    original_end_time = ckpt.get("original_end_time")
    macro_files = ckpt.get("macro_files", None)

    if original_daily_chan_start is None or original_accumulation_start is None or original_sim_start is None:
        raise ValueError(
            "This checkpoint does not contain the original run window. "
            "It was likely created by the older checkpoint format."
        )

    final_end_time = end_time if end_time is not None else original_end_time
    resumed_checkpoint_path = make_resumed_checkpoint_path(checkpoint_path)

    checkpoint_plot_start = infer_checkpoint_plot_start_time(
        ckpt=ckpt,
        daily_csv_path=daily_csv_path,
        k5m_csv_path=k5m_csv_path,
        verbose=verbose,
    )

    if verbose:
        print(f"[RESUME WRAPPER] load_checkpoint={checkpoint_path}")
        print(f"[RESUME WRAPPER] resumed_checkpoint_save={resumed_checkpoint_path}")
        print(f"[RESUME WRAPPER] code={code}")
        print(f"[RESUME WRAPPER] original_daily_chan_start={original_daily_chan_start}")
        print(f"[RESUME WRAPPER] original_accumulation_start={original_accumulation_start}")
        print(f"[RESUME WRAPPER] original_sim_start={original_sim_start}")
        print(f"[RESUME WRAPPER] original_end_time={original_end_time}")
        print(f"[RESUME WRAPPER] continue_until={final_end_time}")
        print(f"[RESUME WRAPPER] plot_from={checkpoint_plot_start}")
        print(f"[RESUME WRAPPER] output_dir={output_dir}")

    res = run_daily_prob_then_5m_xgb_gated(
        daily_csv_path=daily_csv_path,
        k5m_csv_path=k5m_csv_path,
        code=code,

        daily_chan_start=original_daily_chan_start,
        accumulation_start=original_accumulation_start,
        sim_start=original_sim_start,
        end_time=final_end_time,

        N_confirm=5,
        min_labeled_days_to_train=200,
        retrain_every_new_labels=25,
        dp_lookback=5,

        p_sell_level=0.30,
        p_buy_level=0.20,

        lookahead_days_5m=2.0,
        retrain_every_days_5m=5,
        min_samples_total_5m=300,

        threshold_window_days=2.0,
        threshold_ret_grid=None,
        threshold_min_open_signals=10,

        initial_capital=100000.0,
        fee_pct=0.0,

        daily_chan_max_klines=int(ckpt.get("daily_chan_max_klines", 500)),
        five_chan_max_klines=int(ckpt.get("five_chan_max_klines", 500)),

        macro_files=macro_files,

        output_dir=output_dir,
        verbose=verbose,

        resume_from_checkpoint_path=checkpoint_path,
        save_checkpoint_path=resumed_checkpoint_path,
        checkpoint_every_n_days=5,
    )

    res["checkpoint_plot_start"] = checkpoint_plot_start

    if plot_from_checkpoint:
        plot_resumed_segment_from_checkpoint(
            res=res,
            checkpoint_start_time=checkpoint_plot_start,
            title_prefix=f"{code} resumed from checkpoint",
            output_dir=output_dir,
        )

    return res


# ============================================================
# EXAMPLE: FRESH RUN
# ============================================================
# res = run_daily_prob_then_5m_xgb_gated(
#     daily_csv_path="DataAPI/data/QQQ_DAY.csv",
#     k5m_csv_path="DataAPI/data/QQQ_5M.csv",
#     code="QQQ",

#     daily_chan_start="2014-06-01",
#     accumulation_start="2016-10-01",
#     sim_start="2019-01-01",
#     end_time="2026-12-31",

#     N_confirm=5,
#     min_labeled_days_to_train=200,
#     retrain_every_new_labels=25,
#     dp_lookback=5,

#     p_sell_level=0.30,
#     p_buy_level=0.20,

#     lookahead_days_5m=2.0,
#     retrain_every_days_5m=5,
#     min_samples_total_5m=300,

#     threshold_window_days=2.0,
#     threshold_ret_grid=None,
#     threshold_min_open_signals=10,

#     initial_capital=100000.0,
#     fee_pct=0.0,

#     daily_chan_max_klines=500,
#     five_chan_max_klines=500,

#     macro_files={
#         "vix_":   "VIX.csv",
#         "dxy_":   "DXY.csv",
#         "us5y_":  "US5Y.csv",
#         "us10y_": "US10Y.csv",
#         "us30y_": "US30Y.csv",
#         "xau_":   "XAU.csv",
#         "nyxbt_": "NYXBT.csv",
#         "10y2ys_": "10Y2YS.csv",
#         "us2y_": "US2Y.csv",
#         #spgsci_": "SPGSCI.csv",
#     },

#     output_dir="output_dailyprob_gated_5m_xgb_QQQ_macro_us2",
#     verbose=True,

#     save_checkpoint_path="checkpoints/QQQ_macro_US2_checkpoint.joblib",
#     checkpoint_every_n_days=5,
# )

# ============================================================
# EXAMPLE: RESUME
# ============================================================
# res = resume_from_checkpoint(
#     checkpoint_path="checkpoints/QQQ_macro_checkpoint.joblib",
#     daily_csv_path="DataAPI/data/QQQ_DAY.csv",
#     k5m_csv_path="DataAPI/data/QQQ_5M.csv",
#     end_time="2026-12-31",
#     output_dir="output_resumed_QQQ_macro",
#     verbose=True,
#     plot_from_checkpoint=True,
# )
#
# display(res["trades_df"].tail(50))
# display(res["daily_log_df"].tail(20))
# print("checkpoint_plot_start =", res.get("checkpoint_plot_start"))

# %%
res = run_daily_prob_then_5m_xgb_gated(
    daily_csv_path="DataAPI/data/QQQ_DAY.csv",
    k5m_csv_path="DataAPI/data/QQQ_5M.csv",
    code="QQQ",

    daily_chan_start="2020-06-01",
    accumulation_start="2022-10-01",
    sim_start="2024-01-01",
    end_time="2026-12-31",

    N_confirm=5,
    min_labeled_days_to_train=200,
    retrain_every_new_labels=25,
    dp_lookback=5,

    p_sell_level=0.30,
    p_buy_level=0.20,

    lookahead_days_5m=2.0,
    retrain_every_days_5m=5,
    min_samples_total_5m=300,

    threshold_window_days=2.0,
    threshold_ret_grid=None,
    threshold_min_open_signals=10,

    initial_capital=100000.0,
    fee_pct=0.0,

    daily_chan_max_klines=500,
    five_chan_max_klines=500,

    macro_files={
        "vix_":   "VIX.csv",
        # "dxy_":   "DXY.csv",
        # "us5y_":  "US5Y.csv",
        # "us10y_": "US10Y.csv",
        # "us30y_": "US30Y.csv",
        # "xau_":   "XAU.csv",
        # "nyxbt_": "NYXBT.csv",
        # "10y2ys_": "10Y2YS.csv",
        # "us2y_": "US2Y.csv",
        # "spgsci_": "SPGSCI.csv",
        # "spy_": "SPY_DAY.csv",
        # "qqq_": "QQQ_DAY.csv",
        # "rut_": "RUT.csv",
        # "vvix_": "VVIX.csv",
        # "vix3m_": "VIX3M.csv",
        # "vxn_": "VXN.csv",
        # "rvx_": "RVX.csv",
        # "ixic_": "IXIC.csv",
        # "ndx_": "NDX.csv",
        # "dji_": "DJI.csv",
    },

    output_dir="output_dailyprob_gated_5m_xgb_QQQ_noMacro_us2",
    verbose=True,

    save_checkpoint_path="checkpoints/QQQ_noMacro_US2_checkpoint.joblib",
    checkpoint_every_n_days=5,
)
# Out:
# [TRAIN][DAILY-PROB] n=200 pos=40 (20.00%)
# [TRAIN][DAILY-PROB] n=225 pos=45 (20.00%)
# [TRAIN][DAILY-PROB] n=250 pos=45 (18.00%)
# [TRAIN][DAILY-PROB] n=275 pos=49 (17.82%)
# [TRAIN][DAILY-PROB] n=300 pos=54 (18.00%)
# [TRAIN][DAILY-PROB] n=325 pos=62 (19.08%)
# [TRAIN][DAILY-PROB] n=350 pos=65 (18.57%)
# [TRAIN][DAILY-PROB] n=375 pos=71 (18.93%)
# [TRAIN][DAILY-PROB] n=400 pos=78 (19.50%)
# [TRAIN][DAILY-PROB] n=425 pos=79 (18.59%)
# [TRAIN][DAILY-PROB] n=450 pos=89 (19.78%)
# [TRAIN][DAILY-PROB] n=475 pos=91 (19.16%)
# [TRAIN][DAILY-PROB] n=500 pos=100 (20.00%)
# [TRAIN][DAILY-PROB] n=525 pos=106 (20.19%)
# [TRAIN][DAILY-PROB] n=550 pos=115 (20.91%)
# [TRAIN][DAILY-PROB] n=575 pos=122 (21.22%)
# [TRAIN][DAILY-PROB] n=600 pos=131 (21.83%)
# [TRAIN][DAILY-PROB] n=625 pos=133 (21.28%)
# [TRAIN][DAILY-PROB] n=650 pos=136 (20.92%)
# [TRAIN][DAILY-PROB] n=675 pos=146 (21.63%)
# [TRAIN][DAILY-PROB] n=700 pos=152 (21.71%)
# [TRAIN][DAILY-PROB] n=725 pos=154 (21.24%)
# [TRAIN][DAILY-PROB] n=750 pos=156 (20.80%)
# [TRAIN][DAILY-PROB] n=775 pos=160 (20.65%)
# [TRAIN][DAILY-PROB] n=800 pos=168 (21.00%)
# [TRAIN][DAILY-PROB] n=825 pos=176 (21.33%)
# [TRAIN][DAILY-PROB] n=850 pos=185 (21.76%)
# [TRAIN][DAILY-PROB] n=875 pos=186 (21.26%)
# [TRAIN][DAILY-PROB] n=900 pos=194 (21.56%)
# [TRAIN][DAILY-PROB] n=925 pos=195 (21.08%)
# [TRAIN][DAILY-PROB] n=950 pos=202 (21.26%)
# [TRAIN][DAILY-PROB] n=975 pos=205 (21.03%)
# [TRAIN][DAILY-PROB] n=1000 pos=209 (20.90%)
# [TRAIN][DAILY-PROB] n=1025 pos=213 (20.78%)
# [TRAIN][DAILY-PROB] n=1050 pos=224 (21.33%)
# [TRAIN][DAILY-PROB] n=1075 pos=227 (21.12%)
# [TRAIN][DAILY-PROB] n=1100 pos=233 (21.18%)
# [TRAIN][DAILY-PROB] n=1125 pos=236 (20.98%)
# [TRAIN][DAILY-PROB] n=1150 pos=241 (20.96%)
# [TRAIN][DAILY-PROB] n=1175 pos=252 (21.45%)
# [TRAIN][DAILY-PROB] n=1200 pos=260 (21.67%)
# [TRAIN][DAILY-PROB] n=1225 pos=264 (21.55%)
# [TRAIN][DAILY-PROB] n=1250 pos=266 (21.28%)
# [TRAIN][DAILY-PROB] n=1275 pos=267 (20.94%)
# [TRAIN][DAILY-PROB] n=1300 pos=278 (21.38%)
# [TRAIN][DAILY-PROB] n=1325 pos=282 (21.28%)
# [TRAIN][DAILY-PROB] n=1350 pos=288 (21.33%)
# [TRAIN][DAILY-PROB] n=1375 pos=295 (21.45%)
# [TRAIN][DAILY-PROB] n=1400 pos=299 (21.36%)
# [TRAIN][DAILY-PROB] n=1425 pos=304 (21.33%)
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_noMacro_us2\daily_lr_feature_importance.csv
# [PHASE2/3] 5m feed begins at accumulation_start=2022-10-01, trading starts at sim_s=2024-01-01
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2022-10-07 19:55:00
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2022-10-14 19:55:00
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2022-10-21 19:55:00
# [TRAIN][5M] asof=2022-10-26 feats=69 buy=YES sell=NO rows=711
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2022-10-28 19:55:00
# [TRAIN][5M] asof=2022-10-31 feats=69 buy=YES sell=YES rows=784
# [TH-OPT][GLOBAL] asof_bar=4601 buy_th=2.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=4792 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2022-11-04 19:55:00
# [TRAIN][5M] asof=2022-11-07 feats=69 buy=YES sell=YES rows=922
# [TH-OPT][GLOBAL] asof_bar=5174 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=5365 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=5556 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=5747 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2022-11-11 19:55:00
# [TRAIN][5M] asof=2022-11-14 feats=69 buy=YES sell=YES rows=1134
# [TH-OPT][GLOBAL] asof_bar=5939 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=6130 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=6320 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=6512 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=6702 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2022-11-18 19:55:00
# [TRAIN][5M] asof=2022-11-21 feats=69 buy=YES sell=YES rows=1332
# [TH-OPT][GLOBAL] asof_bar=6894 buy_th=0.75 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=7084 buy_th=1.25 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=7274 buy_th=1.10 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=7422 buy_th=1.65 sell_th=-0.50
# [TRAIN][5M] asof=2022-11-28 feats=69 buy=YES sell=YES rows=1512
# [TH-OPT][GLOBAL] asof_bar=7614 buy_th=2.40 sell_th=0.90
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2022-11-28 19:55:00
# [TH-OPT][GLOBAL] asof_bar=7806 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=7997 buy_th=2.45 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=8187 buy_th=-0.50 sell_th=0.55
# [TH-OPT][GLOBAL] asof_bar=8376 buy_th=1.30 sell_th=-0.50
# [TRAIN][5M] asof=2022-12-05 feats=69 buy=YES sell=YES rows=1646
# [TH-OPT][GLOBAL] asof_bar=8567 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2022-12-05 19:55:00
# [TH-OPT][GLOBAL] asof_bar=8757 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=8949 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=9140 buy_th=-0.50 sell_th=1.25
# [TH-OPT][GLOBAL] asof_bar=9328 buy_th=-0.50 sell_th=1.25
# [TRAIN][5M] asof=2022-12-12 feats=69 buy=YES sell=YES rows=1757
# [TH-OPT][GLOBAL] asof_bar=9518 buy_th=2.25 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2022-12-12 19:55:00
# [TH-OPT][GLOBAL] asof_bar=9710 buy_th=2.25 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=9901 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=10093 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=10285 buy_th=2.50 sell_th=0.95
# [TRAIN][5M] asof=2022-12-19 feats=69 buy=YES sell=YES rows=1901
# [TH-OPT][GLOBAL] asof_bar=10476 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2022-12-19 19:55:00
# [TH-OPT][GLOBAL] asof_bar=10667 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=10856 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=11048 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=11235 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2022-12-27 feats=69 buy=YES sell=YES rows=2129
# [TH-OPT][GLOBAL] asof_bar=11427 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2022-12-27 19:55:00
# [TH-OPT][GLOBAL] asof_bar=11619 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=11810 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=12001 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2023-01-03 feats=69 buy=YES sell=YES rows=2290
# [TH-OPT][GLOBAL] asof_bar=12192 buy_th=1.55 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=12384 buy_th=1.90 sell_th=1.85
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-01-04 19:55:00
# [TH-OPT][GLOBAL] asof_bar=12576 buy_th=1.90 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=12766 buy_th=2.45 sell_th=0.75
# [TRAIN][5M] asof=2023-01-09 feats=69 buy=YES sell=YES rows=2402
# [TH-OPT][GLOBAL] asof_bar=12958 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=13146 buy_th=2.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=13338 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-01-11 19:55:00
# [TRAIN][5M] asof=2023-01-17 feats=69 buy=YES sell=YES rows=2578
# [TH-OPT][GLOBAL] asof_bar=14101 buy_th=-0.50 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=14293 buy_th=-0.50 sell_th=1.15
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-01-19 19:55:00
# [TH-OPT][GLOBAL] asof_bar=14479 buy_th=-0.50 sell_th=2.05
# [TRAIN][5M] asof=2023-01-23 feats=69 buy=YES sell=YES rows=2738
# [TH-OPT][GLOBAL] asof_bar=14862 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=15054 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=15246 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-01-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=15436 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2023-01-30 feats=69 buy=YES sell=YES rows=2922
# [TH-OPT][GLOBAL] asof_bar=15628 buy_th=-0.50 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=15820 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=16011 buy_th=-0.50 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-02-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=16389 buy_th=-0.50 sell_th=2.45
# [TRAIN][5M] asof=2023-02-06 feats=69 buy=YES sell=YES rows=3143
# [TH-OPT][GLOBAL] asof_bar=16581 buy_th=-0.50 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=16773 buy_th=-0.50 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=16964 buy_th=-0.50 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=17156 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-02-09 19:55:00
# [TH-OPT][GLOBAL] asof_bar=17341 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2023-02-13 feats=69 buy=YES sell=YES rows=3359
# [TH-OPT][GLOBAL] asof_bar=18108 buy_th=2.35 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-02-16 19:55:00
# [TH-OPT][GLOBAL] asof_bar=18300 buy_th=2.45 sell_th=1.70
# [TRAIN][5M] asof=2023-02-21 feats=69 buy=YES sell=YES rows=3506
# [TH-OPT][GLOBAL] asof_bar=18491 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=18683 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=18873 buy_th=-0.50 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=19062 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-02-24 19:55:00
# [TRAIN][5M] asof=2023-02-27 feats=69 buy=YES sell=YES rows=3639
# [TH-OPT][GLOBAL] asof_bar=19252 buy_th=1.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=19444 buy_th=1.75 sell_th=2.20
# [TH-OPT][GLOBAL] asof_bar=19636 buy_th=1.65 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=19828 buy_th=2.50 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=20019 buy_th=-0.50 sell_th=2.40
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-03-03 19:55:00
# [TRAIN][5M] asof=2023-03-06 feats=69 buy=YES sell=YES rows=3872
# [TH-OPT][GLOBAL] asof_bar=20209 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=20400 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=20591 buy_th=-0.50 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=20783 buy_th=-0.50 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=20974 buy_th=-0.50 sell_th=1.65
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-03-10 19:55:00
# [TRAIN][5M] asof=2023-03-13 feats=69 buy=YES sell=YES rows=4045
# [TH-OPT][GLOBAL] asof_bar=21166 buy_th=-0.50 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=21358 buy_th=1.45 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=21550 buy_th=1.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=21741 buy_th=0.75 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-03-17 19:55:00
# [TRAIN][5M] asof=2023-03-20 feats=69 buy=YES sell=YES rows=4232
# [TH-OPT][GLOBAL] asof_bar=22123 buy_th=-0.50 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=22315 buy_th=-0.50 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=22885 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-03-24 19:55:00
# [TRAIN][5M] asof=2023-03-27 feats=69 buy=YES sell=YES rows=4422
# [TH-OPT][GLOBAL] asof_bar=23074 buy_th=-0.50 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=23261 buy_th=2.30 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=23453 buy_th=-0.50 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=23644 buy_th=2.05 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-03-31 19:55:00
# [TRAIN][5M] asof=2023-04-03 feats=69 buy=YES sell=YES rows=4633
# [TH-OPT][GLOBAL] asof_bar=24023 buy_th=-0.50 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=24215 buy_th=-0.50 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=24403 buy_th=-0.50 sell_th=0.60
# [TH-OPT][GLOBAL] asof_bar=24594 buy_th=-0.50 sell_th=1.35
# [TRAIN][5M] asof=2023-04-10 feats=69 buy=YES sell=YES rows=4783
# [TH-OPT][GLOBAL] asof_bar=24786 buy_th=2.30 sell_th=1.30
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-04-10 19:55:00
# [TH-OPT][GLOBAL] asof_bar=24978 buy_th=2.20 sell_th=1.40
# [TH-OPT][GLOBAL] asof_bar=25168 buy_th=-0.50 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=25359 buy_th=2.50 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=25547 buy_th=2.35 sell_th=1.45
# [TRAIN][5M] asof=2023-04-17 feats=69 buy=YES sell=YES rows=4988
# [TH-OPT][GLOBAL] asof_bar=25737 buy_th=2.10 sell_th=1.95
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-04-17 19:55:00
# [TH-OPT][GLOBAL] asof_bar=25927 buy_th=2.10 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=26118 buy_th=2.00 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=26310 buy_th=2.50 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=26499 buy_th=2.50 sell_th=1.85
# [TRAIN][5M] asof=2023-04-24 feats=69 buy=YES sell=YES rows=5172
# [TH-OPT][GLOBAL] asof_bar=26690 buy_th=1.50 sell_th=0.65
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-04-24 19:55:00
# [TH-OPT][GLOBAL] asof_bar=26882 buy_th=1.50 sell_th=0.45
# [TH-OPT][GLOBAL] asof_bar=27074 buy_th=2.25 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=27266 buy_th=-0.50 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=27456 buy_th=-0.50 sell_th=1.65
# [TRAIN][5M] asof=2023-05-01 feats=69 buy=YES sell=YES rows=5365
# [TH-OPT][GLOBAL] asof_bar=27646 buy_th=2.30 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-05-01 19:55:00
# [TH-OPT][GLOBAL] asof_bar=27834 buy_th=2.40 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=28026 buy_th=2.50 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=28217 buy_th=2.50 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=28404 buy_th=2.30 sell_th=2.50
# [TRAIN][5M] asof=2023-05-08 feats=69 buy=YES sell=YES rows=5568
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-05-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=28777 buy_th=1.55 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=28964 buy_th=0.60 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=29155 buy_th=1.60 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=29339 buy_th=0.90 sell_th=1.75
# [TRAIN][5M] asof=2023-05-15 feats=69 buy=YES sell=YES rows=5736
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-05-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=29714 buy_th=-0.50 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=29902 buy_th=-0.50 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=30094 buy_th=1.55 sell_th=1.25
# [TH-OPT][GLOBAL] asof_bar=30284 buy_th=1.10 sell_th=0.45
# [TRAIN][5M] asof=2023-05-22 feats=69 buy=YES sell=YES rows=5871
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-05-22 19:55:00
# [TH-OPT][GLOBAL] asof_bar=30661 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=30851 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=31043 buy_th=-0.50 sell_th=0.90
# [TRAIN][5M] asof=2023-05-30 feats=69 buy=YES sell=YES rows=6115
# [TH-OPT][GLOBAL] asof_bar=31425 buy_th=-0.50 sell_th=1.80
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-05-30 19:55:00
# [TH-OPT][GLOBAL] asof_bar=31616 buy_th=-0.50 sell_th=1.50
# [TH-OPT][GLOBAL] asof_bar=31805 buy_th=-0.50 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=31995 buy_th=-0.50 sell_th=1.80
# [TRAIN][5M] asof=2023-06-05 feats=69 buy=YES sell=YES rows=6257
# [TH-OPT][GLOBAL] asof_bar=32373 buy_th=2.25 sell_th=2.10
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-06-06 19:55:00
# [TH-OPT][GLOBAL] asof_bar=32564 buy_th=2.25 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=32753 buy_th=2.50 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=32942 buy_th=-0.50 sell_th=1.00
# [TRAIN][5M] asof=2023-06-12 feats=69 buy=YES sell=YES rows=6462
# [TH-OPT][GLOBAL] asof_bar=33134 buy_th=1.30 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=33324 buy_th=1.05 sell_th=2.45
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-06-13 19:55:00
# [TH-OPT][GLOBAL] asof_bar=33516 buy_th=1.35 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=33707 buy_th=1.50 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=33897 buy_th=2.20 sell_th=2.50
# [TRAIN][5M] asof=2023-06-20 feats=69 buy=YES sell=YES rows=6637
# [TH-OPT][GLOBAL] asof_bar=34088 buy_th=-0.50 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=34278 buy_th=-0.50 sell_th=1.35
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-06-21 19:55:00
# [TH-OPT][GLOBAL] asof_bar=34469 buy_th=-0.50 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=34658 buy_th=2.50 sell_th=0.65
# [TRAIN][5M] asof=2023-06-26 feats=69 buy=YES sell=YES rows=6839
# [TH-OPT][GLOBAL] asof_bar=34850 buy_th=2.05 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=35040 buy_th=1.95 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=35230 buy_th=1.35 sell_th=1.60
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-06-28 19:55:00
# [TH-OPT][GLOBAL] asof_bar=35421 buy_th=1.50 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=35611 buy_th=1.55 sell_th=2.05
# [TRAIN][5M] asof=2023-07-03 feats=69 buy=YES sell=YES rows=7044
# [TH-OPT][GLOBAL] asof_bar=35756 buy_th=1.75 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=35948 buy_th=1.35 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=36139 buy_th=1.40 sell_th=1.95
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-07-06 19:55:00
# [TH-OPT][GLOBAL] asof_bar=36326 buy_th=1.05 sell_th=1.85
# [TRAIN][5M] asof=2023-07-10 feats=69 buy=YES sell=YES rows=7200
# [TH-OPT][GLOBAL] asof_bar=36515 buy_th=1.25 sell_th=0.60
# [TH-OPT][GLOBAL] asof_bar=36705 buy_th=-0.50 sell_th=0.85
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-07-13 19:55:00
# [TH-OPT][GLOBAL] asof_bar=37274 buy_th=0.60 sell_th=-0.50
# [TRAIN][5M] asof=2023-07-17 feats=69 buy=YES sell=YES rows=7403
# [TH-OPT][GLOBAL] asof_bar=37465 buy_th=-0.50 sell_th=0.55
# [TH-OPT][GLOBAL] asof_bar=37656 buy_th=-0.50 sell_th=0.55
# [TH-OPT][GLOBAL] asof_bar=37848 buy_th=-0.50 sell_th=0.45
# [TH-OPT][GLOBAL] asof_bar=38039 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-07-20 19:55:00
# [TH-OPT][GLOBAL] asof_bar=38228 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2023-07-24 feats=69 buy=YES sell=YES rows=7558
# [TH-OPT][GLOBAL] asof_bar=38611 buy_th=2.00 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=38800 buy_th=2.30 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=38990 buy_th=2.10 sell_th=1.15
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-07-27 19:55:00
# [TH-OPT][GLOBAL] asof_bar=39178 buy_th=1.80 sell_th=1.75
# [TRAIN][5M] asof=2023-07-31 feats=69 buy=YES sell=YES rows=7774
# [TH-OPT][GLOBAL] asof_bar=39366 buy_th=1.35 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=39557 buy_th=1.25 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=39749 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=39941 buy_th=2.35 sell_th=1.05
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-08-03 19:55:00
# [TH-OPT][GLOBAL] asof_bar=40130 buy_th=2.00 sell_th=0.55
# [TRAIN][5M] asof=2023-08-07 feats=69 buy=YES sell=YES rows=7964
# [TH-OPT][GLOBAL] asof_bar=40513 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=40704 buy_th=1.50 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=40896 buy_th=1.70 sell_th=1.65
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-08-10 19:55:00
# [TH-OPT][GLOBAL] asof_bar=41081 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2023-08-14 feats=69 buy=YES sell=YES rows=8158
# [TH-OPT][GLOBAL] asof_bar=41272 buy_th=-0.50 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=41463 buy_th=2.45 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=41655 buy_th=2.45 sell_th=1.70
# [TH-OPT][GLOBAL] asof_bar=41847 buy_th=2.15 sell_th=1.15
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-08-17 19:55:00
# [TH-OPT][GLOBAL] asof_bar=42037 buy_th=-0.50 sell_th=1.55
# [TRAIN][5M] asof=2023-08-21 feats=69 buy=YES sell=YES rows=8374
# [TH-OPT][GLOBAL] asof_bar=42418 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=42609 buy_th=0.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=42801 buy_th=1.05 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-08-24 19:55:00
# [TH-OPT][GLOBAL] asof_bar=42992 buy_th=1.15 sell_th=-0.50
# [TRAIN][5M] asof=2023-08-28 feats=69 buy=YES sell=YES rows=8615
# [TH-OPT][GLOBAL] asof_bar=43755 buy_th=1.10 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-08-31 19:55:00
# [TH-OPT][GLOBAL] asof_bar=43937 buy_th=1.30 sell_th=-0.50
# [TRAIN][5M] asof=2023-09-05 feats=69 buy=YES sell=YES rows=8791
# [TH-OPT][GLOBAL] asof_bar=44129 buy_th=1.25 sell_th=0.40
# [TH-OPT][GLOBAL] asof_bar=44317 buy_th=2.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=44506 buy_th=2.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=44698 buy_th=1.55 sell_th=0.85
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-09-08 19:55:00
# [TRAIN][5M] asof=2023-09-11 feats=69 buy=YES sell=YES rows=8928
# [TH-OPT][GLOBAL] asof_bar=45078 buy_th=1.05 sell_th=1.70
# [TH-OPT][GLOBAL] asof_bar=45264 buy_th=0.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=45451 buy_th=0.75 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=45641 buy_th=1.10 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-09-15 19:55:00
# [TRAIN][5M] asof=2023-09-18 feats=69 buy=YES sell=YES rows=9110
# [TH-OPT][GLOBAL] asof_bar=45830 buy_th=1.70 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=46019 buy_th=1.70 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=46211 buy_th=2.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=46403 buy_th=2.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=46591 buy_th=-0.50 sell_th=1.25
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-09-22 19:55:00
# [TRAIN][5M] asof=2023-09-25 feats=69 buy=YES sell=YES rows=9315
# [TH-OPT][GLOBAL] asof_bar=46783 buy_th=2.50 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=46974 buy_th=-0.50 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=47166 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=47357 buy_th=2.50 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=47548 buy_th=2.50 sell_th=2.15
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-09-29 19:55:00
# [TRAIN][5M] asof=2023-10-02 feats=69 buy=YES sell=YES rows=9509
# [TH-OPT][GLOBAL] asof_bar=47739 buy_th=1.30 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=47930 buy_th=1.60 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=48121 buy_th=2.40 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=48313 buy_th=1.85 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=48504 buy_th=2.10 sell_th=2.45
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-10-06 19:55:00
# [TRAIN][5M] asof=2023-10-09 feats=69 buy=YES sell=YES rows=9702
# [TH-OPT][GLOBAL] asof_bar=48696 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=48885 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=49076 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=49268 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=49456 buy_th=1.05 sell_th=2.35
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-10-13 19:55:00
# [TRAIN][5M] asof=2023-10-16 feats=69 buy=YES sell=YES rows=9875
# [TH-OPT][GLOBAL] asof_bar=49837 buy_th=2.25 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=50029 buy_th=2.45 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=50221 buy_th=2.45 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=50409 buy_th=-0.50 sell_th=0.75
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-10-20 19:55:00
# [TRAIN][5M] asof=2023-10-23 feats=69 buy=YES sell=YES rows=10110
# [TH-OPT][GLOBAL] asof_bar=50598 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=50790 buy_th=2.35 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=50981 buy_th=2.25 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=51173 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=51365 buy_th=2.45 sell_th=2.45
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-10-27 19:55:00
# [TRAIN][5M] asof=2023-10-30 feats=69 buy=YES sell=YES rows=10317
# [TH-OPT][GLOBAL] asof_bar=51556 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=51748 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=51940 buy_th=0.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=52132 buy_th=0.25 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-11-03 19:55:00
# [TRAIN][5M] asof=2023-11-06 feats=69 buy=YES sell=YES rows=10492
# [TH-OPT][GLOBAL] asof_bar=53084 buy_th=2.20 sell_th=1.50
# [TH-OPT][GLOBAL] asof_bar=53273 buy_th=-0.50 sell_th=1.85
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-11-10 19:55:00
# [TRAIN][5M] asof=2023-11-13 feats=69 buy=YES sell=YES rows=10684
# [TH-OPT][GLOBAL] asof_bar=53463 buy_th=-0.50 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=53655 buy_th=-0.50 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=53847 buy_th=1.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=54037 buy_th=1.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=54222 buy_th=1.05 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-11-17 19:55:00
# [TRAIN][5M] asof=2023-11-20 feats=69 buy=YES sell=YES rows=10882
# [TH-OPT][GLOBAL] asof_bar=54413 buy_th=1.85 sell_th=1.70
# [TH-OPT][GLOBAL] asof_bar=54603 buy_th=1.75 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=54793 buy_th=2.25 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=54937 buy_th=1.60 sell_th=-0.50
# [TRAIN][5M] asof=2023-11-27 feats=69 buy=YES sell=YES rows=11042
# [TH-OPT][GLOBAL] asof_bar=55123 buy_th=1.20 sell_th=1.45
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-11-27 19:55:00
# [TH-OPT][GLOBAL] asof_bar=55315 buy_th=1.60 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=55506 buy_th=1.10 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=55691 buy_th=0.90 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=55880 buy_th=0.90 sell_th=0.85
# [TRAIN][5M] asof=2023-12-04 feats=69 buy=YES sell=YES rows=11284
# [TH-OPT][GLOBAL] asof_bar=56070 buy_th=1.80 sell_th=2.05
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-12-04 19:55:00
# [TH-OPT][GLOBAL] asof_bar=56262 buy_th=1.80 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=56454 buy_th=1.80 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=56644 buy_th=1.70 sell_th=2.20
# [TH-OPT][GLOBAL] asof_bar=56825 buy_th=0.50 sell_th=1.95
# [TRAIN][5M] asof=2023-12-11 feats=69 buy=YES sell=YES rows=11486
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-12-11 19:55:00
# [TH-OPT][GLOBAL] asof_bar=57588 buy_th=0.95 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=57780 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2023-12-18 feats=69 buy=YES sell=YES rows=11713
# [TH-OPT][GLOBAL] asof_bar=57967 buy_th=-0.50 sell_th=0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-12-18 19:55:00
# [TH-OPT][GLOBAL] asof_bar=58157 buy_th=2.50 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=58347 buy_th=-0.50 sell_th=0.60
# [TH-OPT][GLOBAL] asof_bar=58537 buy_th=2.25 sell_th=0.70
# [TH-OPT][GLOBAL] asof_bar=58719 buy_th=-0.50 sell_th=0.80
# [TRAIN][5M] asof=2023-12-26 feats=69 buy=YES sell=YES rows=11862
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2023-12-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=59447 buy_th=1.55 sell_th=1.35
# [TRAIN][5M] asof=2024-01-02 feats=69 buy=YES sell=YES rows=11975
# [TH-OPT][GLOBAL] asof_bar=59828 buy_th=2.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-01-03 19:55:00
# [TH-OPT][GLOBAL] asof_bar=60016 buy_th=2.20 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=60203 buy_th=2.45 sell_th=0.95
# [TRAIN][5M] asof=2024-01-08 feats=69 buy=YES sell=YES rows=12121
# [TH-OPT][GLOBAL] asof_bar=60586 buy_th=1.25 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=60778 buy_th=1.05 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-01-10 19:55:00
# [TH-OPT][GLOBAL] asof_bar=60969 buy_th=0.90 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=61146 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2024-01-16 feats=69 buy=YES sell=YES rows=12405
# [TH-OPT][GLOBAL] asof_bar=61338 buy_th=1.10 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=61530 buy_th=1.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=61722 buy_th=1.75 sell_th=2.15
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-01-18 19:55:00
# [TRAIN][5M] asof=2024-01-22 feats=69 buy=YES sell=YES rows=12593
# [TH-OPT][GLOBAL] asof_bar=62295 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=62487 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=62677 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-01-25 19:55:00
# [TH-OPT][GLOBAL] asof_bar=62867 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2024-01-29 feats=69 buy=YES sell=YES rows=12748
# [TH-OPT][GLOBAL] asof_bar=63250 buy_th=2.25 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=63442 buy_th=2.00 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=63634 buy_th=1.75 sell_th=0.35
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-02-01 19:55:00
# [TH-OPT][GLOBAL] asof_bar=63823 buy_th=-0.50 sell_th=1.85
# [TRAIN][5M] asof=2024-02-05 feats=69 buy=YES sell=YES rows=12917
# [TH-OPT][GLOBAL] asof_bar=64206 buy_th=1.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=64398 buy_th=1.30 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=64589 buy_th=0.85 sell_th=2.45
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-02-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=64769 buy_th=1.00 sell_th=2.40
# [TRAIN][5M] asof=2024-02-12 feats=69 buy=YES sell=YES rows=13072
# [TH-OPT][GLOBAL] asof_bar=64960 buy_th=2.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=65152 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=65343 buy_th=2.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-02-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=65720 buy_th=2.25 sell_th=0.60
# [TRAIN][5M] asof=2024-02-20 feats=69 buy=YES sell=YES rows=13248
# [TH-OPT][GLOBAL] asof_bar=65912 buy_th=2.05 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=66103 buy_th=2.50 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=66295 buy_th=0.90 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=66483 buy_th=0.80 sell_th=2.40
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-02-23 19:55:00
# [TRAIN][5M] asof=2024-02-26 feats=69 buy=YES sell=YES rows=13406
# [TH-OPT][GLOBAL] asof_bar=66674 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=66866 buy_th=2.50 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=67058 buy_th=2.35 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=67249 buy_th=2.35 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=67438 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-03-01 19:55:00
# [TRAIN][5M] asof=2024-03-04 feats=69 buy=YES sell=YES rows=13615
# [TH-OPT][GLOBAL] asof_bar=67629 buy_th=1.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=67821 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=68012 buy_th=2.25 sell_th=1.50
# [TH-OPT][GLOBAL] asof_bar=68204 buy_th=1.75 sell_th=1.70
# [TH-OPT][GLOBAL] asof_bar=68396 buy_th=1.90 sell_th=1.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-03-08 19:55:00
# [TRAIN][5M] asof=2024-03-11 feats=69 buy=YES sell=YES rows=13836
# [TH-OPT][GLOBAL] asof_bar=68587 buy_th=2.40 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=68777 buy_th=2.25 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=68969 buy_th=2.25 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=69161 buy_th=1.85 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=69351 buy_th=2.15 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-03-15 19:55:00
# [TRAIN][5M] asof=2024-03-18 feats=69 buy=YES sell=YES rows=13997
# [TH-OPT][GLOBAL] asof_bar=69543 buy_th=2.25 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=69735 buy_th=2.25 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=69927 buy_th=2.40 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=70304 buy_th=0.55 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-03-22 19:55:00
# [TRAIN][5M] asof=2024-03-25 feats=69 buy=YES sell=YES rows=14190
# [TH-OPT][GLOBAL] asof_bar=70496 buy_th=0.70 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=70687 buy_th=0.55 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=70877 buy_th=1.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=71060 buy_th=0.65 sell_th=1.30
# [TRAIN][5M] asof=2024-04-01 feats=69 buy=YES sell=YES rows=14311
# [TH-OPT][GLOBAL] asof_bar=71248 buy_th=1.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-04-01 19:55:00
# [TH-OPT][GLOBAL] asof_bar=71437 buy_th=1.10 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=71625 buy_th=1.10 sell_th=-0.50
# [TRAIN][5M] asof=2024-04-08 feats=69 buy=YES sell=YES rows=14437
# [TH-OPT][GLOBAL] asof_bar=72191 buy_th=1.45 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-04-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=72382 buy_th=1.50 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=72573 buy_th=1.40 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=72765 buy_th=0.85 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=72956 buy_th=1.70 sell_th=2.30
# [TRAIN][5M] asof=2024-04-15 feats=69 buy=YES sell=YES rows=14628
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-04-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=73340 buy_th=2.50 sell_th=1.25
# [TH-OPT][GLOBAL] asof_bar=73531 buy_th=2.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=73723 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=73915 buy_th=-0.50 sell_th=1.15
# [TRAIN][5M] asof=2024-04-22 feats=69 buy=YES sell=YES rows=14763
# [TH-OPT][GLOBAL] asof_bar=74107 buy_th=1.80 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-04-22 19:55:00
# [TH-OPT][GLOBAL] asof_bar=74299 buy_th=1.75 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=74491 buy_th=1.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=74683 buy_th=1.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=74874 buy_th=1.95 sell_th=-0.50
# [TRAIN][5M] asof=2024-04-29 feats=69 buy=YES sell=YES rows=14984
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-04-29 19:55:00
# [TH-OPT][GLOBAL] asof_bar=75257 buy_th=2.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=75449 buy_th=2.20 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=75640 buy_th=2.50 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=75827 buy_th=1.80 sell_th=2.10
# [TRAIN][5M] asof=2024-05-06 feats=69 buy=YES sell=YES rows=15146
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-05-06 19:55:00
# [TH-OPT][GLOBAL] asof_bar=76208 buy_th=2.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=76396 buy_th=1.60 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=76581 buy_th=1.70 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=76770 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2024-05-13 feats=69 buy=YES sell=YES rows=15284
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-05-13 19:55:00
# [TH-OPT][GLOBAL] asof_bar=77143 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=77335 buy_th=-0.50 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=77527 buy_th=-0.50 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=77710 buy_th=0.85 sell_th=1.80
# [TRAIN][5M] asof=2024-05-20 feats=69 buy=YES sell=YES rows=15428
# [TH-OPT][GLOBAL] asof_bar=77893 buy_th=1.95 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-05-20 19:55:00
# [TH-OPT][GLOBAL] asof_bar=78077 buy_th=1.95 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=78266 buy_th=2.20 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=78455 buy_th=-0.50 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=78637 buy_th=2.15 sell_th=1.95
# [TRAIN][5M] asof=2024-05-28 feats=69 buy=YES sell=YES rows=15622
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-05-28 19:55:00
# [TH-OPT][GLOBAL] asof_bar=79020 buy_th=2.05 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=79212 buy_th=2.05 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=79403 buy_th=1.65 sell_th=1.20
# [TRAIN][5M] asof=2024-06-03 feats=69 buy=YES sell=YES rows=15796
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-06-04 19:55:00
# [TRAIN][5M] asof=2024-06-10 feats=69 buy=YES sell=YES rows=15971
# [TH-OPT][GLOBAL] asof_bar=80539 buy_th=2.45 sell_th=0.45
# [TH-OPT][GLOBAL] asof_bar=80728 buy_th=-0.50 sell_th=0.90
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-06-11 19:55:00
# [TH-OPT][GLOBAL] asof_bar=80918 buy_th=2.40 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=81107 buy_th=-0.50 sell_th=0.25
# [TH-OPT][GLOBAL] asof_bar=81298 buy_th=2.00 sell_th=0.55
# [TRAIN][5M] asof=2024-06-17 feats=69 buy=YES sell=YES rows=16149
# [TH-OPT][GLOBAL] asof_bar=81487 buy_th=-0.50 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=81676 buy_th=-0.50 sell_th=1.65
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-06-18 19:55:00
# [TH-OPT][GLOBAL] asof_bar=81868 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=82059 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2024-06-24 feats=69 buy=YES sell=YES rows=16283
# [TH-OPT][GLOBAL] asof_bar=82251 buy_th=2.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=82443 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=82633 buy_th=-0.50 sell_th=1.30
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-06-26 19:55:00
# [TRAIN][5M] asof=2024-07-01 feats=69 buy=YES sell=YES rows=16431
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-07-03 16:55:00
# [TRAIN][5M] asof=2024-07-08 feats=69 buy=YES sell=YES rows=16550
# [TH-OPT][GLOBAL] asof_bar=84484 buy_th=1.85 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-07-11 19:55:00
# [TH-OPT][GLOBAL] asof_bar=84675 buy_th=1.55 sell_th=-0.50
# [TRAIN][5M] asof=2024-07-15 feats=69 buy=YES sell=YES rows=16731
# [TH-OPT][GLOBAL] asof_bar=85050 buy_th=-0.50 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=85242 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=85434 buy_th=2.50 sell_th=0.70
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-07-18 19:55:00
# [TH-OPT][GLOBAL] asof_bar=85622 buy_th=2.30 sell_th=0.15
# [TRAIN][5M] asof=2024-07-22 feats=69 buy=YES sell=YES rows=16964
# [TH-OPT][GLOBAL] asof_bar=86006 buy_th=1.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=86198 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=86390 buy_th=2.00 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-07-25 19:55:00
# [TH-OPT][GLOBAL] asof_bar=86579 buy_th=2.10 sell_th=2.30
# [TRAIN][5M] asof=2024-07-29 feats=69 buy=YES sell=YES rows=17221
# [TH-OPT][GLOBAL] asof_bar=86771 buy_th=0.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=86963 buy_th=0.70 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=87155 buy_th=1.05 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=87347 buy_th=1.95 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-08-01 19:55:00
# [TH-OPT][GLOBAL] asof_bar=87539 buy_th=1.85 sell_th=-0.50
# [TRAIN][5M] asof=2024-08-05 feats=69 buy=YES sell=YES rows=17462
# [TH-OPT][GLOBAL] asof_bar=87731 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=87923 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=88115 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=88307 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-08-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=88495 buy_th=2.35 sell_th=-0.50
# [TRAIN][5M] asof=2024-08-12 feats=69 buy=YES sell=YES rows=17615
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-08-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=89447 buy_th=1.85 sell_th=-0.50
# [TRAIN][5M] asof=2024-08-19 feats=69 buy=YES sell=YES rows=17804
# [TH-OPT][GLOBAL] asof_bar=89639 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=89831 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=90020 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=90208 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-08-22 19:55:00
# [TH-OPT][GLOBAL] asof_bar=90397 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2024-08-26 feats=69 buy=YES sell=YES rows=18006
# [TH-OPT][GLOBAL] asof_bar=90588 buy_th=1.75 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=90778 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=90969 buy_th=2.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=91160 buy_th=2.35 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-08-29 19:55:00
# [TH-OPT][GLOBAL] asof_bar=91350 buy_th=2.10 sell_th=0.65
# [TRAIN][5M] asof=2024-09-03 feats=69 buy=YES sell=YES rows=18169
# [TH-OPT][GLOBAL] asof_bar=91542 buy_th=2.25 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=91734 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=91925 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=92117 buy_th=2.45 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-09-06 19:55:00
# [TRAIN][5M] asof=2024-09-09 feats=69 buy=YES sell=YES rows=18332
# [TH-OPT][GLOBAL] asof_bar=92309 buy_th=1.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=92500 buy_th=1.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=92691 buy_th=0.95 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-09-13 19:55:00
# [TRAIN][5M] asof=2024-09-16 feats=69 buy=YES sell=YES rows=18543
# [TH-OPT][GLOBAL] asof_bar=93259 buy_th=-0.50 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=93450 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=93641 buy_th=1.45 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=93832 buy_th=-0.50 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=94021 buy_th=-0.50 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-09-20 19:55:00
# [TRAIN][5M] asof=2024-09-23 feats=69 buy=YES sell=YES rows=18745
# [TH-OPT][GLOBAL] asof_bar=94210 buy_th=1.90 sell_th=1.40
# [TH-OPT][GLOBAL] asof_bar=94400 buy_th=2.30 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=94589 buy_th=2.50 sell_th=2.15
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-09-27 19:55:00
# [TRAIN][5M] asof=2024-09-30 feats=69 buy=YES sell=YES rows=18901
# [TH-OPT][GLOBAL] asof_bar=95159 buy_th=2.35 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=95350 buy_th=2.45 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=95542 buy_th=2.10 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=95734 buy_th=2.05 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=95925 buy_th=-0.50 sell_th=1.05
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-10-04 19:55:00
# [TRAIN][5M] asof=2024-10-07 feats=69 buy=YES sell=YES rows=19044
# [TH-OPT][GLOBAL] asof_bar=96309 buy_th=-0.50 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=96500 buy_th=-0.50 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=96688 buy_th=1.50 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=96875 buy_th=1.15 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-10-11 19:55:00
# [TRAIN][5M] asof=2024-10-14 feats=69 buy=YES sell=YES rows=19214
# [TH-OPT][GLOBAL] asof_bar=97259 buy_th=2.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=97448 buy_th=1.85 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=97640 buy_th=1.70 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=97820 buy_th=1.20 sell_th=1.05
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-10-18 19:55:00
# [TRAIN][5M] asof=2024-10-21 feats=69 buy=YES sell=YES rows=19422
# [TH-OPT][GLOBAL] asof_bar=98011 buy_th=1.55 sell_th=1.25
# [TH-OPT][GLOBAL] asof_bar=98203 buy_th=1.50 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=98394 buy_th=2.25 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=98584 buy_th=1.90 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=98775 buy_th=0.85 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-10-25 19:55:00
# [TRAIN][5M] asof=2024-10-28 feats=69 buy=YES sell=YES rows=19637
# [TH-OPT][GLOBAL] asof_bar=98966 buy_th=1.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=99157 buy_th=1.55 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=99349 buy_th=1.45 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=99541 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=99727 buy_th=2.40 sell_th=1.20
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-11-01 19:55:00
# [TRAIN][5M] asof=2024-11-04 feats=69 buy=YES sell=YES rows=19830
# [TH-OPT][GLOBAL] asof_bar=99919 buy_th=1.75 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=100109 buy_th=1.00 sell_th=1.30
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-11-08 19:55:00
# [TRAIN][5M] asof=2024-11-11 feats=69 buy=YES sell=YES rows=19998
# [TH-OPT][GLOBAL] asof_bar=101056 buy_th=-0.50 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=101246 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=101437 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=101627 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-11-15 19:55:00
# [TRAIN][5M] asof=2024-11-18 feats=69 buy=YES sell=YES rows=20178
# [TH-OPT][GLOBAL] asof_bar=101819 buy_th=-0.50 sell_th=2.20
# [TH-OPT][GLOBAL] asof_bar=102011 buy_th=-0.50 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=102203 buy_th=1.00 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=102392 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=102581 buy_th=0.10 sell_th=1.90
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-11-22 19:55:00
# [TRAIN][5M] asof=2024-11-25 feats=69 buy=YES sell=YES rows=20369
# [TH-OPT][GLOBAL] asof_bar=102773 buy_th=0.75 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=102965 buy_th=1.15 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=103151 buy_th=1.75 sell_th=-0.50
# [TRAIN][5M] asof=2024-12-02 feats=69 buy=YES sell=YES rows=20486
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-12-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=104065 buy_th=1.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=104248 buy_th=1.40 sell_th=-0.50
# [TRAIN][5M] asof=2024-12-09 feats=69 buy=YES sell=YES rows=20663
# [TH-OPT][GLOBAL] asof_bar=104439 buy_th=2.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-12-09 19:55:00
# [TH-OPT][GLOBAL] asof_bar=104628 buy_th=2.50 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=104819 buy_th=-0.50 sell_th=2.05
# [TRAIN][5M] asof=2024-12-16 feats=69 buy=YES sell=YES rows=20856
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-12-16 19:55:00
# [TH-OPT][GLOBAL] asof_bar=105579 buy_th=1.90 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=105771 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=105963 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=106155 buy_th=2.40 sell_th=-0.50
# [TRAIN][5M] asof=2024-12-23 feats=69 buy=YES sell=YES rows=21039
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-12-23 19:55:00
# [TH-OPT][GLOBAL] asof_bar=106493 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=106683 buy_th=1.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=106871 buy_th=1.75 sell_th=-0.50
# [TRAIN][5M] asof=2024-12-30 feats=69 buy=YES sell=YES rows=21208
# [TH-OPT][GLOBAL] asof_bar=107062 buy_th=2.45 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=107247 buy_th=2.50 sell_th=2.45
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2024-12-31 19:55:00
# [TH-OPT][GLOBAL] asof_bar=107439 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=107627 buy_th=-0.50 sell_th=2.25
# [TRAIN][5M] asof=2025-01-06 feats=69 buy=YES sell=YES rows=21343
# [TH-OPT][GLOBAL] asof_bar=108011 buy_th=0.95 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=108200 buy_th=1.30 sell_th=1.95
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-01-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=108390 buy_th=2.10 sell_th=2.00
# [TRAIN][5M] asof=2025-01-13 feats=69 buy=YES sell=YES rows=21524
# [TH-OPT][GLOBAL] asof_bar=108774 buy_th=2.50 sell_th=2.20
# [TH-OPT][GLOBAL] asof_bar=108964 buy_th=1.85 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=109156 buy_th=0.75 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-01-16 19:55:00
# [TH-OPT][GLOBAL] asof_bar=109348 buy_th=0.65 sell_th=-0.50
# [TRAIN][5M] asof=2025-01-21 feats=69 buy=YES sell=YES rows=21735
# [TH-OPT][GLOBAL] asof_bar=109924 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=110111 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-01-24 19:55:00
# [TRAIN][5M] asof=2025-01-27 feats=69 buy=YES sell=YES rows=21882
# [TH-OPT][GLOBAL] asof_bar=110495 buy_th=-0.50 sell_th=2.20
# [TH-OPT][GLOBAL] asof_bar=110687 buy_th=1.35 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=110879 buy_th=2.10 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=111070 buy_th=2.15 sell_th=2.40
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-01-31 19:55:00
# [TRAIN][5M] asof=2025-02-03 feats=69 buy=YES sell=YES rows=22091
# [TH-OPT][GLOBAL] asof_bar=111262 buy_th=2.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=111454 buy_th=1.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=111646 buy_th=0.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=111838 buy_th=0.30 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=112029 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-02-07 19:55:00
# [TRAIN][5M] asof=2025-02-10 feats=69 buy=YES sell=YES rows=22271
# ...
# [TH-OPT][GLOBAL] asof_bar=130211 buy_th=1.25 sell_th=2.40
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-06-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=130403 buy_th=0.95 sell_th=2.40
# [TRAIN][5M] asof=2025-06-30 feats=69 buy=YES sell=YES rows=25782
# [TH-OPT][GLOBAL] asof_bar=130784 buy_th=1.90 sell_th=0.45
# [TH-OPT][GLOBAL] asof_bar=130975 buy_th=2.20 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=131130 buy_th=-0.50 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-07-03 16:55:00
# [TRAIN][5M] asof=2025-07-07 feats=69 buy=YES sell=YES rows=25940
# [TH-OPT][GLOBAL] asof_bar=131322 buy_th=2.10 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=131513 buy_th=1.80 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=131704 buy_th=1.45 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=131895 buy_th=1.70 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=132083 buy_th=2.25 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-07-11 19:55:00
# [TRAIN][5M] asof=2025-07-14 feats=69 buy=YES sell=YES rows=26106
# [TH-OPT][GLOBAL] asof_bar=132275 buy_th=1.30 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=132467 buy_th=1.55 sell_th=0.60
# [TH-OPT][GLOBAL] asof_bar=132659 buy_th=1.50 sell_th=0.20
# [TH-OPT][GLOBAL] asof_bar=132850 buy_th=-0.50 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=133037 buy_th=1.30 sell_th=0.80
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-07-18 19:55:00
# [TRAIN][5M] asof=2025-07-21 feats=69 buy=YES sell=YES rows=26318
# [TH-OPT][GLOBAL] asof_bar=133229 buy_th=2.05 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=133421 buy_th=2.10 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=133613 buy_th=2.10 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=133804 buy_th=2.05 sell_th=1.25
# [TH-OPT][GLOBAL] asof_bar=133991 buy_th=-0.50 sell_th=1.05
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-07-25 19:55:00
# [TRAIN][5M] asof=2025-07-28 feats=69 buy=YES sell=YES rows=26528
# [TH-OPT][GLOBAL] asof_bar=134373 buy_th=-0.50 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=134757 buy_th=1.20 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=134948 buy_th=2.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-08-01 19:55:00
# [TRAIN][5M] asof=2025-08-04 feats=69 buy=YES sell=YES rows=26716
# [TH-OPT][GLOBAL] asof_bar=135524 buy_th=-0.50 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=135716 buy_th=1.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=135905 buy_th=1.15 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-08-08 19:55:00
# [TRAIN][5M] asof=2025-08-11 feats=69 buy=YES sell=YES rows=26890
# [TH-OPT][GLOBAL] asof_bar=136097 buy_th=-0.50 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=136289 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=136481 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=136672 buy_th=2.40 sell_th=1.50
# [TH-OPT][GLOBAL] asof_bar=136861 buy_th=2.45 sell_th=1.30
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-08-15 19:55:00
# [TRAIN][5M] asof=2025-08-18 feats=69 buy=YES sell=YES rows=27044
# [TH-OPT][GLOBAL] asof_bar=137053 buy_th=-0.50 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=137244 buy_th=2.20 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=137436 buy_th=2.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=137628 buy_th=2.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=137819 buy_th=1.50 sell_th=1.95
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-08-22 19:55:00
# [TRAIN][5M] asof=2025-08-25 feats=69 buy=YES sell=YES rows=27229
# [TH-OPT][GLOBAL] asof_bar=138010 buy_th=1.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=138202 buy_th=1.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=138394 buy_th=-0.50 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=138776 buy_th=1.65 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-08-29 19:55:00
# [TRAIN][5M] asof=2025-09-02 feats=69 buy=YES sell=YES rows=27386
# [TH-OPT][GLOBAL] asof_bar=139160 buy_th=1.55 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=139352 buy_th=1.50 sell_th=2.40
# [TRAIN][5M] asof=2025-09-08 feats=69 buy=YES sell=YES rows=27524
# [TH-OPT][GLOBAL] asof_bar=139734 buy_th=1.15 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-09-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=139926 buy_th=1.40 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=140118 buy_th=-0.50 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=140310 buy_th=0.90 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=140501 buy_th=0.70 sell_th=2.15
# [TRAIN][5M] asof=2025-09-15 feats=69 buy=YES sell=YES rows=27676
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-09-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=140882 buy_th=-0.50 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=141073 buy_th=1.65 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=141264 buy_th=1.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=141453 buy_th=1.60 sell_th=-0.50
# [TRAIN][5M] asof=2025-09-22 feats=69 buy=YES sell=YES rows=27903
# [TH-OPT][GLOBAL] asof_bar=141644 buy_th=-0.50 sell_th=1.85
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-09-22 19:55:00
# [TH-OPT][GLOBAL] asof_bar=141836 buy_th=-0.50 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=142027 buy_th=1.90 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=142219 buy_th=2.00 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=142403 buy_th=1.80 sell_th=1.90
# [TRAIN][5M] asof=2025-09-29 feats=69 buy=YES sell=YES rows=28093
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-09-29 19:55:00
# [TH-OPT][GLOBAL] asof_bar=142786 buy_th=0.85 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=142977 buy_th=0.80 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=143358 buy_th=0.85 sell_th=1.85
# [TRAIN][5M] asof=2025-10-06 feats=69 buy=YES sell=YES rows=28319
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-10-06 19:55:00
# [TH-OPT][GLOBAL] asof_bar=143742 buy_th=2.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=143934 buy_th=-0.50 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=144126 buy_th=1.85 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=144318 buy_th=2.30 sell_th=1.10
# [TRAIN][5M] asof=2025-10-13 feats=69 buy=YES sell=YES rows=28515
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-10-13 19:55:00
# [TH-OPT][GLOBAL] asof_bar=144702 buy_th=-0.50 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=144894 buy_th=2.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=145086 buy_th=1.55 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=145277 buy_th=1.90 sell_th=-0.50
# [TRAIN][5M] asof=2025-10-20 feats=69 buy=YES sell=YES rows=28731
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-10-20 19:55:00
# [TH-OPT][GLOBAL] asof_bar=145660 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=145852 buy_th=2.10 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=146044 buy_th=1.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=146234 buy_th=1.55 sell_th=-0.50
# [TRAIN][5M] asof=2025-10-27 feats=69 buy=YES sell=YES rows=28933
# [TH-OPT][GLOBAL] asof_bar=146426 buy_th=2.50 sell_th=2.25
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-10-27 19:55:00
# [TH-OPT][GLOBAL] asof_bar=146618 buy_th=-0.50 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=146810 buy_th=-0.50 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=147002 buy_th=2.45 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=147191 buy_th=2.50 sell_th=1.90
# [TRAIN][5M] asof=2025-11-03 feats=69 buy=YES sell=YES rows=29148
# [TH-OPT][GLOBAL] asof_bar=147383 buy_th=2.35 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-11-03 19:55:00
# [TH-OPT][GLOBAL] asof_bar=147575 buy_th=1.90 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=147767 buy_th=1.55 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=147959 buy_th=1.20 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=148151 buy_th=1.40 sell_th=1.85
# [TRAIN][5M] asof=2025-11-10 feats=69 buy=YES sell=YES rows=29395
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-11-10 19:55:00
# [TH-OPT][GLOBAL] asof_bar=148535 buy_th=-0.50 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=148727 buy_th=1.35 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=148919 buy_th=2.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=149111 buy_th=2.40 sell_th=-0.50
# [TRAIN][5M] asof=2025-11-17 feats=69 buy=YES sell=YES rows=29603
# [TH-OPT][GLOBAL] asof_bar=149303 buy_th=2.35 sell_th=0.75
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-11-17 19:55:00
# [TH-OPT][GLOBAL] asof_bar=149495 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=149687 buy_th=2.20 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=149879 buy_th=-0.50 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=150071 buy_th=-0.50 sell_th=0.70
# [TRAIN][5M] asof=2025-11-24 feats=69 buy=YES sell=YES rows=29836
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-11-24 19:55:00
# [TH-OPT][GLOBAL] asof_bar=150455 buy_th=1.65 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=150647 buy_th=1.65 sell_th=-0.50
# [TRAIN][5M] asof=2025-12-01 feats=69 buy=YES sell=YES rows=29953
# [TH-OPT][GLOBAL] asof_bar=150995 buy_th=-0.50 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=151187 buy_th=1.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-12-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=151379 buy_th=2.35 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=151571 buy_th=2.35 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=151763 buy_th=1.50 sell_th=2.50
# [TRAIN][5M] asof=2025-12-08 feats=69 buy=YES sell=YES rows=30145
# [TH-OPT][GLOBAL] asof_bar=152147 buy_th=1.65 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-12-09 19:55:00
# [TH-OPT][GLOBAL] asof_bar=152339 buy_th=2.40 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=152531 buy_th=1.75 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=152723 buy_th=2.50 sell_th=1.25
# [TRAIN][5M] asof=2025-12-15 feats=69 buy=YES sell=YES rows=30354
# [TH-OPT][GLOBAL] asof_bar=152915 buy_th=2.30 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=153107 buy_th=1.80 sell_th=1.15
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-12-16 19:55:00
# [TH-OPT][GLOBAL] asof_bar=153299 buy_th=1.50 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=153491 buy_th=2.25 sell_th=1.45
# [TRAIN][5M] asof=2025-12-22 feats=69 buy=YES sell=YES rows=30544
# [TH-OPT][GLOBAL] asof_bar=154067 buy_th=1.35 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-12-23 19:55:00
# [TRAIN][5M] asof=2025-12-29 feats=69 buy=YES sell=YES rows=30658
# [TH-OPT][GLOBAL] asof_bar=154794 buy_th=1.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=154986 buy_th=1.40 sell_th=0.85
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-12-31 19:55:00
# [TH-OPT][GLOBAL] asof_bar=155178 buy_th=1.50 sell_th=-0.50
# [TRAIN][5M] asof=2026-01-05 feats=69 buy=YES sell=YES rows=30773
# [TH-OPT][GLOBAL] asof_bar=155370 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=155562 buy_th=0.55 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=155754 buy_th=0.85 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=155946 buy_th=1.45 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-01-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=156137 buy_th=0.65 sell_th=2.10
# [TRAIN][5M] asof=2026-01-12 feats=69 buy=YES sell=YES rows=30995
# [TH-OPT][GLOBAL] asof_bar=156329 buy_th=-0.50 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=156521 buy_th=0.95 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=156713 buy_th=1.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=156905 buy_th=1.55 sell_th=2.40
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-01-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=157097 buy_th=1.00 sell_th=-0.50
# [TRAIN][5M] asof=2026-01-20 feats=69 buy=YES sell=YES rows=31159
# [TH-OPT][GLOBAL] asof_bar=157481 buy_th=1.45 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=157673 buy_th=1.60 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=157864 buy_th=2.00 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-01-23 19:55:00
# [TRAIN][5M] asof=2026-01-26 feats=69 buy=YES sell=YES rows=31345
# [TH-OPT][GLOBAL] asof_bar=158056 buy_th=2.00 sell_th=2.20
# [TH-OPT][GLOBAL] asof_bar=158248 buy_th=1.00 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=158440 buy_th=0.95 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=158632 buy_th=1.95 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=158824 buy_th=1.70 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-01-30 19:55:00
# [TRAIN][5M] asof=2026-02-02 feats=69 buy=YES sell=YES rows=31572
# [TH-OPT][GLOBAL] asof_bar=159016 buy_th=2.10 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=159208 buy_th=1.95 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=159400 buy_th=2.40 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=159592 buy_th=2.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=159784 buy_th=-0.50 sell_th=2.35
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-02-06 19:55:00
# [TRAIN][5M] asof=2026-02-09 feats=69 buy=YES sell=YES rows=31803
# [TH-OPT][GLOBAL] asof_bar=159976 buy_th=2.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=160168 buy_th=2.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=160360 buy_th=1.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=160552 buy_th=2.05 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=160744 buy_th=2.20 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-02-13 19:55:00
# [TRAIN][5M] asof=2026-02-17 feats=69 buy=YES sell=YES rows=32007
# [TH-OPT][GLOBAL] asof_bar=160936 buy_th=2.40 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=161128 buy_th=2.50 sell_th=1.40
# [TH-OPT][GLOBAL] asof_bar=161320 buy_th=2.45 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=161512 buy_th=2.40 sell_th=1.35
# [TRAIN][5M] asof=2026-02-23 feats=69 buy=YES sell=YES rows=32147
# [TH-OPT][GLOBAL] asof_bar=161704 buy_th=1.70 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-02-23 19:55:00
# [TH-OPT][GLOBAL] asof_bar=161896 buy_th=1.75 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=162088 buy_th=1.50 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=162280 buy_th=1.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=162472 buy_th=1.45 sell_th=1.00
# [TRAIN][5M] asof=2026-03-02 feats=69 buy=YES sell=YES rows=32354
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-03-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=163048 buy_th=2.45 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=163240 buy_th=1.20 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=163432 buy_th=-0.50 sell_th=1.90
# [TRAIN][5M] asof=2026-03-09 feats=69 buy=YES sell=YES rows=32547
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-03-09 19:55:00
# [TH-OPT][GLOBAL] asof_bar=164008 buy_th=2.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=164200 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=164392 buy_th=2.40 sell_th=2.20
# [TRAIN][5M] asof=2026-03-16 feats=69 buy=YES sell=YES rows=32767
# [TH-OPT][GLOBAL] asof_bar=164584 buy_th=1.90 sell_th=1.75
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-03-16 19:55:00
# [TH-OPT][GLOBAL] asof_bar=164775 buy_th=1.90 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=164967 buy_th=2.20 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=165159 buy_th=2.15 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=165351 buy_th=2.40 sell_th=1.50
# [TRAIN][5M] asof=2026-03-23 feats=69 buy=YES sell=YES rows=32981
# [TH-OPT][GLOBAL] asof_bar=165543 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-03-23 19:55:00
# [TH-OPT][GLOBAL] asof_bar=165735 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=165927 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=166119 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-03-27 19:55:00
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_noMacro_us2\trades.csv
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_noMacro_us2\daily_log.csv
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_noMacro_us2\equity_vs_buyhold.png
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_noMacro_us2\price_with_trades.png
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_noMacro_us2\p_day.png
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_noMacro_us2\daily_lr_feature_importance.csv
# [TRADES] total=1241
# [TRADES] first_trade_ts=2024-01-02 06:30:00 (sim_start=2024-01-01 00:00:00)

# %%
res = run_daily_prob_then_5m_xgb_gated(
    daily_csv_path="DataAPI/data/QQQ_DAY.csv",
    k5m_csv_path="DataAPI/data/QQQ_5M.csv",
    code="QQQ",

    daily_chan_start="2016-06-01",
    accumulation_start="2018-10-01",
    sim_start="2024-01-01",
    end_time="2026-12-31",

    N_confirm=5,
    min_labeled_days_to_train=200,
    retrain_every_new_labels=25,
    dp_lookback=5,

    p_sell_level=0.30,
    p_buy_level=0.20,

    lookahead_days_5m=2.0,
    retrain_every_days_5m=5,
    min_samples_total_5m=300,

    threshold_window_days=2.0,
    threshold_ret_grid=None,
    threshold_min_open_signals=10,

    initial_capital=100000.0,
    fee_pct=0.0,

    daily_chan_max_klines=500,
    five_chan_max_klines=500,

    macro_files={
        "vix_":   "VIX.csv",
        # "dxy_":   "DXY.csv",
        # "us5y_":  "US5Y.csv",
        # "us10y_": "US10Y.csv",
        # "us30y_": "US30Y.csv",
        # "xau_":   "XAU.csv",
        # "nyxbt_": "NYXBT.csv",
        # "10y2ys_": "10Y2YS.csv",
        # "us2y_": "US2Y.csv",
        # "spgsci_": "SPGSCI.csv",
        # "spy_": "SPY_DAY.csv",
        # "qqq_": "QQQ_DAY.csv",
        # "rut_": "RUT.csv",
        # "vvix_": "VVIX.csv",
        # "vix3m_": "VIX3M.csv",
        # "vxn_": "VXN.csv",
        # "rvx_": "RVX.csv",
        # "ixic_": "IXIC.csv",
        # "ndx_": "NDX.csv",
        # "dji_": "DJI.csv",
    },

    output_dir="output_dailyprob_gated_5m_xgb_QQQ_noMacro_2016-2024Cumulative",
    verbose=True,

    save_checkpoint_path="checkpoints/QQQ_noMacro_US2_checkpoint.joblib",
    checkpoint_every_n_days=5,
)
# Out:
# [TRAIN][DAILY-PROB] n=200 pos=29 (14.50%)
# [TRAIN][DAILY-PROB] n=225 pos=31 (13.78%)
# [TRAIN][DAILY-PROB] n=250 pos=38 (15.20%)
# [TRAIN][DAILY-PROB] n=275 pos=41 (14.91%)
# [TRAIN][DAILY-PROB] n=300 pos=44 (14.67%)
# [TRAIN][DAILY-PROB] n=325 pos=48 (14.77%)
# [TRAIN][DAILY-PROB] n=350 pos=55 (15.71%)
# [TRAIN][DAILY-PROB] n=375 pos=62 (16.53%)
# [TRAIN][DAILY-PROB] n=400 pos=69 (17.25%)
# [TRAIN][DAILY-PROB] n=425 pos=70 (16.47%)
# [TRAIN][DAILY-PROB] n=450 pos=75 (16.67%)
# [TRAIN][DAILY-PROB] n=475 pos=78 (16.42%)
# [TRAIN][DAILY-PROB] n=500 pos=84 (16.80%)
# [TRAIN][DAILY-PROB] n=525 pos=95 (18.10%)
# [TRAIN][DAILY-PROB] n=550 pos=110 (20.00%)
# [TRAIN][DAILY-PROB] n=575 pos=119 (20.70%)
# [TRAIN][DAILY-PROB] n=600 pos=120 (20.00%)
# [TRAIN][DAILY-PROB] n=625 pos=121 (19.36%)
# [TRAIN][DAILY-PROB] n=650 pos=128 (19.69%)
# [TRAIN][DAILY-PROB] n=675 pos=136 (20.15%)
# [TRAIN][DAILY-PROB] n=700 pos=141 (20.14%)
# [TRAIN][DAILY-PROB] n=725 pos=148 (20.41%)
# [TRAIN][DAILY-PROB] n=750 pos=151 (20.13%)
# [TRAIN][DAILY-PROB] n=775 pos=160 (20.65%)
# [TRAIN][DAILY-PROB] n=800 pos=160 (20.00%)
# [TRAIN][DAILY-PROB] n=825 pos=162 (19.64%)
# [TRAIN][DAILY-PROB] n=850 pos=163 (19.18%)
# [TRAIN][DAILY-PROB] n=875 pos=168 (19.20%)
# [TRAIN][DAILY-PROB] n=900 pos=172 (19.11%)
# [TRAIN][DAILY-PROB] n=925 pos=172 (18.59%)
# [TRAIN][DAILY-PROB] n=950 pos=177 (18.63%)
# [TRAIN][DAILY-PROB] n=975 pos=183 (18.77%)
# [TRAIN][DAILY-PROB] n=1000 pos=188 (18.80%)
# [TRAIN][DAILY-PROB] n=1025 pos=196 (19.12%)
# [TRAIN][DAILY-PROB] n=1050 pos=203 (19.33%)
# [TRAIN][DAILY-PROB] n=1075 pos=204 (18.98%)
# [TRAIN][DAILY-PROB] n=1100 pos=207 (18.82%)
# [TRAIN][DAILY-PROB] n=1125 pos=214 (19.02%)
# [TRAIN][DAILY-PROB] n=1150 pos=218 (18.96%)
# [TRAIN][DAILY-PROB] n=1175 pos=223 (18.98%)
# [TRAIN][DAILY-PROB] n=1200 pos=223 (18.58%)
# [TRAIN][DAILY-PROB] n=1225 pos=226 (18.45%)
# [TRAIN][DAILY-PROB] n=1250 pos=231 (18.48%)
# [TRAIN][DAILY-PROB] n=1275 pos=240 (18.82%)
# [TRAIN][DAILY-PROB] n=1300 pos=243 (18.69%)
# [TRAIN][DAILY-PROB] n=1325 pos=248 (18.72%)
# [TRAIN][DAILY-PROB] n=1350 pos=256 (18.96%)
# [TRAIN][DAILY-PROB] n=1375 pos=257 (18.69%)
# [TRAIN][DAILY-PROB] n=1400 pos=267 (19.07%)
# [TRAIN][DAILY-PROB] n=1425 pos=268 (18.81%)
# [TRAIN][DAILY-PROB] n=1450 pos=278 (19.17%)
# [TRAIN][DAILY-PROB] n=1475 pos=284 (19.25%)
# [TRAIN][DAILY-PROB] n=1500 pos=293 (19.53%)
# [TRAIN][DAILY-PROB] n=1525 pos=299 (19.61%)
# [TRAIN][DAILY-PROB] n=1550 pos=309 (19.94%)
# [TRAIN][DAILY-PROB] n=1575 pos=311 (19.75%)
# [TRAIN][DAILY-PROB] n=1600 pos=314 (19.62%)
# [TRAIN][DAILY-PROB] n=1625 pos=324 (19.94%)
# [TRAIN][DAILY-PROB] n=1650 pos=330 (20.00%)
# [TRAIN][DAILY-PROB] n=1675 pos=332 (19.82%)
# [TRAIN][DAILY-PROB] n=1700 pos=334 (19.65%)
# [TRAIN][DAILY-PROB] n=1725 pos=337 (19.54%)
# [TRAIN][DAILY-PROB] n=1750 pos=346 (19.77%)
# [TRAIN][DAILY-PROB] n=1775 pos=353 (19.89%)
# [TRAIN][DAILY-PROB] n=1800 pos=363 (20.17%)
# [TRAIN][DAILY-PROB] n=1825 pos=364 (19.95%)
# [TRAIN][DAILY-PROB] n=1850 pos=372 (20.11%)
# [TRAIN][DAILY-PROB] n=1875 pos=373 (19.89%)
# [TRAIN][DAILY-PROB] n=1900 pos=379 (19.95%)
# [TRAIN][DAILY-PROB] n=1925 pos=383 (19.90%)
# [TRAIN][DAILY-PROB] n=1950 pos=387 (19.85%)
# [TRAIN][DAILY-PROB] n=1975 pos=391 (19.80%)
# [TRAIN][DAILY-PROB] n=2000 pos=402 (20.10%)
# [TRAIN][DAILY-PROB] n=2025 pos=405 (20.00%)
# [TRAIN][DAILY-PROB] n=2050 pos=410 (20.00%)
# [TRAIN][DAILY-PROB] n=2075 pos=414 (19.95%)
# [TRAIN][DAILY-PROB] n=2100 pos=419 (19.95%)
# [TRAIN][DAILY-PROB] n=2125 pos=429 (20.19%)
# [TRAIN][DAILY-PROB] n=2150 pos=438 (20.37%)
# [TRAIN][DAILY-PROB] n=2175 pos=442 (20.32%)
# [TRAIN][DAILY-PROB] n=2200 pos=444 (20.18%)
# [TRAIN][DAILY-PROB] n=2225 pos=444 (19.96%)
# [TRAIN][DAILY-PROB] n=2250 pos=455 (20.22%)
# [TRAIN][DAILY-PROB] n=2275 pos=459 (20.18%)
# [TRAIN][DAILY-PROB] n=2300 pos=466 (20.26%)
# [TRAIN][DAILY-PROB] n=2325 pos=473 (20.34%)
# [TRAIN][DAILY-PROB] n=2350 pos=476 (20.26%)
# [TRAIN][DAILY-PROB] n=2375 pos=482 (20.29%)
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_noMacro_2016-2024Cumulative\daily_lr_feature_importance.csv
# [PHASE2/3] 5m feed begins at accumulation_start=2018-10-01, trading starts at sim_s=2024-01-01
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2018-10-05 19:55:00
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2018-10-12 19:55:00
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2018-10-19 19:55:00
# [TRAIN][5M] asof=2018-10-26 feats=69 buy=YES sell=NO rows=740
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2018-10-26 19:55:00
# [TRAIN][5M] asof=2018-10-31 feats=69 buy=YES sell=YES rows=898
# [TH-OPT][GLOBAL] asof_bar=4241 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=4615 buy_th=1.55 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2018-11-02 19:55:00
# [TRAIN][5M] asof=2018-11-05 feats=69 buy=YES sell=YES rows=1025
# [TH-OPT][GLOBAL] asof_bar=4990 buy_th=-0.50 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=5182 buy_th=-0.50 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=5370 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=5558 buy_th=-0.50 sell_th=1.75
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2018-11-09 19:55:00
# [TRAIN][5M] asof=2018-11-12 feats=69 buy=YES sell=YES rows=1215
# [TH-OPT][GLOBAL] asof_bar=5934 buy_th=2.30 sell_th=0.25
# [TH-OPT][GLOBAL] asof_bar=6125 buy_th=-0.50 sell_th=0.25
# [TH-OPT][GLOBAL] asof_bar=6316 buy_th=-0.50 sell_th=0.55
# [TH-OPT][GLOBAL] asof_bar=6498 buy_th=-0.50 sell_th=0.85
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2018-11-16 19:55:00
# [TRAIN][5M] asof=2018-11-19 feats=69 buy=YES sell=YES rows=1459
# [TH-OPT][GLOBAL] asof_bar=6690 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=6882 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=7066 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=7205 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2018-11-26 feats=69 buy=YES sell=YES rows=1619
# [TH-OPT][GLOBAL] asof_bar=7393 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2018-11-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=7582 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=7772 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=7963 buy_th=1.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=8143 buy_th=0.80 sell_th=-0.50
# [TRAIN][5M] asof=2018-12-03 feats=69 buy=YES sell=YES rows=1823
# [TH-OPT][GLOBAL] asof_bar=8334 buy_th=0.65 sell_th=1.15
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2018-12-03 19:55:00
# [TH-OPT][GLOBAL] asof_bar=8523 buy_th=1.00 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=8714 buy_th=-0.50 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=8895 buy_th=2.15 sell_th=0.80
# [TRAIN][5M] asof=2018-12-10 feats=69 buy=YES sell=YES rows=1992
# [TH-OPT][GLOBAL] asof_bar=9083 buy_th=-0.50 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=9274 buy_th=-0.50 sell_th=2.40
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2018-12-11 20:00:00
# [TH-OPT][GLOBAL] asof_bar=9463 buy_th=-0.50 sell_th=1.25
# [TH-OPT][GLOBAL] asof_bar=9648 buy_th=-0.50 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=9838 buy_th=-0.50 sell_th=0.55
# [TRAIN][5M] asof=2018-12-17 feats=69 buy=YES sell=YES rows=2197
# [TH-OPT][GLOBAL] asof_bar=10219 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2018-12-18 19:55:00
# [TH-OPT][GLOBAL] asof_bar=10408 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=10600 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=10789 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2018-12-24 feats=69 buy=YES sell=YES rows=2352
# [TH-OPT][GLOBAL] asof_bar=10938 buy_th=1.65 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2018-12-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=11321 buy_th=1.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=11502 buy_th=1.30 sell_th=-0.50
# [TRAIN][5M] asof=2018-12-31 feats=69 buy=YES sell=YES rows=2472
# [TH-OPT][GLOBAL] asof_bar=11872 buy_th=2.45 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=12064 buy_th=2.30 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-01-03 19:55:00
# [TH-OPT][GLOBAL] asof_bar=12250 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2019-01-07 feats=69 buy=YES sell=YES rows=2657
# [TH-OPT][GLOBAL] asof_bar=12436 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=12621 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=12812 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=13000 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-01-10 19:55:00
# [TH-OPT][GLOBAL] asof_bar=13177 buy_th=2.50 sell_th=-0.50
# [TRAIN][5M] asof=2019-01-14 feats=69 buy=YES sell=YES rows=2810
# [TH-OPT][GLOBAL] asof_bar=13363 buy_th=0.95 sell_th=1.25
# [TH-OPT][GLOBAL] asof_bar=13550 buy_th=-0.50 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=13735 buy_th=-0.50 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=13919 buy_th=-0.50 sell_th=0.90
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-01-17 19:55:00
# [TH-OPT][GLOBAL] asof_bar=14108 buy_th=-0.50 sell_th=1.65
# [TRAIN][5M] asof=2019-01-22 feats=69 buy=YES sell=YES rows=2976
# [TH-OPT][GLOBAL] asof_bar=14481 buy_th=2.30 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=14668 buy_th=2.35 sell_th=1.40
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-01-25 19:55:00
# [TRAIN][5M] asof=2019-01-28 feats=69 buy=YES sell=YES rows=3100
# [TH-OPT][GLOBAL] asof_bar=15034 buy_th=2.50 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=15223 buy_th=2.50 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=15414 buy_th=0.65 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=15602 buy_th=1.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=15782 buy_th=1.10 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-02-01 19:55:00
# [TRAIN][5M] asof=2019-02-04 feats=69 buy=YES sell=YES rows=3306
# [TH-OPT][GLOBAL] asof_bar=15959 buy_th=2.05 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=16138 buy_th=2.20 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=16322 buy_th=1.20 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=16510 buy_th=2.45 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=16686 buy_th=2.40 sell_th=1.30
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-02-08 19:55:00
# [TRAIN][5M] asof=2019-02-11 feats=69 buy=YES sell=YES rows=3498
# [TH-OPT][GLOBAL] asof_bar=16865 buy_th=1.55 sell_th=1.40
# [TH-OPT][GLOBAL] asof_bar=17053 buy_th=1.65 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=17417 buy_th=0.25 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=17593 buy_th=0.25 sell_th=2.45
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-02-15 19:55:00
# [TRAIN][5M] asof=2019-02-19 feats=69 buy=YES sell=YES rows=3685
# [TH-OPT][GLOBAL] asof_bar=17768 buy_th=0.85 sell_th=0.55
# [TH-OPT][GLOBAL] asof_bar=17936 buy_th=0.95 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=18113 buy_th=0.85 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=18286 buy_th=0.75 sell_th=1.20
# [TRAIN][5M] asof=2019-02-25 feats=69 buy=YES sell=YES rows=3853
# [TH-OPT][GLOBAL] asof_bar=18476 buy_th=1.85 sell_th=1.35
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-02-25 19:55:00
# [TH-OPT][GLOBAL] asof_bar=18661 buy_th=0.95 sell_th=1.50
# [TH-OPT][GLOBAL] asof_bar=18846 buy_th=1.05 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=19030 buy_th=1.45 sell_th=1.40
# [TH-OPT][GLOBAL] asof_bar=19207 buy_th=1.05 sell_th=-0.50
# [TRAIN][5M] asof=2019-03-04 feats=69 buy=YES sell=YES rows=4012
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-03-04 19:55:00
# [TH-OPT][GLOBAL] asof_bar=19577 buy_th=1.45 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=19752 buy_th=0.85 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=19928 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=20109 buy_th=1.75 sell_th=0.80
# [TRAIN][5M] asof=2019-03-11 feats=69 buy=YES sell=YES rows=4174
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-03-11 19:55:00
# [TH-OPT][GLOBAL] asof_bar=20847 buy_th=0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=21026 buy_th=0.30 sell_th=-0.50
# [TRAIN][5M] asof=2019-03-18 feats=69 buy=YES sell=YES rows=4350
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-03-18 19:55:00
# [TH-OPT][GLOBAL] asof_bar=21562 buy_th=-0.50 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=21744 buy_th=-0.50 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=21928 buy_th=2.30 sell_th=-0.50
# [TRAIN][5M] asof=2019-03-25 feats=69 buy=YES sell=YES rows=4512
# [TH-OPT][GLOBAL] asof_bar=22117 buy_th=1.65 sell_th=0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-03-25 19:55:00
# [TH-OPT][GLOBAL] asof_bar=22299 buy_th=2.05 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=22484 buy_th=2.05 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=22667 buy_th=-0.50 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=22842 buy_th=1.95 sell_th=0.80
# [TRAIN][5M] asof=2019-04-01 feats=69 buy=YES sell=YES rows=4711
# [TH-OPT][GLOBAL] asof_bar=23020 buy_th=-0.50 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-04-01 19:55:00
# [TH-OPT][GLOBAL] asof_bar=23196 buy_th=-0.50 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=23378 buy_th=0.85 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=23563 buy_th=0.85 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=23732 buy_th=1.10 sell_th=-0.50
# [TRAIN][5M] asof=2019-04-08 feats=69 buy=YES sell=YES rows=4882
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-04-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=24073 buy_th=0.70 sell_th=0.60
# [TH-OPT][GLOBAL] asof_bar=24246 buy_th=0.60 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=24422 buy_th=0.55 sell_th=0.45
# [TH-OPT][GLOBAL] asof_bar=24594 buy_th=-0.50 sell_th=0.55
# [TRAIN][5M] asof=2019-04-15 feats=69 buy=YES sell=YES rows=5023
# [TH-OPT][GLOBAL] asof_bar=24760 buy_th=1.20 sell_th=1.00
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-04-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=24940 buy_th=1.15 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=25115 buy_th=-0.50 sell_th=0.45
# [TH-OPT][GLOBAL] asof_bar=25276 buy_th=0.60 sell_th=0.60
# [TRAIN][5M] asof=2019-04-22 feats=69 buy=YES sell=YES rows=5170
# [TH-OPT][GLOBAL] asof_bar=25447 buy_th=-0.50 sell_th=0.70
# [TH-OPT][GLOBAL] asof_bar=25627 buy_th=-0.50 sell_th=1.20
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-04-23 19:55:00
# [TH-OPT][GLOBAL] asof_bar=25812 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=26000 buy_th=1.00 sell_th=0.55
# [TH-OPT][GLOBAL] asof_bar=26161 buy_th=1.20 sell_th=0.50
# [TRAIN][5M] asof=2019-04-29 feats=69 buy=YES sell=YES rows=5367
# [TH-OPT][GLOBAL] asof_bar=26348 buy_th=1.70 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=26528 buy_th=1.70 sell_th=0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-04-30 19:55:00
# [TH-OPT][GLOBAL] asof_bar=26707 buy_th=-0.50 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=27070 buy_th=1.90 sell_th=1.90
# [TRAIN][5M] asof=2019-05-06 feats=69 buy=YES sell=YES rows=5563
# [TH-OPT][GLOBAL] asof_bar=27449 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-05-07 19:55:00
# [TH-OPT][GLOBAL] asof_bar=27637 buy_th=1.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=27828 buy_th=1.65 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=28008 buy_th=2.20 sell_th=1.45
# [TRAIN][5M] asof=2019-05-13 feats=69 buy=YES sell=YES rows=5745
# [TH-OPT][GLOBAL] asof_bar=28199 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=28383 buy_th=2.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-05-14 19:55:00
# [TH-OPT][GLOBAL] asof_bar=28568 buy_th=2.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=28756 buy_th=1.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=28943 buy_th=1.10 sell_th=-0.50
# [TRAIN][5M] asof=2019-05-20 feats=69 buy=YES sell=YES rows=5968
# [TH-OPT][GLOBAL] asof_bar=29315 buy_th=2.20 sell_th=2.30
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-05-21 19:55:00
# [TH-OPT][GLOBAL] asof_bar=29495 buy_th=2.15 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=29684 buy_th=2.45 sell_th=0.50
# [TH-OPT][GLOBAL] asof_bar=29856 buy_th=-0.50 sell_th=0.65
# [TRAIN][5M] asof=2019-05-28 feats=69 buy=YES sell=YES rows=6137
# [TH-OPT][GLOBAL] asof_bar=30043 buy_th=2.30 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=30232 buy_th=-0.50 sell_th=1.60
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-05-29 19:55:00
# [TH-OPT][GLOBAL] asof_bar=30411 buy_th=2.35 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=30597 buy_th=2.50 sell_th=2.00
# [TRAIN][5M] asof=2019-06-03 feats=69 buy=YES sell=YES rows=6293
# [TH-OPT][GLOBAL] asof_bar=30786 buy_th=1.95 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=30978 buy_th=1.95 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=31169 buy_th=0.70 sell_th=2.35
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-06-05 19:55:00
# [TH-OPT][GLOBAL] asof_bar=31359 buy_th=0.80 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=31536 buy_th=0.75 sell_th=-0.50
# [TRAIN][5M] asof=2019-06-10 feats=69 buy=YES sell=YES rows=6471
# [TH-OPT][GLOBAL] asof_bar=31899 buy_th=1.85 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=32081 buy_th=-0.50 sell_th=1.95
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-06-12 19:55:00
# [TH-OPT][GLOBAL] asof_bar=32269 buy_th=1.35 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=32438 buy_th=1.40 sell_th=1.75
# [TRAIN][5M] asof=2019-06-17 feats=69 buy=YES sell=YES rows=6645
# [TH-OPT][GLOBAL] asof_bar=32622 buy_th=0.50 sell_th=1.25
# [TH-OPT][GLOBAL] asof_bar=32809 buy_th=0.70 sell_th=1.75
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-06-19 19:55:00
# [TRAIN][5M] asof=2019-06-24 feats=69 buy=YES sell=YES rows=6766
# [TH-OPT][GLOBAL] asof_bar=33723 buy_th=-0.50 sell_th=0.60
# [TH-OPT][GLOBAL] asof_bar=33906 buy_th=2.45 sell_th=0.70
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-06-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=34086 buy_th=2.50 sell_th=0.60
# [TH-OPT][GLOBAL] asof_bar=34253 buy_th=2.30 sell_th=0.75
# [TRAIN][5M] asof=2019-07-01 feats=69 buy=YES sell=YES rows=6942
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-07-03 16:45:00
# [TH-OPT][GLOBAL] asof_bar=34920 buy_th=0.95 sell_th=2.35
# [TRAIN][5M] asof=2019-07-08 feats=69 buy=YES sell=YES rows=7051
# [TH-OPT][GLOBAL] asof_bar=35097 buy_th=1.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=35278 buy_th=1.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=35467 buy_th=-0.50 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=35646 buy_th=1.10 sell_th=1.00
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-07-11 19:55:00
# [TH-OPT][GLOBAL] asof_bar=35821 buy_th=0.95 sell_th=0.90
# [TRAIN][5M] asof=2019-07-15 feats=69 buy=YES sell=YES rows=7183
# [TH-OPT][GLOBAL] asof_bar=36159 buy_th=1.20 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=36341 buy_th=1.55 sell_th=0.45
# [TH-OPT][GLOBAL] asof_bar=36524 buy_th=1.65 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-07-18 19:55:00
# [TH-OPT][GLOBAL] asof_bar=36702 buy_th=1.70 sell_th=-0.50
# [TRAIN][5M] asof=2019-07-22 feats=69 buy=YES sell=YES rows=7353
# [TH-OPT][GLOBAL] asof_bar=37068 buy_th=0.95 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=37257 buy_th=0.85 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=37444 buy_th=0.95 sell_th=2.15
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-07-25 19:55:00
# [TH-OPT][GLOBAL] asof_bar=37621 buy_th=1.15 sell_th=2.10
# [TRAIN][5M] asof=2019-07-29 feats=69 buy=YES sell=YES rows=7555
# [TH-OPT][GLOBAL] asof_bar=37794 buy_th=1.15 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=37982 buy_th=1.85 sell_th=1.25
# [TH-OPT][GLOBAL] asof_bar=38173 buy_th=1.85 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=38363 buy_th=2.50 sell_th=1.20
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-08-01 19:55:00
# [TH-OPT][GLOBAL] asof_bar=38540 buy_th=2.50 sell_th=0.50
# [TRAIN][5M] asof=2019-08-05 feats=69 buy=YES sell=YES rows=7795
# [TH-OPT][GLOBAL] asof_bar=38732 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=38923 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=39109 buy_th=2.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=39299 buy_th=2.05 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-08-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=39477 buy_th=2.30 sell_th=-0.50
# [TRAIN][5M] asof=2019-08-12 feats=69 buy=YES sell=YES rows=8005
# [TH-OPT][GLOBAL] asof_bar=39666 buy_th=2.30 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=39854 buy_th=2.45 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=40046 buy_th=2.40 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=40236 buy_th=2.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-08-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=40410 buy_th=2.45 sell_th=2.10
# [TRAIN][5M] asof=2019-08-19 feats=69 buy=YES sell=YES rows=8195
# [TH-OPT][GLOBAL] asof_bar=40787 buy_th=1.65 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=40973 buy_th=1.55 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=41158 buy_th=1.15 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-08-22 19:55:00
# [TH-OPT][GLOBAL] asof_bar=41343 buy_th=0.85 sell_th=-0.50
# [TRAIN][5M] asof=2019-08-26 feats=69 buy=YES sell=YES rows=8370
# [TH-OPT][GLOBAL] asof_bar=41531 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=41705 buy_th=2.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=41889 buy_th=2.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=42071 buy_th=1.10 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-08-29 19:55:00
# [TRAIN][5M] asof=2019-09-03 feats=69 buy=YES sell=YES rows=8535
# [TH-OPT][GLOBAL] asof_bar=42439 buy_th=2.30 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=42625 buy_th=2.30 sell_th=2.20
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-09-06 19:55:00
# [TRAIN][5M] asof=2019-09-09 feats=69 buy=YES sell=YES rows=8634
# [TH-OPT][GLOBAL] asof_bar=43148 buy_th=2.25 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=43335 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=43526 buy_th=2.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=43886 buy_th=2.30 sell_th=2.45
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-09-13 19:55:00
# [TRAIN][5M] asof=2019-09-16 feats=69 buy=YES sell=YES rows=8780
# [TH-OPT][GLOBAL] asof_bar=44060 buy_th=1.90 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=44236 buy_th=2.40 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=44411 buy_th=1.95 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=44593 buy_th=2.20 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=44774 buy_th=2.05 sell_th=1.65
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-09-20 19:55:00
# [TRAIN][5M] asof=2019-09-23 feats=69 buy=YES sell=YES rows=8970
# [TH-OPT][GLOBAL] asof_bar=44959 buy_th=1.95 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=45146 buy_th=2.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=45335 buy_th=2.15 sell_th=1.50
# [TH-OPT][GLOBAL] asof_bar=45505 buy_th=1.20 sell_th=0.75
# [TH-OPT][GLOBAL] asof_bar=45672 buy_th=1.60 sell_th=0.75
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-09-27 19:55:00
# [TRAIN][5M] asof=2019-09-30 feats=69 buy=YES sell=YES rows=9138
# [TH-OPT][GLOBAL] asof_bar=45853 buy_th=1.25 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=46037 buy_th=1.30 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=46227 buy_th=1.50 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=46402 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=46584 buy_th=-0.50 sell_th=1.95
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-10-04 19:55:00
# [TRAIN][5M] asof=2019-10-07 feats=69 buy=YES sell=YES rows=9287
# [TH-OPT][GLOBAL] asof_bar=46947 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=47134 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=47324 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=47509 buy_th=0.90 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-10-11 19:55:00
# [TRAIN][5M] asof=2019-10-14 feats=69 buy=YES sell=YES rows=9465
# [TH-OPT][GLOBAL] asof_bar=47690 buy_th=1.70 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=47865 buy_th=-0.50 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=48045 buy_th=0.95 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=48225 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=48396 buy_th=2.40 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-10-18 19:55:00
# [TRAIN][5M] asof=2019-10-21 feats=69 buy=YES sell=YES rows=9590
# [TH-OPT][GLOBAL] asof_bar=48942 buy_th=1.20 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=49125 buy_th=-0.50 sell_th=2.15
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-10-25 19:55:00
# [TRAIN][5M] asof=2019-10-28 feats=69 buy=YES sell=YES rows=9752
# [TH-OPT][GLOBAL] asof_bar=49652 buy_th=-0.50 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=49827 buy_th=-0.50 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=50011 buy_th=1.80 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=50176 buy_th=1.80 sell_th=2.40
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-11-01 19:55:00
# [TRAIN][5M] asof=2019-11-04 feats=69 buy=YES sell=YES rows=9908
# [TH-OPT][GLOBAL] asof_bar=50363 buy_th=-0.50 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=50545 buy_th=-0.50 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=51083 buy_th=1.95 sell_th=1.00
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-11-08 19:55:00
# [TRAIN][5M] asof=2019-11-11 feats=69 buy=YES sell=YES rows=10094
# [TH-OPT][GLOBAL] asof_bar=51261 buy_th=0.90 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=51433 buy_th=1.00 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=51618 buy_th=0.95 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=51804 buy_th=1.00 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=51975 buy_th=-0.50 sell_th=1.10
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-11-15 19:55:00
# [TRAIN][5M] asof=2019-11-18 feats=69 buy=YES sell=YES rows=10311
# [TH-OPT][GLOBAL] asof_bar=52156 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=52340 buy_th=1.15 sell_th=1.40
# [TH-OPT][GLOBAL] asof_bar=52525 buy_th=1.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=52704 buy_th=1.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=52869 buy_th=0.95 sell_th=0.75
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-11-22 19:55:00
# [TRAIN][5M] asof=2019-11-25 feats=69 buy=YES sell=YES rows=10536
# [TH-OPT][GLOBAL] asof_bar=53532 buy_th=1.00 sell_th=-0.50
# [TRAIN][5M] asof=2019-12-02 feats=69 buy=YES sell=YES rows=10636
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-12-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=53908 buy_th=2.30 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=54090 buy_th=2.35 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=54270 buy_th=1.70 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=54426 buy_th=1.85 sell_th=1.50
# [TRAIN][5M] asof=2019-12-09 feats=69 buy=YES sell=YES rows=10782
# [TH-OPT][GLOBAL] asof_bar=54604 buy_th=1.05 sell_th=1.05
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-12-09 19:55:00
# [TH-OPT][GLOBAL] asof_bar=54790 buy_th=0.90 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=54967 buy_th=0.95 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=55152 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2019-12-16 feats=69 buy=YES sell=YES rows=10952
# [TH-OPT][GLOBAL] asof_bar=55516 buy_th=1.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-12-16 19:55:00
# [TH-OPT][GLOBAL] asof_bar=55698 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=56053 buy_th=0.95 sell_th=1.40
# [TH-OPT][GLOBAL] asof_bar=56220 buy_th=0.95 sell_th=1.35
# [TRAIN][5M] asof=2019-12-23 feats=69 buy=YES sell=YES rows=11041
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-12-23 19:55:00
# [TRAIN][5M] asof=2019-12-30 feats=69 buy=YES sell=YES rows=11165
# [TH-OPT][GLOBAL] asof_bar=57025 buy_th=1.60 sell_th=0.50
# [TH-OPT][GLOBAL] asof_bar=57187 buy_th=1.65 sell_th=0.40
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2019-12-31 19:55:00
# [TRAIN][5M] asof=2020-01-06 feats=69 buy=YES sell=YES rows=11335
# [TH-OPT][GLOBAL] asof_bar=57934 buy_th=2.00 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=58121 buy_th=2.45 sell_th=1.90
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-01-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=58310 buy_th=-0.50 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=58479 buy_th=1.95 sell_th=1.60
# [TRAIN][5M] asof=2020-01-13 feats=69 buy=YES sell=YES rows=11568
# [TH-OPT][GLOBAL] asof_bar=58666 buy_th=1.60 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=58851 buy_th=2.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=59033 buy_th=2.00 sell_th=0.25
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-01-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=59220 buy_th=1.75 sell_th=0.40
# [TRAIN][5M] asof=2020-01-21 feats=69 buy=YES sell=YES rows=11766
# [TH-OPT][GLOBAL] asof_bar=59953 buy_th=2.00 sell_th=0.80
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-01-23 19:55:00
# [TH-OPT][GLOBAL] asof_bar=60138 buy_th=2.00 sell_th=1.15
# [TRAIN][5M] asof=2020-01-27 feats=69 buy=YES sell=YES rows=11943
# [TH-OPT][GLOBAL] asof_bar=60329 buy_th=1.85 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=60515 buy_th=1.70 sell_th=0.60
# [TH-OPT][GLOBAL] asof_bar=60895 buy_th=2.25 sell_th=2.00
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-01-30 19:55:00
# [TH-OPT][GLOBAL] asof_bar=61083 buy_th=2.30 sell_th=1.75
# [TRAIN][5M] asof=2020-02-03 feats=69 buy=YES sell=YES rows=12164
# [TH-OPT][GLOBAL] asof_bar=61272 buy_th=0.80 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=61459 buy_th=0.80 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=61651 buy_th=0.90 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=61838 buy_th=1.00 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-02-06 19:55:00
# [TH-OPT][GLOBAL] asof_bar=62027 buy_th=0.95 sell_th=-0.50
# [TRAIN][5M] asof=2020-02-10 feats=69 buy=YES sell=YES rows=12388
# [TH-OPT][GLOBAL] asof_bar=62407 buy_th=-0.50 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=62598 buy_th=-0.50 sell_th=0.90
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-02-13 19:55:00
# [TRAIN][5M] asof=2020-02-18 feats=69 buy=YES sell=YES rows=12552
# [TH-OPT][GLOBAL] asof_bar=63525 buy_th=2.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=63711 buy_th=2.15 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-02-21 19:55:00
# [TRAIN][5M] asof=2020-02-24 feats=69 buy=YES sell=YES rows=12682
# [TH-OPT][GLOBAL] asof_bar=63903 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=64095 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=64287 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=64479 buy_th=-0.50 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=64671 buy_th=-0.50 sell_th=2.00
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-02-28 19:55:00
# [TRAIN][5M] asof=2020-03-02 feats=69 buy=YES sell=YES rows=12915
# [TH-OPT][GLOBAL] asof_bar=64863 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=65055 buy_th=1.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=65247 buy_th=1.95 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=65631 buy_th=1.10 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-03-06 19:55:00
# [TRAIN][5M] asof=2020-03-09 feats=69 buy=YES sell=YES rows=13111
# [TH-OPT][GLOBAL] asof_bar=65821 buy_th=-0.50 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=66013 buy_th=-0.50 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=66205 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=66395 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=66587 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-03-13 19:55:00
# [TRAIN][5M] asof=2020-03-16 feats=69 buy=YES sell=YES rows=13266
# [TH-OPT][GLOBAL] asof_bar=66969 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=67159 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=67351 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=67543 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-03-20 19:55:00
# [TRAIN][5M] asof=2020-03-23 feats=69 buy=YES sell=YES rows=13514
# [TH-OPT][GLOBAL] asof_bar=67735 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=67927 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=68118 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=68310 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=68500 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-03-27 19:55:00
# [TRAIN][5M] asof=2020-03-30 feats=69 buy=YES sell=YES rows=13723
# [TH-OPT][GLOBAL] asof_bar=68884 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=69076 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=69268 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=69458 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-04-03 19:55:00
# [TRAIN][5M] asof=2020-04-06 feats=69 buy=YES sell=YES rows=13891
# [TH-OPT][GLOBAL] asof_bar=69650 buy_th=2.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=69841 buy_th=2.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=70031 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=70222 buy_th=1.45 sell_th=-0.50
# [TRAIN][5M] asof=2020-04-13 feats=69 buy=YES sell=YES rows=14032
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-04-13 19:55:00
# [TH-OPT][GLOBAL] asof_bar=70796 buy_th=-0.50 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=70987 buy_th=-0.50 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=71177 buy_th=-0.50 sell_th=2.25
# [TRAIN][5M] asof=2020-04-20 feats=69 buy=YES sell=YES rows=14233
# [TH-OPT][GLOBAL] asof_bar=71367 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-04-20 19:55:00
# [TH-OPT][GLOBAL] asof_bar=71559 buy_th=-0.50 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=71751 buy_th=-0.50 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=71939 buy_th=-0.50 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=72127 buy_th=-0.50 sell_th=2.50
# [TRAIN][5M] asof=2020-04-27 feats=69 buy=YES sell=YES rows=14502
# [TH-OPT][GLOBAL] asof_bar=72319 buy_th=0.90 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-04-27 19:55:00
# [TH-OPT][GLOBAL] asof_bar=72509 buy_th=2.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=72699 buy_th=1.85 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=72888 buy_th=0.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=73076 buy_th=1.10 sell_th=-0.50
# [TRAIN][5M] asof=2020-05-04 feats=69 buy=YES sell=YES rows=14696
# [TH-OPT][GLOBAL] asof_bar=73266 buy_th=-0.50 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-05-04 19:55:00
# [TH-OPT][GLOBAL] asof_bar=73455 buy_th=-0.50 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=73642 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=73834 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=74024 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2020-05-11 feats=69 buy=YES sell=YES rows=14901
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-05-11 19:55:00
# [TH-OPT][GLOBAL] asof_bar=74404 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=74596 buy_th=2.45 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=74786 buy_th=-0.50 sell_th=1.40
# [TH-OPT][GLOBAL] asof_bar=74974 buy_th=2.50 sell_th=2.45
# [TRAIN][5M] asof=2020-05-18 feats=69 buy=YES sell=YES rows=15123
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-05-18 19:55:00
# [TH-OPT][GLOBAL] asof_bar=75354 buy_th=1.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=75546 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=75923 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2020-05-26 feats=69 buy=YES sell=YES rows=15337
# [TH-OPT][GLOBAL] asof_bar=76113 buy_th=2.40 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-05-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=76304 buy_th=2.30 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=76496 buy_th=2.10 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=76686 buy_th=1.70 sell_th=2.30
# [TRAIN][5M] asof=2020-06-01 feats=69 buy=YES sell=YES rows=15498
# [TH-OPT][GLOBAL] asof_bar=76876 buy_th=0.60 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=77068 buy_th=0.90 sell_th=2.25
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-06-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=77254 buy_th=0.75 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=77439 buy_th=0.70 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=77620 buy_th=0.85 sell_th=2.50
# [TRAIN][5M] asof=2020-06-08 feats=69 buy=YES sell=YES rows=15724
# [TH-OPT][GLOBAL] asof_bar=77809 buy_th=2.15 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=77997 buy_th=2.25 sell_th=2.45
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-06-09 19:55:00
# [TH-OPT][GLOBAL] asof_bar=78380 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=78569 buy_th=2.35 sell_th=-0.50
# [TRAIN][5M] asof=2020-06-15 feats=69 buy=YES sell=YES rows=15895
# [TH-OPT][GLOBAL] asof_bar=78951 buy_th=2.20 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-06-16 19:55:00
# [TH-OPT][GLOBAL] asof_bar=79143 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=79331 buy_th=2.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=79517 buy_th=2.30 sell_th=-0.50
# [TRAIN][5M] asof=2020-06-22 feats=69 buy=YES sell=YES rows=16117
# [TH-OPT][GLOBAL] asof_bar=79707 buy_th=1.60 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=79897 buy_th=-0.50 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-06-23 19:55:00
# [TH-OPT][GLOBAL] asof_bar=80084 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=80274 buy_th=-0.50 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=80462 buy_th=-0.50 sell_th=2.50
# [TRAIN][5M] asof=2020-06-29 feats=69 buy=YES sell=YES rows=16314
# [TH-OPT][GLOBAL] asof_bar=80844 buy_th=1.45 sell_th=2.20
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-06-30 19:55:00
# [TH-OPT][GLOBAL] asof_bar=81030 buy_th=1.35 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=81216 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2020-07-06 feats=69 buy=YES sell=YES rows=16463
# [TH-OPT][GLOBAL] asof_bar=81596 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=81788 buy_th=-0.50 sell_th=0.75
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-07-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=81975 buy_th=-0.50 sell_th=1.95
# [TRAIN][5M] asof=2020-07-13 feats=69 buy=YES sell=YES rows=16700
# [TH-OPT][GLOBAL] asof_bar=82355 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=82547 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=82735 buy_th=2.35 sell_th=1.35
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-07-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=82926 buy_th=2.30 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=83107 buy_th=2.45 sell_th=0.85
# [TRAIN][5M] asof=2020-07-20 feats=69 buy=YES sell=YES rows=16900
# [TH-OPT][GLOBAL] asof_bar=83489 buy_th=1.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=83681 buy_th=2.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-07-22 19:55:00
# [TH-OPT][GLOBAL] asof_bar=83872 buy_th=2.25 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=84059 buy_th=2.40 sell_th=-0.50
# [TRAIN][5M] asof=2020-07-27 feats=69 buy=YES sell=YES rows=17099
# [TH-OPT][GLOBAL] asof_bar=84441 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=84628 buy_th=1.70 sell_th=1.00
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-07-29 19:55:00
# [TH-OPT][GLOBAL] asof_bar=84820 buy_th=0.75 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=85010 buy_th=0.60 sell_th=2.25
# [TRAIN][5M] asof=2020-08-03 feats=69 buy=YES sell=YES rows=17292
# [TH-OPT][GLOBAL] asof_bar=85391 buy_th=1.25 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=85578 buy_th=1.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-08-05 19:55:00
# [TH-OPT][GLOBAL] asof_bar=85762 buy_th=1.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=85948 buy_th=1.50 sell_th=-0.50
# [TRAIN][5M] asof=2020-08-10 feats=69 buy=YES sell=YES rows=17482
# [TH-OPT][GLOBAL] asof_bar=86134 buy_th=2.25 sell_th=1.50
# [TH-OPT][GLOBAL] asof_bar=86326 buy_th=1.90 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=86515 buy_th=-0.50 sell_th=1.75
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-08-12 19:55:00
# [TH-OPT][GLOBAL] asof_bar=86888 buy_th=-0.50 sell_th=1.65
# [TRAIN][5M] asof=2020-08-17 feats=69 buy=YES sell=YES rows=17672
# [TH-OPT][GLOBAL] asof_bar=87448 buy_th=2.10 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-08-19 19:55:00
# [TH-OPT][GLOBAL] asof_bar=87639 buy_th=2.00 sell_th=1.40
# [TH-OPT][GLOBAL] asof_bar=87826 buy_th=1.25 sell_th=0.85
# [TRAIN][5M] asof=2020-08-24 feats=69 buy=YES sell=YES rows=17854
# [TH-OPT][GLOBAL] asof_bar=88203 buy_th=2.25 sell_th=1.70
# [TH-OPT][GLOBAL] asof_bar=88392 buy_th=2.25 sell_th=1.90
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-08-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=88582 buy_th=-0.50 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=88766 buy_th=2.30 sell_th=1.25
# [TRAIN][5M] asof=2020-08-31 feats=69 buy=YES sell=YES rows=18065
# [TH-OPT][GLOBAL] asof_bar=89149 buy_th=-0.50 sell_th=2.30
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-09-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=89532 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=89724 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2020-09-08 feats=69 buy=YES sell=YES rows=18256
# [TH-OPT][GLOBAL] asof_bar=89916 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=90108 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=90299 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-09-10 19:55:00
# [TH-OPT][GLOBAL] asof_bar=90488 buy_th=2.50 sell_th=-0.50
# [TRAIN][5M] asof=2020-09-14 feats=69 buy=YES sell=YES rows=18439
# [TH-OPT][GLOBAL] asof_bar=90679 buy_th=2.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=90871 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=91063 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=91255 buy_th=2.30 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-09-17 19:55:00
# [TH-OPT][GLOBAL] asof_bar=91445 buy_th=1.65 sell_th=-0.50
# [TRAIN][5M] asof=2020-09-21 feats=69 buy=YES sell=YES rows=18651
# [TH-OPT][GLOBAL] asof_bar=91637 buy_th=2.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=91827 buy_th=1.85 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=92018 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=92209 buy_th=2.30 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-09-24 19:55:00
# [TH-OPT][GLOBAL] asof_bar=92396 buy_th=2.05 sell_th=-0.50
# [TRAIN][5M] asof=2020-09-28 feats=69 buy=YES sell=YES rows=18846
# [TH-OPT][GLOBAL] asof_bar=92776 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=92968 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=93160 buy_th=1.85 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-10-01 19:55:00
# [TH-OPT][GLOBAL] asof_bar=93352 buy_th=2.30 sell_th=-0.50
# [TRAIN][5M] asof=2020-10-05 feats=69 buy=YES sell=YES rows=19052
# [TH-OPT][GLOBAL] asof_bar=93736 buy_th=-0.50 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=93927 buy_th=-0.50 sell_th=2.45
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-10-08 19:55:00
# [TRAIN][5M] asof=2020-10-12 feats=69 buy=YES sell=YES rows=19257
# [TH-OPT][GLOBAL] asof_bar=94689 buy_th=0.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=94880 buy_th=1.30 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=95071 buy_th=1.60 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-10-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=95261 buy_th=1.00 sell_th=1.80
# [TRAIN][5M] asof=2020-10-19 feats=69 buy=YES sell=YES rows=19469
# [TH-OPT][GLOBAL] asof_bar=95453 buy_th=2.35 sell_th=2.20
# [TH-OPT][GLOBAL] asof_bar=95645 buy_th=2.20 sell_th=1.50
# [TH-OPT][GLOBAL] asof_bar=95837 buy_th=1.55 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=96025 buy_th=1.65 sell_th=1.10
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-10-22 19:55:00
# [TH-OPT][GLOBAL] asof_bar=96212 buy_th=-0.50 sell_th=1.15
# [TRAIN][5M] asof=2020-10-26 feats=69 buy=YES sell=YES rows=19650
# [TH-OPT][GLOBAL] asof_bar=96404 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=96596 buy_th=2.10 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=96788 buy_th=2.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=96980 buy_th=2.50 sell_th=2.25
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-10-29 19:55:00
# [TH-OPT][GLOBAL] asof_bar=97172 buy_th=1.75 sell_th=2.20
# [TRAIN][5M] asof=2020-11-02 feats=69 buy=YES sell=YES rows=19878
# [TH-OPT][GLOBAL] asof_bar=97364 buy_th=1.90 sell_th=2.20
# [TH-OPT][GLOBAL] asof_bar=97556 buy_th=1.25 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=97748 buy_th=-0.50 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=97940 buy_th=2.15 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-11-05 19:55:00
# [TH-OPT][GLOBAL] asof_bar=98124 buy_th=0.70 sell_th=-0.50
# [TRAIN][5M] asof=2020-11-09 feats=69 buy=YES sell=YES rows=20042
# [TH-OPT][GLOBAL] asof_bar=98700 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=98891 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-11-12 19:55:00
# [TH-OPT][GLOBAL] asof_bar=99082 buy_th=-0.50 sell_th=1.40
# [TRAIN][5M] asof=2020-11-16 feats=69 buy=YES sell=YES rows=20224
# [TH-OPT][GLOBAL] asof_bar=99273 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=99459 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=99650 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=99839 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-11-19 19:55:00
# [TH-OPT][GLOBAL] asof_bar=100023 buy_th=-0.50 sell_th=2.50
# [TRAIN][5M] asof=2020-11-23 feats=69 buy=YES sell=YES rows=20401
# [TH-OPT][GLOBAL] asof_bar=100405 buy_th=-0.50 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=100595 buy_th=1.35 sell_th=1.60
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-11-27 16:55:00
# [TRAIN][5M] asof=2020-11-30 feats=69 buy=YES sell=YES rows=20529
# [TH-OPT][GLOBAL] asof_bar=100932 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=101122 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=101311 buy_th=2.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=101497 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=101681 buy_th=1.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-12-04 19:55:00
# [TRAIN][5M] asof=2020-12-07 feats=69 buy=YES sell=YES rows=20737
# [TH-OPT][GLOBAL] asof_bar=102055 buy_th=2.50 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=102244 buy_th=2.50 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=102433 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=102609 buy_th=2.30 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-12-11 19:55:00
# [TRAIN][5M] asof=2020-12-14 feats=69 buy=YES sell=YES rows=20880
# [TH-OPT][GLOBAL] asof_bar=102985 buy_th=1.60 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=103175 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=103365 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=103552 buy_th=1.30 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-12-18 19:55:00
# [TRAIN][5M] asof=2020-12-21 feats=69 buy=YES sell=YES rows=21051
# [TH-OPT][GLOBAL] asof_bar=103744 buy_th=2.40 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=103930 buy_th=2.50 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=104115 buy_th=1.05 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=104247 buy_th=1.35 sell_th=1.70
# [TRAIN][5M] asof=2020-12-28 feats=69 buy=YES sell=YES rows=21208
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2020-12-28 19:55:00
# [TH-OPT][GLOBAL] asof_bar=104620 buy_th=-0.50 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=104806 buy_th=1.30 sell_th=0.70
# [TH-OPT][GLOBAL] asof_bar=104982 buy_th=1.25 sell_th=2.15
# [TRAIN][5M] asof=2021-01-04 feats=69 buy=YES sell=YES rows=21352
# [TH-OPT][GLOBAL] asof_bar=105171 buy_th=1.70 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=105361 buy_th=1.85 sell_th=2.10
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2021-01-05 19:55:00
# [TH-OPT][GLOBAL] asof_bar=105553 buy_th=0.90 sell_th=1.80
# [TRAIN][5M] asof=2021-01-11 feats=69 buy=YES sell=YES rows=21550
# [TH-OPT][GLOBAL] asof_bar=106124 buy_th=2.50 sell_th=2.35
# ...
# [TRAIN][5M] asof=2025-06-30 feats=69 buy=YES sell=YES rows=63976
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-06-30 19:55:00
# [TH-OPT][GLOBAL] asof_bar=319290 buy_th=1.90 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=319481 buy_th=1.50 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=319636 buy_th=-0.50 sell_th=2.35
# [TRAIN][5M] asof=2025-07-07 feats=69 buy=YES sell=YES rows=64134
# [TH-OPT][GLOBAL] asof_bar=319828 buy_th=1.80 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=320019 buy_th=1.65 sell_th=0.75
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-07-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=320210 buy_th=1.65 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=320401 buy_th=1.65 sell_th=2.20
# [TH-OPT][GLOBAL] asof_bar=320589 buy_th=1.70 sell_th=1.75
# [TRAIN][5M] asof=2025-07-14 feats=69 buy=YES sell=YES rows=64300
# [TH-OPT][GLOBAL] asof_bar=320781 buy_th=1.55 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=320973 buy_th=1.65 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-07-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=321165 buy_th=1.65 sell_th=0.70
# [TH-OPT][GLOBAL] asof_bar=321356 buy_th=1.40 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=321543 buy_th=-0.50 sell_th=1.00
# [TRAIN][5M] asof=2025-07-21 feats=69 buy=YES sell=YES rows=64512
# [TH-OPT][GLOBAL] asof_bar=321735 buy_th=1.35 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=321927 buy_th=1.95 sell_th=1.65
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-07-22 19:55:00
# [TH-OPT][GLOBAL] asof_bar=322119 buy_th=1.55 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=322310 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=322497 buy_th=1.15 sell_th=1.20
# [TRAIN][5M] asof=2025-07-28 feats=69 buy=YES sell=YES rows=64722
# [TH-OPT][GLOBAL] asof_bar=322879 buy_th=1.20 sell_th=1.90
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-07-29 19:55:00
# [TH-OPT][GLOBAL] asof_bar=323263 buy_th=-0.50 sell_th=1.50
# [TH-OPT][GLOBAL] asof_bar=323454 buy_th=2.30 sell_th=-0.50
# [TRAIN][5M] asof=2025-08-04 feats=69 buy=YES sell=YES rows=64910
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-08-05 19:55:00
# [TH-OPT][GLOBAL] asof_bar=324030 buy_th=-0.50 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=324222 buy_th=1.40 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=324411 buy_th=1.15 sell_th=2.00
# [TRAIN][5M] asof=2025-08-11 feats=69 buy=YES sell=YES rows=65084
# [TH-OPT][GLOBAL] asof_bar=324603 buy_th=1.90 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=324795 buy_th=-0.50 sell_th=2.40
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-08-12 19:55:00
# [TH-OPT][GLOBAL] asof_bar=324987 buy_th=1.65 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=325178 buy_th=1.60 sell_th=0.70
# [TH-OPT][GLOBAL] asof_bar=325367 buy_th=1.50 sell_th=0.65
# [TRAIN][5M] asof=2025-08-18 feats=69 buy=YES sell=YES rows=65238
# [TH-OPT][GLOBAL] asof_bar=325559 buy_th=1.25 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=325750 buy_th=2.00 sell_th=1.10
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-08-19 19:55:00
# [TH-OPT][GLOBAL] asof_bar=325942 buy_th=1.90 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=326134 buy_th=1.40 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=326325 buy_th=1.05 sell_th=2.30
# [TRAIN][5M] asof=2025-08-25 feats=69 buy=YES sell=YES rows=65423
# [TH-OPT][GLOBAL] asof_bar=326516 buy_th=1.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=326708 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-08-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=326900 buy_th=-0.50 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=327282 buy_th=1.30 sell_th=-0.50
# [TRAIN][5M] asof=2025-09-02 feats=69 buy=YES sell=YES rows=65580
# [TH-OPT][GLOBAL] asof_bar=327666 buy_th=1.40 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-09-03 19:55:00
# [TH-OPT][GLOBAL] asof_bar=327858 buy_th=-0.50 sell_th=2.45
# [TRAIN][5M] asof=2025-09-08 feats=69 buy=YES sell=YES rows=65718
# [TH-OPT][GLOBAL] asof_bar=328240 buy_th=0.90 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=328432 buy_th=1.15 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=328624 buy_th=1.05 sell_th=1.80
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-09-10 19:55:00
# [TH-OPT][GLOBAL] asof_bar=328816 buy_th=1.05 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=329007 buy_th=0.65 sell_th=2.35
# [TRAIN][5M] asof=2025-09-15 feats=69 buy=YES sell=YES rows=65870
# [TH-OPT][GLOBAL] asof_bar=329388 buy_th=-0.50 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=329579 buy_th=0.75 sell_th=1.60
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-09-17 19:55:00
# [TH-OPT][GLOBAL] asof_bar=329770 buy_th=1.15 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=329959 buy_th=0.70 sell_th=1.30
# [TRAIN][5M] asof=2025-09-22 feats=69 buy=YES sell=YES rows=66097
# [TH-OPT][GLOBAL] asof_bar=330150 buy_th=2.40 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=330342 buy_th=-0.50 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=330533 buy_th=1.80 sell_th=2.00
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-09-24 19:55:00
# [TH-OPT][GLOBAL] asof_bar=330725 buy_th=2.00 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=330909 buy_th=1.65 sell_th=1.75
# [TRAIN][5M] asof=2025-09-29 feats=69 buy=YES sell=YES rows=66287
# [TH-OPT][GLOBAL] asof_bar=331292 buy_th=1.35 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=331483 buy_th=1.30 sell_th=1.10
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-10-01 19:55:00
# [TH-OPT][GLOBAL] asof_bar=331864 buy_th=1.45 sell_th=1.65
# [TRAIN][5M] asof=2025-10-06 feats=69 buy=YES sell=YES rows=66513
# [TH-OPT][GLOBAL] asof_bar=332248 buy_th=1.25 sell_th=1.50
# [TH-OPT][GLOBAL] asof_bar=332440 buy_th=-0.50 sell_th=2.40
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-10-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=332632 buy_th=1.25 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=332824 buy_th=2.05 sell_th=1.55
# [TRAIN][5M] asof=2025-10-13 feats=69 buy=YES sell=YES rows=66709
# [TH-OPT][GLOBAL] asof_bar=333208 buy_th=2.40 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=333400 buy_th=1.95 sell_th=2.10
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-10-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=333592 buy_th=1.50 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=333783 buy_th=1.80 sell_th=1.80
# [TRAIN][5M] asof=2025-10-20 feats=69 buy=YES sell=YES rows=66925
# [TH-OPT][GLOBAL] asof_bar=334166 buy_th=1.25 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=334358 buy_th=2.05 sell_th=1.95
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-10-22 19:55:00
# [TH-OPT][GLOBAL] asof_bar=334550 buy_th=1.50 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=334740 buy_th=-0.50 sell_th=2.50
# [TRAIN][5M] asof=2025-10-27 feats=69 buy=YES sell=YES rows=67127
# [TH-OPT][GLOBAL] asof_bar=334932 buy_th=2.35 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=335124 buy_th=1.10 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=335316 buy_th=-0.50 sell_th=1.95
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-10-29 19:55:00
# [TH-OPT][GLOBAL] asof_bar=335508 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=335697 buy_th=2.45 sell_th=1.75
# [TRAIN][5M] asof=2025-11-03 feats=69 buy=YES sell=YES rows=67342
# [TH-OPT][GLOBAL] asof_bar=335889 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=336081 buy_th=2.40 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=336273 buy_th=2.40 sell_th=1.45
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-11-05 19:55:00
# [TH-OPT][GLOBAL] asof_bar=336465 buy_th=2.45 sell_th=1.25
# [TH-OPT][GLOBAL] asof_bar=336657 buy_th=2.25 sell_th=2.40
# [TRAIN][5M] asof=2025-11-10 feats=69 buy=YES sell=YES rows=67589
# [TH-OPT][GLOBAL] asof_bar=337041 buy_th=-0.50 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=337233 buy_th=1.80 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-11-12 19:55:00
# [TH-OPT][GLOBAL] asof_bar=337425 buy_th=1.80 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=337617 buy_th=2.00 sell_th=2.10
# [TRAIN][5M] asof=2025-11-17 feats=69 buy=YES sell=YES rows=67797
# [TH-OPT][GLOBAL] asof_bar=337809 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=338001 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=338193 buy_th=2.25 sell_th=1.55
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-11-19 19:55:00
# [TH-OPT][GLOBAL] asof_bar=338385 buy_th=2.35 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=338577 buy_th=-0.50 sell_th=1.65
# [TRAIN][5M] asof=2025-11-24 feats=69 buy=YES sell=YES rows=68030
# [TH-OPT][GLOBAL] asof_bar=338961 buy_th=1.70 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=339153 buy_th=1.70 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-11-26 19:55:00
# [TRAIN][5M] asof=2025-12-01 feats=69 buy=YES sell=YES rows=68147
# [TH-OPT][GLOBAL] asof_bar=339501 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=339693 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=339885 buy_th=1.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=340077 buy_th=1.25 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-12-04 19:55:00
# [TH-OPT][GLOBAL] asof_bar=340269 buy_th=1.40 sell_th=-0.50
# [TRAIN][5M] asof=2025-12-08 feats=69 buy=YES sell=YES rows=68339
# [TH-OPT][GLOBAL] asof_bar=340653 buy_th=1.60 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=340845 buy_th=1.40 sell_th=2.20
# [TH-OPT][GLOBAL] asof_bar=341037 buy_th=1.65 sell_th=1.15
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-12-11 19:55:00
# [TH-OPT][GLOBAL] asof_bar=341229 buy_th=2.30 sell_th=2.15
# [TRAIN][5M] asof=2025-12-15 feats=69 buy=YES sell=YES rows=68548
# [TH-OPT][GLOBAL] asof_bar=341421 buy_th=2.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=341613 buy_th=2.20 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=341805 buy_th=2.05 sell_th=0.40
# [TH-OPT][GLOBAL] asof_bar=341997 buy_th=2.25 sell_th=0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-12-18 19:55:00
# [TRAIN][5M] asof=2025-12-22 feats=69 buy=YES sell=YES rows=68738
# [TH-OPT][GLOBAL] asof_bar=342573 buy_th=1.15 sell_th=2.45
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2025-12-26 19:55:00
# [TRAIN][5M] asof=2025-12-29 feats=69 buy=YES sell=YES rows=68852
# [TH-OPT][GLOBAL] asof_bar=343300 buy_th=1.45 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=343492 buy_th=1.70 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=343684 buy_th=1.25 sell_th=2.10
# [TRAIN][5M] asof=2026-01-05 feats=69 buy=YES sell=YES rows=68967
# [TH-OPT][GLOBAL] asof_bar=343876 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-01-05 19:55:00
# [TH-OPT][GLOBAL] asof_bar=344068 buy_th=0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=344260 buy_th=0.75 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=344452 buy_th=1.95 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=344643 buy_th=1.45 sell_th=2.05
# [TRAIN][5M] asof=2026-01-12 feats=69 buy=YES sell=YES rows=69189
# [TH-OPT][GLOBAL] asof_bar=344835 buy_th=1.05 sell_th=2.45
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-01-12 19:55:00
# [TH-OPT][GLOBAL] asof_bar=345027 buy_th=1.20 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=345219 buy_th=2.05 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=345411 buy_th=2.40 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=345603 buy_th=1.50 sell_th=-0.50
# [TRAIN][5M] asof=2026-01-20 feats=69 buy=YES sell=YES rows=69353
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-01-20 19:55:00
# [TH-OPT][GLOBAL] asof_bar=345987 buy_th=2.20 sell_th=1.70
# [TH-OPT][GLOBAL] asof_bar=346179 buy_th=2.10 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=346370 buy_th=2.25 sell_th=2.00
# [TRAIN][5M] asof=2026-01-26 feats=69 buy=YES sell=YES rows=69539
# [TH-OPT][GLOBAL] asof_bar=346562 buy_th=1.90 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=346754 buy_th=1.25 sell_th=2.15
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-01-27 19:55:00
# [TH-OPT][GLOBAL] asof_bar=346946 buy_th=0.90 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=347138 buy_th=2.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=347330 buy_th=1.80 sell_th=-0.50
# [TRAIN][5M] asof=2026-02-02 feats=69 buy=YES sell=YES rows=69766
# [TH-OPT][GLOBAL] asof_bar=347522 buy_th=2.10 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=347714 buy_th=1.85 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-02-03 19:55:00
# [TH-OPT][GLOBAL] asof_bar=347906 buy_th=2.45 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=348098 buy_th=2.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=348290 buy_th=-0.50 sell_th=2.20
# [TRAIN][5M] asof=2026-02-09 feats=69 buy=YES sell=YES rows=69997
# [TH-OPT][GLOBAL] asof_bar=348482 buy_th=1.90 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=348674 buy_th=2.35 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-02-10 19:55:00
# [TH-OPT][GLOBAL] asof_bar=348866 buy_th=1.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=349058 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=349250 buy_th=2.30 sell_th=-0.50
# [TRAIN][5M] asof=2026-02-17 feats=69 buy=YES sell=YES rows=70201
# [TH-OPT][GLOBAL] asof_bar=349442 buy_th=2.50 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=349634 buy_th=2.50 sell_th=1.70
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-02-18 19:55:00
# [TH-OPT][GLOBAL] asof_bar=349826 buy_th=2.40 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=350018 buy_th=2.20 sell_th=0.90
# [TRAIN][5M] asof=2026-02-23 feats=69 buy=YES sell=YES rows=70341
# [TH-OPT][GLOBAL] asof_bar=350210 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=350402 buy_th=1.05 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=350594 buy_th=1.50 sell_th=2.10
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-02-25 19:55:00
# [TH-OPT][GLOBAL] asof_bar=350786 buy_th=1.85 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=350978 buy_th=2.00 sell_th=1.35
# [TRAIN][5M] asof=2026-03-02 feats=69 buy=YES sell=YES rows=70548
# [TH-OPT][GLOBAL] asof_bar=351554 buy_th=2.50 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-03-04 19:55:00
# [TH-OPT][GLOBAL] asof_bar=351746 buy_th=1.35 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=351938 buy_th=2.30 sell_th=1.90
# [TRAIN][5M] asof=2026-03-09 feats=69 buy=YES sell=YES rows=70741
# [TH-OPT][GLOBAL] asof_bar=352514 buy_th=1.80 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-03-11 19:55:00
# [TH-OPT][GLOBAL] asof_bar=352706 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=352898 buy_th=2.45 sell_th=2.25
# [TRAIN][5M] asof=2026-03-16 feats=69 buy=YES sell=YES rows=70961
# [TH-OPT][GLOBAL] asof_bar=353090 buy_th=1.95 sell_th=1.70
# [TH-OPT][GLOBAL] asof_bar=353281 buy_th=2.20 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=353473 buy_th=2.50 sell_th=2.40
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-03-18 19:55:00
# [TH-OPT][GLOBAL] asof_bar=353665 buy_th=2.35 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=353857 buy_th=-0.50 sell_th=1.80
# [TRAIN][5M] asof=2026-03-23 feats=69 buy=YES sell=YES rows=71175
# [TH-OPT][GLOBAL] asof_bar=354049 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=354241 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=354433 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-03-25 19:55:00
# [TH-OPT][GLOBAL] asof_bar=354625 buy_th=-0.50 sell_th=1.15
# [CHECKPOINT] saved -> checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-03-27 19:55:00
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_noMacro_2016-2024Cumulative\trades.csv
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_noMacro_2016-2024Cumulative\daily_log.csv
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_noMacro_2016-2024Cumulative\equity_vs_buyhold.png
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_noMacro_2016-2024Cumulative\price_with_trades.png
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_noMacro_2016-2024Cumulative\p_day.png
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_noMacro_2016-2024Cumulative\daily_lr_feature_importance.csv
# [TRADES] total=896
# [TRADES] first_trade_ts=2024-01-02 06:30:00 (sim_start=2024-01-01 00:00:00)

# %%
res = resume_from_checkpoint(
    checkpoint_path="checkpoints/QQQ_noMacro_US2_checkpoint.joblib",
    daily_csv_path="DataAPI/data/QQQ_DAY.csv",
    k5m_csv_path="DataAPI/data/QQQ_5M.csv",
    end_time="2026-12-31",
    output_dir="output_resumed_QQQ_noMacro_2018-2024",
    verbose=True,
    plot_from_checkpoint=True,
)
# Out:
# [PLOT START] inferred from checkpoint key 'checkpoint_time' = 2026-03-27 19:55:00
# [RESUME WRAPPER] load_checkpoint=checkpoints/QQQ_noMacro_US2_checkpoint.joblib
# [RESUME WRAPPER] resumed_checkpoint_save=checkpoints\resumed\QQQ_noMacro_US2_checkpoint__resumed.joblib
# [RESUME WRAPPER] code=QQQ
# [RESUME WRAPPER] original_daily_chan_start=2016-06-01
# [RESUME WRAPPER] original_accumulation_start=2018-10-01
# [RESUME WRAPPER] original_sim_start=2024-01-01
# [RESUME WRAPPER] original_end_time=2026-12-31
# [RESUME WRAPPER] continue_until=2026-12-31
# [RESUME WRAPPER] plot_from=2026-03-27 19:55:00
# [RESUME WRAPPER] output_dir=output_resumed_QQQ_noMacro_2018-2024
# [RESUME] loading checkpoint: checkpoints/QQQ_noMacro_US2_checkpoint.joblib @ 2026-03-27 19:55:00
# [RESUME] last_warm_day_ts=2026-03-27 00:00:00
# [RESUME] last_warm_5m_ts=2026-03-27 19:55:00
# [RESUME] realigned daily_i_start=2470 / 2474
# [RESUME] realigned five_i_start=354818 / 355777
# [RESUME] daily_model=YES 5m_buy=YES 5m_sell=YES
# [SAVED] output_resumed_QQQ_noMacro_2018-2024\daily_lr_feature_importance.csv
# [PHASE2/3] 5m feed begins at accumulation_start=2018-10-01, trading starts at sim_s=2024-01-01
# [TRAIN][5M] asof=2026-03-27 feats=69 buy=YES sell=YES rows=71348
# [TH-OPT][GLOBAL] asof_bar=355009 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=355200 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2026-04-01 feats=69 buy=YES sell=YES rows=71540
# [CHECKPOINT] saved -> checkpoints\resumed\QQQ_noMacro_US2_checkpoint__resumed.joblib @ 2026-04-02 19:55:00
# [SAVED] output_resumed_QQQ_noMacro_2018-2024\trades.csv
# [SAVED] output_resumed_QQQ_noMacro_2018-2024\daily_log.csv
# [SAVED] output_resumed_QQQ_noMacro_2018-2024\equity_vs_buyhold.png
# [SAVED] output_resumed_QQQ_noMacro_2018-2024\price_with_trades.png
# [SAVED] output_resumed_QQQ_noMacro_2018-2024\p_day.png
# [SAVED] output_resumed_QQQ_noMacro_2018-2024\daily_lr_feature_importance.csv
# [TRADES] total=900
# [TRADES] first_trade_ts=2018-10-09 06:30:00 (sim_start=2024-01-01 00:00:00)
