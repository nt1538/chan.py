# %%
# ============================================================
# FULL CHECKPOINT / RESUME CODE
# + DAILY MACRO / INDEX FEATURES
# + YIELD CURVE FEATURE (TNX - FVX)
# ============================================================

import os
import copy
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from dataclasses import dataclass
from typing import List, Optional, Any, Dict
import xgboost as xgb

from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.calibration import CalibratedClassifierCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MaxAbsScaler
from sklearn.impute import SimpleImputer

# ---- your Chan imports ----
from sliding_window_chan import SlidingWindowChan
from ChanConfig import CChanConfig
from Common.CEnum import DATA_FIELD, KL_TYPE, AUTYPE
try:
    from Common.CEnum import DATA_SRC
except Exception:
    class DATA_SRC:
        CSV = "CSV"
from KLine.KLine_Unit import CKLine_Unit
from Common.CTime import CTime


# ============================================================
# BACKWARD-COMPAT CLASS DEFINITIONS
# ============================================================

@dataclass
class RetModelPack:
    feature_cols: List[str]
    model_ret: xgb.XGBRegressor

@dataclass
class DailyProbState:
    model: Optional[Any] = None
    new_labels: int = 0
    trained_n: int = 0


# ============================================================
# BASIC HELPERS
# ============================================================

def _safe_div(a, b, eps=1e-12):
    return a / (b + eps)

def _pick_col(df: pd.DataFrame, candidates: List[str]) -> Optional[str]:
    cols = list(df.columns)
    for c in candidates:
        if c in cols:
            return c
    lower_map = {c.lower(): c for c in cols}
    for c in candidates:
        if c.lower() in lower_map:
            return lower_map[c.lower()]
    return None

def save_joblib(path: str, obj):
    os.makedirs(os.path.dirname(path), exist_ok=True)
    joblib.dump(obj, path, compress=3)

def load_joblib(path: str):
    return joblib.load(path)

def _safe_copy_list_of_dict(lst):
    if lst is None:
        return []
    out = []
    for x in lst:
        try:
            out.append(dict(x))
        except Exception:
            pass
    return out

def _safe_set_to_list(s):
    if s is None:
        return []
    return list(s)

def _safe_list_to_set(lst):
    if lst is None:
        return set()
    out = set()
    for x in lst:
        if isinstance(x, list):
            out.add(tuple(x))
        else:
            out.add(x)
    return out


# ============================================================
# OHLCV CSV LOADER
# ============================================================

def load_ohlcv_csv(path: str, freq_name: str) -> pd.DataFrame:
    df = pd.read_csv(path)

    ts_col = _pick_col(df, ["timestamp", "date", "datetime", "time"])
    if ts_col is None:
        ts_col = df.columns[0]
    df[ts_col] = pd.to_datetime(df[ts_col], errors="coerce")
    df = df.dropna(subset=[ts_col]).sort_values(ts_col).reset_index(drop=True)
    df = df.rename(columns={ts_col: "timestamp"})

    open_col  = _pick_col(df, ["open", "Open", "o", "O"])
    high_col  = _pick_col(df, ["high", "High", "h", "H"])
    low_col   = _pick_col(df, ["low", "Low", "l", "L"])
    close_col = _pick_col(df, ["close", "Close", "adj_close", "Adj Close", "AdjClose", "c", "C"])
    vol_col   = _pick_col(df, ["volume", "Volume", "vol", "Vol", "v", "V"])

    if open_col is None or close_col is None:
        raise ValueError(f"{freq_name} CSV must contain open/close columns.")
    if high_col is None:
        high_col = close_col
    if low_col is None:
        low_col = close_col

    df["_open"]  = pd.to_numeric(df[open_col], errors="coerce").astype(float)
    df["_high"]  = pd.to_numeric(df[high_col], errors="coerce").astype(float)
    df["_low"]   = pd.to_numeric(df[low_col], errors="coerce").astype(float)
    df["_close"] = pd.to_numeric(df[close_col], errors="coerce").astype(float)
    df["_vol"]   = pd.to_numeric(df[vol_col], errors="coerce").astype(float) if vol_col is not None else 0.0

    df = df.dropna(subset=["_open", "_high", "_low", "_close"]).reset_index(drop=True)
    df["day"] = df["timestamp"].dt.normalize()
    return df


# ============================================================
# DAILY KLINE FEATURES
# ============================================================

KLINE_KEYS = [
    "ret1","ret_5","ret_10","ret_20","ret_40",
    "vol_5","vol_10","vol_20","vol_40",
    "atr_14","range_over_atr","close_pos","gap",
    "above_ma_20","above_ma_50","above_ma_100",
    "slope40",
]

def compute_daily_kline_features(df_day: pd.DataFrame) -> pd.DataFrame:
    d = df_day.copy().sort_values("timestamp").reset_index(drop=True)
    o = d["_open"].astype(float)
    h = d["_high"].astype(float)
    l = d["_low"].astype(float)
    c = d["_close"].astype(float)

    prev_c = c.shift(1)
    d["ret1"] = (_safe_div(c, prev_c) - 1.0).replace([np.inf, -np.inf], np.nan).fillna(0.0)

    tr = pd.concat([(h-l).abs(), (h-prev_c).abs(), (l-prev_c).abs()], axis=1).max(axis=1)
    d["tr"] = tr.fillna(0.0)
    d["atr_14"] = d["tr"].rolling(14).mean().bfill().fillna(0.0)

    d["range"] = (h - l).fillna(0.0)
    d["range_over_atr"] = _safe_div(d["range"], d["atr_14"]).replace([np.inf, -np.inf], np.nan).fillna(0.0)

    rng = (h - l).replace(0.0, np.nan)
    d["close_pos"] = ((c - l) / rng).replace([np.inf, -np.inf], np.nan).fillna(0.5)
    d["gap"] = (_safe_div(o, prev_c) - 1.0).replace([np.inf, -np.inf], np.nan).fillna(0.0)

    for w in [5, 10, 20, 40]:
        d[f"ret_{w}"] = (_safe_div(c, c.shift(w)) - 1.0).replace([np.inf, -np.inf], np.nan).fillna(0.0)
        d[f"vol_{w}"] = d["ret1"].rolling(w).std().replace([np.inf, -np.inf], np.nan).fillna(0.0)

    for w in [20, 50, 100]:
        ma = c.rolling(w).mean()
        d[f"above_ma_{w}"] = (_safe_div(c, ma) - 1.0).replace([np.inf, -np.inf], np.nan).fillna(0.0)

    def _slope_log(x):
        x = np.asarray(x, dtype=float)
        x = np.log(np.maximum(x, 1e-12))
        t = np.arange(len(x), dtype=float)
        t = t - t.mean()
        x = x - x.mean()
        den = (t*t).sum()
        return 0.0 if den <= 0 else float((t*x).sum() / den)

    d["slope40"] = d["_close"].rolling(40).apply(_slope_log, raw=False).fillna(0.0)
    return d

def make_kline_dict(row: pd.Series) -> Dict[str, float]:
    out = {}
    for k in KLINE_KEYS:
        val = row[k] if k in row.index else 0.0
        out[f"k_{k}"] = float(val) if np.isfinite(val) else 0.0
    return out


# ============================================================
# MACRO / INDEX FEATURES
# ============================================================

def load_macro_features_from_folder(folder: str, files: Dict[str, str], start: str) -> pd.DataFrame:
    out = None

    for pref, fn in files.items():
        path = os.path.join(folder, fn)
        if not os.path.exists(path):
            raise FileNotFoundError(f"Macro file not found: {path}")

        dfm = load_ohlcv_csv(path, pref.upper())
        dfm = dfm[dfm["timestamp"] >= pd.to_datetime(start)].copy().reset_index(drop=True)
        dfm["ts_norm"] = pd.to_datetime(dfm["timestamp"]).dt.normalize()

        dfm_feat = compute_daily_kline_features(dfm)

        # raw close level
        dfm_feat[f"{pref}level"] = dfm_feat["_close"].astype(float)

        keep_cols = ["ts_norm", f"{pref}level"] + KLINE_KEYS
        dfm_feat = dfm_feat[keep_cols].copy()

        rename = {k: f"{pref}{k}" for k in KLINE_KEYS}
        dfm_feat = dfm_feat.rename(columns=rename)

        out = dfm_feat.copy() if out is None else out.merge(dfm_feat, on="ts_norm", how="outer")

    if out is None:
        out = pd.DataFrame(columns=["ts_norm"])

    # 10Y - 5Y yield curve
    if ("us10y_level" in out.columns) and ("us5y_level" in out.columns):
        out["yc_10y5y_level"] = out["us10y_level"] - out["us5y_level"]

        prev = out["yc_10y5y_level"].shift(1)
        out["yc_10y5y_ret1"] = (_safe_div(out["yc_10y5y_level"], prev) - 1.0).replace([np.inf, -np.inf], np.nan).fillna(0.0)

        for w in [5, 10, 20, 40]:
            out[f"yc_10y5y_chg_{w}"] = (out["yc_10y5y_level"] - out["yc_10y5y_level"].shift(w)).replace([np.inf, -np.inf], np.nan).fillna(0.0)

    return out.sort_values("ts_norm").reset_index(drop=True)


# ============================================================
# CHAN BUILDERS
# ============================================================

def to_ctime(ts) -> CTime:
    if isinstance(ts, CTime):
        return ts
    dt = pd.to_datetime(ts).to_pydatetime()
    try:
        return CTime(dt.year, dt.month, dt.day, dt.hour, dt.minute, dt.second, auto=False)
    except Exception:
        pass
    try:
        return CTime(dt.year, dt.month, dt.day, dt.hour, dt.minute, dt.second)
    except Exception:
        pass
    s = dt.strftime("%Y-%m-%d %H:%M:%S")
    try:
        return CTime(s, auto=False)
    except Exception:
        return CTime(s)

def build_klu(ts, o, h, l, c, v=0.0) -> CKLine_Unit:
    ct = to_ctime(ts)
    kl_dict = {
        DATA_FIELD.FIELD_TIME: ct,
        DATA_FIELD.FIELD_OPEN: float(o),
        DATA_FIELD.FIELD_HIGH: float(h),
        DATA_FIELD.FIELD_LOW:  float(l),
        DATA_FIELD.FIELD_CLOSE: float(c),
        DATA_FIELD.FIELD_VOLUME: float(v),
        "time": ct, "timestamp": ct, "datetime": ct, "dt": ct,
        "open": float(o), "high": float(h), "low": float(l), "close": float(c),
        "volume": float(v),
    }
    klu = CKLine_Unit(kl_dict)
    try:
        klu.time = ct
    except Exception:
        pass
    return klu

def feed_chan_one(chan_obj, klu: CKLine_Unit):
    if hasattr(chan_obj, "process_new_kline"):
        return chan_obj.process_new_kline(klu)
    if hasattr(chan_obj, "step_load"):
        return chan_obj.step_load([klu])
    raise AttributeError("Chan object has neither process_new_kline nor step_load")


# ============================================================
# DAILY BSP HELPERS
# ============================================================

def normalize_bsp_row(r: Dict[str, Any]) -> Dict[str, Any]:
    rr = dict(r)
    if "timestamp" in rr:
        rr["timestamp"] = pd.to_datetime(rr["timestamp"], errors="coerce")
    if "direction" not in rr or rr["direction"] is None:
        if rr.get("is_buy", None) is not None:
            rr["direction"] = "buy" if bool(rr["is_buy"]) else "sell"
        else:
            rr["direction"] = "buy"
    rr["direction"] = str(rr["direction"]).lower()
    if "bsp_type" in rr and rr["bsp_type"] is not None:
        rr["bsp_type"] = str(rr["bsp_type"]).lower()
    else:
        rr["bsp_type"] = "?"
    return rr

def extract_bsp_rows_from_chan(chan_obj) -> List[Dict[str, Any]]:
    if hasattr(chan_obj, "export_new_historical_bsp_to_list"):
        out = chan_obj.export_new_historical_bsp_to_list()
        return out if out else []
    if hasattr(chan_obj, "export_new_bsp_to_list"):
        out = chan_obj.export_new_bsp_to_list()
        return out if out else []
    return []

def latest_bsp_dir_up_to(bsp_rows: List[Dict[str, Any]], ts: pd.Timestamp) -> Optional[str]:
    past = [r for r in bsp_rows if pd.to_datetime(r["timestamp"]) <= ts]
    if not past:
        return None
    past = sorted(past, key=lambda x: pd.to_datetime(x["timestamp"]))
    return str(past[-1].get("direction", "")).lower()

def make_daily_bsp_context(bsp_hist: List[Dict[str, Any]], cur_ts: pd.Timestamp, window_days: int = 60) -> Dict[str, float]:
    past = [r for r in bsp_hist if pd.to_datetime(r["timestamp"]) <= cur_ts]
    past = sorted(past, key=lambda x: pd.to_datetime(x["timestamp"]))
    if not past:
        return {
            "ctx_has_bsp": 0.0,
            "ctx_last_dir_buy": 0.0,
            "ctx_last_dir_sell": 0.0,
            "ctx_days_since_last_bsp": 999.0,
            "ctx_days_since_last_buy": 999.0,
            "ctx_days_since_last_sell": 999.0,
            "ctx_density_total": 0.0,
            "ctx_density_buy": 0.0,
            "ctx_density_sell": 0.0,
            "ctx_density_imb": 0.0,
        }

    last = past[-1]
    last_dir = str(last.get("direction", "")).lower()
    days_since_last = float((cur_ts.normalize() - pd.to_datetime(last["timestamp"]).normalize()).days)

    def _days_since(target: str) -> float:
        for r in reversed(past):
            if str(r.get("direction", "")).lower() == target:
                return float((cur_ts.normalize() - pd.to_datetime(r["timestamp"]).normalize()).days)
        return 999.0

    start = cur_ts.normalize() - pd.Timedelta(days=int(window_days))
    recent = [r for r in past if pd.to_datetime(r["timestamp"]).normalize() >= start]
    buy = sum(1 for r in recent if str(r.get("direction", "")).lower() == "buy")
    sell = sum(1 for r in recent if str(r.get("direction", "")).lower() == "sell")
    tot = max(1.0, float(buy + sell))

    return {
        "ctx_has_bsp": 1.0,
        "ctx_last_dir_buy": 1.0 if last_dir == "buy" else 0.0,
        "ctx_last_dir_sell": 1.0 if last_dir == "sell" else 0.0,
        "ctx_days_since_last_bsp": days_since_last,
        "ctx_days_since_last_buy": _days_since("buy"),
        "ctx_days_since_last_sell": _days_since("sell"),
        "ctx_density_total": float(len(recent)),
        "ctx_density_buy": float(buy),
        "ctx_density_sell": float(sell),
        "ctx_density_imb": float((sell - buy) / tot),
    }

def compute_chain_endpoints(bsp_rows: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
    if not bsp_rows:
        return []
    bsps = sorted(bsp_rows, key=lambda r: pd.to_datetime(r["timestamp"]))
    ends = []
    cur_dir = str(bsps[0].get("direction", "")).lower()
    cur_end = bsps[0]
    cur_end_i = 0
    for i in range(1, len(bsps)):
        d = str(bsps[i].get("direction", "")).lower()
        if d == cur_dir:
            cur_end = bsps[i]
            cur_end_i = i
        else:
            ends.append({"end_ts": pd.to_datetime(cur_end["timestamp"]).normalize(), "end_dir": cur_dir, "end_i": cur_end_i})
            cur_dir = d
            cur_end = bsps[i]
            cur_end_i = i
    ends.append({"end_ts": pd.to_datetime(cur_end["timestamp"]).normalize(), "end_dir": cur_dir, "end_i": cur_end_i})
    return ends

def regime_for_day_from_ends(day_norm: pd.Timestamp, ends: List[Dict[str, Any]]) -> str:
    if len(ends) < 2:
        return "unknown"
    for k in range(len(ends) - 1):
        a = ends[k]
        b = ends[k + 1]
        a_ts, a_dir = a["end_ts"], a["end_dir"]
        b_ts, b_dir = b["end_ts"], b["end_dir"]
        if (day_norm >= a_ts) and (day_norm <= b_ts):
            if a_dir == "buy" and b_dir == "sell":
                return "up"
            if a_dir == "sell" and b_dir == "buy":
                return "down"
    return "unknown"


# ============================================================
# DAILY LABEL + MODEL
# ============================================================

def label_confirm_extreme(df_day_feat: pd.DataFrame, idx: int, N: int, base_dir: str) -> Optional[int]:
    if N <= 0:
        return None
    if idx + N >= len(df_day_feat):
        return None
    h0 = float(df_day_feat.loc[idx, "_high"])
    l0 = float(df_day_feat.loc[idx, "_low"])
    fut = df_day_feat.loc[idx+1:idx+N]
    if fut.empty:
        return None
    if base_dir == "sell":
        mx = float(fut["_high"].max())
        return 1 if mx < h0 else 0
    if base_dir == "buy":
        mn = float(fut["_low"].min())
        return 1 if mn > l0 else 0
    return None

def make_daily_features_one_model(
    kline_row: pd.Series,
    bsp_hist_up_to_day: List[Dict[str, Any]],
    p_val: float,
    dp_minK: float,
    dp_maxK: float,
    regime: str,
    base_dir: Optional[str],
    macro_cols: Optional[List[str]] = None,
) -> Dict[str, float]:
    feats: Dict[str, float] = {}
    feats.update(make_kline_dict(kline_row))

    if macro_cols is not None:
        for c in macro_cols:
            if c in kline_row.index:
                val = kline_row[c]
                feats[c] = float(val) if np.isfinite(val) else 0.0

    ts = pd.to_datetime(kline_row["timestamp"])
    feats.update(make_daily_bsp_context(bsp_hist_up_to_day, ts, window_days=60))

    feats["p"] = float(p_val) if np.isfinite(p_val) else 0.0
    feats["dp_minK"] = float(dp_minK) if np.isfinite(dp_minK) else 0.0
    feats["dp_maxK"] = float(dp_maxK) if np.isfinite(dp_maxK) else 0.0

    rg = str(regime).lower()
    feats["rg_up"] = 1.0 if rg == "up" else 0.0
    feats["rg_down"] = 1.0 if rg == "down" else 0.0
    feats["rg_unknown"] = 1.0 if rg not in ("up", "down") else 0.0

    bd = str(base_dir).lower() if base_dir is not None else "none"
    feats["bd_buy"] = 1.0 if bd == "buy" else 0.0
    feats["bd_sell"] = 1.0 if bd == "sell" else 0.0
    feats["bd_none"] = 1.0 if bd not in ("buy", "sell") else 0.0

    return feats

def fit_prob_model_dicts(X_dicts: List[Dict[str, float]], y: np.ndarray):
    base = Pipeline([
        ("vec", DictVectorizer(sparse=True)),
        ("scaler", MaxAbsScaler()),
        ("lr", LogisticRegression(
            max_iter=8000,
            class_weight="balanced",
            solver="saga",
            C=0.5,
            n_jobs=-1
        ))
    ])
    uniq, counts = np.unique(y, return_counts=True)
    if len(uniq) < 2:
        raise ValueError("Only one class in y so far.")
    min_count = int(counts.min())

    if min_count >= 5:
        cal = CalibratedClassifierCV(base, method="sigmoid", cv=3)
        cal.fit(X_dicts, y)
        return cal
    elif min_count >= 3:
        cal = CalibratedClassifierCV(base, method="sigmoid", cv=2)
        cal.fit(X_dicts, y)
        return cal
    else:
        base.fit(X_dicts, y)
        return base

def predict_prob(model, X_dicts: List[Dict[str, float]]) -> np.ndarray:
    return model.predict_proba(X_dicts)[:, 1]

def _get_underlying_pipeline(model):
    if hasattr(model, "calibrated_classifiers_") and len(getattr(model, "calibrated_classifiers_", [])) > 0:
        cc0 = model.calibrated_classifiers_[0]
        if hasattr(cc0, "estimator") and cc0.estimator is not None:
            return cc0.estimator
    return model

def feature_importance_from_lr(model, top_n: int = 80) -> pd.DataFrame:
    pipe = _get_underlying_pipeline(model)
    if not (hasattr(pipe, "named_steps") and "vec" in pipe.named_steps and "lr" in pipe.named_steps):
        return pd.DataFrame(columns=["feature", "coef", "abs_coef"])
    vec = pipe.named_steps["vec"]
    lr = pipe.named_steps["lr"]

    try:
        names = np.array(vec.get_feature_names_out(), dtype=object)
    except Exception:
        names = np.array(getattr(vec, "feature_names_", []), dtype=object)

    coef = lr.coef_.ravel()
    if len(names) != len(coef):
        return pd.DataFrame(columns=["feature", "coef", "abs_coef"])

    df_imp = pd.DataFrame({"feature": names, "coef": coef})
    df_imp["abs_coef"] = df_imp["coef"].abs()
    return df_imp.sort_values("abs_coef", ascending=False).head(int(top_n)).reset_index(drop=True)


# ============================================================
# 5M MODEL + THRESHOLDS
# ============================================================

LABEL_COLS = {"best_return_pct"}
BSP_TYPE_MAP = {"1":1,"2":2,"3a":3,"1p":4,"2s":5,"3b":6}

def prepare_ml_dataset(df: pd.DataFrame) -> pd.DataFrame:
    if df.empty:
        return df
    df = df.copy()

    if "direction" in df.columns:
        d = df["direction"].fillna("unknown").astype(str).str.lower()
        df["direction_encoded"] = np.where(d == "buy", 1, np.where(d == "sell", 0, -1)).astype(np.int32)

    if "bsp_type" in df.columns:
        t = df["bsp_type"].fillna("unknown").astype(str).str.lower()
        df["bsp_type_encoded"] = t.map(BSP_TYPE_MAP).fillna(0).astype(np.int32)

    df = df.replace([np.inf, -np.inf], np.nan)

    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    numeric_cols = [c for c in numeric_cols if c not in LABEL_COLS]

    if numeric_cols:
        imputer = SimpleImputer(strategy="mean")
        imputed = imputer.fit_transform(df[numeric_cols])
        df[numeric_cols] = pd.DataFrame(imputed, columns=numeric_cols, index=df.index).fillna(0.0)

    return df

def get_feature_columns(df: pd.DataFrame) -> List[str]:
    exclude = set(LABEL_COLS) | {
        "timestamp","code","direction","bsp_type","klu_idx",
        "has_best_exit","best_exit_type","best_exit_klu_idx","best_exit_price",
        "regime_bucket",
    }
    num_cols = df.select_dtypes(include=[np.number, "bool"]).columns.tolist()
    cols = [c for c in num_cols if c not in exclude]
    return sorted(cols)

def to_float_matrix(df: pd.DataFrame, cols: List[str]) -> np.ndarray:
    if not cols:
        return np.zeros((len(df), 0), dtype=np.float32)
    X = df[cols].copy()
    for c in cols:
        X[c] = pd.to_numeric(X[c], errors="coerce")
    X = X.replace([np.inf, -np.inf], np.nan).fillna(0.0)
    return X.to_numpy(dtype=np.float32, copy=False)

def _fit_ret_pack(df_dir: pd.DataFrame, feature_cols: List[str], seed: int) -> RetModelPack:
    ret_df = df_dir.dropna(subset=["best_return_pct"]).copy()
    X = to_float_matrix(ret_df, feature_cols)
    y = ret_df["best_return_pct"].to_numpy(dtype=np.float32)

    model = xgb.XGBRegressor(
        n_estimators=500,
        max_depth=5,
        learning_rate=0.05,
        subsample=0.85,
        colsample_bytree=0.85,
        reg_lambda=1.0,
        random_state=seed,
        n_jobs=4,
    )
    model.fit(X, y)
    return RetModelPack(feature_cols=feature_cols, model_ret=model)

def train_models_two_sided_ret_only(
    bsp_df: pd.DataFrame,
    feature_cols: List[str],
    min_samples_total: int = 300,
):
    if bsp_df.empty or "direction" not in bsp_df.columns:
        return None, None

    df = bsp_df.copy()
    for c in feature_cols:
        if c not in df.columns:
            df[c] = 0.0

    buy_df = df[df["direction"].astype(str).str.lower() == "buy"].copy()
    sell_df = df[df["direction"].astype(str).str.lower() == "sell"].copy()

    buy_pack = None
    if len(buy_df.dropna(subset=["best_return_pct"])) >= min_samples_total:
        buy_pack = _fit_ret_pack(buy_df, feature_cols, seed=42)

    sell_pack = None
    if len(sell_df.dropna(subset=["best_return_pct"])) >= min_samples_total:
        sell_pack = _fit_ret_pack(sell_df, feature_cols, seed=52)

    return buy_pack, sell_pack

def predict_ret(pack: RetModelPack, row_df: pd.DataFrame) -> float:
    X = to_float_matrix(row_df, pack.feature_cols)
    return float(pack.model_ret.predict(X)[0])

def make_ret_grid(start: float = -0.5, end: float = 2.5, step: float = 0.05) -> List[float]:
    vals = np.arange(start, end + 1e-12, step, dtype=float)
    return [float(x) for x in vals]

def _bars_from_days(days: float, bar_interval_minutes: int) -> int:
    minutes = float(days) * 24.0 * 60.0
    return max(1, int(round(minutes / float(bar_interval_minutes))))

def label_bestlookahead_for_ready_points(
    bsp_rows: List[Dict[str, Any]],
    highs: np.ndarray,
    lows: np.ndarray,
    closes: np.ndarray,
    lookahead_days: float,
    bar_interval_minutes: int,
    current_bar_idx: int,
):
    if not bsp_rows:
        return
    lookahead_bars = _bars_from_days(lookahead_days, bar_interval_minutes)
    n = len(closes)

    for r in bsp_rows:
        if not np.isnan(r.get("best_return_pct", np.nan)):
            continue
        i = r.get("klu_idx", None)
        if i is None:
            continue
        i = int(i)
        end_i = i + lookahead_bars
        if end_i >= n:
            continue
        if end_i > current_bar_idx:
            continue

        d = str(r.get("direction", "buy")).lower()
        c0 = float(closes[i])

        if d == "buy":
            mx = float(np.nanmax(highs[i + 1 : end_i + 1]))
            r["best_return_pct"] = (mx - c0) / c0 * 100.0
        else:
            mn = float(np.nanmin(lows[i + 1 : end_i + 1]))
            r["best_return_pct"] = (c0 - mn) / c0 * 100.0

def _simulate_realized_ret_only_long(
    events: List[Dict[str, Any]],
    pred_buy: Dict[Any, float],
    pred_sell: Dict[Any, float],
    buy_th: float,
    sell_th: float,
    next_open_by_idx: np.ndarray,
    closes: np.ndarray,
    end_bar_idx: int,
    fee_pct: float = 0.0,
):
    cash = 1.0
    pos = 0
    qty = 0.0
    trades = 0

    def exec_next_open(idx: int):
        if not (0 <= idx < len(next_open_by_idx)):
            return None
        px = next_open_by_idx[idx]
        if px is None or (isinstance(px, float) and np.isnan(px)):
            return None
        return float(px)

    for r in events:
        d = str(r.get("direction", "")).lower()
        ki = int(r.get("klu_idx", -1))
        px = exec_next_open(ki)
        if px is None:
            continue

        if pos == 0 and d == "buy":
            key = (int(r.get("klu_idx",-1)), "buy", str(r.get("bsp_type","?")))
            pr = pred_buy.get(key)
            if pr is not None and pr >= float(buy_th):
                notional = cash
                spend = notional * (1 + fee_pct)
                if spend > cash:
                    spend = cash
                    notional = spend / (1 + fee_pct)
                qty = notional / px
                cash -= spend
                pos = 1
                trades += 1

        elif pos == 1 and d == "sell":
            key = (int(r.get("klu_idx",-1)), "sell", str(r.get("bsp_type","?")))
            pr = pred_sell.get(key)
            if pr is not None and pr >= float(sell_th):
                cash += (qty * px) * (1 - fee_pct)
                qty = 0.0
                pos = 0
                trades += 1

    end_px = float(closes[end_bar_idx])
    eq = cash if pos == 0 else (cash + qty * end_px)
    return float(eq), int(trades)

def choose_thresholds_global_realized(
    df_5m: pd.DataFrame,
    bsp_rows: List[Dict[str, Any]],
    buy_pack: Optional[RetModelPack],
    sell_pack: Optional[RetModelPack],
    asof_bar_idx: int,
    window_days: float,
    ret_grid: List[float],
    next_open_by_idx: np.ndarray,
    closes: np.ndarray,
    fee_pct: float = 0.0,
    min_open_signals: int = 10,
):
    if df_5m.empty or not bsp_rows or buy_pack is None or sell_pack is None:
        return None

    end_ts = pd.to_datetime(df_5m.loc[asof_bar_idx, "timestamp"])
    start_ts = end_ts - pd.Timedelta(days=float(window_days))

    events = []
    buy_cand = []
    sell_cand = []
    for r in bsp_rows:
        t = pd.to_datetime(r.get("timestamp", None), errors="coerce")
        if pd.isna(t) or not (start_ts <= t <= end_ts):
            continue
        ki = r.get("klu_idx", None)
        if ki is None:
            continue
        rr = dict(r)
        rr["klu_idx"] = int(ki)
        events.append(rr)
        d = str(rr.get("direction","")).lower()
        if d == "buy":
            buy_cand.append(rr)
        elif d == "sell":
            sell_cand.append(rr)

    if len(buy_cand) < int(min_open_signals) or len(sell_cand) < 1:
        return None

    events.sort(key=lambda x: int(x["klu_idx"]))

    buy_df = prepare_ml_dataset(pd.DataFrame(buy_cand))
    for c in buy_pack.feature_cols:
        if c not in buy_df.columns:
            buy_df[c] = 0.0
    buy_pred = buy_pack.model_ret.predict(to_float_matrix(buy_df, buy_pack.feature_cols)).astype(float)
    pred_buy = {(int(buy_cand[i]["klu_idx"]), "buy", str(buy_cand[i].get("bsp_type","?"))): float(buy_pred[i]) for i in range(len(buy_cand))}

    sell_df = prepare_ml_dataset(pd.DataFrame(sell_cand))
    for c in sell_pack.feature_cols:
        if c not in sell_df.columns:
            sell_df[c] = 0.0
    sell_pred = sell_pack.model_ret.predict(to_float_matrix(sell_df, sell_pack.feature_cols)).astype(float)
    pred_sell = {(int(sell_cand[i]["klu_idx"]), "sell", str(sell_cand[i].get("bsp_type","?"))): float(sell_pred[i]) for i in range(len(sell_cand))}

    end_bar_idx = asof_bar_idx
    best_eq = None
    best_pair = None

    for bt in ret_grid:
        for st in ret_grid:
            eq, trades = _simulate_realized_ret_only_long(
                events=events,
                pred_buy=pred_buy,
                pred_sell=pred_sell,
                buy_th=float(bt),
                sell_th=float(st),
                next_open_by_idx=next_open_by_idx,
                closes=closes,
                end_bar_idx=end_bar_idx,
                fee_pct=fee_pct,
            )
            if best_eq is None or eq > best_eq:
                best_eq = float(eq)
                best_pair = (float(bt), float(st))

    return best_pair


# ============================================================
# EXECUTION ENGINE
# ============================================================

class ExecutionEngine:
    def __init__(self, initial_capital: float, fee_pct: float):
        self.cash = float(initial_capital)
        self.fee_pct = float(fee_pct)
        self.pos = 0
        self.qty = 0.0
        self.entry_px = None
        self.entry_idx = None
        self.pending_order = None
        self.trades = []

    def _exec_px(self, seen_idx: int, next_open_by_idx: np.ndarray):
        if not (0 <= seen_idx < len(next_open_by_idx)):
            return None
        px = next_open_by_idx[seen_idx]
        if px is None or (isinstance(px, float) and np.isnan(px)):
            return None
        return float(px)

    def place_order_for_next_bar(self, side: str, seen_idx: int, reason: str, meta: dict = None, overwrite=True):
        if self.pending_order is not None and not overwrite:
            return
        self.pending_order = {"side": side, "seen_idx": int(seen_idx), "reason": reason, "meta": dict(meta) if meta else {}}

    def maybe_execute_pending(self, next_open_by_idx: np.ndarray):
        if self.pending_order is None:
            return
        side = self.pending_order["side"]
        idx  = self.pending_order["seen_idx"]
        reason = self.pending_order["reason"]
        meta = self.pending_order.get("meta", {}) or {}

        px = self._exec_px(idx, next_open_by_idx)
        if px is None:
            return

        fee = self.fee_pct

        if side == "buy" and self.pos == 0:
            notional = self.cash / (1.0 + fee)
            fee_amt = notional * fee
            qty = notional / px
            self.cash -= (notional + fee_amt)
            self.pos = 1
            self.qty = qty
            self.entry_px = px
            self.entry_idx = idx
            self.trades.append({"side":"buy","seen_idx":idx,"exec_px":px,"qty":qty,"fee":fee_amt,"reason":reason, **meta})

        elif side == "sell" and self.pos == 1:
            notional = self.qty * px
            fee_amt = notional * fee
            recv = notional - fee_amt
            self.cash += recv
            pnl = (px - self.entry_px) * self.qty - fee_amt
            self.trades.append({
                "side":"sell","seen_idx":idx,"exec_px":px,"qty":self.qty,"fee":fee_amt,"reason":reason,
                "pnl": pnl, "entry_px": self.entry_px, "entry_idx": self.entry_idx, **meta
            })
            self.pos = 0
            self.qty = 0.0
            self.entry_px = None
            self.entry_idx = None

        self.pending_order = None

    def mark_to_market(self, last_close: float) -> float:
        px = float(last_close)
        if self.pos == 0:
            return float(self.cash)
        return float(self.cash + self.qty * px)

    def state_dict(self) -> dict:
        return {
            "cash": self.cash,
            "fee_pct": self.fee_pct,
            "pos": self.pos,
            "qty": self.qty,
            "entry_px": self.entry_px,
            "entry_idx": self.entry_idx,
            "pending_order": copy.deepcopy(self.pending_order),
            "trades": copy.deepcopy(self.trades),
        }

    def load_state_dict(self, d: dict):
        self.cash = float(d.get("cash", self.cash))
        self.fee_pct = float(d.get("fee_pct", self.fee_pct))
        self.pos = int(d.get("pos", 0))
        self.qty = float(d.get("qty", 0.0))
        self.entry_px = d.get("entry_px", None)
        self.entry_idx = d.get("entry_idx", None)
        self.pending_order = copy.deepcopy(d.get("pending_order", None))
        self.trades = copy.deepcopy(d.get("trades", []))


# ============================================================
# 5M INDEX LOAD
# ============================================================

def load_5m_index(df_5m: pd.DataFrame, start_time: str, end_time: str):
    df = df_5m.copy()
    st = pd.to_datetime(start_time)
    et = pd.to_datetime(end_time)
    df = df[(df["timestamp"] >= st) & (df["timestamp"] <= et)].copy().reset_index(drop=True)

    df = df.rename(columns={"_open":"Open","_high":"High","_low":"Low","_close":"Close","_vol":"Volume"})
    df.columns = [str(c).strip() for c in df.columns]

    if not df.columns.is_unique:
        df = df.loc[:, ~df.columns.duplicated(keep="first")]

    df["date"] = df["timestamp"].dt.date
    df["next_open"] = df["Open"].shift(-1)
    df["next_close"] = df["Close"].shift(-1)

    next_open_by_idx = df["next_open"].to_numpy()
    next_close_by_idx = df["next_close"].to_numpy()
    closes = df["Close"].to_numpy(dtype=float)
    highs  = df["High"].to_numpy(dtype=float)
    lows   = df["Low"].to_numpy(dtype=float)

    day_close_map = df.groupby("date")["Close"].last().to_dict()
    all_days = sorted(df["date"].unique())
    return df, next_open_by_idx, next_close_by_idx, closes, highs, lows, day_close_map, all_days

def compute_buy_hold_equity(day_close_map: dict, daily_dates: list, initial_capital: float) -> pd.Series:
    closes, dates = [], []
    for d in daily_dates:
        px = day_close_map.get(d)
        if px is None or pd.isna(px):
            continue
        dates.append(d)
        closes.append(float(px))
    if not closes:
        return pd.Series(dtype=float)
    first = closes[0]
    equity = [initial_capital * (c / first) for c in closes]
    return pd.Series(equity, index=pd.to_datetime(dates))


# ============================================================
# GATE LOGIC
# ============================================================

def gate_from_p(p_day: float, p_sell_level: float, p_buy_level: float) -> str:
    if not np.isfinite(p_day):
        return "NO_P"
    if p_day >= p_sell_level:
        return "FORCE_SELL"
    if p_day <= p_buy_level:
        return "FORCE_BUY"
    return "FREE"


# ============================================================
# CLASS-FREE SERIALIZATION HELPERS
# ============================================================

def pack_ret_modelpack_for_save(pack):
    if pack is None:
        return None
    return {
        "__type__": "RetModelPack",
        "feature_cols": list(pack.feature_cols),
        "model_ret": pack.model_ret,
    }

def unpack_ret_modelpack_from_load(obj):
    if obj is None:
        return None
    if isinstance(obj, dict) and obj.get("__type__") == "RetModelPack":
        return RetModelPack(
            feature_cols=list(obj["feature_cols"]),
            model_ret=obj["model_ret"],
        )
    return obj


# ============================================================
# CHECKPOINT BUNDLE BUILD / LOAD
# ============================================================

def build_checkpoint_bundle(
    *,
    code: str,
    checkpoint_time: str,

    original_daily_chan_start: str,
    original_accumulation_start: str,
    original_sim_start: str,
    original_end_time: str,

    macro_files: dict,

    daily_prob_model,
    daily_prob_trained_n: int,
    X_days,
    y_days,
    pending_idx,
    p_by_day,
    p_series,
    dp_vs_minK_series,
    dp_vs_maxK_series,
    bsp_rows_daily,
    seen_bsp_daily,

    buy_pack,
    sell_pack,
    buy_ret_th_live: float,
    sell_ret_th_live: float,

    bsp_rows_5m,
    seen_keys_5m,

    engine_state: dict,
    daily_log,

    daily_i_last: int,
    five_i_last: int,
    current_day,

    warmup_daily_bars: pd.DataFrame,
    warmup_5m_bars: pd.DataFrame,

    daily_chan_max_klines: int,
    five_chan_max_klines: int,
):
    p_by_day_str = {}
    if p_by_day is not None:
        for k, v in p_by_day.items():
            try:
                p_by_day_str[str(pd.to_datetime(k))] = float(v)
            except Exception:
                pass

    bundle = {
        "schema": "chan_xgb_dailyprob_checkpoint_v4_macro",
        "code": code,
        "checkpoint_time": checkpoint_time,

        "original_daily_chan_start": str(original_daily_chan_start),
        "original_accumulation_start": str(original_accumulation_start),
        "original_sim_start": str(original_sim_start),
        "original_end_time": str(original_end_time),

        "macro_files": copy.deepcopy(macro_files),

        "daily_prob_model": daily_prob_model,
        "daily_prob_trained_n": int(daily_prob_trained_n),

        "X_days": copy.deepcopy(X_days),
        "y_days": copy.deepcopy(y_days),
        "pending_idx": copy.deepcopy(pending_idx),

        "p_by_day_str": p_by_day_str,
        "p_series": np.asarray(p_series, dtype=float),
        "dp_vs_minK_series": np.asarray(dp_vs_minK_series, dtype=float),
        "dp_vs_maxK_series": np.asarray(dp_vs_maxK_series, dtype=float),

        "bsp_rows_daily": _safe_copy_list_of_dict(bsp_rows_daily),
        "seen_bsp_daily_list": _safe_set_to_list(seen_bsp_daily),

        "buy_pack": pack_ret_modelpack_for_save(buy_pack),
        "sell_pack": pack_ret_modelpack_for_save(sell_pack),

        "buy_ret_th_live": float(buy_ret_th_live),
        "sell_ret_th_live": float(sell_ret_th_live),

        "bsp_rows_5m": _safe_copy_list_of_dict(bsp_rows_5m),
        "seen_keys_5m_list": _safe_set_to_list(seen_keys_5m),

        "engine_state": copy.deepcopy(engine_state),
        "daily_log": copy.deepcopy(daily_log),

        "daily_i_last": int(daily_i_last),
        "five_i_last": int(five_i_last),
        "current_day": None if current_day is None else str(current_day),

        "warmup_daily_bars": warmup_daily_bars.reset_index(drop=True),
        "warmup_5m_bars": warmup_5m_bars.reset_index(drop=True),

        "daily_chan_max_klines": int(daily_chan_max_klines),
        "five_chan_max_klines": int(five_chan_max_klines),
    }
    return bundle

def load_checkpoint_bundle(path: str) -> dict:
    b = load_joblib(path)
    if not isinstance(b, dict):
        raise ValueError("Checkpoint is not a dict.")
    schema = b.get("schema", "")
    if schema not in (
        "chan_xgb_dailyprob_checkpoint_v1",
        "chan_xgb_dailyprob_checkpoint_v2",
        "chan_xgb_dailyprob_checkpoint_v3",
        "chan_xgb_dailyprob_checkpoint_v4_macro",
    ):
        raise ValueError(f"Unknown checkpoint schema: {schema}")
    return b


# ============================================================
# CHECKPOINT START-TIME INFERENCE
# ============================================================

def _load_any_csv_time_index(csv_path: str) -> pd.DataFrame:
    df = pd.read_csv(csv_path)

    ts_candidates = ["timestamp", "date", "datetime", "time"]
    ts_col = None
    for c in ts_candidates:
        if c in df.columns:
            ts_col = c
            break

    if ts_col is None:
        lower_map = {c.lower(): c for c in df.columns}
        for c in ts_candidates:
            if c.lower() in lower_map:
                ts_col = lower_map[c.lower()]
                break

    if ts_col is None:
        ts_col = df.columns[0]

    df[ts_col] = pd.to_datetime(df[ts_col], errors="coerce")
    df = df.dropna(subset=[ts_col]).sort_values(ts_col).reset_index(drop=True)
    df = df.rename(columns={ts_col: "timestamp"})
    return df

def infer_checkpoint_plot_start_time(
    ckpt: dict,
    daily_csv_path: str | None = None,
    k5m_csv_path: str | None = None,
    verbose: bool = True,
):
    ts_keys = [
        "last_checkpoint_time",
        "last_processed_time",
        "last_processed_ts",
        "resume_time",
        "resume_ts",
        "cur_time",
        "current_time",
        "last_day_time",
        "last_day_ts",
        "last_daily_ts",
        "last_5m_ts",
        "five_ts_last",
        "day_ts_last",
        "checkpoint_time",
    ]
    for k in ts_keys:
        if k in ckpt and ckpt[k] is not None:
            try:
                ts = pd.to_datetime(ckpt[k])
                if pd.notna(ts):
                    if verbose:
                        print(f"[PLOT START] inferred from checkpoint key '{k}' = {ts}")
                    return ts
            except Exception:
                pass

    daily_idx_keys = [
        "daily_i_last",
        "day_i_last",
        "last_daily_i",
        "last_day_idx",
        "daily_idx_last",
        "current_daily_i",
        "resume_daily_i",
    ]
    if daily_csv_path is not None and os.path.exists(daily_csv_path):
        try:
            df_day = _load_any_csv_time_index(daily_csv_path)
            for k in daily_idx_keys:
                if k in ckpt and ckpt[k] is not None:
                    i = int(ckpt[k])
                    if 0 <= i < len(df_day):
                        ts = pd.to_datetime(df_day.loc[i, "timestamp"])
                        if verbose:
                            print(f"[PLOT START] inferred from daily index key '{k}' = {ts}")
                        return ts
        except Exception as e:
            if verbose:
                print(f"[PLOT START] daily index inference failed: {e}")

    five_idx_keys = [
        "five_i_last",
        "last_5m_i",
        "five_idx_last",
        "current_five_i",
        "resume_five_i",
        "seen_idx_last",
    ]
    if k5m_csv_path is not None and os.path.exists(k5m_csv_path):
        try:
            df_5m = _load_any_csv_time_index(k5m_csv_path)
            for k in five_idx_keys:
                if k in ckpt and ckpt[k] is not None:
                    i = int(ckpt[k])
                    if 0 <= i < len(df_5m):
                        ts = pd.to_datetime(df_5m.loc[i, "timestamp"])
                        if verbose:
                            print(f"[PLOT START] inferred from 5m index key '{k}' = {ts}")
                        return ts
        except Exception as e:
            if verbose:
                print(f"[PLOT START] 5m index inference failed: {e}")

    if verbose:
        print("[PLOT START] could not infer checkpoint plot start time.")
    return None


# ============================================================
# RESUMED-SEGMENT PLOTTING
# ============================================================

def plot_resumed_segment_from_checkpoint(
    res: dict,
    checkpoint_start_time,
    title_prefix: str = "Resumed Run",
    output_dir: str | None = None,
):
    if "daily_log_df" not in res:
        print("res['daily_log_df'] not found, cannot plot.")
        return

    d = res["daily_log_df"].copy()

    if "timestamp" in d.columns:
        d["plot_time"] = pd.to_datetime(d["timestamp"], errors="coerce")
    elif "date" in d.columns:
        d["plot_time"] = pd.to_datetime(d["date"], errors="coerce")
    else:
        ts_candidates = [c for c in d.columns if "time" in c.lower() or "date" in c.lower()]
        if len(ts_candidates) == 0:
            print("No timestamp/date column found in daily_log_df.")
            return
        d["plot_time"] = pd.to_datetime(d[ts_candidates[0]], errors="coerce")

    d = d.dropna(subset=["plot_time"]).sort_values("plot_time").reset_index(drop=True)

    if checkpoint_start_time is not None:
        d = d[d["plot_time"] >= pd.to_datetime(checkpoint_start_time)].copy().reset_index(drop=True)

    if len(d) == 0:
        print("No rows available after checkpoint start time.")
        return

    if output_dir:
        os.makedirs(output_dir, exist_ok=True)

    equity_col = None
    for c in ["equity", "portfolio_value", "nav", "strategy_equity"]:
        if c in d.columns:
            equity_col = c
            break

    if equity_col is not None:
        plt.figure(figsize=(16, 6))
        base_eq = float(d[equity_col].iloc[0]) if np.isfinite(d[equity_col].iloc[0]) else 1.0
        plt.plot(d["plot_time"], d[equity_col] / (base_eq + 1e-12), label="Strategy (normalized)")
        plt.title(f"{title_prefix} | Equity after checkpoint")
        plt.legend()
        plt.grid(True, alpha=0.25)
        plt.tight_layout()
        if output_dir:
            plt.savefig(os.path.join(output_dir, "resumed_equity_from_checkpoint.png"), dpi=200)
        plt.show()

    p_col = None
    for c in d.columns:
        cl = c.lower()
        if c == "p_day" or "prob" in cl or "p_" in cl:
            p_col = c
            break

    if p_col is not None:
        plt.figure(figsize=(16, 5))
        plt.plot(d["plot_time"], d[p_col], label=p_col)
        plt.title(f"{title_prefix} | Daily probability after checkpoint")
        plt.grid(True, alpha=0.25)
        plt.legend()
        plt.tight_layout()
        if output_dir:
            plt.savefig(os.path.join(output_dir, "resumed_pday_from_checkpoint.png"), dpi=200)
        plt.show()

    if "trades_df" in res and isinstance(res["trades_df"], pd.DataFrame) and not res["trades_df"].empty:
        tr = res["trades_df"].copy()
        if "ts" in tr.columns:
            tr["plot_time"] = pd.to_datetime(tr["ts"], errors="coerce")
            tr = tr.dropna(subset=["plot_time"]).sort_values("plot_time").reset_index(drop=True)

            if checkpoint_start_time is not None:
                tr = tr[tr["plot_time"] >= pd.to_datetime(checkpoint_start_time)].copy().reset_index(drop=True)

            if len(tr) > 0 and "exec_px" in tr.columns:
                plt.figure(figsize=(16, 6))
                buys = tr[tr["side"].astype(str).str.lower() == "buy"]
                sells = tr[tr["side"].astype(str).str.lower() == "sell"]

                if len(buys):
                    plt.scatter(buys["plot_time"], buys["exec_px"], marker="^", label="Buy")
                if len(sells):
                    plt.scatter(sells["plot_time"], sells["exec_px"], marker="v", label="Sell")

                plt.title(f"{title_prefix} | Trades after checkpoint")
                plt.grid(True, alpha=0.25)
                plt.legend()
                plt.tight_layout()
                if output_dir:
                    plt.savefig(os.path.join(output_dir, "resumed_trades_from_checkpoint.png"), dpi=200)
                plt.show()


# ============================================================
# MAIN STRATEGY RUNNER
# ============================================================

def run_daily_prob_then_5m_xgb_gated(
    daily_csv_path: str,
    k5m_csv_path: str,
    code: str = "QQQ",

    daily_chan_start: str = "2016-06-01",
    accumulation_start: str = "2018-10-01",
    sim_start: str = "2019-01-01",
    end_time: str = "2019-12-30",

    N_confirm: int = 5,
    min_labeled_days_to_train: int = 200,
    retrain_every_new_labels: int = 25,
    dp_lookback: int = 5,

    p_sell_level: float = 0.30,
    p_buy_level: float = 0.20,

    bar_interval_minutes: int = 5,
    lookahead_days_5m: float = 2.0,
    retrain_every_days_5m: int = 5,
    min_samples_total_5m: int = 300,

    threshold_window_days: float = 2.0,
    threshold_ret_grid=None,
    threshold_min_open_signals: int = 10,

    initial_capital: float = 100000.0,
    fee_pct: float = 0.0,

    daily_chan_max_klines: int = 500,
    five_chan_max_klines: int = 20000,

    macro_files: dict | None = None,

    output_dir: str = "output_dailyprob_gated_5m_xgb",
    verbose: bool = True,

    save_checkpoint_path: str | None = None,
    checkpoint_every_n_days: int = 1,
    resume_from_checkpoint_path: str | None = None,
):
    os.makedirs(output_dir, exist_ok=True)

    if macro_files is None:
        macro_files = {
            "vix_":   "VIX.csv",
            "dxy_":   "DXY.csv",
            "us5y_":  "FVX.csv",
            "us10y_": "TNX.csv",
            "us30y_": "TYX.csv",
            "xau_":   "XAU.csv",
            "nyxbt_": "NYXBT.csv",
        }

    # ----------------------------
    # Load raw data
    # ----------------------------
    df_day_raw = load_ohlcv_csv(daily_csv_path, "DAILY")
    df_5m_raw  = load_ohlcv_csv(k5m_csv_path, "5M")

    daily_s = pd.to_datetime(daily_chan_start)
    acc_s   = pd.to_datetime(accumulation_start)
    sim_s   = pd.to_datetime(sim_start)
    end_t   = pd.to_datetime(end_time)

    df_day = df_day_raw[(df_day_raw["timestamp"] >= daily_s) & (df_day_raw["timestamp"] <= end_t)].copy().reset_index(drop=True)
    if df_day.empty:
        raise ValueError("No daily bars in requested range.")
    df_day_feat = compute_daily_kline_features(df_day)
    df_day_feat["ts_norm"] = pd.to_datetime(df_day_feat["timestamp"]).dt.normalize()

    macro_folder = os.path.dirname(os.path.abspath(daily_csv_path))
    macro_feat = load_macro_features_from_folder(
        folder=macro_folder,
        files=macro_files,
        start=daily_chan_start,
    )
    df_day_feat = df_day_feat.merge(macro_feat, on="ts_norm", how="left").sort_values("timestamp").reset_index(drop=True)

    macro_cols = [
        c for c in df_day_feat.columns
        if (
            c.startswith("vix_")
            or c.startswith("dxy_")
            or c.startswith("us5y_")
            or c.startswith("us10y_")
            or c.startswith("us30y_")
            or c.startswith("xau_")
            or c.startswith("nyxbt_")
            or c.startswith("yc_")
        )
    ]

    df_5m = df_5m_raw[(df_5m_raw["timestamp"] >= acc_s) & (df_5m_raw["timestamp"] <= end_t + pd.Timedelta(days=1))].copy()
    df_5m = df_5m.sort_values("timestamp").reset_index(drop=True)

    df_5m_idx, next_open_by_idx, next_close_by_idx, closes, highs, lows, day_close_map, all_days = load_5m_index(
        df_5m, accumulation_start, end_time
    )
    buy_hold = compute_buy_hold_equity(day_close_map, all_days, initial_capital)

    # ----------------------------
    # Chan config / objects
    # ----------------------------
    config = CChanConfig({
        "cal_demark": True,
        "cal_kdj": True,
        "cal_dmi": True,
        "cal_rsi": True,
        "cal_rsl": True,
        "cal_demand_index": True,
        "cal_adline": True,
        "cal_bb_vals": True,
        "cal_kc_vals": True,
        "cal_starc_vals": True,
        "bi_strict": True,
        "trigger_step": True,
        "skip_step": 0,
        "divergence_rate": float("inf"),
        "bsp2_follow_1": True,
        "bsp3_follow_1": False,
        "min_zs_cnt": 0,
        "bs1_peak": False,
        "macd_algo": "peak",
        "bs_type": "1,2,3a,1p,2s,3b",
        "print_warning": False,
        "zs_algo": "normal",
    })

    daily_chan = SlidingWindowChan(
        code=code,
        begin_time=None,
        end_time=None,
        data_src=getattr(DATA_SRC, "CSV", "CSV"),
        lv_list=[KL_TYPE.K_DAY],
        config=config,
        autype=AUTYPE.QFQ,
        max_klines=int(daily_chan_max_klines),
    )

    chan_5m = SlidingWindowChan(
        code=code,
        begin_time=None,
        end_time=None,
        data_src=getattr(DATA_SRC, "CSV", "CSV"),
        lv_list=[KL_TYPE.K_5M],
        config=config,
        autype=AUTYPE.QFQ,
        max_klines=int(five_chan_max_klines),
    )

    # ----------------------------
    # Fresh state defaults
    # ----------------------------
    bsp_rows_daily = []
    seen_bsp_daily = set()

    X_days = []
    y_days = []
    st = DailyProbState()
    pending_idx = []

    p_series = np.full(len(df_day_feat), np.nan, dtype=float)
    dp_vs_minK_series = np.full(len(df_day_feat), np.nan, dtype=float)
    dp_vs_maxK_series = np.full(len(df_day_feat), np.nan, dtype=float)
    p_by_day = {}

    engine = ExecutionEngine(initial_capital=initial_capital, fee_pct=fee_pct)
    bsp_rows_5m = []
    seen_keys_5m = set()
    buy_pack = None
    sell_pack = None
    last_train_day = None

    if threshold_ret_grid is None:
        threshold_ret_grid = make_ret_grid(-0.5, 2.5, 0.05)
    buy_ret_th_live = 0.30
    sell_ret_th_live = 0.30

    daily_i_start = 0
    five_i_start = 0
    current_day = None
    daily_log = []

    # ----------------------------
    # Resume restore
    # ----------------------------
    if resume_from_checkpoint_path is not None and os.path.exists(resume_from_checkpoint_path):
        B = load_checkpoint_bundle(resume_from_checkpoint_path)
        if verbose:
            print(f"[RESUME] loading checkpoint: {resume_from_checkpoint_path} @ {B.get('checkpoint_time')}")

        st.model = B.get("daily_prob_model", None)
        st.trained_n = int(B.get("daily_prob_trained_n", 0))
        st.new_labels = 0

        X_days = B.get("X_days", []) or []
        y_days = B.get("y_days", []) or []
        pending_idx = B.get("pending_idx", []) or []

        p_series_loaded = B.get("p_series", None)
        if p_series_loaded is not None and len(p_series_loaded) == len(p_series):
            p_series = np.asarray(p_series_loaded, dtype=float)

        dp_min_loaded = B.get("dp_vs_minK_series", None)
        dp_max_loaded = B.get("dp_vs_maxK_series", None)
        if dp_min_loaded is not None and len(dp_min_loaded) == len(dp_vs_minK_series):
            dp_vs_minK_series = np.asarray(dp_min_loaded, dtype=float)
        if dp_max_loaded is not None and len(dp_max_loaded) == len(dp_vs_maxK_series):
            dp_vs_maxK_series = np.asarray(dp_max_loaded, dtype=float)

        p_by_day_str = B.get("p_by_day_str", {}) or {}
        p_by_day = {pd.to_datetime(k).normalize(): float(v) for k, v in p_by_day_str.items()}

        bsp_rows_daily = B.get("bsp_rows_daily", []) or []
        seen_bsp_daily = _safe_list_to_set(B.get("seen_bsp_daily_list", []))

        buy_pack = unpack_ret_modelpack_from_load(B.get("buy_pack", None))
        sell_pack = unpack_ret_modelpack_from_load(B.get("sell_pack", None))
        buy_ret_th_live = float(B.get("buy_ret_th_live", buy_ret_th_live))
        sell_ret_th_live = float(B.get("sell_ret_th_live", sell_ret_th_live))

        bsp_rows_5m = B.get("bsp_rows_5m", []) or []
        seen_keys_5m = _safe_list_to_set(B.get("seen_keys_5m_list", []))

        engine.load_state_dict(B.get("engine_state", {}) or {})
        daily_log = B.get("daily_log", []) or []

        daily_i_start = int(B.get("daily_i_last", -1)) + 1
        five_i_start = int(B.get("five_i_last", -1)) + 1

        cur_day_s = B.get("current_day", None)
        current_day = None if cur_day_s is None else datetime.date.fromisoformat(cur_day_s)

        warm_day = B.get("warmup_daily_bars", None)
        if warm_day is not None and len(warm_day):
            for _, rr in warm_day.iterrows():
                ts = pd.to_datetime(rr["timestamp"])
                daily_chan.process_new_kline(build_klu(ts, rr["_open"], rr["_high"], rr["_low"], rr["_close"], rr.get("_vol", 0.0)))

        warm_5m = B.get("warmup_5m_bars", None)
        if warm_5m is not None and len(warm_5m):
            for _, rr in warm_5m.iterrows():
                ts = pd.to_datetime(rr["timestamp"])
                feed_chan_one(chan_5m, build_klu(ts, rr["_open"], rr["_high"], rr["_low"], rr["_close"], rr.get("_vol", 0.0)))

        if verbose:
            print(f"[RESUME] daily_i_start={daily_i_start} / {len(df_day_feat)}")
            print(f"[RESUME] five_i_start={five_i_start} / {len(df_5m_idx)}")
            print(f"[RESUME] daily_model={'YES' if st.model is not None else 'NO'} "
                  f"5m_buy={'YES' if buy_pack else 'NO'} 5m_sell={'YES' if sell_pack else 'NO'}")

    # ----------------------------
    # Daily trainer helper
    # ----------------------------
    def maybe_train_daily():
        if len(y_days) < int(min_labeled_days_to_train):
            return
        if st.model is None or st.new_labels >= int(retrain_every_new_labels):
            y = np.asarray(y_days, dtype=int)
            if len(np.unique(y)) < 2:
                return
            try:
                st.model = fit_prob_model_dicts(X_days, y)
                st.trained_n = len(y)
                st.new_labels = 0
                if verbose:
                    print(f"[TRAIN][DAILY-PROB] n={len(y)} pos={int(y.sum())} ({y.mean():.2%})")
            except Exception as e:
                if verbose:
                    print(f"[TRAIN][DAILY-PROB] skipped: {e}")

    # ----------------------------
    # Save checkpoint helper
    # ----------------------------
    def save_checkpoint(now_ts: pd.Timestamp, daily_i_last: int, five_i_last: int, current_day):
        nonlocal daily_log
        if save_checkpoint_path is None:
            return

        warm_daily = df_day_raw[df_day_raw["timestamp"] <= now_ts].tail(int(daily_chan_max_klines)).copy()
        warm_5m = df_5m_raw[df_5m_raw["timestamp"] <= now_ts].tail(int(five_chan_max_klines)).copy()

        bundle = build_checkpoint_bundle(
            code=code,
            checkpoint_time=str(now_ts),

            original_daily_chan_start=str(daily_chan_start),
            original_accumulation_start=str(accumulation_start),
            original_sim_start=str(sim_start),
            original_end_time=str(end_time),

            macro_files=macro_files,

            daily_prob_model=st.model,
            daily_prob_trained_n=st.trained_n,
            X_days=X_days,
            y_days=y_days,
            pending_idx=pending_idx,
            p_by_day=p_by_day,
            p_series=p_series,
            dp_vs_minK_series=dp_vs_minK_series,
            dp_vs_maxK_series=dp_vs_maxK_series,
            bsp_rows_daily=bsp_rows_daily,
            seen_bsp_daily=seen_bsp_daily,

            buy_pack=buy_pack,
            sell_pack=sell_pack,
            buy_ret_th_live=buy_ret_th_live,
            sell_ret_th_live=sell_ret_th_live,

            bsp_rows_5m=bsp_rows_5m,
            seen_keys_5m=seen_keys_5m,

            engine_state=engine.state_dict(),
            daily_log=daily_log,

            daily_i_last=daily_i_last,
            five_i_last=five_i_last,
            current_day=current_day,

            warmup_daily_bars=warm_daily[["timestamp","_open","_high","_low","_close","_vol"]].reset_index(drop=True),
            warmup_5m_bars=warm_5m[["timestamp","_open","_high","_low","_close","_vol"]].reset_index(drop=True),

            daily_chan_max_klines=daily_chan_max_klines,
            five_chan_max_klines=five_chan_max_klines,
        )

        save_joblib(save_checkpoint_path, bundle)
        if verbose:
            print(f"[CHECKPOINT] saved -> {save_checkpoint_path} @ {now_ts}")

    # ----------------------------
    # DAILY PHASE
    # ----------------------------
    for i in range(daily_i_start, len(df_day_feat)):
        r = df_day_feat.loc[i]
        ts = pd.to_datetime(r["timestamp"])
        day = ts.normalize()

        daily_chan.process_new_kline(build_klu(ts, r["_open"], r["_high"], r["_low"], r["_close"], r["_vol"]))

        new_bsp = extract_bsp_rows_from_chan(daily_chan)
        if new_bsp:
            for rr0 in new_bsp:
                rr = normalize_bsp_row(dict(rr0))
                rr.setdefault("timestamp", ts)
                key = (pd.to_datetime(rr["timestamp"]).strftime("%Y-%m-%d"), rr["direction"], rr.get("bsp_type", "?"))
                if key in seen_bsp_daily:
                    continue
                seen_bsp_daily.add(key)
                bsp_rows_daily.append(rr)

        ends = compute_chain_endpoints(bsp_rows_daily)
        regime = regime_for_day_from_ends(day, ends)
        base_dir_today = latest_bsp_dir_up_to(bsp_rows_daily, ts)

        p_val = np.nan
        if st.model is not None:
            bsp_hist = [b for b in bsp_rows_daily if pd.to_datetime(b["timestamp"]) <= ts]
            feat_i = make_daily_features_one_model(
                kline_row=r,
                bsp_hist_up_to_day=bsp_hist,
                p_val=0.0,
                dp_minK=0.0,
                dp_maxK=0.0,
                regime=regime,
                base_dir=base_dir_today,
                macro_cols=macro_cols,
            )
            p_val = float(predict_prob(st.model, [feat_i])[0])
            p_series[i] = p_val
            p_by_day[day] = p_val

        lb = int(dp_lookback)
        p_minK = np.nan
        p_maxK = np.nan
        if lb > 0 and i >= 1 and np.isfinite(p_val):
            start = max(0, i - lb)
            prev = pd.Series(p_series[start:i]).dropna()
            if len(prev) > 0:
                p_minK = float(prev.min())
                p_maxK = float(prev.max())

        dp_vs_minK = (p_val - p_minK) if (np.isfinite(p_val) and np.isfinite(p_minK)) else np.nan
        dp_vs_maxK = (p_val - p_maxK) if (np.isfinite(p_val) and np.isfinite(p_maxK)) else np.nan
        dp_vs_minK_series[i] = dp_vs_minK
        dp_vs_maxK_series[i] = dp_vs_maxK

        pending_idx.append(i)
        while pending_idx and i >= pending_idx[0] + int(N_confirm):
            j = pending_idx.pop(0)
            t0 = pd.to_datetime(df_day_feat.loc[j, "timestamp"])
            base_dir_j = latest_bsp_dir_up_to(bsp_rows_daily, t0)
            if base_dir_j not in ("buy", "sell"):
                continue

            y = label_confirm_extreme(df_day_feat, j, int(N_confirm), base_dir_j)
            if y is None:
                continue

            ends_j = compute_chain_endpoints([b for b in bsp_rows_daily if pd.to_datetime(b["timestamp"]) <= t0])
            regime_j = regime_for_day_from_ends(t0.normalize(), ends_j)

            bsp_hist_j = [b for b in bsp_rows_daily if pd.to_datetime(b["timestamp"]) <= t0]
            feat_j = make_daily_features_one_model(
                kline_row=df_day_feat.loc[j],
                bsp_hist_up_to_day=bsp_hist_j,
                p_val=float(p_series[j]) if np.isfinite(p_series[j]) else 0.0,
                dp_minK=float(dp_vs_minK_series[j]) if np.isfinite(dp_vs_minK_series[j]) else 0.0,
                dp_maxK=float(dp_vs_maxK_series[j]) if np.isfinite(dp_vs_maxK_series[j]) else 0.0,
                regime=regime_j,
                base_dir=base_dir_j,
                macro_cols=macro_cols,
            )

            X_days.append(feat_j)
            y_days.append(int(y))
            st.new_labels += 1

        maybe_train_daily()

    feat_imp_path = os.path.join(output_dir, "daily_lr_feature_importance.csv")
    if st.model is not None:
        try:
            imp_df = feature_importance_from_lr(st.model, top_n=120)
            imp_df.to_csv(feat_imp_path, index=False)
            if verbose:
                print(f"[SAVED] {feat_imp_path}")
        except Exception as e:
            if verbose:
                print(f"[IMP][DAILY-PROB] skipped: {e}")

    # ----------------------------
    # 5M PHASE
    # ----------------------------
    if verbose:
        print(f"[PHASE2/3] 5m feed begins at accumulation_start={acc_s.date()}, trading starts at sim_s={sim_s.date()}")

    def maybe_retrain_5m(day_ts: pd.Timestamp):
        nonlocal buy_pack, sell_pack, last_train_day
        if last_train_day is not None and (day_ts - last_train_day).days < int(retrain_every_days_5m):
            return
        dfb = pd.DataFrame(bsp_rows_5m)
        if dfb.empty:
            return
        dfb2 = prepare_ml_dataset(dfb)
        feat_cols = get_feature_columns(dfb2)
        bp, sp = train_models_two_sided_ret_only(dfb2, feat_cols, min_samples_total=min_samples_total_5m)
        if bp is not None:
            buy_pack = bp
        if sp is not None:
            sell_pack = sp
        if (bp is not None) or (sp is not None):
            last_train_day = day_ts
            if verbose:
                print(f"[TRAIN][5M] asof={day_ts.date()} feats={len(feat_cols)} buy={'YES' if bp else 'NO'} sell={'YES' if sp else 'NO'} rows={len(dfb2)}")

    def maybe_opt_thresholds(asof_bar_idx: int):
        nonlocal buy_ret_th_live, sell_ret_th_live
        if buy_pack is None or sell_pack is None:
            return
        out = choose_thresholds_global_realized(
            df_5m=df_5m_idx,
            bsp_rows=bsp_rows_5m,
            buy_pack=buy_pack,
            sell_pack=sell_pack,
            asof_bar_idx=asof_bar_idx,
            window_days=threshold_window_days,
            ret_grid=threshold_ret_grid,
            next_open_by_idx=next_open_by_idx,
            closes=closes,
            fee_pct=fee_pct,
            min_open_signals=threshold_min_open_signals,
        )
        if out is not None:
            buy_ret_th_live, sell_ret_th_live = out
            if verbose:
                print(f"[TH-OPT][GLOBAL] asof_bar={asof_bar_idx} buy_th={buy_ret_th_live:.2f} sell_th={sell_ret_th_live:.2f}")

    sim_start_ts = pd.to_datetime(sim_start)
    last_day_end_idx = None
    day_gate = "NO_P"
    must_trade_dir = None
    allow_buy = True
    allow_sell = True
    days_since_checkpoint = 0

    for i in range(five_i_start, len(df_5m_idx)):
        bar_ts = pd.to_datetime(df_5m_idx.loc[i, "timestamp"])
        bar_day = bar_ts.date()
        in_sim = (bar_ts >= sim_start_ts)

        if current_day is None:
            current_day = bar_day
            p_day = p_by_day.get(pd.to_datetime(bar_day), np.nan)
            day_gate = gate_from_p(p_day, p_sell_level, p_buy_level)

            allow_buy = True
            allow_sell = True
            must_trade_dir = None

            if day_gate == "FORCE_BUY":
                allow_sell = False
                if engine.pos == 0:
                    must_trade_dir = "buy"
            elif day_gate == "FORCE_SELL":
                allow_buy = False
                if engine.pos == 1:
                    must_trade_dir = "sell"

        if bar_day != current_day:
            prev_day = current_day
            prev_day_ts = pd.to_datetime(prev_day)

            label_bestlookahead_for_ready_points(
                bsp_rows=bsp_rows_5m,
                highs=highs, lows=lows, closes=closes,
                lookahead_days=lookahead_days_5m,
                bar_interval_minutes=bar_interval_minutes,
                current_bar_idx=i,
            )

            maybe_retrain_5m(prev_day_ts)
            if last_day_end_idx is not None:
                maybe_opt_thresholds(last_day_end_idx)

            day_close = day_close_map.get(prev_day)
            equity = engine.mark_to_market(day_close) if day_close is not None else engine.cash
            daily_log.append({
                "date": prev_day,
                "equity": equity,
                "cash": engine.cash,
                "pos": engine.pos,
                "buy_th": buy_ret_th_live,
                "sell_th": sell_ret_th_live,
                "p_day": float(p_by_day.get(pd.to_datetime(prev_day), np.nan)),
            })

            days_since_checkpoint += 1
            if save_checkpoint_path is not None and days_since_checkpoint >= int(checkpoint_every_n_days):
                save_checkpoint(
                    now_ts=pd.to_datetime(df_5m_idx.loc[last_day_end_idx, "timestamp"]),
                    daily_i_last=(len(df_day_feat) - 1),
                    five_i_last=int(last_day_end_idx),
                    current_day=prev_day,
                )
                days_since_checkpoint = 0

            current_day = bar_day
            p_day = p_by_day.get(pd.to_datetime(bar_day), np.nan)
            day_gate = gate_from_p(p_day, p_sell_level, p_buy_level)

            allow_buy = True
            allow_sell = True
            must_trade_dir = None

            if day_gate == "FORCE_BUY":
                allow_sell = False
                if engine.pos == 0:
                    must_trade_dir = "buy"
            elif day_gate == "FORCE_SELL":
                allow_buy = False
                if engine.pos == 1:
                    must_trade_dir = "sell"

        last_day_end_idx = i

        if in_sim:
            engine.maybe_execute_pending(next_open_by_idx)

        klu = build_klu(
            df_5m_idx.loc[i, "timestamp"],
            df_5m_idx.loc[i, "Open"], df_5m_idx.loc[i, "High"], df_5m_idx.loc[i, "Low"], df_5m_idx.loc[i, "Close"],
            df_5m_idx.loc[i, "Volume"],
        )
        feed_chan_one(chan_5m, klu)

        new_rows = extract_bsp_rows_from_chan(chan_5m)
        if not new_rows:
            continue

        for r0 in new_rows:
            r = dict(r0)
            r.setdefault("timestamp", str(bar_ts))
            r.setdefault("klu_idx", i)

            if "direction" not in r or r["direction"] is None:
                if r.get("is_buy", None) is not None:
                    r["direction"] = "buy" if bool(r["is_buy"]) else "sell"
                else:
                    r["direction"] = "buy"
            r["direction"] = str(r["direction"]).lower()
            if "bsp_type" in r and r["bsp_type"] is not None:
                r["bsp_type"] = str(r["bsp_type"]).lower()
            r.setdefault("best_return_pct", np.nan)

            k = (int(r.get("klu_idx", -1)), str(r.get("direction")), str(r.get("bsp_type")))
            if k in seen_keys_5m:
                continue
            seen_keys_5m.add(k)
            bsp_rows_5m.append(r)

            if not in_sim:
                continue

            d = str(r.get("direction", "buy")).lower()
            ki = int(r.get("klu_idx", i))

            if d == "buy" and not allow_buy:
                continue
            if d == "sell" and not allow_sell:
                continue
            if must_trade_dir is not None and d != must_trade_dir:
                continue

            if d == "buy" and engine.pos == 0 and buy_pack is not None:
                row_df = prepare_ml_dataset(pd.DataFrame([r]))
                for cc in buy_pack.feature_cols:
                    if cc not in row_df.columns:
                        row_df[cc] = 0.0
                pr = predict_ret(buy_pack, row_df)
                if pr >= float(buy_ret_th_live):
                    engine.place_order_for_next_bar(
                        side="buy",
                        seen_idx=ki,
                        reason=("FORCE_BUY->first acceptable 5m signal" if day_gate == "FORCE_BUY" else "5m BUY signal"),
                        meta={
                            "ts": str(bar_ts),
                            "p_day": float(p_by_day.get(pd.to_datetime(bar_day), np.nan)),
                            "pred": float(pr),
                            "th": float(buy_ret_th_live),
                            "gate": day_gate,
                        },
                    )
                    if must_trade_dir == "buy":
                        must_trade_dir = None

            elif d == "sell" and engine.pos == 1 and sell_pack is not None:
                row_df = prepare_ml_dataset(pd.DataFrame([r]))
                for cc in sell_pack.feature_cols:
                    if cc not in row_df.columns:
                        row_df[cc] = 0.0
                pr = predict_ret(sell_pack, row_df)
                if pr >= float(sell_ret_th_live):
                    engine.place_order_for_next_bar(
                        side="sell",
                        seen_idx=ki,
                        reason=("FORCE_SELL->first acceptable 5m signal" if day_gate == "FORCE_SELL" else "5m SELL signal"),
                        meta={
                            "ts": str(bar_ts),
                            "p_day": float(p_by_day.get(pd.to_datetime(bar_day), np.nan)),
                            "pred": float(pr),
                            "th": float(sell_ret_th_live),
                            "gate": day_gate,
                        },
                    )
                    if must_trade_dir == "sell":
                        must_trade_dir = None

    if current_day is not None:
        day_close = day_close_map.get(current_day)
        equity = engine.mark_to_market(day_close) if day_close is not None else engine.cash
        daily_log.append({
            "date": current_day,
            "equity": equity,
            "cash": engine.cash,
            "pos": engine.pos,
            "buy_th": buy_ret_th_live,
            "sell_th": sell_ret_th_live,
            "p_day": float(p_by_day.get(pd.to_datetime(current_day), np.nan)),
        })

    if save_checkpoint_path is not None and len(df_5m_idx) > 0:
        final_ts = pd.to_datetime(df_5m_idx.loc[len(df_5m_idx)-1, "timestamp"])
        save_checkpoint(
            now_ts=final_ts,
            daily_i_last=(len(df_day_feat) - 1),
            five_i_last=(len(df_5m_idx) - 1),
            current_day=current_day,
        )

    # ----------------------------
    # Save outputs
    # ----------------------------
    trades_df = pd.DataFrame(engine.trades)
    daily_df = pd.DataFrame(daily_log)
    if not daily_df.empty:
        if "date" in daily_df.columns:
            daily_df["date"] = pd.to_datetime(daily_df["date"])
            daily_df = daily_df.sort_values("date").reset_index(drop=True)

    trades_csv = os.path.join(output_dir, "trades.csv")
    daily_csv = os.path.join(output_dir, "daily_log.csv")
    trades_df.to_csv(trades_csv, index=False)
    daily_df.to_csv(daily_csv, index=False)

    out_eq = os.path.join(output_dir, "equity_vs_buyhold.png")
    out_px = os.path.join(output_dir, "price_with_trades.png")
    out_p  = os.path.join(output_dir, "p_day.png")

    plt.figure()
    if not daily_df.empty and "date" in daily_df.columns and "equity" in daily_df.columns:
        plt.plot(daily_df["date"], daily_df["equity"], label="Strategy Equity")
    if len(buy_hold) > 0:
        plt.plot(buy_hold.index, buy_hold.values, label="Buy&Hold")
    plt.legend()
    plt.title("Equity vs Buy&Hold")
    plt.xlabel("Date")
    plt.ylabel("Equity")
    plt.savefig(out_eq, dpi=150, bbox_inches="tight")
    plt.show()

    plt.figure()
    plt.plot(df_5m_idx["timestamp"], df_5m_idx["Close"], label="5m Close")
    if not trades_df.empty and "seen_idx" in trades_df.columns and "exec_px" in trades_df.columns:
        for _, tr in trades_df.iterrows():
            idx = int(tr["seen_idx"])
            if idx in df_5m_idx.index:
                t = pd.to_datetime(df_5m_idx.loc[idx, "timestamp"])
                px = float(tr["exec_px"])
                if tr.get("side", "") == "buy":
                    plt.scatter([t], [px], marker="^")
                else:
                    plt.scatter([t], [px], marker="v")
    plt.title("Price with Trade Markers")
    plt.xlabel("Time")
    plt.ylabel("Price")
    plt.savefig(out_px, dpi=150, bbox_inches="tight")
    plt.show()

    days_sorted = sorted(p_by_day.keys())
    if days_sorted:
        plt.figure()
        xs = pd.to_datetime(days_sorted)
        ys = [p_by_day[d] for d in days_sorted]
        plt.plot(xs, ys, label="p_day")
        plt.axhline(p_sell_level, linestyle="--", label="p_sell_level")
        plt.axhline(p_buy_level, linestyle="--", label="p_buy_level")
        plt.legend()
        plt.title("Daily Probability p_day")
        plt.xlabel("Date")
        plt.ylabel("Probability")
        plt.savefig(out_p, dpi=150, bbox_inches="tight")
        plt.show()

    if verbose:
        print(f"[SAVED] {trades_csv}")
        print(f"[SAVED] {daily_csv}")
        print(f"[SAVED] {out_eq}")
        print(f"[SAVED] {out_px}")
        if days_sorted:
            print(f"[SAVED] {out_p}")
        if st.model is not None:
            print(f"[SAVED] {feat_imp_path}")
        print(f"[TRADES] total={len(trades_df)}")
        if not trades_df.empty and "seen_idx" in trades_df.columns:
            min_seen_idx = int(trades_df["seen_idx"].min())
            if min_seen_idx in df_5m_idx.index:
                ts0 = pd.to_datetime(df_5m_idx.loc[min_seen_idx, "timestamp"])
                print(f"[TRADES] first_trade_ts={ts0} (sim_start={sim_start_ts})")
            else:
                print(f"[TRADES] first_trade_seen_idx={min_seen_idx} not found in current df_5m_idx index")

    return {
        "trades_df": trades_df,
        "daily_log_df": daily_df,
        "p_by_day": p_by_day,
        "buy_hold": buy_hold,
        "output_dir": output_dir,
        "checkpoint_path": save_checkpoint_path,
    }


# ============================================================
# RESUME WRAPPER
# ============================================================

def resume_from_checkpoint(
    checkpoint_path: str,
    daily_csv_path: str,
    k5m_csv_path: str,
    end_time: str | None = None,
    output_dir: str = "output_resumed_run",
    verbose: bool = True,
    plot_from_checkpoint: bool = True,
):
    if not os.path.exists(checkpoint_path):
        raise FileNotFoundError(f"Checkpoint not found: {checkpoint_path}")

    ckpt = load_checkpoint_bundle(checkpoint_path)

    code = ckpt.get("code", "QQQ")
    original_daily_chan_start = ckpt.get("original_daily_chan_start")
    original_accumulation_start = ckpt.get("original_accumulation_start")
    original_sim_start = ckpt.get("original_sim_start")
    original_end_time = ckpt.get("original_end_time")
    macro_files = ckpt.get("macro_files", None)

    if original_daily_chan_start is None or original_accumulation_start is None or original_sim_start is None:
        raise ValueError(
            "This checkpoint does not contain the original run window. "
            "It was likely created by the older checkpoint format."
        )

    final_end_time = end_time if end_time is not None else original_end_time

    checkpoint_plot_start = infer_checkpoint_plot_start_time(
        ckpt=ckpt,
        daily_csv_path=daily_csv_path,
        k5m_csv_path=k5m_csv_path,
        verbose=verbose,
    )

    if verbose:
        print(f"[RESUME WRAPPER] checkpoint={checkpoint_path}")
        print(f"[RESUME WRAPPER] code={code}")
        print(f"[RESUME WRAPPER] original_daily_chan_start={original_daily_chan_start}")
        print(f"[RESUME WRAPPER] original_accumulation_start={original_accumulation_start}")
        print(f"[RESUME WRAPPER] original_sim_start={original_sim_start}")
        print(f"[RESUME WRAPPER] original_end_time={original_end_time}")
        print(f"[RESUME WRAPPER] continue_until={final_end_time}")
        print(f"[RESUME WRAPPER] plot_from={checkpoint_plot_start}")
        print(f"[RESUME WRAPPER] output_dir={output_dir}")

    res = run_daily_prob_then_5m_xgb_gated(
        daily_csv_path=daily_csv_path,
        k5m_csv_path=k5m_csv_path,
        code=code,

        daily_chan_start=original_daily_chan_start,
        accumulation_start=original_accumulation_start,
        sim_start=original_sim_start,
        end_time=final_end_time,

        N_confirm=5,
        min_labeled_days_to_train=200,
        retrain_every_new_labels=25,
        dp_lookback=5,

        p_sell_level=0.30,
        p_buy_level=0.20,

        lookahead_days_5m=2.0,
        retrain_every_days_5m=5,
        min_samples_total_5m=300,

        threshold_window_days=2.0,
        threshold_ret_grid=None,
        threshold_min_open_signals=10,

        initial_capital=100000.0,
        fee_pct=0.0,

        daily_chan_max_klines=int(ckpt.get("daily_chan_max_klines", 500)),
        five_chan_max_klines=int(ckpt.get("five_chan_max_klines", 20000)),

        macro_files=macro_files,

        output_dir=output_dir,
        verbose=verbose,

        resume_from_checkpoint_path=checkpoint_path,
        save_checkpoint_path=checkpoint_path,
        checkpoint_every_n_days=5,
    )

    res["checkpoint_plot_start"] = checkpoint_plot_start

    if plot_from_checkpoint:
        plot_resumed_segment_from_checkpoint(
            res=res,
            checkpoint_start_time=checkpoint_plot_start,
            title_prefix=f"{code} resumed from checkpoint",
            output_dir=output_dir,
        )

    return res


# ============================================================
# EXAMPLE: FRESH RUN
# ============================================================
res = run_daily_prob_then_5m_xgb_gated(
    daily_csv_path="DataAPI/data/QQQ_DAY.csv",
    k5m_csv_path="DataAPI/data/QQQ_5M.csv",
    code="QQQ",

    daily_chan_start="2014-06-01",
    accumulation_start="2016-10-01",
    sim_start="2019-01-01",
    end_time="2026-12-31",

    N_confirm=5,
    min_labeled_days_to_train=200,
    retrain_every_new_labels=25,
    dp_lookback=5,

    p_sell_level=0.30,
    p_buy_level=0.20,

    lookahead_days_5m=2.0,
    retrain_every_days_5m=5,
    min_samples_total_5m=300,

    threshold_window_days=2.0,
    threshold_ret_grid=None,
    threshold_min_open_signals=10,

    initial_capital=100000.0,
    fee_pct=0.0,

    daily_chan_max_klines=500,
    five_chan_max_klines=500,

    macro_files={
        "vix_":   "VIX.csv",
        "dxy_":   "DXY.csv",
        "us5y_":  "US5Y.csv",
        "us10y_": "US10Y.csv",
        "us30y_": "US30Y.csv",
        "xau_":   "XAU.csv",
        "nyxbt_": "NYXBT.csv",
        "10y2ys_": "10Y2YS.csv",
        "us2y_": "US2Y.csv",
        #spgsci_": "SPGSCI.csv",
    },

    output_dir="output_dailyprob_gated_5m_xgb_QQQ_macro_us2",
    verbose=True,

    save_checkpoint_path="checkpoints/QQQ_macro_US2_checkpoint.joblib",
    checkpoint_every_n_days=5,
)

# ============================================================
# EXAMPLE: RESUME
# ============================================================
# res = resume_from_checkpoint(
#     checkpoint_path="checkpoints/QQQ_macro_checkpoint.joblib",
#     daily_csv_path="DataAPI/data/QQQ_DAY.csv",
#     k5m_csv_path="DataAPI/data/QQQ_5M.csv",
#     end_time="2026-12-31",
#     output_dir="output_resumed_QQQ_macro",
#     verbose=True,
#     plot_from_checkpoint=True,
# )
#
# display(res["trades_df"].tail(50))
# display(res["daily_log_df"].tail(20))
# print("checkpoint_plot_start =", res.get("checkpoint_plot_start"))
# Out:
# [TRAIN][DAILY-PROB] n=200 pos=42 (21.00%)
# [TRAIN][DAILY-PROB] n=225 pos=49 (21.78%)
# [TRAIN][DAILY-PROB] n=250 pos=59 (23.60%)
# [TRAIN][DAILY-PROB] n=275 pos=68 (24.73%)
# [TRAIN][DAILY-PROB] n=300 pos=77 (25.67%)
# [TRAIN][DAILY-PROB] n=325 pos=82 (25.23%)
# [TRAIN][DAILY-PROB] n=350 pos=92 (26.29%)
# [TRAIN][DAILY-PROB] n=375 pos=96 (25.60%)
# [TRAIN][DAILY-PROB] n=400 pos=107 (26.75%)
# [TRAIN][DAILY-PROB] n=425 pos=111 (26.12%)
# [TRAIN][DAILY-PROB] n=450 pos=118 (26.22%)
# [TRAIN][DAILY-PROB] n=475 pos=122 (25.68%)
# [TRAIN][DAILY-PROB] n=500 pos=125 (25.00%)
# [TRAIN][DAILY-PROB] n=525 pos=131 (24.95%)
# [TRAIN][DAILY-PROB] n=550 pos=138 (25.09%)
# [TRAIN][DAILY-PROB] n=575 pos=144 (25.04%)
# [TRAIN][DAILY-PROB] n=600 pos=149 (24.83%)
# [TRAIN][DAILY-PROB] n=625 pos=150 (24.00%)
# [TRAIN][DAILY-PROB] n=650 pos=152 (23.38%)
# [TRAIN][DAILY-PROB] n=675 pos=155 (22.96%)
# [TRAIN][DAILY-PROB] n=700 pos=156 (22.29%)
# [TRAIN][DAILY-PROB] n=725 pos=162 (22.34%)
# [TRAIN][DAILY-PROB] n=750 pos=163 (21.73%)
# [TRAIN][DAILY-PROB] n=775 pos=168 (21.68%)
# [TRAIN][DAILY-PROB] n=800 pos=173 (21.62%)
# [TRAIN][DAILY-PROB] n=825 pos=175 (21.21%)
# [TRAIN][DAILY-PROB] n=850 pos=181 (21.29%)
# [TRAIN][DAILY-PROB] n=875 pos=187 (21.37%)
# [TRAIN][DAILY-PROB] n=900 pos=191 (21.22%)
# [TRAIN][DAILY-PROB] n=925 pos=200 (21.62%)
# [TRAIN][DAILY-PROB] n=950 pos=203 (21.37%)
# [TRAIN][DAILY-PROB] n=975 pos=208 (21.33%)
# [TRAIN][DAILY-PROB] n=1000 pos=210 (21.00%)
# [TRAIN][DAILY-PROB] n=1025 pos=217 (21.17%)
# [TRAIN][DAILY-PROB] n=1050 pos=224 (21.33%)
# [TRAIN][DAILY-PROB] n=1075 pos=239 (22.23%)
# [TRAIN][DAILY-PROB] n=1100 pos=251 (22.82%)
# [TRAIN][DAILY-PROB] n=1125 pos=253 (22.49%)
# [TRAIN][DAILY-PROB] n=1150 pos=254 (22.09%)
# [TRAIN][DAILY-PROB] n=1175 pos=261 (22.21%)
# [TRAIN][DAILY-PROB] n=1200 pos=269 (22.42%)
# [TRAIN][DAILY-PROB] n=1225 pos=274 (22.37%)
# [TRAIN][DAILY-PROB] n=1250 pos=279 (22.32%)
# [TRAIN][DAILY-PROB] n=1275 pos=283 (22.20%)
# [TRAIN][DAILY-PROB] n=1300 pos=292 (22.46%)
# [TRAIN][DAILY-PROB] n=1325 pos=293 (22.11%)
# [TRAIN][DAILY-PROB] n=1350 pos=295 (21.85%)
# [TRAIN][DAILY-PROB] n=1375 pos=296 (21.53%)
# [TRAIN][DAILY-PROB] n=1400 pos=301 (21.50%)
# [TRAIN][DAILY-PROB] n=1425 pos=304 (21.33%)
# [TRAIN][DAILY-PROB] n=1450 pos=305 (21.03%)
# [TRAIN][DAILY-PROB] n=1475 pos=307 (20.81%)
# [TRAIN][DAILY-PROB] n=1500 pos=315 (21.00%)
# [TRAIN][DAILY-PROB] n=1525 pos=319 (20.92%)
# [TRAIN][DAILY-PROB] n=1550 pos=325 (20.97%)
# [TRAIN][DAILY-PROB] n=1575 pos=336 (21.33%)
# [TRAIN][DAILY-PROB] n=1600 pos=337 (21.06%)
# [TRAIN][DAILY-PROB] n=1625 pos=340 (20.92%)
# [TRAIN][DAILY-PROB] n=1650 pos=347 (21.03%)
# [TRAIN][DAILY-PROB] n=1675 pos=350 (20.90%)
# [TRAIN][DAILY-PROB] n=1700 pos=356 (20.94%)
# [TRAIN][DAILY-PROB] n=1725 pos=356 (20.64%)
# [TRAIN][DAILY-PROB] n=1750 pos=359 (20.51%)
# [TRAIN][DAILY-PROB] n=1775 pos=362 (20.39%)
# [TRAIN][DAILY-PROB] n=1800 pos=373 (20.72%)
# [TRAIN][DAILY-PROB] n=1825 pos=376 (20.60%)
# [TRAIN][DAILY-PROB] n=1850 pos=381 (20.59%)
# [TRAIN][DAILY-PROB] n=1875 pos=387 (20.64%)
# [TRAIN][DAILY-PROB] n=1900 pos=390 (20.53%)
# [TRAIN][DAILY-PROB] n=1925 pos=400 (20.78%)
# [TRAIN][DAILY-PROB] n=1950 pos=401 (20.56%)
# [TRAIN][DAILY-PROB] n=1975 pos=410 (20.76%)
# [TRAIN][DAILY-PROB] n=2000 pos=417 (20.85%)
# [TRAIN][DAILY-PROB] n=2025 pos=424 (20.94%)
# [TRAIN][DAILY-PROB] n=2050 pos=432 (21.07%)
# [TRAIN][DAILY-PROB] n=2075 pos=439 (21.16%)
# [TRAIN][DAILY-PROB] n=2100 pos=444 (21.14%)
# [TRAIN][DAILY-PROB] n=2125 pos=447 (21.04%)
# [TRAIN][DAILY-PROB] n=2150 pos=456 (21.21%)
# [TRAIN][DAILY-PROB] n=2175 pos=463 (21.29%)
# [TRAIN][DAILY-PROB] n=2200 pos=465 (21.14%)
# [TRAIN][DAILY-PROB] n=2225 pos=466 (20.94%)
# [TRAIN][DAILY-PROB] n=2250 pos=468 (20.80%)
# [TRAIN][DAILY-PROB] n=2275 pos=476 (20.92%)
# [TRAIN][DAILY-PROB] n=2300 pos=486 (21.13%)
# [TRAIN][DAILY-PROB] n=2325 pos=496 (21.33%)
# [TRAIN][DAILY-PROB] n=2350 pos=497 (21.15%)
# [TRAIN][DAILY-PROB] n=2375 pos=503 (21.18%)
# [TRAIN][DAILY-PROB] n=2400 pos=506 (21.08%)
# [TRAIN][DAILY-PROB] n=2425 pos=511 (21.07%)
# [TRAIN][DAILY-PROB] n=2450 pos=516 (21.06%)
# [TRAIN][DAILY-PROB] n=2475 pos=518 (20.93%)
# [TRAIN][DAILY-PROB] n=2500 pos=524 (20.96%)
# [TRAIN][DAILY-PROB] n=2525 pos=532 (21.07%)
# [TRAIN][DAILY-PROB] n=2550 pos=538 (21.10%)
# [TRAIN][DAILY-PROB] n=2575 pos=541 (21.01%)
# [TRAIN][DAILY-PROB] n=2600 pos=544 (20.92%)
# [TRAIN][DAILY-PROB] n=2625 pos=551 (20.99%)
# [TRAIN][DAILY-PROB] n=2650 pos=558 (21.06%)
# [TRAIN][DAILY-PROB] n=2675 pos=567 (21.20%)
# [TRAIN][DAILY-PROB] n=2700 pos=575 (21.30%)
# [TRAIN][DAILY-PROB] n=2725 pos=576 (21.14%)
# [TRAIN][DAILY-PROB] n=2750 pos=577 (20.98%)
# [TRAIN][DAILY-PROB] n=2775 pos=585 (21.08%)
# [TRAIN][DAILY-PROB] n=2800 pos=592 (21.14%)
# [TRAIN][DAILY-PROB] n=2825 pos=597 (21.13%)
# [TRAIN][DAILY-PROB] n=2850 pos=606 (21.26%)
# [TRAIN][DAILY-PROB] n=2875 pos=608 (21.15%)
# [TRAIN][DAILY-PROB] n=2900 pos=615 (21.21%)
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_macro_us2\daily_lr_feature_importance.csv
# [PHASE2/3] 5m feed begins at accumulation_start=2016-10-01, trading starts at sim_s=2019-01-01
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2016-10-07 19:50:00
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2016-10-14 19:55:00
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2016-10-21 19:55:00
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2016-10-28 19:55:00
# [TRAIN][5M] asof=2016-11-03 feats=69 buy=NO sell=YES rows=726
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2016-11-04 19:55:00
# [TRAIN][5M] asof=2016-11-08 feats=69 buy=YES sell=YES rows=816
# [TH-OPT][GLOBAL] asof_bar=3953 buy_th=1.70 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=4130 buy_th=2.50 sell_th=1.70
# [TH-OPT][GLOBAL] asof_bar=4304 buy_th=2.50 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=4471 buy_th=2.45 sell_th=1.70
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2016-11-11 19:55:00
# [TRAIN][5M] asof=2016-11-14 feats=69 buy=YES sell=YES rows=964
# [TH-OPT][GLOBAL] asof_bar=4630 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=4773 buy_th=2.40 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=4922 buy_th=2.00 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=5076 buy_th=1.65 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=5213 buy_th=1.85 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2016-11-18 19:55:00
# [TRAIN][5M] asof=2016-11-21 feats=69 buy=YES sell=YES rows=1137
# [TH-OPT][GLOBAL] asof_bar=5629 buy_th=1.60 sell_th=-0.50
# [TRAIN][5M] asof=2016-11-28 feats=69 buy=YES sell=YES rows=1246
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2016-11-28 19:55:00
# [TH-OPT][GLOBAL] asof_bar=5979 buy_th=1.60 sell_th=0.75
# [TH-OPT][GLOBAL] asof_bar=6128 buy_th=2.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=6280 buy_th=2.45 sell_th=-0.50
# [TRAIN][5M] asof=2016-12-05 feats=69 buy=YES sell=YES rows=1376
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2016-12-05 19:55:00
# [TH-OPT][GLOBAL] asof_bar=7106 buy_th=0.15 sell_th=-0.50
# [TRAIN][5M] asof=2016-12-12 feats=69 buy=YES sell=YES rows=1542
# [TH-OPT][GLOBAL] asof_bar=7260 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2016-12-12 19:55:00
# [TH-OPT][GLOBAL] asof_bar=7418 buy_th=0.25 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=7866 buy_th=0.35 sell_th=-0.50
# [TRAIN][5M] asof=2016-12-19 feats=69 buy=YES sell=YES rows=1646
# [TH-OPT][GLOBAL] asof_bar=7990 buy_th=0.80 sell_th=1.05
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2016-12-19 19:55:00
# [TH-OPT][GLOBAL] asof_bar=8110 buy_th=0.75 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=8228 buy_th=0.60 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=8362 buy_th=0.85 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=8484 buy_th=0.95 sell_th=1.00
# [TRAIN][5M] asof=2016-12-27 feats=69 buy=YES sell=YES rows=1835
# [TH-OPT][GLOBAL] asof_bar=8599 buy_th=0.85 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2016-12-27 19:15:00
# [TH-OPT][GLOBAL] asof_bar=8723 buy_th=1.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=8842 buy_th=1.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=8979 buy_th=2.05 sell_th=-0.50
# [TRAIN][5M] asof=2017-01-03 feats=69 buy=YES sell=YES rows=1925
# [TH-OPT][GLOBAL] asof_bar=9125 buy_th=1.85 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=9261 buy_th=-0.50 sell_th=1.60
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-01-04 19:55:00
# [TRAIN][5M] asof=2017-01-09 feats=69 buy=YES sell=YES rows=2026
# [TH-OPT][GLOBAL] asof_bar=9806 buy_th=-0.50 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=9943 buy_th=-0.50 sell_th=2.25
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-01-11 19:55:00
# [TRAIN][5M] asof=2017-01-17 feats=69 buy=YES sell=YES rows=2166
# [TH-OPT][GLOBAL] asof_bar=10367 buy_th=0.60 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=10511 buy_th=0.50 sell_th=0.70
# [TH-OPT][GLOBAL] asof_bar=10651 buy_th=0.50 sell_th=0.70
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-01-19 19:55:00
# [TH-OPT][GLOBAL] asof_bar=10799 buy_th=0.65 sell_th=0.80
# [TRAIN][5M] asof=2017-01-23 feats=69 buy=YES sell=YES rows=2301
# [TH-OPT][GLOBAL] asof_bar=10940 buy_th=0.80 sell_th=0.70
# [TH-OPT][GLOBAL] asof_bar=11091 buy_th=0.85 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=11393 buy_th=0.95 sell_th=0.65
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-01-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=11531 buy_th=0.90 sell_th=0.70
# [TRAIN][5M] asof=2017-01-30 feats=69 buy=YES sell=YES rows=2483
# [TH-OPT][GLOBAL] asof_bar=11834 buy_th=2.30 sell_th=0.15
# [TH-OPT][GLOBAL] asof_bar=11994 buy_th=2.30 sell_th=0.50
# [TH-OPT][GLOBAL] asof_bar=12144 buy_th=2.35 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-02-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=12279 buy_th=2.25 sell_th=0.30
# [TRAIN][5M] asof=2017-02-06 feats=69 buy=YES sell=YES rows=2633
# [TH-OPT][GLOBAL] asof_bar=12402 buy_th=0.50 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=12539 buy_th=0.35 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=12675 buy_th=0.40 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=12813 buy_th=0.45 sell_th=1.60
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-02-09 19:55:00
# [TRAIN][5M] asof=2017-02-13 feats=69 buy=YES sell=YES rows=2763
# [TH-OPT][GLOBAL] asof_bar=13226 buy_th=1.95 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=13385 buy_th=-0.50 sell_th=0.95
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-02-16 19:55:00
# [TRAIN][5M] asof=2017-02-21 feats=69 buy=YES sell=YES rows=2926
# [TH-OPT][GLOBAL] asof_bar=14250 buy_th=1.65 sell_th=0.30
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-02-24 19:55:00
# [TRAIN][5M] asof=2017-02-27 feats=69 buy=YES sell=YES rows=3052
# [TH-OPT][GLOBAL] asof_bar=14529 buy_th=1.55 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=14678 buy_th=1.55 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=14808 buy_th=1.65 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=14947 buy_th=1.65 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-03-03 19:55:00
# [TRAIN][5M] asof=2017-03-06 feats=69 buy=YES sell=YES rows=3187
# [TH-OPT][GLOBAL] asof_bar=15220 buy_th=0.80 sell_th=0.70
# [TH-OPT][GLOBAL] asof_bar=15358 buy_th=0.80 sell_th=0.70
# [TH-OPT][GLOBAL] asof_bar=15498 buy_th=0.80 sell_th=0.60
# [TH-OPT][GLOBAL] asof_bar=15642 buy_th=1.25 sell_th=0.75
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-03-10 19:55:00
# [TRAIN][5M] asof=2017-03-13 feats=69 buy=YES sell=YES rows=3334
# [TH-OPT][GLOBAL] asof_bar=15901 buy_th=0.65 sell_th=0.75
# [TH-OPT][GLOBAL] asof_bar=16036 buy_th=-0.50 sell_th=1.05
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-03-17 19:55:00
# [TRAIN][5M] asof=2017-03-20 feats=69 buy=YES sell=YES rows=3464
# [TH-OPT][GLOBAL] asof_bar=16582 buy_th=1.55 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=16749 buy_th=1.60 sell_th=0.35
# [TH-OPT][GLOBAL] asof_bar=16900 buy_th=1.20 sell_th=0.55
# [TH-OPT][GLOBAL] asof_bar=17043 buy_th=1.55 sell_th=0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-03-24 19:35:00
# [TRAIN][5M] asof=2017-03-27 feats=69 buy=YES sell=YES rows=3616
# [TH-OPT][GLOBAL] asof_bar=17204 buy_th=1.50 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=17356 buy_th=0.55 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=17506 buy_th=1.30 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=17785 buy_th=0.55 sell_th=2.00
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-03-31 19:55:00
# [TRAIN][5M] asof=2017-04-03 feats=69 buy=YES sell=YES rows=3777
# [TH-OPT][GLOBAL] asof_bar=18047 buy_th=0.90 sell_th=0.70
# [TH-OPT][GLOBAL] asof_bar=18202 buy_th=0.75 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=18492 buy_th=0.75 sell_th=0.65
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-04-07 19:55:00
# [TRAIN][5M] asof=2017-04-10 feats=69 buy=YES sell=YES rows=3936
# [TH-OPT][GLOBAL] asof_bar=18628 buy_th=0.90 sell_th=0.55
# [TH-OPT][GLOBAL] asof_bar=18768 buy_th=1.05 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=18907 buy_th=0.85 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=19042 buy_th=0.95 sell_th=-0.50
# [TRAIN][5M] asof=2017-04-17 feats=69 buy=YES sell=YES rows=4058
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-04-17 19:55:00
# [TH-OPT][GLOBAL] asof_bar=19321 buy_th=-0.50 sell_th=0.60
# [TH-OPT][GLOBAL] asof_bar=19471 buy_th=1.45 sell_th=1.50
# [TH-OPT][GLOBAL] asof_bar=19754 buy_th=0.55 sell_th=-0.50
# [TRAIN][5M] asof=2017-04-24 feats=69 buy=YES sell=YES rows=4227
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-04-24 19:55:00
# [TRAIN][5M] asof=2017-05-01 feats=69 buy=YES sell=YES rows=4344
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-05-01 19:55:00
# [TH-OPT][GLOBAL] asof_bar=20936 buy_th=2.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=21080 buy_th=2.35 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=21222 buy_th=2.40 sell_th=2.05
# [TRAIN][5M] asof=2017-05-08 feats=69 buy=YES sell=YES rows=4492
# [TH-OPT][GLOBAL] asof_bar=21362 buy_th=-0.50 sell_th=0.30
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-05-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=21508 buy_th=0.85 sell_th=-0.00
# [TH-OPT][GLOBAL] asof_bar=21633 buy_th=0.95 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=21765 buy_th=1.20 sell_th=1.70
# [TH-OPT][GLOBAL] asof_bar=21907 buy_th=0.95 sell_th=0.05
# [TRAIN][5M] asof=2017-05-15 feats=69 buy=YES sell=YES rows=4647
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-05-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=22370 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=22541 buy_th=1.70 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=22688 buy_th=1.75 sell_th=1.05
# [TRAIN][5M] asof=2017-05-22 feats=69 buy=YES sell=YES rows=4781
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-05-22 19:55:00
# [TH-OPT][GLOBAL] asof_bar=22987 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=23443 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2017-05-30 feats=69 buy=YES sell=YES rows=4957
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-05-30 19:35:00
# [TH-OPT][GLOBAL] asof_bar=23732 buy_th=1.85 sell_th=0.55
# [TH-OPT][GLOBAL] asof_bar=23871 buy_th=-0.50 sell_th=0.75
# [TRAIN][5M] asof=2017-06-05 feats=69 buy=YES sell=YES rows=5083
# [TH-OPT][GLOBAL] asof_bar=24165 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=24314 buy_th=1.70 sell_th=0.80
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-06-06 19:55:00
# [TH-OPT][GLOBAL] asof_bar=24458 buy_th=1.60 sell_th=0.65
# [TH-OPT][GLOBAL] asof_bar=24609 buy_th=1.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=24766 buy_th=1.80 sell_th=-0.50
# [TRAIN][5M] asof=2017-06-12 feats=69 buy=YES sell=YES rows=5241
# [TH-OPT][GLOBAL] asof_bar=24945 buy_th=1.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=25114 buy_th=1.70 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-06-13 19:55:00
# [TH-OPT][GLOBAL] asof_bar=25280 buy_th=1.85 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=25457 buy_th=1.85 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=25612 buy_th=1.70 sell_th=-0.50
# [TRAIN][5M] asof=2017-06-19 feats=69 buy=YES sell=YES rows=5413
# [TH-OPT][GLOBAL] asof_bar=25933 buy_th=1.95 sell_th=1.75
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-06-20 19:55:00
# [TH-OPT][GLOBAL] asof_bar=26107 buy_th=1.20 sell_th=1.50
# [TH-OPT][GLOBAL] asof_bar=26411 buy_th=1.40 sell_th=2.50
# [TRAIN][5M] asof=2017-06-26 feats=69 buy=YES sell=YES rows=5552
# [TH-OPT][GLOBAL] asof_bar=26573 buy_th=1.95 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=26758 buy_th=2.30 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-06-27 19:55:00
# [TH-OPT][GLOBAL] asof_bar=26934 buy_th=2.45 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=27112 buy_th=2.50 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=27275 buy_th=2.15 sell_th=0.70
# [TRAIN][5M] asof=2017-07-03 feats=69 buy=YES sell=YES rows=5719
# [TH-OPT][GLOBAL] asof_bar=27403 buy_th=2.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-07-05 19:55:00
# [TH-OPT][GLOBAL] asof_bar=27729 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=27879 buy_th=-0.50 sell_th=1.75
# [TRAIN][5M] asof=2017-07-10 feats=69 buy=YES sell=YES rows=5825
# [TH-OPT][GLOBAL] asof_bar=28034 buy_th=0.75 sell_th=2.20
# [TH-OPT][GLOBAL] asof_bar=28178 buy_th=0.30 sell_th=2.45
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-07-12 19:55:00
# [TH-OPT][GLOBAL] asof_bar=28491 buy_th=0.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=28631 buy_th=0.30 sell_th=-0.50
# [TRAIN][5M] asof=2017-07-17 feats=69 buy=YES sell=YES rows=5984
# [TH-OPT][GLOBAL] asof_bar=28948 buy_th=1.85 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=29095 buy_th=1.80 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-07-19 19:55:00
# [TRAIN][5M] asof=2017-07-24 feats=69 buy=YES sell=YES rows=6160
# [TH-OPT][GLOBAL] asof_bar=29549 buy_th=-0.50 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=29692 buy_th=-0.50 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=29854 buy_th=-0.50 sell_th=0.95
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-07-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=30011 buy_th=1.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=30174 buy_th=1.30 sell_th=0.75
# [TRAIN][5M] asof=2017-07-31 feats=69 buy=YES sell=YES rows=6302
# [TH-OPT][GLOBAL] asof_bar=30334 buy_th=1.55 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=30506 buy_th=-0.50 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=30665 buy_th=-0.50 sell_th=2.45
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-08-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=30808 buy_th=1.45 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=30943 buy_th=1.40 sell_th=-0.50
# [TRAIN][5M] asof=2017-08-07 feats=69 buy=YES sell=YES rows=6447
# [TH-OPT][GLOBAL] asof_bar=31416 buy_th=1.25 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-08-09 19:55:00
# [TH-OPT][GLOBAL] asof_bar=31597 buy_th=1.90 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=31762 buy_th=1.80 sell_th=0.55
# [TRAIN][5M] asof=2017-08-14 feats=69 buy=YES sell=YES rows=6621
# [TH-OPT][GLOBAL] asof_bar=32246 buy_th=1.05 sell_th=2.45
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-08-16 19:55:00
# [TH-OPT][GLOBAL] asof_bar=32409 buy_th=2.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=32578 buy_th=2.00 sell_th=1.50
# [TRAIN][5M] asof=2017-08-21 feats=69 buy=YES sell=YES rows=6786
# [TH-OPT][GLOBAL] asof_bar=32742 buy_th=2.10 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=32900 buy_th=2.00 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=33064 buy_th=-0.50 sell_th=0.85
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-08-23 19:55:00
# [TH-OPT][GLOBAL] asof_bar=33230 buy_th=1.25 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=33382 buy_th=1.35 sell_th=0.90
# [TRAIN][5M] asof=2017-08-28 feats=69 buy=YES sell=YES rows=7015
# [TH-OPT][GLOBAL] asof_bar=33553 buy_th=0.85 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=33721 buy_th=0.85 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=33872 buy_th=1.60 sell_th=2.30
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-08-30 19:55:00
# [TRAIN][5M] asof=2017-09-05 feats=69 buy=YES sell=YES rows=7159
# [TH-OPT][GLOBAL] asof_bar=34332 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=34488 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=34642 buy_th=2.20 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-09-07 19:55:00
# [TH-OPT][GLOBAL] asof_bar=34792 buy_th=-0.50 sell_th=2.30
# [TRAIN][5M] asof=2017-09-11 feats=69 buy=YES sell=YES rows=7282
# [TH-OPT][GLOBAL] asof_bar=35111 buy_th=0.80 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=35267 buy_th=0.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=35429 buy_th=0.85 sell_th=1.80
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-09-14 19:55:00
# [TH-OPT][GLOBAL] asof_bar=35575 buy_th=0.75 sell_th=2.40
# [TRAIN][5M] asof=2017-09-18 feats=69 buy=YES sell=YES rows=7404
# [TH-OPT][GLOBAL] asof_bar=35726 buy_th=1.40 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=35876 buy_th=0.95 sell_th=0.50
# [TH-OPT][GLOBAL] asof_bar=36018 buy_th=1.25 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=36161 buy_th=1.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-09-21 19:55:00
# [TH-OPT][GLOBAL] asof_bar=36314 buy_th=1.50 sell_th=1.20
# [TRAIN][5M] asof=2017-09-25 feats=69 buy=YES sell=YES rows=7521
# [TH-OPT][GLOBAL] asof_bar=36478 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=36630 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=36787 buy_th=-0.50 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=36927 buy_th=1.35 sell_th=1.35
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-09-28 19:55:00
# [TH-OPT][GLOBAL] asof_bar=37060 buy_th=0.90 sell_th=1.45
# [TRAIN][5M] asof=2017-10-02 feats=69 buy=YES sell=YES rows=7689
# [TH-OPT][GLOBAL] asof_bar=37342 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=37475 buy_th=1.00 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=37614 buy_th=1.05 sell_th=2.35
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-10-05 19:55:00
# [TRAIN][5M] asof=2017-10-09 feats=69 buy=YES sell=YES rows=7809
# [TH-OPT][GLOBAL] asof_bar=38017 buy_th=1.50 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=38158 buy_th=-0.50 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=38308 buy_th=1.35 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-10-12 19:55:00
# [TH-OPT][GLOBAL] asof_bar=38453 buy_th=1.60 sell_th=2.50
# [TRAIN][5M] asof=2017-10-16 feats=69 buy=YES sell=YES rows=7980
# [TH-OPT][GLOBAL] asof_bar=38729 buy_th=1.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=38876 buy_th=0.95 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=39053 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-10-19 19:55:00
# [TH-OPT][GLOBAL] asof_bar=39189 buy_th=1.05 sell_th=2.40
# [TRAIN][5M] asof=2017-10-23 feats=69 buy=YES sell=YES rows=8108
# [TH-OPT][GLOBAL] asof_bar=39332 buy_th=1.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=39483 buy_th=0.75 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=39633 buy_th=1.25 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=39801 buy_th=-0.50 sell_th=0.65
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-10-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=39975 buy_th=-0.50 sell_th=2.15
# [TRAIN][5M] asof=2017-10-30 feats=69 buy=YES sell=YES rows=8288
# [TH-OPT][GLOBAL] asof_bar=40122 buy_th=2.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=40272 buy_th=-0.50 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=40441 buy_th=2.25 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=40593 buy_th=2.45 sell_th=1.90
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-11-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=40732 buy_th=2.30 sell_th=2.35
# [TRAIN][5M] asof=2017-11-06 feats=69 buy=YES sell=YES rows=8418
# [TH-OPT][GLOBAL] asof_bar=41031 buy_th=1.40 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=41184 buy_th=1.20 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=41356 buy_th=1.25 sell_th=1.30
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-11-09 19:55:00
# [TH-OPT][GLOBAL] asof_bar=41512 buy_th=1.30 sell_th=0.95
# [TRAIN][5M] asof=2017-11-13 feats=69 buy=YES sell=YES rows=8649
# [TH-OPT][GLOBAL] asof_bar=41664 buy_th=1.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=41815 buy_th=1.20 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=41988 buy_th=1.55 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=42155 buy_th=1.30 sell_th=0.85
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-11-16 19:55:00
# [TRAIN][5M] asof=2017-11-20 feats=69 buy=YES sell=YES rows=8789
# [TH-OPT][GLOBAL] asof_bar=42595 buy_th=-0.50 sell_th=2.45
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-11-24 16:55:00
# [TRAIN][5M] asof=2017-11-27 feats=69 buy=YES sell=YES rows=8921
# [TH-OPT][GLOBAL] asof_bar=43320 buy_th=1.70 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=43488 buy_th=1.85 sell_th=1.85
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-12-01 19:55:00
# [TRAIN][5M] asof=2017-12-04 feats=69 buy=YES sell=YES rows=9025
# [TH-OPT][GLOBAL] asof_bar=43846 buy_th=2.05 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=44019 buy_th=1.85 sell_th=0.95
# [TH-OPT][GLOBAL] asof_bar=44192 buy_th=2.00 sell_th=0.15
# [TH-OPT][GLOBAL] asof_bar=44361 buy_th=1.35 sell_th=1.40
# [TH-OPT][GLOBAL] asof_bar=44527 buy_th=-0.50 sell_th=1.35
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-12-08 19:55:00
# [TRAIN][5M] asof=2017-12-11 feats=69 buy=YES sell=YES rows=9178
# [TH-OPT][GLOBAL] asof_bar=44691 buy_th=-0.50 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=44844 buy_th=0.45 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=44993 buy_th=0.60 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=45153 buy_th=0.55 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=45314 buy_th=0.75 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-12-15 19:55:00
# [TRAIN][5M] asof=2017-12-18 feats=69 buy=YES sell=YES rows=9378
# [TH-OPT][GLOBAL] asof_bar=45481 buy_th=1.45 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=45627 buy_th=1.70 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=45783 buy_th=1.50 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=45926 buy_th=1.20 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=46048 buy_th=1.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2017-12-22 19:55:00
# [TRAIN][5M] asof=2017-12-26 feats=69 buy=YES sell=YES rows=9528
# [TH-OPT][GLOBAL] asof_bar=46189 buy_th=1.80 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=46325 buy_th=1.65 sell_th=0.75
# [TH-OPT][GLOBAL] asof_bar=46477 buy_th=1.15 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=46632 buy_th=1.75 sell_th=-0.50
# [TRAIN][5M] asof=2018-01-02 feats=69 buy=YES sell=YES rows=9670
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-01-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=47297 buy_th=-0.50 sell_th=1.40
# [TRAIN][5M] asof=2018-01-08 feats=69 buy=YES sell=YES rows=9813
# [TH-OPT][GLOBAL] asof_bar=47620 buy_th=2.25 sell_th=0.35
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-01-09 19:55:00
# [TH-OPT][GLOBAL] asof_bar=47795 buy_th=-0.50 sell_th=0.20
# [TH-OPT][GLOBAL] asof_bar=47953 buy_th=2.50 sell_th=0.85
# [TRAIN][5M] asof=2018-01-16 feats=69 buy=YES sell=YES rows=9995
# [TH-OPT][GLOBAL] asof_bar=48308 buy_th=2.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=48493 buy_th=2.45 sell_th=1.20
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-01-17 19:55:00
# [TH-OPT][GLOBAL] asof_bar=48661 buy_th=2.10 sell_th=0.75
# [TH-OPT][GLOBAL] asof_bar=48831 buy_th=2.15 sell_th=0.65
# [TRAIN][5M] asof=2018-01-22 feats=69 buy=YES sell=YES rows=10173
# [TH-OPT][GLOBAL] asof_bar=49168 buy_th=1.20 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=49342 buy_th=1.95 sell_th=0.85
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-01-24 19:55:00
# [TH-OPT][GLOBAL] asof_bar=49512 buy_th=1.75 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=49674 buy_th=1.25 sell_th=1.25
# [TRAIN][5M] asof=2018-01-29 feats=69 buy=YES sell=YES rows=10412
# [TH-OPT][GLOBAL] asof_bar=49849 buy_th=1.30 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=50028 buy_th=1.45 sell_th=0.90
# [TH-OPT][GLOBAL] asof_bar=50209 buy_th=1.40 sell_th=1.15
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-01-31 19:55:00
# [TH-OPT][GLOBAL] asof_bar=50385 buy_th=1.20 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=50577 buy_th=1.65 sell_th=-0.50
# [TRAIN][5M] asof=2018-02-05 feats=69 buy=YES sell=YES rows=10648
# [TH-OPT][GLOBAL] asof_bar=50958 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=51148 buy_th=2.35 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-02-07 19:55:00
# [TH-OPT][GLOBAL] asof_bar=51335 buy_th=2.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=51513 buy_th=2.00 sell_th=-0.50
# [TRAIN][5M] asof=2018-02-12 feats=69 buy=YES sell=YES rows=10848
# [TH-OPT][GLOBAL] asof_bar=51700 buy_th=-0.50 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=51875 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=52061 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-02-14 19:55:00
# [TH-OPT][GLOBAL] asof_bar=52245 buy_th=1.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=52426 buy_th=0.95 sell_th=-0.50
# [TRAIN][5M] asof=2018-02-20 feats=69 buy=YES sell=YES rows=11033
# [TH-OPT][GLOBAL] asof_bar=52612 buy_th=-0.50 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=52796 buy_th=-0.50 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=52984 buy_th=-0.50 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-02-22 19:55:00
# [TH-OPT][GLOBAL] asof_bar=53168 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2018-02-26 feats=69 buy=YES sell=YES rows=11207
# [TH-OPT][GLOBAL] asof_bar=53522 buy_th=1.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=53703 buy_th=1.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-03-01 19:55:00
# [TH-OPT][GLOBAL] asof_bar=54071 buy_th=2.35 sell_th=2.50
# [TRAIN][5M] asof=2018-03-05 feats=69 buy=YES sell=YES rows=11359
# [TH-OPT][GLOBAL] asof_bar=54440 buy_th=1.85 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=54622 buy_th=1.90 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=54800 buy_th=0.80 sell_th=0.95
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-03-08 19:55:00
# [TRAIN][5M] asof=2018-03-12 feats=69 buy=YES sell=YES rows=11533
# [TH-OPT][GLOBAL] asof_bar=55166 buy_th=2.05 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=55348 buy_th=2.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=55530 buy_th=2.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=55706 buy_th=2.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-03-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=55881 buy_th=1.80 sell_th=-0.50
# [TRAIN][5M] asof=2018-03-19 feats=69 buy=YES sell=YES rows=11708
# [TH-OPT][GLOBAL] asof_bar=56073 buy_th=1.75 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=56256 buy_th=1.80 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=56430 buy_th=-0.50 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=56620 buy_th=-0.50 sell_th=1.15
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-03-22 19:55:00
# [TH-OPT][GLOBAL] asof_bar=56800 buy_th=-0.50 sell_th=1.05
# [TRAIN][5M] asof=2018-03-26 feats=69 buy=YES sell=YES rows=11943
# [TH-OPT][GLOBAL] asof_bar=56991 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=57180 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=57372 buy_th=2.05 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=57561 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-03-29 19:55:00
# [TRAIN][5M] asof=2018-04-02 feats=69 buy=YES sell=YES rows=12084
# [TH-OPT][GLOBAL] asof_bar=57744 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=57929 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=58121 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=58307 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=58484 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-04-06 19:55:00
# [TRAIN][5M] asof=2018-04-09 feats=69 buy=YES sell=YES rows=12332
# [TH-OPT][GLOBAL] asof_bar=58673 buy_th=2.50 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=58861 buy_th=1.65 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=59042 buy_th=1.90 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=59218 buy_th=2.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=59388 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-04-13 19:55:00
# [TRAIN][5M] asof=2018-04-16 feats=69 buy=YES sell=YES rows=12563
# [TH-OPT][GLOBAL] asof_bar=59562 buy_th=2.05 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=59744 buy_th=2.35 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=60092 buy_th=2.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=60269 buy_th=2.20 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-04-20 19:55:00
# [TRAIN][5M] asof=2018-04-23 feats=69 buy=YES sell=YES rows=12744
# [TH-OPT][GLOBAL] asof_bar=60448 buy_th=2.10 sell_th=1.05
# [TH-OPT][GLOBAL] asof_bar=60633 buy_th=2.15 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=60821 buy_th=-0.50 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=61010 buy_th=-0.50 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-04-27 19:55:00
# [TRAIN][5M] asof=2018-04-30 feats=69 buy=YES sell=YES rows=12934
# [TH-OPT][GLOBAL] asof_bar=61533 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=61711 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=61882 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=62053 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-05-04 19:55:00
# [TRAIN][5M] asof=2018-05-07 feats=69 buy=YES sell=YES rows=13101
# [TH-OPT][GLOBAL] asof_bar=62406 buy_th=1.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=62586 buy_th=0.95 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=62758 buy_th=1.15 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-05-11 19:55:00
# [TRAIN][5M] asof=2018-05-14 feats=69 buy=YES sell=YES rows=13273
# [TH-OPT][GLOBAL] asof_bar=63088 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=63256 buy_th=2.45 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=63424 buy_th=2.50 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=63595 buy_th=-0.50 sell_th=1.70
# [TH-OPT][GLOBAL] asof_bar=63754 buy_th=2.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-05-18 19:55:00
# [TRAIN][5M] asof=2018-05-21 feats=69 buy=YES sell=YES rows=13471
# [TH-OPT][GLOBAL] asof_bar=64091 buy_th=1.30 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=64274 buy_th=2.10 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=64443 buy_th=-0.50 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=64600 buy_th=1.40 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-05-25 19:55:00
# [TRAIN][5M] asof=2018-05-29 feats=69 buy=YES sell=YES rows=13661
# [TH-OPT][GLOBAL] asof_bar=64785 buy_th=-0.50 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=64958 buy_th=0.80 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=65283 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2018-06-04 feats=69 buy=YES sell=YES rows=13775
# [TH-OPT][GLOBAL] asof_bar=65461 buy_th=-0.50 sell_th=1.90
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-06-04 19:55:00
# [TH-OPT][GLOBAL] asof_bar=65641 buy_th=-0.50 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=65990 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=66157 buy_th=2.40 sell_th=-0.50
# [TRAIN][5M] asof=2018-06-11 feats=69 buy=YES sell=YES rows=13955
# [TH-OPT][GLOBAL] asof_bar=66323 buy_th=1.90 sell_th=2.30
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-06-11 19:55:00
# [TH-OPT][GLOBAL] asof_bar=66499 buy_th=2.00 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=66670 buy_th=1.70 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=66843 buy_th=-0.50 sell_th=1.50
# [TH-OPT][GLOBAL] asof_bar=67022 buy_th=1.95 sell_th=1.45
# [TRAIN][5M] asof=2018-06-18 feats=69 buy=YES sell=YES rows=14177
# [TH-OPT][GLOBAL] asof_bar=67202 buy_th=1.10 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-06-18 19:55:00
# [TH-OPT][GLOBAL] asof_bar=67387 buy_th=1.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=67745 buy_th=1.70 sell_th=0.55
# [TH-OPT][GLOBAL] asof_bar=67908 buy_th=1.55 sell_th=0.60
# [TRAIN][5M] asof=2018-06-25 feats=69 buy=YES sell=YES rows=14377
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-06-25 19:55:00
# [TH-OPT][GLOBAL] asof_bar=68276 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=68467 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=68651 buy_th=2.05 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=68828 buy_th=1.80 sell_th=-0.50
# [TRAIN][5M] asof=2018-07-02 feats=69 buy=YES sell=YES rows=14564
# [TH-OPT][GLOBAL] asof_bar=69010 buy_th=0.85 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-07-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=69149 buy_th=1.95 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=69332 buy_th=1.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=69504 buy_th=1.45 sell_th=-0.50
# [TRAIN][5M] asof=2018-07-09 feats=69 buy=YES sell=YES rows=14733
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-07-10 19:55:00
# [TRAIN][5M] asof=2018-07-16 feats=69 buy=YES sell=YES rows=14899
# [TH-OPT][GLOBAL] asof_bar=70563 buy_th=2.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=70737 buy_th=2.30 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-07-17 19:55:00
# [TH-OPT][GLOBAL] asof_bar=70918 buy_th=1.30 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=71102 buy_th=1.95 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=71269 buy_th=2.15 sell_th=1.80
# [TRAIN][5M] asof=2018-07-23 feats=69 buy=YES sell=YES rows=15030
# [TH-OPT][GLOBAL] asof_bar=71450 buy_th=1.75 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=71630 buy_th=1.75 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-07-24 19:55:00
# [TRAIN][5M] asof=2018-07-30 feats=69 buy=YES sell=YES rows=15166
# [TH-OPT][GLOBAL] asof_bar=72349 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=72534 buy_th=-0.50 sell_th=2.35
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-07-31 19:55:00
# [TH-OPT][GLOBAL] asof_bar=72714 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=72896 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=73054 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2018-08-06 feats=69 buy=YES sell=YES rows=15330
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-08-07 19:55:00
# [TH-OPT][GLOBAL] asof_bar=73560 buy_th=1.60 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=73741 buy_th=1.70 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=73912 buy_th=1.55 sell_th=2.30
# [TRAIN][5M] asof=2018-08-13 feats=69 buy=YES sell=YES rows=15490
# [TH-OPT][GLOBAL] asof_bar=74083 buy_th=0.75 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=74263 buy_th=-0.50 sell_th=2.20
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-08-14 19:55:00
# [TH-OPT][GLOBAL] asof_bar=74438 buy_th=1.20 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=74626 buy_th=1.95 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=74788 buy_th=1.85 sell_th=1.55
# [TRAIN][5M] asof=2018-08-20 feats=69 buy=YES sell=YES rows=15663
# [TH-OPT][GLOBAL] asof_bar=74954 buy_th=1.35 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=75134 buy_th=1.75 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-08-21 19:55:00
# [TH-OPT][GLOBAL] asof_bar=75314 buy_th=0.55 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=75471 buy_th=0.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=75626 buy_th=0.85 sell_th=-0.50
# [TRAIN][5M] asof=2018-08-27 feats=69 buy=YES sell=YES rows=15850
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-08-28 19:55:00
# [TH-OPT][GLOBAL] asof_bar=76326 buy_th=-0.50 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=76488 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2018-09-04 feats=69 buy=YES sell=YES rows=16039
# [TH-OPT][GLOBAL] asof_bar=76841 buy_th=2.35 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-09-05 19:55:00
# [TH-OPT][GLOBAL] asof_bar=77024 buy_th=2.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=77186 buy_th=2.40 sell_th=0.80
# [TRAIN][5M] asof=2018-09-10 feats=69 buy=YES sell=YES rows=16188
# [TH-OPT][GLOBAL] asof_bar=77554 buy_th=2.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=77730 buy_th=1.90 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-09-12 19:55:00
# [TH-OPT][GLOBAL] asof_bar=78057 buy_th=2.05 sell_th=-0.50
# [TRAIN][5M] asof=2018-09-17 feats=69 buy=YES sell=YES rows=16377
# [TH-OPT][GLOBAL] asof_bar=78418 buy_th=2.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=78583 buy_th=1.50 sell_th=1.95
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-09-19 19:55:00
# [TH-OPT][GLOBAL] asof_bar=78760 buy_th=1.35 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=78932 buy_th=2.05 sell_th=-0.50
# [TRAIN][5M] asof=2018-09-24 feats=69 buy=YES sell=YES rows=16549
# [TH-OPT][GLOBAL] asof_bar=79105 buy_th=1.80 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=79276 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=79459 buy_th=1.20 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-09-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=79633 buy_th=-0.50 sell_th=2.40
# [TRAIN][5M] asof=2018-10-01 feats=69 buy=YES sell=YES rows=16685
# [TH-OPT][GLOBAL] asof_bar=79963 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=80136 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=80300 buy_th=1.95 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-10-03 19:55:00
# [TH-OPT][GLOBAL] asof_bar=80483 buy_th=2.00 sell_th=0.80
# [TH-OPT][GLOBAL] asof_bar=80663 buy_th=2.20 sell_th=-0.50
# [TRAIN][5M] asof=2018-10-08 feats=69 buy=YES sell=YES rows=16884
# [TH-OPT][GLOBAL] asof_bar=80847 buy_th=2.05 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=81022 buy_th=1.75 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=81207 buy_th=2.45 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-10-10 19:55:00
# [TH-OPT][GLOBAL] asof_bar=81399 buy_th=2.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=81584 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2018-10-15 feats=69 buy=YES sell=YES rows=17046
# [TH-OPT][GLOBAL] asof_bar=81962 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-10-17 19:55:00
# [TH-OPT][GLOBAL] asof_bar=82337 buy_th=1.75 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=82515 buy_th=1.80 sell_th=-0.50
# [TRAIN][5M] asof=2018-10-22 feats=69 buy=YES sell=YES rows=17210
# [TH-OPT][GLOBAL] asof_bar=82699 buy_th=1.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=82891 buy_th=2.30 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=83082 buy_th=2.15 sell_th=2.30
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-10-24 19:55:00
# [TH-OPT][GLOBAL] asof_bar=83274 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=83465 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2018-10-29 feats=69 buy=YES sell=YES rows=17485
# [TH-OPT][GLOBAL] asof_bar=83656 buy_th=2.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=83848 buy_th=2.20 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=84038 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-10-31 19:55:00
# [TH-OPT][GLOBAL] asof_bar=84412 buy_th=2.05 sell_th=-0.50
# [TRAIN][5M] asof=2018-11-05 feats=69 buy=YES sell=YES rows=17707
# [TH-OPT][GLOBAL] asof_bar=84787 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=84979 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-11-07 19:55:00
# [TH-OPT][GLOBAL] asof_bar=85167 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=85355 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2018-11-12 feats=69 buy=YES sell=YES rows=17897
# [TH-OPT][GLOBAL] asof_bar=85731 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=85922 buy_th=-0.50 sell_th=2.10
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-11-14 19:55:00
# [TH-OPT][GLOBAL] asof_bar=86113 buy_th=-0.50 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=86295 buy_th=-0.50 sell_th=1.75
# [TRAIN][5M] asof=2018-11-19 feats=69 buy=YES sell=YES rows=18141
# [TH-OPT][GLOBAL] asof_bar=86487 buy_th=2.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=86679 buy_th=1.75 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=86863 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-11-21 19:55:00
# [TH-OPT][GLOBAL] asof_bar=87002 buy_th=2.45 sell_th=-0.50
# [TRAIN][5M] asof=2018-11-26 feats=69 buy=YES sell=YES rows=18301
# [TH-OPT][GLOBAL] asof_bar=87190 buy_th=0.70 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=87379 buy_th=1.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=87569 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=87760 buy_th=1.30 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-11-29 19:55:00
# [TH-OPT][GLOBAL] asof_bar=87940 buy_th=0.65 sell_th=-0.50
# [TRAIN][5M] asof=2018-12-03 feats=69 buy=YES sell=YES rows=18505
# [TH-OPT][GLOBAL] asof_bar=88131 buy_th=-0.50 sell_th=1.50
# [TH-OPT][GLOBAL] asof_bar=88320 buy_th=-0.50 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=88511 buy_th=-0.50 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=88692 buy_th=-0.50 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-12-07 19:55:00
# [TRAIN][5M] asof=2018-12-10 feats=69 buy=YES sell=YES rows=18674
# [TH-OPT][GLOBAL] asof_bar=88880 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=89071 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=89260 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=89445 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=89635 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-12-14 19:55:00
# [TRAIN][5M] asof=2018-12-17 feats=69 buy=YES sell=YES rows=18879
# [TH-OPT][GLOBAL] asof_bar=90016 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=90205 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=90397 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=90586 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-12-21 19:55:00
# [TRAIN][5M] asof=2018-12-24 feats=69 buy=YES sell=YES rows=19034
# [TH-OPT][GLOBAL] asof_bar=90735 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=91118 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=91299 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2018-12-31 feats=69 buy=YES sell=YES rows=19154
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2018-12-31 19:55:00
# [TH-OPT][GLOBAL] asof_bar=91669 buy_th=-0.50 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=91861 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=92047 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2019-01-07 feats=69 buy=YES sell=YES rows=19339
# [TH-OPT][GLOBAL] asof_bar=92233 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=92418 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2019-01-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=92609 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=92797 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=92974 buy_th=2.45 sell_th=-0.50
# [TRAIN][5M] asof=2019-01-14 feats=69 buy=YES sell=YES rows=19492
# [TH-OPT][GLOBAL] asof_bar=93160 buy_th=1.25 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=93347 buy_th=1.55 sell_th=2.20
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2019-01-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=93532 buy_th=1.25 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=93716 buy_th=1.15 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=93905 buy_th=1.65 sell_th=2.50
# [TRAIN][5M] asof=2019-01-22 feats=69 buy=YES sell=YES rows=19658
# [TH-OPT][GLOBAL] asof_bar=94278 buy_th=2.30 sell_th=1.90
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2019-01-23 19:55:00
# [TH-OPT][GLOBAL] asof_bar=94465 buy_th=2.40 sell_th=1.85
# [TRAIN][5M] asof=2019-01-28 feats=69 buy=YES sell=YES rows=19782
# [TH-OPT][GLOBAL] asof_bar=94831 buy_th=2.35 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=95020 buy_th=2.50 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=95211 buy_th=1.90 sell_th=2.35
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2019-01-30 19:55:00
# [TH-OPT][GLOBAL] asof_bar=95399 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=95579 buy_th=1.35 sell_th=-0.50
# ...
# [TH-OPT][GLOBAL] asof_bar=396025 buy_th=1.70 sell_th=2.20
# [TRAIN][5M] asof=2025-06-09 feats=69 buy=YES sell=YES rows=80250
# [TH-OPT][GLOBAL] asof_bar=396217 buy_th=1.75 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=396408 buy_th=1.30 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=396598 buy_th=0.90 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-06-11 19:55:00
# [TH-OPT][GLOBAL] asof_bar=396789 buy_th=2.05 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=396978 buy_th=1.95 sell_th=-0.50
# [TRAIN][5M] asof=2025-06-16 feats=69 buy=YES sell=YES rows=80369
# [TH-OPT][GLOBAL] asof_bar=397170 buy_th=2.15 sell_th=1.50
# [TH-OPT][GLOBAL] asof_bar=397362 buy_th=1.25 sell_th=1.25
# [TH-OPT][GLOBAL] asof_bar=397554 buy_th=1.05 sell_th=2.10
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-06-18 19:55:00
# [TRAIN][5M] asof=2025-06-23 feats=69 buy=YES sell=YES rows=80511
# [TH-OPT][GLOBAL] asof_bar=397938 buy_th=-0.50 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=398130 buy_th=-0.50 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=398322 buy_th=-0.50 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=398514 buy_th=0.65 sell_th=2.40
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-06-26 19:55:00
# [TH-OPT][GLOBAL] asof_bar=398706 buy_th=0.85 sell_th=2.25
# [TRAIN][5M] asof=2025-06-30 feats=69 buy=YES sell=YES rows=80658
# [TH-OPT][GLOBAL] asof_bar=399087 buy_th=1.70 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=399278 buy_th=1.45 sell_th=1.75
# [TH-OPT][GLOBAL] asof_bar=399433 buy_th=-0.50 sell_th=2.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-07-03 16:55:00
# [TRAIN][5M] asof=2025-07-07 feats=69 buy=YES sell=YES rows=80816
# [TH-OPT][GLOBAL] asof_bar=399625 buy_th=1.75 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=399816 buy_th=1.65 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=400007 buy_th=1.50 sell_th=0.85
# [TH-OPT][GLOBAL] asof_bar=400198 buy_th=1.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=400386 buy_th=2.15 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-07-11 19:55:00
# [TRAIN][5M] asof=2025-07-14 feats=69 buy=YES sell=YES rows=80982
# [TH-OPT][GLOBAL] asof_bar=400578 buy_th=2.05 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=400770 buy_th=1.40 sell_th=0.70
# [TH-OPT][GLOBAL] asof_bar=400962 buy_th=1.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=401153 buy_th=-0.50 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=401340 buy_th=1.65 sell_th=1.20
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-07-18 19:55:00
# [TRAIN][5M] asof=2025-07-21 feats=69 buy=YES sell=YES rows=81194
# [TH-OPT][GLOBAL] asof_bar=401532 buy_th=1.50 sell_th=1.20
# [TH-OPT][GLOBAL] asof_bar=401724 buy_th=2.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=401916 buy_th=1.55 sell_th=1.80
# [TH-OPT][GLOBAL] asof_bar=402107 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=402294 buy_th=1.20 sell_th=0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-07-25 19:55:00
# [TRAIN][5M] asof=2025-07-28 feats=69 buy=YES sell=YES rows=81404
# [TH-OPT][GLOBAL] asof_bar=402676 buy_th=1.15 sell_th=1.10
# [TH-OPT][GLOBAL] asof_bar=403060 buy_th=2.30 sell_th=1.40
# [TH-OPT][GLOBAL] asof_bar=403251 buy_th=2.40 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-08-01 19:55:00
# [TRAIN][5M] asof=2025-08-04 feats=69 buy=YES sell=YES rows=81592
# [TH-OPT][GLOBAL] asof_bar=403827 buy_th=1.80 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=404019 buy_th=1.55 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=404208 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-08-08 19:55:00
# [TRAIN][5M] asof=2025-08-11 feats=69 buy=YES sell=YES rows=81766
# [TH-OPT][GLOBAL] asof_bar=404400 buy_th=1.95 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=404592 buy_th=-0.50 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=404784 buy_th=1.95 sell_th=1.50
# [TH-OPT][GLOBAL] asof_bar=404975 buy_th=-0.50 sell_th=1.25
# [TH-OPT][GLOBAL] asof_bar=405164 buy_th=1.55 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-08-15 19:55:00
# [TRAIN][5M] asof=2025-08-18 feats=69 buy=YES sell=YES rows=81920
# [TH-OPT][GLOBAL] asof_bar=405356 buy_th=1.80 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=405547 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=405739 buy_th=2.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=405931 buy_th=1.40 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=406122 buy_th=1.30 sell_th=2.05
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-08-22 19:55:00
# [TRAIN][5M] asof=2025-08-25 feats=69 buy=YES sell=YES rows=82105
# [TH-OPT][GLOBAL] asof_bar=406313 buy_th=1.60 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=406505 buy_th=-0.50 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=406697 buy_th=-0.50 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=407079 buy_th=1.10 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-08-29 19:55:00
# [TRAIN][5M] asof=2025-09-02 feats=69 buy=YES sell=YES rows=82262
# [TH-OPT][GLOBAL] asof_bar=407463 buy_th=1.60 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=407655 buy_th=1.45 sell_th=1.80
# [TRAIN][5M] asof=2025-09-08 feats=69 buy=YES sell=YES rows=82400
# [TH-OPT][GLOBAL] asof_bar=408037 buy_th=1.35 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-09-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=408229 buy_th=-0.50 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=408421 buy_th=1.35 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=408613 buy_th=1.35 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=408804 buy_th=1.05 sell_th=2.15
# [TRAIN][5M] asof=2025-09-15 feats=69 buy=YES sell=YES rows=82552
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-09-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=409185 buy_th=1.50 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=409376 buy_th=1.70 sell_th=2.20
# [TH-OPT][GLOBAL] asof_bar=409567 buy_th=1.45 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=409756 buy_th=0.90 sell_th=1.80
# [TRAIN][5M] asof=2025-09-22 feats=69 buy=YES sell=YES rows=82779
# [TH-OPT][GLOBAL] asof_bar=409947 buy_th=-0.50 sell_th=2.15
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-09-22 19:55:00
# [TH-OPT][GLOBAL] asof_bar=410139 buy_th=-0.50 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=410330 buy_th=1.70 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=410522 buy_th=2.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=410706 buy_th=1.95 sell_th=2.00
# [TRAIN][5M] asof=2025-09-29 feats=69 buy=YES sell=YES rows=82969
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-09-29 19:55:00
# [TH-OPT][GLOBAL] asof_bar=411089 buy_th=1.10 sell_th=0.70
# [TH-OPT][GLOBAL] asof_bar=411280 buy_th=1.20 sell_th=0.75
# [TH-OPT][GLOBAL] asof_bar=411661 buy_th=-0.50 sell_th=1.25
# [TRAIN][5M] asof=2025-10-06 feats=69 buy=YES sell=YES rows=83195
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-10-06 19:55:00
# [TH-OPT][GLOBAL] asof_bar=412045 buy_th=1.35 sell_th=2.15
# [TH-OPT][GLOBAL] asof_bar=412237 buy_th=1.25 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=412429 buy_th=1.40 sell_th=1.90
# [TH-OPT][GLOBAL] asof_bar=412621 buy_th=2.05 sell_th=1.50
# [TRAIN][5M] asof=2025-10-13 feats=69 buy=YES sell=YES rows=83391
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-10-13 19:55:00
# [TH-OPT][GLOBAL] asof_bar=413005 buy_th=-0.50 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=413197 buy_th=2.05 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=413389 buy_th=1.60 sell_th=1.95
# [TH-OPT][GLOBAL] asof_bar=413580 buy_th=1.80 sell_th=0.95
# [TRAIN][5M] asof=2025-10-20 feats=69 buy=YES sell=YES rows=83607
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-10-20 19:55:00
# [TH-OPT][GLOBAL] asof_bar=413963 buy_th=1.15 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=414155 buy_th=2.35 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=414347 buy_th=1.50 sell_th=2.35
# [TH-OPT][GLOBAL] asof_bar=414537 buy_th=-0.50 sell_th=-0.50
# [TRAIN][5M] asof=2025-10-27 feats=69 buy=YES sell=YES rows=83809
# [TH-OPT][GLOBAL] asof_bar=414729 buy_th=-0.50 sell_th=1.65
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-10-27 19:55:00
# [TH-OPT][GLOBAL] asof_bar=414921 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=415113 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=415305 buy_th=-0.50 sell_th=2.20
# [TH-OPT][GLOBAL] asof_bar=415494 buy_th=2.45 sell_th=2.40
# [TRAIN][5M] asof=2025-11-03 feats=69 buy=YES sell=YES rows=84024
# [TH-OPT][GLOBAL] asof_bar=415686 buy_th=1.90 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-11-03 19:55:00
# [TH-OPT][GLOBAL] asof_bar=415878 buy_th=2.35 sell_th=1.00
# [TH-OPT][GLOBAL] asof_bar=416070 buy_th=2.15 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=416262 buy_th=2.20 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=416454 buy_th=2.45 sell_th=1.70
# [TRAIN][5M] asof=2025-11-10 feats=69 buy=YES sell=YES rows=84271
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-11-10 19:55:00
# [TH-OPT][GLOBAL] asof_bar=416838 buy_th=-0.50 sell_th=2.30
# [TH-OPT][GLOBAL] asof_bar=417030 buy_th=1.60 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=417222 buy_th=1.40 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=417414 buy_th=2.25 sell_th=-0.50
# [TRAIN][5M] asof=2025-11-17 feats=69 buy=YES sell=YES rows=84479
# [TH-OPT][GLOBAL] asof_bar=417606 buy_th=2.35 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-11-17 19:55:00
# [TH-OPT][GLOBAL] asof_bar=417798 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=417990 buy_th=2.35 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=418182 buy_th=-0.50 sell_th=1.35
# [TH-OPT][GLOBAL] asof_bar=418374 buy_th=2.35 sell_th=1.20
# [TRAIN][5M] asof=2025-11-24 feats=69 buy=YES sell=YES rows=84712
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-11-24 19:55:00
# [TH-OPT][GLOBAL] asof_bar=418758 buy_th=1.40 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=418950 buy_th=1.40 sell_th=-0.50
# [TRAIN][5M] asof=2025-12-01 feats=69 buy=YES sell=YES rows=84829
# [TH-OPT][GLOBAL] asof_bar=419298 buy_th=1.95 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=419490 buy_th=1.90 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-12-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=419682 buy_th=1.05 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=419874 buy_th=1.10 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=420066 buy_th=1.50 sell_th=-0.50
# [TRAIN][5M] asof=2025-12-08 feats=69 buy=YES sell=YES rows=85021
# [TH-OPT][GLOBAL] asof_bar=420450 buy_th=-0.50 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-12-09 19:55:00
# [TH-OPT][GLOBAL] asof_bar=420642 buy_th=1.65 sell_th=2.00
# [TH-OPT][GLOBAL] asof_bar=420834 buy_th=1.60 sell_th=0.55
# [TH-OPT][GLOBAL] asof_bar=421026 buy_th=2.35 sell_th=1.30
# [TRAIN][5M] asof=2025-12-15 feats=69 buy=YES sell=YES rows=85230
# [TH-OPT][GLOBAL] asof_bar=421218 buy_th=2.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=421410 buy_th=2.00 sell_th=1.75
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-12-16 19:55:00
# [TH-OPT][GLOBAL] asof_bar=421602 buy_th=1.65 sell_th=1.70
# [TH-OPT][GLOBAL] asof_bar=421794 buy_th=1.85 sell_th=1.55
# [TRAIN][5M] asof=2025-12-22 feats=69 buy=YES sell=YES rows=85420
# [TH-OPT][GLOBAL] asof_bar=422370 buy_th=0.85 sell_th=2.40
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-12-23 19:55:00
# [TRAIN][5M] asof=2025-12-29 feats=69 buy=YES sell=YES rows=85534
# [TH-OPT][GLOBAL] asof_bar=423097 buy_th=1.10 sell_th=1.40
# [TH-OPT][GLOBAL] asof_bar=423289 buy_th=1.15 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2025-12-31 19:55:00
# [TH-OPT][GLOBAL] asof_bar=423481 buy_th=1.40 sell_th=-0.50
# [TRAIN][5M] asof=2026-01-05 feats=69 buy=YES sell=YES rows=85649
# [TH-OPT][GLOBAL] asof_bar=423673 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=423865 buy_th=0.75 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=424057 buy_th=1.60 sell_th=2.05
# [TH-OPT][GLOBAL] asof_bar=424249 buy_th=1.05 sell_th=1.10
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2026-01-08 19:55:00
# [TH-OPT][GLOBAL] asof_bar=424440 buy_th=1.40 sell_th=2.45
# [TRAIN][5M] asof=2026-01-12 feats=69 buy=YES sell=YES rows=85871
# [TH-OPT][GLOBAL] asof_bar=424632 buy_th=-0.50 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=424824 buy_th=-0.50 sell_th=1.85
# [TH-OPT][GLOBAL] asof_bar=425016 buy_th=1.35 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=425208 buy_th=2.30 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2026-01-15 19:55:00
# [TH-OPT][GLOBAL] asof_bar=425400 buy_th=1.60 sell_th=-0.50
# [TRAIN][5M] asof=2026-01-20 feats=69 buy=YES sell=YES rows=86035
# [TH-OPT][GLOBAL] asof_bar=425784 buy_th=1.45 sell_th=1.65
# [TH-OPT][GLOBAL] asof_bar=425976 buy_th=1.40 sell_th=1.25
# [TH-OPT][GLOBAL] asof_bar=426167 buy_th=1.85 sell_th=1.65
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2026-01-23 19:55:00
# [TRAIN][5M] asof=2026-01-26 feats=69 buy=YES sell=YES rows=86221
# [TH-OPT][GLOBAL] asof_bar=426359 buy_th=1.95 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=426551 buy_th=0.95 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=426743 buy_th=-0.50 sell_th=2.45
# [TH-OPT][GLOBAL] asof_bar=426935 buy_th=2.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=427127 buy_th=2.15 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2026-01-30 19:55:00
# [TRAIN][5M] asof=2026-02-02 feats=69 buy=YES sell=YES rows=86448
# [TH-OPT][GLOBAL] asof_bar=427319 buy_th=1.30 sell_th=2.50
# [TH-OPT][GLOBAL] asof_bar=427511 buy_th=2.45 sell_th=2.40
# [TH-OPT][GLOBAL] asof_bar=427703 buy_th=2.35 sell_th=1.70
# [TH-OPT][GLOBAL] asof_bar=427895 buy_th=2.15 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=428087 buy_th=-0.50 sell_th=1.80
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2026-02-06 19:55:00
# [TRAIN][5M] asof=2026-02-09 feats=69 buy=YES sell=YES rows=86679
# [TH-OPT][GLOBAL] asof_bar=428279 buy_th=1.75 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=428471 buy_th=1.75 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=428663 buy_th=1.65 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=428855 buy_th=2.45 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=429047 buy_th=2.35 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2026-02-13 19:55:00
# [TRAIN][5M] asof=2026-02-17 feats=69 buy=YES sell=YES rows=86883
# [TH-OPT][GLOBAL] asof_bar=429239 buy_th=2.45 sell_th=1.15
# [TH-OPT][GLOBAL] asof_bar=429431 buy_th=2.00 sell_th=1.55
# [TH-OPT][GLOBAL] asof_bar=429623 buy_th=2.20 sell_th=1.30
# [TH-OPT][GLOBAL] asof_bar=429815 buy_th=2.00 sell_th=1.00
# [TRAIN][5M] asof=2026-02-23 feats=69 buy=YES sell=YES rows=87023
# [TH-OPT][GLOBAL] asof_bar=430007 buy_th=2.35 sell_th=-0.50
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2026-02-23 19:55:00
# [TH-OPT][GLOBAL] asof_bar=430199 buy_th=2.15 sell_th=1.60
# [TH-OPT][GLOBAL] asof_bar=430391 buy_th=1.65 sell_th=1.45
# [TH-OPT][GLOBAL] asof_bar=430583 buy_th=2.00 sell_th=-0.50
# [TH-OPT][GLOBAL] asof_bar=430775 buy_th=2.00 sell_th=1.30
# [TRAIN][5M] asof=2026-03-02 feats=69 buy=YES sell=YES rows=87230
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2026-03-02 19:55:00
# [TH-OPT][GLOBAL] asof_bar=431351 buy_th=1.95 sell_th=2.25
# [TH-OPT][GLOBAL] asof_bar=431543 buy_th=1.10 sell_th=2.10
# [TH-OPT][GLOBAL] asof_bar=431735 buy_th=2.50 sell_th=1.15
# [TRAIN][5M] asof=2026-03-09 feats=69 buy=YES sell=YES rows=87423
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2026-03-09 19:55:00
# [CHECKPOINT] saved -> checkpoints/QQQ_macro_US2_checkpoint.joblib @ 2026-03-10 19:55:00
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_macro_us2\trades.csv
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_macro_us2\daily_log.csv
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_macro_us2\equity_vs_buyhold.png
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_macro_us2\price_with_trades.png
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_macro_us2\p_day.png
# [SAVED] output_dailyprob_gated_5m_xgb_QQQ_macro_us2\daily_lr_feature_importance.csv
# [TRADES] total=3616
# [TRADES] first_trade_ts=2019-01-02 04:00:00 (sim_start=2019-01-01 00:00:00)
