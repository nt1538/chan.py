# %%
from adaptive_reward_checkpoint_fresh import run_adaptive_reward_yfinance_range_backtest

res = run_adaptive_reward_yfinance_range_backtest(
    checkpoint_path="output_adaptive_reward_resumed_fresh_TQQQ_252days_at_2020/final_checkpoint.joblib",
    start_date="2026-06-01",
    end_date="2026-06-05",
    output_dir="output_adaptive_reward_range_backtest",
    daily_threshold_lookback_days_override=252,
    refresh_data=True,
    verbose=True,
)
# Out:
# [RANGE BACKTEST] start=2026-06-01 09:30:00 close=2026-06-05 16:00:00 checkpoint=output_adaptive_reward_resumed_fresh_TQQQ_252days_at_2020/final_checkpoint.joblib
# [TRAIN][5M] asof=2026-05-26 feats=69 buy=YES sell=YES rows=121233
# [TRAIN][5M] asof=2026-06-01 feats=69 buy=YES sell=YES rows=121287
# [SAVED] output_adaptive_reward_range_backtest\TQQQ_range_20260601_20260605\trades.csv
# [SAVED] output_adaptive_reward_range_backtest\TQQQ_range_20260601_20260605\signal_decisions.csv
# [SAVED] output_adaptive_reward_range_backtest\TQQQ_range_20260601_20260605\daily_log.csv
# [SAVED] output_adaptive_reward_range_backtest\TQQQ_range_20260601_20260605\daily_reward_log.csv
# [SAVED] output_adaptive_reward_range_backtest\TQQQ_range_20260601_20260605\equity_vs_buyhold.png
# [SAVED] output_adaptive_reward_range_backtest\TQQQ_range_20260601_20260605\price_with_trades.png
# [SAVED] output_adaptive_reward_range_backtest\TQQQ_range_20260601_20260605\price_with_signals.png
# ...
