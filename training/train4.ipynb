# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
from pathlib import Path
import warnings
from datetime import datetime, timedelta
from tqdm import tqdm
import time
import os

# Suppress warnings
warnings.filterwarnings('ignore')

def run_daily_rolling_window_backtest(
    data_path,
    output_dir="./output/daily_rolling_backtest",
    training_window_days=30,
    rolling_period_days=14,
    start_date=None,
    position_size=1.0,
    initial_capital=10000,
    model_params=None
):
    """
    Run a daily rolling window backtest.
    
    Args:
        data_path: Path to the dataset CSV file
        output_dir: Directory to save output files
        training_window_days: Number of days to use for training (default: 30 days)
        rolling_period_days: Number of days to roll forward (default: 14 days)
        start_date: Starting date for backtest (format: "YYYY-MM-DD"), if None will use earliest possible
        position_size: Portion of capital to use per trade (default: 100%)
        initial_capital: Initial capital for backtest (default: $10,000)
        model_params: Dictionary of XGBoost model parameters (will use defaults if None)
    
    Returns:
        DataFrame of daily returns and performance metrics
    """
    # Create output directory
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    
    # Default model parameters
    if model_params is None:
        model_params = {
            'max_depth': 6,
            'learning_rate': 0.1,
            'n_estimators': 100,
            'random_state': 42
        }
    
    print("=" * 80)
    print("Daily Rolling Window Backtesting")
    print("=" * 80)
    print(f"Training window: {training_window_days} days")
    print(f"Rolling period: {rolling_period_days} days")
    print(f"Start date: {start_date if start_date else 'Earliest possible'}")
    print(f"Position size: {position_size * 100}%")
    print(f"Initial capital: ${initial_capital}")
    print("=" * 80)
    
    # Load dataset
    print("\n[1/5] Loading dataset...")
    df = pd.read_csv(data_path)
    print(f"Data shape: {df.shape}")
    
    # Convert timestamp to datetime
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    print(f"Full dataset date range: {df['timestamp'].min()} to {df['timestamp'].max()}")
    
    # Identify unique dates in the dataset
    df['date'] = df['timestamp'].dt.date
    unique_dates = df['date'].unique()
    unique_dates = np.sort(unique_dates)  # Sort dates chronologically
    print(f"Number of unique trading days: {len(unique_dates)}")
    
    # Set start date index
    if start_date:
        start_date = pd.to_datetime(start_date).date()
        if start_date in unique_dates:
            start_idx = np.where(unique_dates == start_date)[0][0]
        else:
            # Find the closest date after the specified start date
            valid_dates = unique_dates[unique_dates >= start_date]
            if len(valid_dates) > 0:
                start_idx = np.where(unique_dates == valid_dates[0])[0][0]
            else:
                raise ValueError(f"No valid dates found after specified start date: {start_date}")
    else:
        # Find a good starting point with enough data for the initial window
        start_idx = 0
    
    # Ensure we have enough data for our analysis
    required_days = training_window_days + 2 + rolling_period_days  # training + threshold + test + rolling days
    if start_idx + required_days > len(unique_dates):
        raise ValueError(f"Not enough trading days in dataset. Need at least {required_days} days after start date.")
    
    # Define the dates for the entire backtest period
    backtest_dates = unique_dates[start_idx:start_idx + training_window_days + 2 + rolling_period_days]
    print(f"Backtest period: {backtest_dates[0]} to {backtest_dates[-1]}")
    
    # Identify feature columns
    print("\n[2/5] Identifying feature columns...")
    
    # Exclude metadata and target columns
    exclude_patterns = ['timestamp', 'bsp_type', 'direction', 'profit_target', 
                       'has_profit', 'return_', 'label_', 'target_return_', 
                       'snapshot_', 'klu_idx', 'exit_', 'date']
    
    # Filter to feature columns only
    feature_cols = [col for col in df.columns 
                    if not any(pat in col for pat in exclude_patterns)]
    
    # Remove encoded columns if original exists
    if 'direction' in feature_cols and 'direction_encoded' in feature_cols:
        feature_cols.remove('direction')
    if 'bsp_type' in feature_cols and 'bsp_type_encoded' in feature_cols:
        feature_cols.remove('bsp_type')
    
    feature_cols = sorted(feature_cols)
    print(f"Features identified: {len(feature_cols)}")
    
    # Helper function to calculate metrics
    def calculate_metrics(y_true, y_pred):
        mse = mean_squared_error(y_true, y_pred)
        rmse = np.sqrt(mse)
        mae = mean_absolute_error(y_true, y_pred)
        r2 = r2_score(y_true, y_pred) if len(np.unique(y_true)) > 1 else 0
        
        # Calculate accuracy (correct direction prediction)
        correct_direction = np.mean((y_true > 0) == (y_pred > 0)) * 100
        
        return {
            'MSE': mse,
            'RMSE': rmse,
            'MAE': mae,
            'R2': r2,
            'Accuracy': correct_direction
        }
    
    # Function to optimize thresholds using grid search
    def optimize_thresholds(signals_df):
        """Find optimal buy/sell thresholds for signal data"""
        if len(signals_df) == 0:
            return 0.0, 0.0  # Default thresholds if no signals
        
        # Define threshold ranges
        thresholds = np.linspace(-0.5, 2.0, 26)  # -0.5% to 2.0% in 0.25% steps
        
        best_return = -float('inf')
        best_buy_threshold = 0.0
        best_sell_threshold = 0.0
        
        # Simple grid search
        for buy_threshold in thresholds:
            for sell_threshold in thresholds:
                # Simulate trading with these thresholds
                buy_signals = signals_df[signals_df['direction'] == 'buy']
                sell_signals = signals_df[signals_df['direction'] == 'sell']
                
                # Filter signals based on thresholds
                valid_buys = buy_signals[buy_signals['predicted_profit_pct'] >= buy_threshold]
                valid_sells = sell_signals[sell_signals['predicted_profit_pct'] >= sell_threshold]
                
                # Calculate a score (e.g., average profit of valid signals)
                buy_score = valid_buys['profit_target_pct'].mean() if len(valid_buys) > 0 else 0
                sell_score = valid_sells['profit_target_pct'].mean() if len(valid_sells) > 0 else 0
                
                # Combined score weighted by signal counts
                combined_score = (len(valid_buys) * buy_score + len(valid_sells) * sell_score) / (len(valid_buys) + len(valid_sells)) if (len(valid_buys) + len(valid_sells)) > 0 else 0
                
                # Update best thresholds if better
                if combined_score > best_return:
                    best_return = combined_score
                    best_buy_threshold = buy_threshold
                    best_sell_threshold = sell_threshold
        
        return best_buy_threshold, best_sell_threshold
    
    # Function to backtest a single day with given thresholds
    def backtest_day(signals_df, buy_threshold, sell_threshold, initial_capital=10000, position_size=1.0):
        """Run backtest for a single day with specified thresholds"""
        if len(signals_df) == 0:
            return {
                'final_value': initial_capital,
                'return_pct': 0.0,
                'trades': 0,
                'win_rate': 0.0,
                'signals': 0,
                'buy_signals': 0,
                'sell_signals': 0,
            }
        
        # Sort signals chronologically
        signals_df = signals_df.sort_values('timestamp').reset_index(drop=True)
        
        # Strategy state
        capital = initial_capital
        cash = initial_capital
        shares = 0
        entry_price = 0
        trades = []
        
        # Process signals
        for _, row in signals_df.iterrows():
            current_price = row['klu_close']
            predicted_profit = row['predicted_profit_pct']
            direction = row['direction']
            
            # Buy logic
            if direction == 'buy' and shares == 0:
                if predicted_profit >= buy_threshold:
                    trade_capital = cash * position_size
                    shares = trade_capital / current_price
                    entry_price = current_price
                    cash -= trade_capital
                    
                    trades.append({
                        'entry_price': current_price,
                        'direction': 'buy'
                    })
            
            # Sell logic
            elif direction == 'sell' and shares > 0:
                if predicted_profit >= sell_threshold:
                    exit_value = shares * current_price
                    trade_profit = exit_value - (shares * entry_price)
                    trade_return_pct = (trade_profit / (shares * entry_price)) * 100
                    
                    cash += exit_value
                    
                    # Record trade result
                    if trades:
                        trades[-1].update({
                            'exit_price': current_price,
                            'trade_profit': trade_profit,
                            'trade_return_pct': trade_return_pct
                        })
                    
                    # Reset position
                    shares = 0
                    entry_price = 0
        
        # Close any open position at the end of the day
        if shares > 0:
            final_price = signals_df.iloc[-1]['klu_close']
            exit_value = shares * final_price
            trade_profit = exit_value - (shares * entry_price)
            trade_return_pct = (trade_profit / (shares * entry_price)) * 100
            
            cash += exit_value
            
            if trades:
                trades[-1].update({
                    'exit_price': final_price,
                    'trade_profit': trade_profit,
                    'trade_return_pct': trade_return_pct,
                    'note': 'Closed at end of day'
                })
        
        # Calculate metrics
        final_value = cash
        return_pct = ((final_value / initial_capital) - 1) * 100
        
        completed_trades = sum(1 for trade in trades if 'exit_price' in trade)
        winning_trades = sum(1 for trade in trades if 'trade_return_pct' in trade and trade['trade_return_pct'] > 0)
        win_rate = (winning_trades / completed_trades * 100) if completed_trades > 0 else 0
        
        buy_signals = len(signals_df[signals_df['direction'] == 'buy'])
        sell_signals = len(signals_df[signals_df['direction'] == 'sell'])
        
        return {
            'final_value': final_value,
            'return_pct': return_pct,
            'trades': completed_trades,
            'win_rate': win_rate,
            'signals': len(signals_df),
            'buy_signals': buy_signals,
            'sell_signals': sell_signals,
        }
    
    # Calculate Buy & Hold return for a specific day
    def calculate_buy_hold(day_df):
        """Calculate Buy & Hold return for a specific day"""
        if len(day_df) == 0:
            return 0.0
        
        # Sort chronologically
        day_df = day_df.sort_values('timestamp').reset_index(drop=True)
        
        # Get first and last prices
        first_price = day_df.iloc[0]['klu_close']
        last_price = day_df.iloc[-1]['klu_close']
        
        # Calculate return
        return ((last_price / first_price) - 1) * 100
    
    # Prepare data structures to store results
    daily_results = []
    model_metrics = []
    
    # Start rolling window backtest
    print("\n[3/5] Starting rolling window backtest...")
    
    # Loop through each day in the rolling period
    for day in tqdm(range(rolling_period_days), desc="Processing days"):
        # Define window indices
        train_start_idx = day
        train_end_idx = day + training_window_days - 1
        threshold_day_idx = train_end_idx + 1
        test_day_idx = threshold_day_idx + 1
        
        # Skip if we don't have enough days left
        if test_day_idx >= len(backtest_dates):
            print(f"  Warning: Not enough days left for complete window at day {day}, skipping...")
            continue
        
        # Extract dates for each period
        train_dates = backtest_dates[train_start_idx:train_end_idx + 1]
        threshold_date = backtest_dates[threshold_day_idx]
        test_date = backtest_dates[test_day_idx]
        
        print(f"\nDay {day+1}/{rolling_period_days}: Testing on {test_date}")
        print(f"  Training period: {train_dates[0]} to {train_dates[-1]} ({len(train_dates)} days)")
        print(f"  Threshold optimization: {threshold_date}")
        print(f"  Testing: {test_date}")
        
        # Filter data for each period
        train_df = df[df['date'].isin(train_dates)].copy()
        threshold_df = df[df['date'] == threshold_date].copy()
        test_df = df[df['date'] == test_date].copy()
        
        # Check if we have sufficient data in each period
        if len(train_df) < 100:  # Arbitrary minimum sample size
            print(f"  Warning: Insufficient training data ({len(train_df)} samples), skipping day {day}...")
            continue
            
        if len(threshold_df) == 0:
            print(f"  Warning: No data for threshold day {threshold_date}, skipping day {day}...")
            continue
            
        if len(test_df) == 0:
            print(f"  Warning: No data for test day {test_date}, skipping day {day}...")
            continue
        
        # Split data by buy/sell signals
        train_valid = train_df[train_df['has_profit_target'] == 1].copy()
        train_buy = train_valid[train_valid['direction'] == 'buy'].copy()
        train_sell = train_valid[train_valid['direction'] == 'sell'].copy()
        
        threshold_valid = threshold_df[threshold_df['has_profit_target'] == 1].copy()
        threshold_buy = threshold_valid[threshold_valid['direction'] == 'buy'].copy()
        threshold_sell = threshold_valid[threshold_valid['direction'] == 'sell'].copy()
        
        test_valid = test_df[test_df['has_profit_target'] == 1].copy()
        test_buy = test_valid[test_valid['direction'] == 'buy'].copy()
        test_sell = test_valid[test_valid['direction'] == 'sell'].copy()
        
        # Log data sizes
        print(f"  Training data: {len(train_valid)} signals ({len(train_buy)} buy, {len(train_sell)} sell)")
        print(f"  Threshold data: {len(threshold_valid)} signals ({len(threshold_buy)} buy, {len(threshold_sell)} sell)")
        print(f"  Test data: {len(test_valid)} signals ({len(test_buy)} buy, {len(test_sell)} sell)")
        
        # Skip if not enough training data for either buy or sell
        if len(train_buy) < 10 or len(train_sell) < 10:
            print(f"  Warning: Not enough buy/sell training samples, skipping day {day}...")
            continue
        
        # Prepare training data
        X_train_buy = train_buy[feature_cols].fillna(0)
        y_train_buy = train_buy['profit_target_pct']
        
        X_train_sell = train_sell[feature_cols].fillna(0)
        y_train_sell = train_sell['profit_target_pct']
        
        # Train Buy model
        print(f"  Training Buy model...")
        buy_model = xgb.XGBRegressor(**model_params)
        buy_model.fit(X_train_buy, y_train_buy)
        
        # Train Sell model
        print(f"  Training Sell model...")
        sell_model = xgb.XGBRegressor(**model_params)
        sell_model.fit(X_train_sell, y_train_sell)
        
        # Make predictions on threshold day
        if len(threshold_buy) > 0:
            X_threshold_buy = threshold_buy[feature_cols].fillna(0)
            threshold_buy['predicted_profit_pct'] = buy_model.predict(X_threshold_buy)
        
        if len(threshold_sell) > 0:
            X_threshold_sell = threshold_sell[feature_cols].fillna(0)
            threshold_sell['predicted_profit_pct'] = sell_model.predict(X_threshold_sell)
        
        # Combine threshold predictions
        threshold_signals = pd.concat([threshold_buy, threshold_sell], ignore_index=True)
        
        # Optimize thresholds on threshold day
        print(f"  Optimizing thresholds...")
        optimal_buy_threshold, optimal_sell_threshold = optimize_thresholds(threshold_signals)
        print(f"  Optimal thresholds: Buy={optimal_buy_threshold:.2f}%, Sell={optimal_sell_threshold:.2f}%")
        
        # Make predictions on test day
        if len(test_buy) > 0:
            X_test_buy = test_buy[feature_cols].fillna(0)
            test_buy['predicted_profit_pct'] = buy_model.predict(X_test_buy)
        
        if len(test_sell) > 0:
            X_test_sell = test_sell[feature_cols].fillna(0)
            test_sell['predicted_profit_pct'] = sell_model.predict(X_test_sell)
        
        # Combine test predictions
        test_signals = pd.concat([test_buy, test_sell], ignore_index=True)
        
        # Calculate test metrics
        if len(test_buy) > 0:
            buy_metrics = calculate_metrics(test_buy['profit_target_pct'], test_buy['predicted_profit_pct'])
        else:
            buy_metrics = None
            
        if len(test_sell) > 0:
            sell_metrics = calculate_metrics(test_sell['profit_target_pct'], test_sell['predicted_profit_pct'])
        else:
            sell_metrics = None
        
        # Run backtest on test day with optimal thresholds
        print(f"  Running backtest on test day...")
        backtest_result = backtest_day(test_signals, optimal_buy_threshold, optimal_sell_threshold, initial_capital, position_size)
        
        # Calculate Buy & Hold for comparison
        bh_return = calculate_buy_hold(test_df)
        
        # Record results
        daily_result = {
            'day': day + 1,
            'date': test_date,
            'train_start': train_dates[0],
            'train_end': train_dates[-1],
            'threshold_date': threshold_date,
            'buy_threshold': optimal_buy_threshold,
            'sell_threshold': optimal_sell_threshold,
            'strategy_return': backtest_result['return_pct'],
            'buy_hold_return': bh_return,
            'vs_buy_hold': backtest_result['return_pct'] - bh_return,
            'signals': backtest_result['signals'],
            'trades': backtest_result['trades'],
            'win_rate': backtest_result['win_rate'],
            'final_value': backtest_result['final_value'],
            'buy_signals': backtest_result['buy_signals'],
            'sell_signals': backtest_result['sell_signals'],
        }
        
        daily_results.append(daily_result)
        
        # Record model metrics
        model_metric = {
            'day': day + 1,
            'date': test_date,
            'buy_model_samples': len(train_buy),
            'sell_model_samples': len(train_sell),
        }
        
        # Add buy metrics
        if buy_metrics:
            model_metric.update({
                'buy_rmse': buy_metrics['RMSE'],
                'buy_mae': buy_metrics['MAE'],
                'buy_r2': buy_metrics['R2'],
                'buy_accuracy': buy_metrics['Accuracy'],
            })
            
        # Add sell metrics
        if sell_metrics:
            model_metric.update({
                'sell_rmse': sell_metrics['RMSE'],
                'sell_mae': sell_metrics['MAE'],
                'sell_r2': sell_metrics['R2'],
                'sell_accuracy': sell_metrics['Accuracy'],
            })
            
        model_metrics.append(model_metric)
        
        # Report summary for this day
        print(f"  Test day results:")
        print(f"    Strategy return: {backtest_result['return_pct']:.2f}%")
        print(f"    Buy & Hold return: {bh_return:.2f}%")
        print(f"    Outperformance: {backtest_result['return_pct'] - bh_return:+.2f}%")
        print(f"    Trades: {backtest_result['trades']}, Win rate: {backtest_result['win_rate']:.1f}%")
    
    # Convert results to DataFrames
    daily_results_df = pd.DataFrame(daily_results)
    model_metrics_df = pd.DataFrame(model_metrics)
    
    # Analysis and Visualization
    print("\n[4/5] Analyzing results...")
    
    if len(daily_results_df) > 0:
        # Calculate cumulative returns
        daily_results_df['cumulative_strategy'] = (1 + daily_results_df['strategy_return'] / 100).cumprod() * 100 - 100
        daily_results_df['cumulative_buy_hold'] = (1 + daily_results_df['buy_hold_return'] / 100).cumprod() * 100 - 100
        
        # Overall performance metrics
        final_strategy_return = daily_results_df['cumulative_strategy'].iloc[-1]
        final_buy_hold_return = daily_results_df['cumulative_buy_hold'].iloc[-1]
        
        win_days = sum(daily_results_df['strategy_return'] > 0)
        total_days = len(daily_results_df)
        win_rate = (win_days / total_days * 100) if total_days > 0 else 0
        
        outperformance_days = sum(daily_results_df['strategy_return'] > daily_results_df['buy_hold_return'])
        outperformance_rate = (outperformance_days / total_days * 100) if total_days > 0 else 0
        
        print("\n" + "=" * 80)
        print("DAILY ROLLING WINDOW BACKTEST RESULTS")
        print("=" * 80)
        print(f"Total days analyzed: {total_days}")
        print(f"Strategy cumulative return: {final_strategy_return:.2f}%")
        print(f"Buy & Hold cumulative return: {final_buy_hold_return:.2f}%")
        print(f"Strategy vs. Buy & Hold: {final_strategy_return - final_buy_hold_return:+.2f}%")
        print(f"Win rate (positive return days): {win_rate:.1f}%")
        print(f"Outperformance rate (days beating Buy & Hold): {outperformance_rate:.1f}%")
        
        # Create visualizations
        print("\n[5/5] Creating visualizations...")
        
        # 1. Cumulative returns comparison
        plt.figure(figsize=(12, 6))
        plt.plot(daily_results_df['day'], daily_results_df['cumulative_strategy'], label='Strategy', linewidth=2)
        plt.plot(daily_results_df['day'], daily_results_df['cumulative_buy_hold'], label='Buy & Hold', linewidth=2)
        plt.axhline(y=0, color='gray', linestyle='--', alpha=0.5)
        plt.title('Cumulative Returns: Strategy vs. Buy & Hold', fontsize=14)
        plt.xlabel('Day')
        plt.ylabel('Cumulative Return (%)')
        plt.legend()
        plt.grid(alpha=0.3)
        plt.tight_layout()
        plt.savefig(f"{output_dir}/cumulative_returns.png", dpi=150)
        print(f"Saved: {output_dir}/cumulative_returns.png")
        
        # 2. Daily returns comparison
        plt.figure(figsize=(12, 6))
        plt.bar(range(len(daily_results_df)), daily_results_df['strategy_return'], alpha=0.7, label='Strategy')
        plt.bar(range(len(daily_results_df)), daily_results_df['buy_hold_return'], alpha=0.5, label='Buy & Hold')
        plt.axhline(y=0, color='black', linestyle='-', alpha=0.3)
        plt.title('Daily Returns: Strategy vs. Buy & Hold', fontsize=14)
        plt.xlabel('Day')
        plt.ylabel('Return (%)')
        plt.legend()
        plt.grid(alpha=0.3)
        plt.tight_layout()
        plt.savefig(f"{output_dir}/daily_returns.png", dpi=150)
        print(f"Saved: {output_dir}/daily_returns.png")
        
        # 3. Strategy outperformance
        plt.figure(figsize=(12, 6))
        plt.bar(range(len(daily_results_df)), 
                daily_results_df['strategy_return'] - daily_results_df['buy_hold_return'],
                color=['green' if x > 0 else 'red' for x in 
                       daily_results_df['strategy_return'] - daily_results_df['buy_hold_return']])
        plt.axhline(y=0, color='black', linestyle='-', alpha=0.3)
        plt.title('Daily Strategy Outperformance vs. Buy & Hold', fontsize=14)
        plt.xlabel('Day')
        plt.ylabel('Outperformance (%)')
        plt.grid(alpha=0.3)
        plt.tight_layout()
        plt.savefig(f"{output_dir}/strategy_outperformance.png", dpi=150)
        print(f"Saved: {output_dir}/strategy_outperformance.png")
        
        # 4. Model metrics over time
        if len(model_metrics_df) > 0 and 'buy_accuracy' in model_metrics_df.columns and 'sell_accuracy' in model_metrics_df.columns:
            plt.figure(figsize=(12, 6))
            plt.plot(model_metrics_df['day'], model_metrics_df['buy_accuracy'], label='Buy Model Accuracy', marker='o')
            plt.plot(model_metrics_df['day'], model_metrics_df['sell_accuracy'], label='Sell Model Accuracy', marker='s')
            plt.axhline(y=50, color='red', linestyle='--', alpha=0.5, label='Random Guess')
            plt.title('Model Direction Accuracy Over Time', fontsize=14)
            plt.xlabel('Day')
            plt.ylabel('Direction Accuracy (%)')
            plt.legend()
            plt.grid(alpha=0.3)
            plt.tight_layout()
            plt.savefig(f"{output_dir}/model_accuracy.png", dpi=150)
            print(f"Saved: {output_dir}/model_accuracy.png")
        
        # 5. Threshold evolution
        plt.figure(figsize=(12, 6))
        plt.plot(daily_results_df['day'], daily_results_df['buy_threshold'], label='Buy Threshold', marker='o')
        plt.plot(daily_results_df['day'], daily_results_df['sell_threshold'], label='Sell Threshold', marker='s')
        plt.title('Optimal Threshold Evolution', fontsize=14)
        plt.xlabel('Day')
        plt.ylabel('Profit Threshold (%)')
        plt.legend()
        plt.grid(alpha=0.3)
        plt.tight_layout()
        plt.savefig(f"{output_dir}/threshold_evolution.png", dpi=150)
        print(f"Saved: {output_dir}/threshold_evolution.png")
        
        # Save results to CSV
        daily_results_df.to_csv(f"{output_dir}/daily_results.csv", index=False)
        model_metrics_df.to_csv(f"{output_dir}/model_metrics.csv", index=False)
        print(f"Saved results to {output_dir}/daily_results.csv and {output_dir}/model_metrics.csv")
        
        # Generate summary report
        with open(f"{output_dir}/backtest_summary.txt", 'w') as f:
            f.write("Daily Rolling Window Backtest Summary\n")
            f.write("=" * 80 + "\n\n")
            
            f.write("CONFIGURATION:\n")
            f.write(f"  Training window: {training_window_days} days\n")
            f.write(f"  Rolling period: {rolling_period_days} days\n")
            f.write(f"  Position size: {position_size * 100}%\n")
            f.write(f"  Initial capital: ${initial_capital}\n\n")
            
            f.write("OVERALL PERFORMANCE:\n")
            f.write(f"  Total days analyzed: {total_days}\n")
            f.write(f"  Strategy cumulative return: {final_strategy_return:.2f}%\n")
            f.write(f"  Buy & Hold cumulative return: {final_buy_hold_return:.2f}%\n")
            f.write(f"  Strategy vs. Buy & Hold: {final_strategy_return - final_buy_hold_return:+.2f}%\n")
            f.write(f"  Win rate (positive return days): {win_rate:.1f}%\n")
            f.write(f"  Outperformance rate (days beating Buy & Hold): {outperformance_rate:.1f}%\n\n")
            
            f.write("DAILY RESULTS:\n")
            for i, row in daily_results_df.iterrows():
                f.write(f"  Day {row['day']} ({row['date']}): Strategy {row['strategy_return']:.2f}%, ")
                f.write(f"B&H {row['buy_hold_return']:.2f}%, Diff {row['vs_buy_hold']:+.2f}%, ")
                f.write(f"Thresholds: Buy={row['buy_threshold']:.2f}%, Sell={row['sell_threshold']:.2f}%\n")
            
            f.write("\nANALYSIS:\n")
            strategy_better = "OUTPERFORMED" if final_strategy_return > final_buy_hold_return else "UNDERPERFORMED"
            f.write(f"The daily rolling window strategy {strategy_better} Buy & Hold over the {rolling_period_days}-day period ")
            f.write(f"by {final_strategy_return - final_buy_hold_return:+.2f}%.\n")
            
        print(f"Saved summary to {output_dir}/backtest_summary.txt")
        
        # Copy output to user-accessible location
        os.makedirs("/mnt/user-data/outputs/daily_rolling_backtest", exist_ok=True)
        os.system(f"cp -r {output_dir}/* /mnt/user-data/outputs/daily_rolling_backtest/")
        
        print("\n" + "=" * 80)
        print("Daily Rolling Window Backtest Complete!")
        print("=" * 80)
        
        print(f"\n📈 All results saved to: /mnt/user-data/outputs/daily_rolling_backtest/")
        
        return daily_results_df
    else:
        print("No valid daily results data to analyze")
        return pd.DataFrame()

# Example usage
if __name__ == "__main__":
    # Configuration
    DATA_PATH = "./output/enhanced_bs_features/SPY_testing_dataset_21.1.1-12.31.csv"  # Path to your dataset
    OUTPUT_DIR = "./output/daily_rolling_backtest"
    
    # Parameters
    TRAINING_WINDOW_DAYS = 30  # Use 1 month of data for training
    ROLLING_PERIOD_DAYS = 200   # Number of days to roll forward
    POSITION_SIZE = 1.0        # Use 100% of capital per trade
    INITIAL_CAPITAL = 10000    # Initial capital
    
    # Run backtest
    results_df = run_daily_rolling_window_backtest(
        data_path=DATA_PATH,
        output_dir=OUTPUT_DIR,
        training_window_days=TRAINING_WINDOW_DAYS,
        rolling_period_days=ROLLING_PERIOD_DAYS,
        position_size=POSITION_SIZE,
        initial_capital=INITIAL_CAPITAL
    )
# Out:
# ================================================================================
# Daily Rolling Window Backtesting
# ================================================================================
# Training window: 30 days
# Rolling period: 200 days
# Start date: Earliest possible
# Position size: 100.0%
# Initial capital: $10000
# ================================================================================
#
# [1/5] Loading dataset...
# Data shape: (10139, 79)
# Full dataset date range: 2021-01-04 07:05:00 to 2021-12-31 15:55:00
# Number of unique trading days: 252
# Backtest period: 2021-01-04 to 2021-12-02
#
# [2/5] Identifying feature columns...
# Features identified: 64
#
# [3/5] Starting rolling window backtest...
# Processing days:   0%|          | 0/200 [00:00<?, ?it/s]
# Day 1/200: Testing on 2021-02-18
#   Training period: 2021-01-04 to 2021-02-16 (30 days)
#   Threshold optimization: 2021-02-17
#   Testing: 2021-02-18
#   Training data: 1242 signals (488 buy, 754 sell)
#   Threshold data: 21 signals (5 buy, 16 sell)
#   Test data: 41 signals (22 buy, 19 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   0%|          | 1/200 [00:00<02:20,  1.42it/s]
#   Optimal thresholds: Buy=1.10%, Sell=0.50%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.03%
#     Buy & Hold return: -0.35%
#     Outperformance: +0.32%
#     Trades: 1, Win rate: 0.0%
#
# Day 2/200: Testing on 2021-02-19
#   Training period: 2021-01-05 to 2021-02-17 (30 days)
#   Threshold optimization: 2021-02-18
#   Testing: 2021-02-19
#   Training data: 1223 signals (461 buy, 762 sell)
#   Threshold data: 41 signals (22 buy, 19 sell)
#   Test data: 30 signals (13 buy, 17 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   1%|          | 2/200 [00:01<02:14,  1.47it/s]
#   Optimal thresholds: Buy=1.10%, Sell=0.70%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: -0.35%
#     Outperformance: +0.35%
#     Trades: 0, Win rate: 0.0%
#
# Day 3/200: Testing on 2021-02-22
#   Training period: 2021-01-06 to 2021-02-18 (30 days)
#   Threshold optimization: 2021-02-19
#   Testing: 2021-02-22
#   Training data: 1223 signals (476 buy, 747 sell)
#   Threshold data: 30 signals (13 buy, 17 sell)
#   Test data: 6 signals (2 buy, 4 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   2%|▏         | 3/200 [00:02<02:10,  1.51it/s]
#   Optimal thresholds: Buy=0.90%, Sell=1.00%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: 0.17%
#     Outperformance: -0.17%
#     Trades: 0, Win rate: 0.0%
#
# Day 4/200: Testing on 2021-02-23
#   Training period: 2021-01-07 to 2021-02-19 (30 days)
#   Threshold optimization: 2021-02-22
#   Testing: 2021-02-23
#   Training data: 1228 signals (487 buy, 741 sell)
#   Threshold data: 6 signals (2 buy, 4 sell)
#   Test data: 42 signals (31 buy, 11 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   2%|▏         | 4/200 [00:02<02:06,  1.54it/s]
#   Optimal thresholds: Buy=0.60%, Sell=0.10%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.11%
#     Buy & Hold return: 0.23%
#     Outperformance: -0.12%
#     Trades: 2, Win rate: 50.0%
#
# Day 5/200: Testing on 2021-02-24
#   Training period: 2021-01-08 to 2021-02-22 (30 days)
#   Threshold optimization: 2021-02-23
#   Testing: 2021-02-24
#   Training data: 1199 signals (485 buy, 714 sell)
#   Threshold data: 42 signals (31 buy, 11 sell)
#   Test data: 51 signals (7 buy, 44 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   2%|▎         | 5/200 [00:03<02:05,  1.56it/s]
#   Optimal thresholds: Buy=0.80%, Sell=1.30%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.99%
#     Buy & Hold return: 1.40%
#     Outperformance: -0.41%
#     Trades: 1, Win rate: 100.0%
#
# Day 6/200: Testing on 2021-02-25
#   Training period: 2021-01-11 to 2021-02-23 (30 days)
#   Threshold optimization: 2021-02-24
#   Testing: 2021-02-25
#   Training data: 1210 signals (510 buy, 700 sell)
#   Threshold data: 51 signals (7 buy, 44 sell)
#   Test data: 57 signals (41 buy, 16 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   3%|▎         | 6/200 [00:03<02:04,  1.55it/s]
#   Optimal thresholds: Buy=2.00%, Sell=1.20%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.41%
#     Buy & Hold return: -2.90%
#     Outperformance: +2.49%
#     Trades: 2, Win rate: 0.0%
#
# Day 7/200: Testing on 2021-02-26
#   Training period: 2021-01-12 to 2021-02-24 (30 days)
#   Threshold optimization: 2021-02-25
#   Testing: 2021-02-26
#   Training data: 1207 signals (494 buy, 713 sell)
#   Threshold data: 57 signals (41 buy, 16 sell)
#   Test data: 35 signals (13 buy, 22 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   4%|▎         | 7/200 [00:04<02:06,  1.52it/s]
#   Optimal thresholds: Buy=2.00%, Sell=0.60%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.21%
#     Buy & Hold return: 0.85%
#     Outperformance: -0.65%
#     Trades: 1, Win rate: 100.0%
#
# Day 8/200: Testing on 2021-03-01
#   Training period: 2021-01-13 to 2021-02-25 (30 days)
#   Threshold optimization: 2021-02-26
#   Testing: 2021-03-01
#   Training data: 1223 signals (519 buy, 704 sell)
#   Threshold data: 35 signals (13 buy, 22 sell)
#   Test data: 22 signals (7 buy, 15 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   4%|▍         | 8/200 [00:05<02:06,  1.52it/s]
#   Optimal thresholds: Buy=1.50%, Sell=2.00%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: 1.33%
#     Outperformance: -1.33%
#     Trades: 0, Win rate: 0.0%
#
# Day 9/200: Testing on 2021-03-02
#   Training period: 2021-01-14 to 2021-02-26 (30 days)
#   Threshold optimization: 2021-03-01
#   Testing: 2021-03-02
#   Training data: 1213 signals (508 buy, 705 sell)
#   Threshold data: 22 signals (7 buy, 15 sell)
#   Test data: 56 signals (32 buy, 24 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   4%|▍         | 9/200 [00:05<02:05,  1.53it/s]
#   Optimal thresholds: Buy=0.90%, Sell=0.60%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.83%
#     Buy & Hold return: -0.07%
#     Outperformance: +0.90%
#     Trades: 2, Win rate: 100.0%
#
# Day 10/200: Testing on 2021-03-03
#   Training period: 2021-01-15 to 2021-03-01 (30 days)
#   Threshold optimization: 2021-03-02
#   Testing: 2021-03-03
#   Training data: 1208 signals (511 buy, 697 sell)
#   Threshold data: 56 signals (32 buy, 24 sell)
#   Test data: 72 signals (58 buy, 14 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   5%|▌         | 10/200 [00:06<02:03,  1.53it/s]
#   Optimal thresholds: Buy=1.20%, Sell=1.40%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.40%
#     Buy & Hold return: -2.41%
#     Outperformance: +2.01%
#     Trades: 1, Win rate: 0.0%
#
# Day 11/200: Testing on 2021-03-04
#   Training period: 2021-01-19 to 2021-03-02 (30 days)
#   Threshold optimization: 2021-03-03
#   Testing: 2021-03-04
#   Training data: 1224 signals (512 buy, 712 sell)
#   Threshold data: 72 signals (58 buy, 14 sell)
#   Test data: 43 signals (39 buy, 4 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   6%|▌         | 11/200 [00:07<02:02,  1.54it/s]
#   Optimal thresholds: Buy=1.40%, Sell=2.00%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.26%
#     Buy & Hold return: -1.58%
#     Outperformance: +1.32%
#     Trades: 2, Win rate: 50.0%
#
# Day 12/200: Testing on 2021-03-05
#   Training period: 2021-01-20 to 2021-03-03 (30 days)
#   Threshold optimization: 2021-03-04
#   Testing: 2021-03-05
#   Training data: 1262 signals (562 buy, 700 sell)
#   Threshold data: 43 signals (39 buy, 4 sell)
#   Test data: 52 signals (17 buy, 35 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   6%|▌         | 12/200 [00:07<02:02,  1.54it/s]
#   Optimal thresholds: Buy=1.40%, Sell=1.50%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.02%
#     Buy & Hold return: 1.79%
#     Outperformance: -1.77%
#     Trades: 1, Win rate: 100.0%
#
# Day 13/200: Testing on 2021-03-08
#   Training period: 2021-01-21 to 2021-03-04 (30 days)
#   Threshold optimization: 2021-03-05
#   Testing: 2021-03-08
#   Training data: 1238 signals (600 buy, 638 sell)
#   Threshold data: 52 signals (17 buy, 35 sell)
#   Test data: 49 signals (17 buy, 32 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   6%|▋         | 13/200 [00:08<02:01,  1.54it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=1.90%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.08%
#     Buy & Hold return: 0.53%
#     Outperformance: -0.60%
#     Trades: 3, Win rate: 66.7%
#
# Day 14/200: Testing on 2021-03-09
#   Training period: 2021-01-22 to 2021-03-05 (30 days)
#   Threshold optimization: 2021-03-08
#   Testing: 2021-03-09
#   Training data: 1253 signals (617 buy, 636 sell)
#   Threshold data: 49 signals (17 buy, 32 sell)
#   Test data: 63 signals (17 buy, 46 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   7%|▋         | 14/200 [00:09<02:00,  1.55it/s]
#   Optimal thresholds: Buy=0.60%, Sell=1.90%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.43%
#     Buy & Hold return: 0.30%
#     Outperformance: -0.72%
#     Trades: 1, Win rate: 0.0%
#
# Day 15/200: Testing on 2021-03-10
#   Training period: 2021-01-25 to 2021-03-08 (30 days)
#   Threshold optimization: 2021-03-09
#   Testing: 2021-03-10
#   Training data: 1277 signals (616 buy, 661 sell)
#   Threshold data: 63 signals (17 buy, 46 sell)
#   Test data: 44 signals (25 buy, 19 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   8%|▊         | 15/200 [00:09<01:59,  1.55it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=2.00%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.44%
#     Buy & Hold return: 0.52%
#     Outperformance: -0.08%
#     Trades: 1, Win rate: 100.0%
#
# Day 16/200: Testing on 2021-03-11
#   Training period: 2021-01-26 to 2021-03-09 (30 days)
#   Threshold optimization: 2021-03-10
#   Testing: 2021-03-11
#   Training data: 1294 signals (611 buy, 683 sell)
#   Threshold data: 44 signals (25 buy, 19 sell)
#   Test data: 44 signals (7 buy, 37 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   8%|▊         | 16/200 [00:10<01:57,  1.56it/s]
#   Optimal thresholds: Buy=0.80%, Sell=1.80%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: 0.44%
#     Outperformance: -0.44%
#     Trades: 0, Win rate: 0.0%
#
# Day 17/200: Testing on 2021-03-12
#   Training period: 2021-01-27 to 2021-03-10 (30 days)
#   Threshold optimization: 2021-03-11
#   Testing: 2021-03-12
#   Training data: 1315 signals (629 buy, 686 sell)
#   Threshold data: 44 signals (7 buy, 37 sell)
#   Test data: 26 signals (15 buy, 11 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   8%|▊         | 17/200 [00:11<02:03,  1.48it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=-0.50%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 1.06%
#     Buy & Hold return: 0.77%
#     Outperformance: +0.29%
#     Trades: 4, Win rate: 100.0%
#
# Day 18/200: Testing on 2021-03-15
#   Training period: 2021-01-28 to 2021-03-11 (30 days)
#   Threshold optimization: 2021-03-12
#   Testing: 2021-03-15
#   Training data: 1287 signals (567 buy, 720 sell)
#   Threshold data: 26 signals (15 buy, 11 sell)
#   Test data: 59 signals (18 buy, 41 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:   9%|▉         | 18/200 [00:11<01:59,  1.52it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=1.70%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.28%
#     Buy & Hold return: 0.42%
#     Outperformance: -0.14%
#     Trades: 1, Win rate: 100.0%
#
# Day 19/200: Testing on 2021-03-16
#   Training period: 2021-01-29 to 2021-03-12 (30 days)
#   Threshold optimization: 2021-03-15
#   Testing: 2021-03-16
#   Training data: 1264 signals (571 buy, 693 sell)
#   Threshold data: 59 signals (18 buy, 41 sell)
#   Test data: 34 signals (8 buy, 26 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  10%|▉         | 19/200 [00:12<01:58,  1.53it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=1.70%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.11%
#     Buy & Hold return: -0.09%
#     Outperformance: +0.20%
#     Trades: 1, Win rate: 100.0%
#
# Day 20/200: Testing on 2021-03-17
#   Training period: 2021-02-01 to 2021-03-15 (30 days)
#   Threshold optimization: 2021-03-16
#   Testing: 2021-03-17
#   Training data: 1267 signals (557 buy, 710 sell)
#   Threshold data: 34 signals (8 buy, 26 sell)
#   Test data: 31 signals (19 buy, 12 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  10%|█         | 20/200 [00:13<01:56,  1.54it/s]
#   Optimal thresholds: Buy=0.70%, Sell=1.50%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.82%
#     Buy & Hold return: 0.48%
#     Outperformance: +0.34%
#     Trades: 1, Win rate: 100.0%
#
# Day 21/200: Testing on 2021-03-18
#   Training period: 2021-02-02 to 2021-03-16 (30 days)
#   Threshold optimization: 2021-03-17
#   Testing: 2021-03-18
#   Training data: 1273 signals (550 buy, 723 sell)
#   Threshold data: 31 signals (19 buy, 12 sell)
#   Test data: 27 signals (25 buy, 2 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  10%|█         | 21/200 [00:13<01:55,  1.55it/s]
#   Optimal thresholds: Buy=0.90%, Sell=0.80%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: -1.20%
#     Outperformance: +1.20%
#     Trades: 0, Win rate: 0.0%
#
# Day 22/200: Testing on 2021-03-19
#   Training period: 2021-02-03 to 2021-03-17 (30 days)
#   Threshold optimization: 2021-03-18
#   Testing: 2021-03-19
#   Training data: 1251 signals (557 buy, 694 sell)
#   Threshold data: 27 signals (25 buy, 2 sell)
#   Test data: 29 signals (11 buy, 18 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  11%|█         | 22/200 [00:14<01:54,  1.56it/s]
#   Optimal thresholds: Buy=0.90%, Sell=-0.50%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.70%
#     Buy & Hold return: -0.58%
#     Outperformance: +1.28%
#     Trades: 2, Win rate: 100.0%
#
# Day 23/200: Testing on 2021-03-22
#   Training period: 2021-02-04 to 2021-03-18 (30 days)
#   Threshold optimization: 2021-03-19
#   Testing: 2021-03-22
#   Training data: 1236 signals (561 buy, 675 sell)
#   Threshold data: 29 signals (11 buy, 18 sell)
#   Test data: 72 signals (4 buy, 68 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  12%|█▏        | 23/200 [00:15<01:57,  1.51it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=1.60%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 1.21%
#     Buy & Hold return: 1.21%
#     Outperformance: +0.00%
#     Trades: 1, Win rate: 100.0%
#
# Day 24/200: Testing on 2021-03-23
#   Training period: 2021-02-05 to 2021-03-19 (30 days)
#   Threshold optimization: 2021-03-22
#   Testing: 2021-03-23
#   Training data: 1216 signals (564 buy, 652 sell)
#   Threshold data: 72 signals (4 buy, 68 sell)
#   Test data: 23 signals (10 buy, 13 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  12%|█▏        | 24/200 [00:15<02:00,  1.47it/s]
#   Optimal thresholds: Buy=1.10%, Sell=1.70%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.06%
#     Buy & Hold return: -0.35%
#     Outperformance: +0.28%
#     Trades: 1, Win rate: 0.0%
#
# Day 25/200: Testing on 2021-03-24
#   Training period: 2021-02-08 to 2021-03-22 (30 days)
#   Threshold optimization: 2021-03-23
#   Testing: 2021-03-24
#   Training data: 1258 signals (547 buy, 711 sell)
#   Threshold data: 23 signals (10 buy, 13 sell)
#   Test data: 33 signals (23 buy, 10 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  12%|█▎        | 25/200 [00:16<01:57,  1.49it/s]
#   Optimal thresholds: Buy=1.40%, Sell=0.80%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: -0.70%
#     Outperformance: +0.70%
#     Trades: 0, Win rate: 0.0%
#
# Day 26/200: Testing on 2021-03-25
#   Training period: 2021-02-09 to 2021-03-23 (30 days)
#   Threshold optimization: 2021-03-24
#   Testing: 2021-03-25
#   Training data: 1232 signals (545 buy, 687 sell)
#   Threshold data: 33 signals (23 buy, 10 sell)
#   Test data: 39 signals (25 buy, 14 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  13%|█▎        | 26/200 [00:17<01:56,  1.49it/s]
#   Optimal thresholds: Buy=1.10%, Sell=1.30%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.67%
#     Buy & Hold return: 0.43%
#     Outperformance: +0.24%
#     Trades: 1, Win rate: 100.0%
#
# Day 27/200: Testing on 2021-03-26
#   Training period: 2021-02-10 to 2021-03-24 (30 days)
#   Threshold optimization: 2021-03-25
#   Testing: 2021-03-26
#   Training data: 1199 signals (537 buy, 662 sell)
#   Threshold data: 39 signals (25 buy, 14 sell)
#   Test data: 39 signals (19 buy, 20 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  14%|█▎        | 27/200 [00:17<01:53,  1.52it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=1.30%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.72%
#     Buy & Hold return: 1.14%
#     Outperformance: -0.42%
#     Trades: 1, Win rate: 100.0%
#
# Day 28/200: Testing on 2021-03-29
#   Training period: 2021-02-11 to 2021-03-25 (30 days)
#   Threshold optimization: 2021-03-26
#   Testing: 2021-03-29
#   Training data: 1217 signals (557 buy, 660 sell)
#   Threshold data: 39 signals (19 buy, 20 sell)
#   Test data: 59 signals (14 buy, 45 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  14%|█▍        | 28/200 [00:18<01:51,  1.54it/s]
#   Optimal thresholds: Buy=0.30%, Sell=1.60%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.95%
#     Buy & Hold return: 0.64%
#     Outperformance: +0.31%
#     Trades: 3, Win rate: 100.0%
#
# Day 29/200: Testing on 2021-03-30
#   Training period: 2021-02-12 to 2021-03-26 (30 days)
#   Threshold optimization: 2021-03-29
#   Testing: 2021-03-30
#   Training data: 1222 signals (563 buy, 659 sell)
#   Threshold data: 59 signals (14 buy, 45 sell)
#   Test data: 35 signals (24 buy, 11 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  14%|█▍        | 29/200 [00:19<01:52,  1.52it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=1.90%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.30%
#     Buy & Hold return: -0.10%
#     Outperformance: +0.40%
#     Trades: 3, Win rate: 66.7%
#
# Day 30/200: Testing on 2021-03-31
#   Training period: 2021-02-16 to 2021-03-29 (30 days)
#   Threshold optimization: 2021-03-30
#   Testing: 2021-03-31
#   Training data: 1243 signals (572 buy, 671 sell)
#   Threshold data: 35 signals (24 buy, 11 sell)
#   Test data: 37 signals (10 buy, 27 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  15%|█▌        | 30/200 [00:19<01:51,  1.53it/s]
#   Optimal thresholds: Buy=0.60%, Sell=1.70%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.52%
#     Buy & Hold return: 0.52%
#     Outperformance: +0.00%
#     Trades: 1, Win rate: 100.0%
#
# Day 31/200: Testing on 2021-04-01
#   Training period: 2021-02-17 to 2021-03-30 (30 days)
#   Threshold optimization: 2021-03-31
#   Testing: 2021-04-01
#   Training data: 1234 signals (568 buy, 666 sell)
#   Threshold data: 37 signals (10 buy, 27 sell)
#   Test data: 56 signals (7 buy, 49 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  16%|█▌        | 31/200 [00:20<01:49,  1.54it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=1.50%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.09%
#     Buy & Hold return: 0.91%
#     Outperformance: -0.82%
#     Trades: 2, Win rate: 100.0%
#
# Day 32/200: Testing on 2021-04-05
#   Training period: 2021-02-18 to 2021-03-31 (30 days)
#   Threshold optimization: 2021-04-01
#   Testing: 2021-04-05
#   Training data: 1250 signals (573 buy, 677 sell)
#   Threshold data: 56 signals (7 buy, 49 sell)
#   Test data: 50 signals (2 buy, 48 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  16%|█▌        | 32/200 [00:20<01:49,  1.53it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=1.90%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.28%
#     Buy & Hold return: 1.20%
#     Outperformance: -0.92%
#     Trades: 1, Win rate: 100.0%
#
# Day 33/200: Testing on 2021-04-06
#   Training period: 2021-02-19 to 2021-04-01 (30 days)
#   Threshold optimization: 2021-04-05
#   Testing: 2021-04-06
#   Training data: 1265 signals (558 buy, 707 sell)
#   Threshold data: 50 signals (2 buy, 48 sell)
#   Test data: 49 signals (7 buy, 42 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  16%|█▋        | 33/200 [00:21<01:49,  1.52it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=0.90%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.40%
#     Buy & Hold return: 0.40%
#     Outperformance: +0.00%
#     Trades: 1, Win rate: 100.0%
#
# Day 34/200: Testing on 2021-04-07
#   Training period: 2021-02-22 to 2021-04-05 (30 days)
#   Threshold optimization: 2021-04-06
#   Testing: 2021-04-07
#   Training data: 1285 signals (547 buy, 738 sell)
#   Threshold data: 49 signals (7 buy, 42 sell)
#   Test data: 56 signals (29 buy, 27 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  17%|█▋        | 34/200 [00:22<01:49,  1.52it/s]
#   Optimal thresholds: Buy=1.30%, Sell=1.70%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.41%
#     Buy & Hold return: 0.41%
#     Outperformance: -0.00%
#     Trades: 1, Win rate: 100.0%
#
# Day 35/200: Testing on 2021-04-08
#   Training period: 2021-02-23 to 2021-04-06 (30 days)
#   Threshold optimization: 2021-04-07
#   Testing: 2021-04-08
#   Training data: 1328 signals (552 buy, 776 sell)
#   Threshold data: 56 signals (29 buy, 27 sell)
#   Test data: 41 signals (15 buy, 26 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  18%|█▊        | 35/200 [00:22<01:48,  1.52it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=1.00%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.46%
#     Buy & Hold return: 0.35%
#     Outperformance: +0.11%
#     Trades: 1, Win rate: 100.0%
#
# Day 36/200: Testing on 2021-04-09
#   Training period: 2021-02-24 to 2021-04-07 (30 days)
#   Threshold optimization: 2021-04-08
#   Testing: 2021-04-09
#   Training data: 1342 signals (550 buy, 792 sell)
#   Threshold data: 41 signals (15 buy, 26 sell)
#   Test data: 39 signals (9 buy, 30 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  18%|█▊        | 36/200 [00:23<01:47,  1.53it/s]
#   Optimal thresholds: Buy=1.00%, Sell=0.50%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.70%
#     Buy & Hold return: 0.59%
#     Outperformance: +0.11%
#     Trades: 1, Win rate: 100.0%
#
# Day 37/200: Testing on 2021-04-12
#   Training period: 2021-02-25 to 2021-04-08 (30 days)
#   Threshold optimization: 2021-04-09
#   Testing: 2021-04-12
#   Training data: 1332 signals (558 buy, 774 sell)
#   Threshold data: 39 signals (9 buy, 30 sell)
#   Test data: 35 signals (13 buy, 22 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  18%|█▊        | 37/200 [00:24<01:45,  1.54it/s]
#   Optimal thresholds: Buy=0.80%, Sell=0.50%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.37%
#     Buy & Hold return: 0.25%
#     Outperformance: +0.12%
#     Trades: 3, Win rate: 100.0%
#
# Day 38/200: Testing on 2021-04-13
#   Training period: 2021-02-26 to 2021-04-09 (30 days)
#   Threshold optimization: 2021-04-12
#   Testing: 2021-04-13
#   Training data: 1314 signals (526 buy, 788 sell)
#   Threshold data: 35 signals (13 buy, 22 sell)
#   Test data: 23 signals (11 buy, 12 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  19%|█▉        | 38/200 [00:24<01:43,  1.56it/s]
#   Optimal thresholds: Buy=0.80%, Sell=0.80%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.47%
#     Buy & Hold return: 0.29%
#     Outperformance: +0.18%
#     Trades: 1, Win rate: 100.0%
#
# Day 39/200: Testing on 2021-04-14
#   Training period: 2021-03-01 to 2021-04-12 (30 days)
#   Threshold optimization: 2021-04-13
#   Testing: 2021-04-14
#   Training data: 1314 signals (526 buy, 788 sell)
#   Threshold data: 23 signals (11 buy, 12 sell)
#   Test data: 19 signals (5 buy, 14 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  20%|█▉        | 39/200 [00:25<01:42,  1.57it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=1.20%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.17%
#     Buy & Hold return: -0.47%
#     Outperformance: +0.30%
#     Trades: 1, Win rate: 0.0%
#
# Day 40/200: Testing on 2021-04-15
#   Training period: 2021-03-02 to 2021-04-13 (30 days)
#   Threshold optimization: 2021-04-14
#   Testing: 2021-04-15
#   Training data: 1315 signals (530 buy, 785 sell)
#   Threshold data: 19 signals (5 buy, 14 sell)
#   Test data: 38 signals (7 buy, 31 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  20%|██        | 40/200 [00:26<01:41,  1.58it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=0.60%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.73%
#     Buy & Hold return: 0.63%
#     Outperformance: +0.10%
#     Trades: 2, Win rate: 100.0%
#
# Day 41/200: Testing on 2021-04-16
#   Training period: 2021-03-03 to 2021-04-14 (30 days)
#   Threshold optimization: 2021-04-15
#   Testing: 2021-04-16
#   Training data: 1278 signals (503 buy, 775 sell)
#   Threshold data: 38 signals (7 buy, 31 sell)
#   Test data: 26 signals (3 buy, 23 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  20%|██        | 41/200 [00:26<01:40,  1.58it/s]
#   Optimal thresholds: Buy=0.70%, Sell=1.10%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.54%
#     Buy & Hold return: 0.54%
#     Outperformance: +0.00%
#     Trades: 1, Win rate: 100.0%
#
# Day 42/200: Testing on 2021-04-19
#   Training period: 2021-03-04 to 2021-04-15 (30 days)
#   Threshold optimization: 2021-04-16
#   Testing: 2021-04-19
#   Training data: 1244 signals (452 buy, 792 sell)
#   Threshold data: 26 signals (3 buy, 23 sell)
#   Test data: 32 signals (8 buy, 24 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  21%|██        | 42/200 [00:27<01:39,  1.60it/s]
#   Optimal thresholds: Buy=1.30%, Sell=0.20%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: -0.21%
#     Outperformance: +0.21%
#     Trades: 0, Win rate: 0.0%
#
# Day 43/200: Testing on 2021-04-20
#   Training period: 2021-03-05 to 2021-04-16 (30 days)
#   Threshold optimization: 2021-04-19
#   Testing: 2021-04-20
#   Training data: 1227 signals (416 buy, 811 sell)
#   Threshold data: 32 signals (8 buy, 24 sell)
#   Test data: 31 signals (25 buy, 6 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  22%|██▏       | 43/200 [00:27<01:38,  1.59it/s]
#   Optimal thresholds: Buy=1.10%, Sell=0.40%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.11%
#     Buy & Hold return: -0.40%
#     Outperformance: +0.29%
#     Trades: 1, Win rate: 0.0%
#
# Day 44/200: Testing on 2021-04-21
#   Training period: 2021-03-08 to 2021-04-19 (30 days)
#   Threshold optimization: 2021-04-20
#   Testing: 2021-04-21
#   Training data: 1207 signals (407 buy, 800 sell)
#   Threshold data: 31 signals (25 buy, 6 sell)
#   Test data: 56 signals (23 buy, 33 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  22%|██▏       | 44/200 [00:28<01:37,  1.60it/s]
#   Optimal thresholds: Buy=0.70%, Sell=0.80%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 1.01%
#     Buy & Hold return: 0.59%
#     Outperformance: +0.42%
#     Trades: 2, Win rate: 50.0%
#
# Day 45/200: Testing on 2021-04-22
#   Training period: 2021-03-09 to 2021-04-20 (30 days)
#   Threshold optimization: 2021-04-21
#   Testing: 2021-04-22
#   Training data: 1189 signals (415 buy, 774 sell)
#   Threshold data: 56 signals (23 buy, 33 sell)
#   Test data: 32 signals (9 buy, 23 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  22%|██▎       | 45/200 [00:29<01:37,  1.59it/s]
#   Optimal thresholds: Buy=1.00%, Sell=0.70%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: -0.73%
#     Outperformance: +0.73%
#     Trades: 0, Win rate: 0.0%
#
# Day 46/200: Testing on 2021-04-23
#   Training period: 2021-03-10 to 2021-04-21 (30 days)
#   Threshold optimization: 2021-04-22
#   Testing: 2021-04-23
#   Training data: 1182 signals (421 buy, 761 sell)
#   Threshold data: 32 signals (9 buy, 23 sell)
#   Test data: 34 signals (2 buy, 32 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  23%|██▎       | 46/200 [00:29<01:36,  1.60it/s]
#   Optimal thresholds: Buy=0.70%, Sell=1.20%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 1.27%
#     Buy & Hold return: 1.09%
#     Outperformance: +0.18%
#     Trades: 1, Win rate: 100.0%
#
# Day 47/200: Testing on 2021-04-26
#   Training period: 2021-03-11 to 2021-04-22 (30 days)
#   Threshold optimization: 2021-04-23
#   Testing: 2021-04-26
#   Training data: 1170 signals (405 buy, 765 sell)
#   Threshold data: 34 signals (2 buy, 32 sell)
#   Test data: 29 signals (5 buy, 24 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  24%|██▎       | 47/200 [00:30<01:35,  1.60it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=1.10%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.19%
#     Buy & Hold return: 0.31%
#     Outperformance: -0.12%
#     Trades: 2, Win rate: 100.0%
#
# Day 48/200: Testing on 2021-04-27
#   Training period: 2021-03-12 to 2021-04-23 (30 days)
#   Threshold optimization: 2021-04-26
#   Testing: 2021-04-27
#   Training data: 1160 signals (400 buy, 760 sell)
#   Threshold data: 29 signals (5 buy, 24 sell)
#   Test data: 34 signals (14 buy, 20 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  24%|██▍       | 48/200 [00:31<01:36,  1.58it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=1.20%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.06%
#     Buy & Hold return: 0.00%
#     Outperformance: +0.06%
#     Trades: 1, Win rate: 100.0%
#
# Day 49/200: Testing on 2021-04-28
#   Training period: 2021-03-15 to 2021-04-26 (30 days)
#   Threshold optimization: 2021-04-27
#   Testing: 2021-04-28
#   Training data: 1163 signals (390 buy, 773 sell)
#   Threshold data: 34 signals (14 buy, 20 sell)
#   Test data: 30 signals (20 buy, 10 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  24%|██▍       | 49/200 [00:31<01:35,  1.58it/s]
#   Optimal thresholds: Buy=0.40%, Sell=1.20%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.21%
#     Buy & Hold return: 0.01%
#     Outperformance: +0.20%
#     Trades: 2, Win rate: 100.0%
#
# Day 50/200: Testing on 2021-04-29
#   Training period: 2021-03-16 to 2021-04-27 (30 days)
#   Threshold optimization: 2021-04-28
#   Testing: 2021-04-29
#   Training data: 1138 signals (386 buy, 752 sell)
#   Threshold data: 30 signals (20 buy, 10 sell)
#   Test data: 38 signals (10 buy, 28 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  25%|██▌       | 50/200 [00:32<01:33,  1.61it/s]
#   Optimal thresholds: Buy=0.70%, Sell=1.00%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.18%
#     Buy & Hold return: -0.27%
#     Outperformance: +0.09%
#     Trades: 1, Win rate: 0.0%
#
# Day 51/200: Testing on 2021-04-30
#   Training period: 2021-03-17 to 2021-04-28 (30 days)
#   Threshold optimization: 2021-04-29
#   Testing: 2021-04-30
#   Training data: 1134 signals (398 buy, 736 sell)
#   Threshold data: 38 signals (10 buy, 28 sell)
#   Test data: 48 signals (17 buy, 31 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  26%|██▌       | 51/200 [00:32<01:31,  1.63it/s]
#   Optimal thresholds: Buy=0.80%, Sell=0.70%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: -0.34%
#     Outperformance: +0.34%
#     Trades: 0, Win rate: 0.0%
#
# Day 52/200: Testing on 2021-05-03
#   Training period: 2021-03-18 to 2021-04-29 (30 days)
#   Threshold optimization: 2021-04-30
#   Testing: 2021-05-03
#   Training data: 1141 signals (389 buy, 752 sell)
#   Threshold data: 48 signals (17 buy, 31 sell)
#   Test data: 26 signals (9 buy, 17 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  26%|██▌       | 52/200 [00:33<01:31,  1.61it/s]
#   Optimal thresholds: Buy=0.80%, Sell=0.60%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: -0.37%
#     Outperformance: +0.37%
#     Trades: 0, Win rate: 0.0%
#
# Day 53/200: Testing on 2021-05-04
#   Training period: 2021-03-19 to 2021-04-30 (30 days)
#   Threshold optimization: 2021-05-03
#   Testing: 2021-05-04
#   Training data: 1162 signals (381 buy, 781 sell)
#   Threshold data: 26 signals (9 buy, 17 sell)
#   Test data: 20 signals (20 buy, 0 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  26%|██▋       | 53/200 [00:34<01:30,  1.63it/s]
#   Optimal thresholds: Buy=0.70%, Sell=0.70%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.42%
#     Buy & Hold return: -1.25%
#     Outperformance: +0.83%
#     Trades: 1, Win rate: 0.0%
#
# Day 54/200: Testing on 2021-05-05
#   Training period: 2021-03-22 to 2021-05-03 (30 days)
#   Threshold optimization: 2021-05-04
#   Testing: 2021-05-05
#   Training data: 1159 signals (379 buy, 780 sell)
#   Threshold data: 20 signals (20 buy, 0 sell)
#   Test data: 50 signals (23 buy, 27 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  27%|██▋       | 54/200 [00:34<01:27,  1.66it/s]
#   Optimal thresholds: Buy=0.70%, Sell=-0.50%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: -0.41%
#     Outperformance: +0.41%
#     Trades: 0, Win rate: 0.0%
#
# Day 55/200: Testing on 2021-05-06
#   Training period: 2021-03-23 to 2021-05-04 (30 days)
#   Threshold optimization: 2021-05-05
#   Testing: 2021-05-06
#   Training data: 1107 signals (395 buy, 712 sell)
#   Threshold data: 50 signals (23 buy, 27 sell)
#   Test data: 35 signals (17 buy, 18 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  28%|██▊       | 55/200 [00:35<01:27,  1.66it/s]
#   Optimal thresholds: Buy=0.40%, Sell=1.00%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.82%
#     Buy & Hold return: 0.60%
#     Outperformance: +0.21%
#     Trades: 1, Win rate: 100.0%
#
# Day 56/200: Testing on 2021-05-07
#   Training period: 2021-03-24 to 2021-05-05 (30 days)
#   Threshold optimization: 2021-05-06
#   Testing: 2021-05-07
#   Training data: 1134 signals (408 buy, 726 sell)
#   Threshold data: 35 signals (17 buy, 18 sell)
#   Test data: 38 signals (2 buy, 36 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  28%|██▊       | 56/200 [00:35<01:26,  1.66it/s]
#   Optimal thresholds: Buy=0.70%, Sell=1.10%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: 0.76%
#     Outperformance: -0.76%
#     Trades: 0, Win rate: 0.0%
#
# Day 57/200: Testing on 2021-05-10
#   Training period: 2021-03-25 to 2021-05-06 (30 days)
#   Threshold optimization: 2021-05-07
#   Testing: 2021-05-10
#   Training data: 1136 signals (402 buy, 734 sell)
#   Threshold data: 38 signals (2 buy, 36 sell)
#   Test data: 45 signals (22 buy, 23 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  28%|██▊       | 57/200 [00:36<01:25,  1.67it/s]
#   Optimal thresholds: Buy=0.30%, Sell=-0.50%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.08%
#     Buy & Hold return: -1.00%
#     Outperformance: +1.09%
#     Trades: 1, Win rate: 100.0%
#
# Day 58/200: Testing on 2021-05-11
#   Training period: 2021-03-26 to 2021-05-07 (30 days)
#   Threshold optimization: 2021-05-10
#   Testing: 2021-05-11
#   Training data: 1135 signals (379 buy, 756 sell)
#   Threshold data: 45 signals (22 buy, 23 sell)
#   Test data: 38 signals (32 buy, 6 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  29%|██▉       | 58/200 [00:37<01:24,  1.68it/s]
#   Optimal thresholds: Buy=0.70%, Sell=1.70%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.06%
#     Buy & Hold return: 0.00%
#     Outperformance: +0.06%
#     Trades: 1, Win rate: 100.0%
#
# Day 59/200: Testing on 2021-05-12
#   Training period: 2021-03-29 to 2021-05-10 (30 days)
#   Threshold optimization: 2021-05-11
#   Testing: 2021-05-12
#   Training data: 1141 signals (382 buy, 759 sell)
#   Threshold data: 38 signals (32 buy, 6 sell)
#   Test data: 37 signals (28 buy, 9 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  30%|██▉       | 59/200 [00:37<01:24,  1.67it/s]
#   Optimal thresholds: Buy=1.90%, Sell=-0.50%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: -1.89%
#     Outperformance: +1.89%
#     Trades: 0, Win rate: 0.0%
#
# Day 60/200: Testing on 2021-05-13
#   Training period: 2021-03-30 to 2021-05-11 (30 days)
#   Threshold optimization: 2021-05-12
#   Testing: 2021-05-13
#   Training data: 1120 signals (400 buy, 720 sell)
#   Threshold data: 37 signals (28 buy, 9 sell)
#   Test data: 44 signals (20 buy, 24 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  30%|███       | 60/200 [00:38<01:23,  1.67it/s]
#   Optimal thresholds: Buy=1.30%, Sell=0.30%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 1.91%
#     Buy & Hold return: 1.69%
#     Outperformance: +0.22%
#     Trades: 1, Win rate: 100.0%
#
# Day 61/200: Testing on 2021-05-14
#   Training period: 2021-03-31 to 2021-05-12 (30 days)
#   Threshold optimization: 2021-05-13
#   Testing: 2021-05-14
#   Training data: 1122 signals (404 buy, 718 sell)
#   Threshold data: 44 signals (20 buy, 24 sell)
#   Test data: 28 signals (12 buy, 16 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  30%|███       | 61/200 [00:38<01:23,  1.66it/s]
#   Optimal thresholds: Buy=1.20%, Sell=0.60%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: 1.17%
#     Outperformance: -1.17%
#     Trades: 0, Win rate: 0.0%
#
# Day 62/200: Testing on 2021-05-17
#   Training period: 2021-04-01 to 2021-05-13 (30 days)
#   Threshold optimization: 2021-05-14
#   Testing: 2021-05-17
#   Training data: 1129 signals (414 buy, 715 sell)
#   Threshold data: 28 signals (12 buy, 16 sell)
#   Test data: 26 signals (24 buy, 2 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  31%|███       | 62/200 [00:39<01:23,  1.66it/s]
#   Optimal thresholds: Buy=0.60%, Sell=0.80%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.12%
#     Buy & Hold return: -0.49%
#     Outperformance: +0.37%
#     Trades: 3, Win rate: 33.3%
#
# Day 63/200: Testing on 2021-05-18
#   Training period: 2021-04-05 to 2021-05-14 (30 days)
#   Threshold optimization: 2021-05-17
#   Testing: 2021-05-18
#   Training data: 1101 signals (419 buy, 682 sell)
#   Threshold data: 26 signals (24 buy, 2 sell)
#   Test data: 54 signals (37 buy, 17 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  32%|███▏      | 63/200 [00:40<01:22,  1.66it/s]
#   Optimal thresholds: Buy=1.30%, Sell=0.60%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: -1.55%
#     Outperformance: +1.55%
#     Trades: 0, Win rate: 0.0%
#
# Day 64/200: Testing on 2021-05-19
#   Training period: 2021-04-06 to 2021-05-17 (30 days)
#   Threshold optimization: 2021-05-18
#   Testing: 2021-05-19
#   Training data: 1077 signals (441 buy, 636 sell)
#   Threshold data: 54 signals (37 buy, 17 sell)
#   Test data: 35 signals (35 buy, 0 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  32%|███▏      | 64/200 [00:40<01:23,  1.63it/s]
#   Optimal thresholds: Buy=1.20%, Sell=1.80%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.98%
#     Buy & Hold return: 0.04%
#     Outperformance: +0.94%
#     Trades: 1, Win rate: 100.0%
#
# Day 65/200: Testing on 2021-05-20
#   Training period: 2021-04-07 to 2021-05-18 (30 days)
#   Threshold optimization: 2021-05-19
#   Testing: 2021-05-20
#   Training data: 1082 signals (471 buy, 611 sell)
#   Threshold data: 35 signals (35 buy, 0 sell)
#   Test data: 60 signals (5 buy, 55 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  32%|███▎      | 65/200 [00:41<01:22,  1.64it/s]
#   Optimal thresholds: Buy=1.10%, Sell=-0.50%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.28%
#     Buy & Hold return: 1.62%
#     Outperformance: -1.33%
#     Trades: 1, Win rate: 100.0%
#
# Day 66/200: Testing on 2021-05-21
#   Training period: 2021-04-08 to 2021-05-19 (30 days)
#   Threshold optimization: 2021-05-20
#   Testing: 2021-05-21
#   Training data: 1061 signals (477 buy, 584 sell)
#   Threshold data: 60 signals (5 buy, 55 sell)
#   Test data: 45 signals (14 buy, 31 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  33%|███▎      | 66/200 [00:42<01:24,  1.59it/s]
#   Optimal thresholds: Buy=1.80%, Sell=1.70%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: -0.23%
#     Outperformance: +0.23%
#     Trades: 0, Win rate: 0.0%
#
# Day 67/200: Testing on 2021-05-24
#   Training period: 2021-04-09 to 2021-05-20 (30 days)
#   Threshold optimization: 2021-05-21
#   Testing: 2021-05-24
#   Training data: 1080 signals (467 buy, 613 sell)
#   Threshold data: 45 signals (14 buy, 31 sell)
#   Test data: 62 signals (19 buy, 43 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  34%|███▎      | 67/200 [00:42<01:26,  1.53it/s]
#   Optimal thresholds: Buy=0.80%, Sell=1.30%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: 0.70%
#     Outperformance: -0.70%
#     Trades: 0, Win rate: 0.0%
#
# Day 68/200: Testing on 2021-05-25
#   Training period: 2021-04-12 to 2021-05-21 (30 days)
#   Threshold optimization: 2021-05-24
#   Testing: 2021-05-25
#   Training data: 1086 signals (472 buy, 614 sell)
#   Threshold data: 62 signals (19 buy, 43 sell)
#   Test data: 40 signals (23 buy, 17 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  34%|███▍      | 68/200 [00:43<01:26,  1.53it/s]
#   Optimal thresholds: Buy=0.00%, Sell=1.50%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.17%
#     Buy & Hold return: -0.34%
#     Outperformance: +0.16%
#     Trades: 1, Win rate: 0.0%
#
# Day 69/200: Testing on 2021-05-26
#   Training period: 2021-04-13 to 2021-05-24 (30 days)
#   Threshold optimization: 2021-05-25
#   Testing: 2021-05-26
#   Training data: 1113 signals (478 buy, 635 sell)
#   Threshold data: 40 signals (23 buy, 17 sell)
#   Test data: 49 signals (26 buy, 23 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  34%|███▍      | 69/200 [00:44<01:24,  1.55it/s]
#   Optimal thresholds: Buy=0.50%, Sell=1.00%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.07%
#     Buy & Hold return: -0.22%
#     Outperformance: +0.29%
#     Trades: 2, Win rate: 50.0%
#
# Day 70/200: Testing on 2021-05-27
#   Training period: 2021-04-14 to 2021-05-25 (30 days)
#   Threshold optimization: 2021-05-26
#   Testing: 2021-05-27
#   Training data: 1130 signals (490 buy, 640 sell)
#   Threshold data: 49 signals (26 buy, 23 sell)
#   Test data: 32 signals (21 buy, 11 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  35%|███▌      | 70/200 [00:44<01:25,  1.52it/s]
#   Optimal thresholds: Buy=0.30%, Sell=1.20%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.69%
#     Buy & Hold return: 0.69%
#     Outperformance: -0.00%
#     Trades: 1, Win rate: 100.0%
#
# Day 71/200: Testing on 2021-05-28
#   Training period: 2021-04-15 to 2021-05-26 (30 days)
#   Threshold optimization: 2021-05-27
#   Testing: 2021-05-28
#   Training data: 1160 signals (511 buy, 649 sell)
#   Threshold data: 32 signals (21 buy, 11 sell)
#   Test data: 39 signals (13 buy, 26 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  36%|███▌      | 71/200 [00:45<01:25,  1.51it/s]
#   Optimal thresholds: Buy=0.50%, Sell=1.70%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: -0.04%
#     Outperformance: +0.04%
#     Trades: 0, Win rate: 0.0%
#
# Day 72/200: Testing on 2021-06-01
#   Training period: 2021-04-16 to 2021-05-27 (30 days)
#   Threshold optimization: 2021-05-28
#   Testing: 2021-06-01
#   Training data: 1154 signals (525 buy, 629 sell)
#   Threshold data: 39 signals (13 buy, 26 sell)
#   Test data: 45 signals (29 buy, 16 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  36%|███▌      | 72/200 [00:46<01:23,  1.52it/s]
#   Optimal thresholds: Buy=0.40%, Sell=1.00%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.34%
#     Buy & Hold return: -0.62%
#     Outperformance: +0.28%
#     Trades: 1, Win rate: 0.0%
#
# Day 73/200: Testing on 2021-06-02
#   Training period: 2021-04-19 to 2021-05-28 (30 days)
#   Threshold optimization: 2021-06-01
#   Testing: 2021-06-02
#   Training data: 1167 signals (535 buy, 632 sell)
#   Threshold data: 45 signals (29 buy, 16 sell)
#   Test data: 50 signals (16 buy, 34 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  36%|███▋      | 73/200 [00:46<01:23,  1.53it/s]
#   Optimal thresholds: Buy=0.60%, Sell=0.70%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.16%
#     Buy & Hold return: 0.22%
#     Outperformance: -0.06%
#     Trades: 1, Win rate: 100.0%
#
# Day 74/200: Testing on 2021-06-03
#   Training period: 2021-04-20 to 2021-06-01 (30 days)
#   Threshold optimization: 2021-06-02
#   Testing: 2021-06-03
#   Training data: 1180 signals (556 buy, 624 sell)
#   Threshold data: 50 signals (16 buy, 34 sell)
#   Test data: 57 signals (39 buy, 18 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  37%|███▋      | 74/200 [00:47<01:22,  1.53it/s]
# ...
#   Threshold optimization: 2021-10-28
#   Testing: 2021-10-29
#   Training data: 1179 signals (547 buy, 632 sell)
#   Threshold data: 43 signals (10 buy, 33 sell)
#   Test data: 41 signals (8 buy, 33 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  89%|████████▉ | 178/200 [02:03<00:14,  1.50it/s]
#   Optimal thresholds: Buy=0.20%, Sell=1.20%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.92%
#     Buy & Hold return: 0.76%
#     Outperformance: +0.16%
#     Trades: 1, Win rate: 100.0%
#
# Day 179/200: Testing on 2021-11-01
#   Training period: 2021-09-17 to 2021-10-28 (30 days)
#   Threshold optimization: 2021-10-29
#   Testing: 2021-11-01
#   Training data: 1169 signals (528 buy, 641 sell)
#   Threshold data: 41 signals (8 buy, 33 sell)
#   Test data: 50 signals (6 buy, 44 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  90%|████████▉ | 179/200 [02:04<00:13,  1.52it/s]
#   Optimal thresholds: Buy=0.50%, Sell=1.00%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.17%
#     Buy & Hold return: 0.04%
#     Outperformance: -0.21%
#     Trades: 1, Win rate: 0.0%
#
# Day 180/200: Testing on 2021-11-02
#   Training period: 2021-09-20 to 2021-10-29 (30 days)
#   Threshold optimization: 2021-11-01
#   Testing: 2021-11-02
#   Training data: 1164 signals (492 buy, 672 sell)
#   Threshold data: 50 signals (6 buy, 44 sell)
#   Test data: 33 signals (4 buy, 29 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  90%|█████████ | 180/200 [02:04<00:12,  1.56it/s]
#   Optimal thresholds: Buy=0.70%, Sell=0.70%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.48%
#     Buy & Hold return: 0.52%
#     Outperformance: -0.04%
#     Trades: 1, Win rate: 100.0%
#
# Day 181/200: Testing on 2021-11-03
#   Training period: 2021-09-21 to 2021-11-01 (30 days)
#   Threshold optimization: 2021-11-02
#   Testing: 2021-11-03
#   Training data: 1167 signals (455 buy, 712 sell)
#   Threshold data: 33 signals (4 buy, 29 sell)
#   Test data: 10 signals (5 buy, 5 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  90%|█████████ | 181/200 [02:05<00:12,  1.58it/s]
#   Optimal thresholds: Buy=0.50%, Sell=1.00%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.02%
#     Buy & Hold return: -0.11%
#     Outperformance: +0.09%
#     Trades: 1, Win rate: 0.0%
#
# Day 182/200: Testing on 2021-11-04
#   Training period: 2021-09-22 to 2021-11-02 (30 days)
#   Threshold optimization: 2021-11-03
#   Testing: 2021-11-04
#   Training data: 1167 signals (428 buy, 739 sell)
#   Threshold data: 10 signals (5 buy, 5 sell)
#   Test data: 47 signals (18 buy, 29 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  91%|█████████ | 182/200 [02:05<00:11,  1.58it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=0.90%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.45%
#     Buy & Hold return: 0.45%
#     Outperformance: +0.00%
#     Trades: 1, Win rate: 100.0%
#
# Day 183/200: Testing on 2021-11-05
#   Training period: 2021-09-23 to 2021-11-03 (30 days)
#   Threshold optimization: 2021-11-04
#   Testing: 2021-11-05
#   Training data: 1145 signals (427 buy, 718 sell)
#   Threshold data: 47 signals (18 buy, 29 sell)
#   Test data: 29 signals (0 buy, 29 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  92%|█████████▏| 183/200 [02:06<00:10,  1.59it/s]
#   Optimal thresholds: Buy=0.90%, Sell=0.40%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: 0.40%
#     Outperformance: -0.40%
#     Trades: 0, Win rate: 0.0%
#
# Day 184/200: Testing on 2021-11-08
#   Training period: 2021-09-24 to 2021-11-04 (30 days)
#   Threshold optimization: 2021-11-05
#   Testing: 2021-11-08
#   Training data: 1152 signals (441 buy, 711 sell)
#   Threshold data: 29 signals (0 buy, 29 sell)
#   Test data: 29 signals (2 buy, 27 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  92%|█████████▏| 184/200 [02:07<00:09,  1.64it/s]
#   Optimal thresholds: Buy=-0.50%, Sell=0.40%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: -0.24%
#     Outperformance: +0.24%
#     Trades: 1, Win rate: 0.0%
#
# Day 185/200: Testing on 2021-11-09
#   Training period: 2021-09-27 to 2021-11-05 (30 days)
#   Threshold optimization: 2021-11-08
#   Testing: 2021-11-09
#   Training data: 1136 signals (416 buy, 720 sell)
#   Threshold data: 29 signals (2 buy, 27 sell)
#   Test data: 28 signals (5 buy, 23 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  92%|█████████▎| 185/200 [02:07<00:09,  1.64it/s]
#   Optimal thresholds: Buy=1.30%, Sell=0.30%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: -0.35%
#     Outperformance: +0.35%
#     Trades: 0, Win rate: 0.0%
#
# Day 186/200: Testing on 2021-11-10
#   Training period: 2021-09-28 to 2021-11-08 (30 days)
#   Threshold optimization: 2021-11-09
#   Testing: 2021-11-10
#   Training data: 1125 signals (404 buy, 721 sell)
#   Threshold data: 28 signals (5 buy, 23 sell)
#   Test data: 58 signals (29 buy, 29 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  93%|█████████▎| 186/200 [02:08<00:08,  1.64it/s]
#   Optimal thresholds: Buy=1.10%, Sell=0.30%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.25%
#     Buy & Hold return: -0.52%
#     Outperformance: +0.77%
#     Trades: 3, Win rate: 33.3%
#
# Day 187/200: Testing on 2021-11-11
#   Training period: 2021-09-29 to 2021-11-09 (30 days)
#   Threshold optimization: 2021-11-10
#   Testing: 2021-11-11
#   Training data: 1105 signals (374 buy, 731 sell)
#   Threshold data: 58 signals (29 buy, 29 sell)
#   Test data: 52 signals (16 buy, 36 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  94%|█████████▎| 187/200 [02:08<00:07,  1.63it/s]
#   Optimal thresholds: Buy=1.30%, Sell=0.40%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: 0.08%
#     Outperformance: -0.08%
#     Trades: 0, Win rate: 0.0%
#
# Day 188/200: Testing on 2021-11-12
#   Training period: 2021-09-30 to 2021-11-10 (30 days)
#   Threshold optimization: 2021-11-11
#   Testing: 2021-11-12
#   Training data: 1111 signals (377 buy, 734 sell)
#   Threshold data: 52 signals (16 buy, 36 sell)
#   Test data: 54 signals (15 buy, 39 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  94%|█████████▍| 188/200 [02:09<00:07,  1.63it/s]
#   Optimal thresholds: Buy=0.40%, Sell=0.60%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.69%
#     Buy & Hold return: 0.69%
#     Outperformance: +0.00%
#     Trades: 1, Win rate: 100.0%
#
# Day 189/200: Testing on 2021-11-15
#   Training period: 2021-10-01 to 2021-11-11 (30 days)
#   Threshold optimization: 2021-11-12
#   Testing: 2021-11-15
#   Training data: 1134 signals (371 buy, 763 sell)
#   Threshold data: 54 signals (15 buy, 39 sell)
#   Test data: 33 signals (11 buy, 22 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  94%|█████████▍| 189/200 [02:10<00:06,  1.61it/s]
#   Optimal thresholds: Buy=0.90%, Sell=0.70%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: -0.13%
#     Outperformance: +0.13%
#     Trades: 0, Win rate: 0.0%
#
# Day 190/200: Testing on 2021-11-16
#   Training period: 2021-10-04 to 2021-11-12 (30 days)
#   Threshold optimization: 2021-11-15
#   Testing: 2021-11-16
#   Training data: 1141 signals (378 buy, 763 sell)
#   Threshold data: 33 signals (11 buy, 22 sell)
#   Test data: 39 signals (14 buy, 25 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  95%|█████████▌| 190/200 [02:10<00:06,  1.62it/s]
#   Optimal thresholds: Buy=0.30%, Sell=0.60%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.66%
#     Buy & Hold return: 0.62%
#     Outperformance: +0.04%
#     Trades: 1, Win rate: 100.0%
#
# Day 191/200: Testing on 2021-11-17
#   Training period: 2021-10-05 to 2021-11-15 (30 days)
#   Threshold optimization: 2021-11-16
#   Testing: 2021-11-17
#   Training data: 1147 signals (373 buy, 774 sell)
#   Threshold data: 39 signals (14 buy, 25 sell)
#   Test data: 35 signals (16 buy, 19 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  96%|█████████▌| 191/200 [02:11<00:05,  1.58it/s]
#   Optimal thresholds: Buy=0.60%, Sell=0.60%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: -0.15%
#     Outperformance: +0.15%
#     Trades: 0, Win rate: 0.0%
#
# Day 192/200: Testing on 2021-11-18
#   Training period: 2021-10-06 to 2021-11-16 (30 days)
#   Threshold optimization: 2021-11-17
#   Testing: 2021-11-18
#   Training data: 1139 signals (379 buy, 760 sell)
#   Threshold data: 35 signals (16 buy, 19 sell)
#   Test data: 43 signals (17 buy, 26 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  96%|█████████▌| 192/200 [02:12<00:05,  1.58it/s]
#   Optimal thresholds: Buy=0.50%, Sell=0.70%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.18%
#     Buy & Hold return: 0.09%
#     Outperformance: +0.09%
#     Trades: 1, Win rate: 100.0%
#
# Day 193/200: Testing on 2021-11-19
#   Training period: 2021-10-07 to 2021-11-17 (30 days)
#   Threshold optimization: 2021-11-18
#   Testing: 2021-11-19
#   Training data: 1126 signals (376 buy, 750 sell)
#   Threshold data: 43 signals (17 buy, 26 sell)
#   Test data: 22 signals (16 buy, 6 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  96%|█████████▋| 193/200 [02:12<00:04,  1.58it/s]
#   Optimal thresholds: Buy=0.30%, Sell=0.80%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.15%
#     Buy & Hold return: -0.46%
#     Outperformance: +0.30%
#     Trades: 1, Win rate: 0.0%
#
# Day 194/200: Testing on 2021-11-22
#   Training period: 2021-10-08 to 2021-11-18 (30 days)
#   Threshold optimization: 2021-11-19
#   Testing: 2021-11-22
#   Training data: 1121 signals (382 buy, 739 sell)
#   Threshold data: 22 signals (16 buy, 6 sell)
#   Test data: 35 signals (20 buy, 15 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  97%|█████████▋| 194/200 [02:13<00:03,  1.57it/s]
#   Optimal thresholds: Buy=0.60%, Sell=0.60%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -1.19%
#     Buy & Hold return: -0.59%
#     Outperformance: -0.60%
#     Trades: 1, Win rate: 0.0%
#
# Day 195/200: Testing on 2021-11-23
#   Training period: 2021-10-11 to 2021-11-19 (30 days)
#   Threshold optimization: 2021-11-22
#   Testing: 2021-11-23
#   Training data: 1120 signals (375 buy, 745 sell)
#   Threshold data: 35 signals (20 buy, 15 sell)
#   Test data: 31 signals (13 buy, 18 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  98%|█████████▊| 195/200 [02:14<00:03,  1.59it/s]
#   Optimal thresholds: Buy=1.20%, Sell=0.50%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: 0.50%
#     Outperformance: -0.50%
#     Trades: 0, Win rate: 0.0%
#
# Day 196/200: Testing on 2021-11-24
#   Training period: 2021-10-12 to 2021-11-22 (30 days)
#   Threshold optimization: 2021-11-23
#   Testing: 2021-11-24
#   Training data: 1122 signals (365 buy, 757 sell)
#   Threshold data: 31 signals (13 buy, 18 sell)
#   Test data: 46 signals (9 buy, 37 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  98%|█████████▊| 196/200 [02:14<00:02,  1.60it/s]
#   Optimal thresholds: Buy=0.90%, Sell=0.50%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: 0.64%
#     Outperformance: -0.64%
#     Trades: 0, Win rate: 0.0%
#
# Day 197/200: Testing on 2021-11-26
#   Training period: 2021-10-13 to 2021-11-23 (30 days)
#   Threshold optimization: 2021-11-24
#   Testing: 2021-11-26
#   Training data: 1131 signals (367 buy, 764 sell)
#   Threshold data: 46 signals (9 buy, 37 sell)
#   Test data: 37 signals (18 buy, 19 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  98%|█████████▊| 197/200 [02:15<00:01,  1.60it/s]
#   Optimal thresholds: Buy=0.60%, Sell=0.60%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: -0.14%
#     Buy & Hold return: -0.91%
#     Outperformance: +0.76%
#     Trades: 2, Win rate: 50.0%
#
# Day 198/200: Testing on 2021-11-29
#   Training period: 2021-10-14 to 2021-11-24 (30 days)
#   Threshold optimization: 2021-11-26
#   Testing: 2021-11-29
#   Training data: 1130 signals (370 buy, 760 sell)
#   Threshold data: 37 signals (18 buy, 19 sell)
#   Test data: 83 signals (30 buy, 53 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days:  99%|█████████▉| 198/200 [02:15<00:01,  1.61it/s]
#   Optimal thresholds: Buy=0.60%, Sell=0.60%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.94%
#     Buy & Hold return: 0.87%
#     Outperformance: +0.07%
#     Trades: 1, Win rate: 100.0%
#
# Day 199/200: Testing on 2021-11-30
#   Training period: 2021-10-15 to 2021-11-26 (30 days)
#   Threshold optimization: 2021-11-29
#   Testing: 2021-11-30
#   Training data: 1122 signals (387 buy, 735 sell)
#   Threshold data: 83 signals (30 buy, 53 sell)
#   Test data: 59 signals (24 buy, 35 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days: 100%|█████████▉| 199/200 [02:16<00:00,  1.60it/s]
#   Optimal thresholds: Buy=1.30%, Sell=0.20%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.63%
#     Buy & Hold return: -0.42%
#     Outperformance: +1.05%
#     Trades: 2, Win rate: 100.0%
#
# Day 200/200: Testing on 2021-12-01
#   Training period: 2021-10-18 to 2021-11-29 (30 days)
#   Threshold optimization: 2021-11-30
#   Testing: 2021-12-01
#   Training data: 1170 signals (409 buy, 761 sell)
#   Threshold data: 59 signals (24 buy, 35 sell)
#   Test data: 43 signals (24 buy, 19 sell)
#   Training Buy model...
#   Training Sell model...
#   Optimizing thresholds...
# Processing days: 100%|██████████| 200/200 [02:17<00:00,  1.46it/s]
#   Optimal thresholds: Buy=1.90%, Sell=1.50%
#   Running backtest on test day...
#   Test day results:
#     Strategy return: 0.00%
#     Buy & Hold return: -2.19%
#     Outperformance: +2.19%
#     Trades: 0, Win rate: 0.0%
#
# [4/5] Analyzing results...
#
# ================================================================================
# DAILY ROLLING WINDOW BACKTEST RESULTS
# ================================================================================
# Total days analyzed: 200
# Strategy cumulative return: 37.39%
# Buy & Hold cumulative return: 12.21%
# Strategy vs. Buy & Hold: +25.18%
# Win rate (positive return days): 48.5%
# Outperformance rate (days beating Buy & Hold): 59.0%
#
# [5/5] Creating visualizations...
# Saved: ./output/daily_rolling_backtest/cumulative_returns.png
# Saved: ./output/daily_rolling_backtest/daily_returns.png
# Saved: ./output/daily_rolling_backtest/strategy_outperformance.png
# Saved: ./output/daily_rolling_backtest/model_accuracy.png
# Saved: ./output/daily_rolling_backtest/threshold_evolution.png
# Saved results to ./output/daily_rolling_backtest/daily_results.csv and ./output/daily_rolling_backtest/model_metrics.csv
# Saved summary to ./output/daily_rolling_backtest/backtest_summary.txt
#
# ================================================================================
# Daily Rolling Window Backtest Complete!
# ================================================================================
#
# 📈 All results saved to: /mnt/user-data/outputs/daily_rolling_backtest/
